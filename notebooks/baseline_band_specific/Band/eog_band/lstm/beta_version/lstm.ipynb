# %%
import os
import numpy as np
import torch

# Check if GPU is available and set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Using device: {device}")

# Set paths for clean and contaminated EEG data
clean_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean"
contaminated_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated"

# Define EEG frequency bands
bands = ["Delta_band", "Theta_band", "Alpha_band", "Beta_band", "Gamma_band", "High_Frequencies_band"]

print(f"✅ Clean EEG Directory: {clean_dir}")
print(f"✅ Contaminated EEG Directory: {contaminated_dir}")
print(f"✅ EEG Bands: {bands}")
# Out:
# ✅ Using device: cuda
# ✅ Clean EEG Directory: /home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean
# ✅ Contaminated EEG Directory: /home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated
# ✅ EEG Bands: ['Delta_band', 'Theta_band', 'Alpha_band', 'Beta_band', 'Gamma_band', 'High_Frequencies_band']

# %%
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = None
        self.counter = 0
        self.stop_training = False

    def __call__(self, current_loss):
        if self.best_loss is None or current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.stop_training = True

# %%
class AdvancedLSTM(nn.Module):
    def __init__(self, input_length):
        super(AdvancedLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=1, hidden_size=512, num_layers=3, batch_first=True, dropout=0.3)
        self.layer_norm = nn.LayerNorm(512)
        self.fc = nn.Linear(512, input_length)

    def forward(self, x):
        x = x.permute(0, 2, 1)  # Reshape to (batch_size, seq_length, channels)
        x, _ = self.lstm(x)  # LSTM output
        x = self.layer_norm(x[:, -1, :])  # Apply layer normalization on the last hidden state
        x = self.fc(x)
        return x

# %%
def normalize_signals(data):
    """Normalize the signals to zero mean and unit variance per sample."""
    return (data - np.mean(data, axis=1, keepdims=True)) / np.std(data, axis=1, keepdims=True)
bands = ["Delta_band", "Theta_band", "Alpha_band", "Beta_band", "Gamma_band", "High_Frequencies_band"]
clean_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean"
contaminated_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated"

# %%
from sklearn.model_selection import train_test_split

def load_and_split_data(band_name):
    """
    Loads EEG data for a specific frequency band, splits into train and test sets based on SNR levels.
    """
    print(f"\n📌 Loading and Splitting Data for {band_name}...")

    # Load clean EEG data
    clean_band_path = os.path.join(clean_dir, f"{band_name}.npy")
    clean_band = np.load(clean_band_path)

    # Load contaminated EEG data across all SNR levels
    contaminated_band = []
    snr_labels = []

    for snr_folder in sorted(os.listdir(contaminated_dir)):  # Iterate through SNR folders
        contaminated_band_path = os.path.join(contaminated_dir, snr_folder, f"{band_name}.npy")
        contaminated_data = np.load(contaminated_band_path)

        contaminated_band.append(contaminated_data)
        snr_labels.extend([snr_folder] * len(contaminated_data))  # Track SNR levels

    # Convert lists to numpy arrays
    contaminated_band = np.concatenate(contaminated_band, axis=0)
    # Convert string labels ("SNR_-7") to integers (-7)
    
    snr_labels = np.array([int(snr.replace("SNR_", "")) for snr in snr_labels])


    # Ensure clean_band is correctly repeated to match contaminated EEG samples
    clean_band_repeated = np.tile(clean_band, (len(contaminated_band) // len(clean_band) + 1, 1))[:len(contaminated_band)]

    # Stratified Train-Test Split
    train_clean, test_clean, train_contaminated, test_contaminated, snr_labels_train, snr_labels_test = train_test_split(
        clean_band_repeated, contaminated_band, snr_labels, test_size=0.2, stratify=snr_labels, random_state=42
    )

    # Inspect data shapes
    print(f"✅ {band_name} Train Clean Shape: {train_clean.shape}, Test Clean Shape: {test_clean.shape}")
    print(f"✅ {band_name} Train Contaminated Shape: {train_contaminated.shape}, Test Contaminated Shape: {test_contaminated.shape}")
    print(f"✅ {band_name} SNR Labels Train: {np.unique(snr_labels_train)}, Test: {np.unique(snr_labels_test)}")

    return train_clean, train_contaminated, test_clean, test_contaminated, snr_labels_train, snr_labels_test

# Load and split data for each EEG band
train_data = {}
test_data = {}

for band in bands:
    train_clean, train_contaminated, test_clean, test_contaminated, snr_labels_train, snr_labels_test = load_and_split_data(band)
    train_data[band] = (train_clean, train_contaminated)
    test_data[band] = (test_clean, test_contaminated, snr_labels_test)

print("\n✅ All EEG bands successfully loaded and split!")
# Out:
# 📌 Loading and Splitting Data for Delta_band...
# ✅ Delta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Delta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Delta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Theta_band...
# ✅ Theta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Theta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Theta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Alpha_band...
# ✅ Alpha_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Alpha_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Alpha_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Beta_band...
# ✅ Beta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Beta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Beta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Gamma_band...
# ✅ Gamma_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Gamma_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Gamma_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for High_Frequencies_band...
# ✅ High_Frequencies_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ High_Frequencies_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ High_Frequencies_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# ✅ All EEG bands successfully loaded and split!

# %%
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
import torch.nn as nn
import torch
def train_and_denoise_band(train_clean, train_contaminated, test_clean, test_contaminated, band_name):
    print(f"\n📌 {band_name} Dataset Shapes:")
    print(f"  Train Clean: {train_clean.shape}, Train Contaminated: {train_contaminated.shape}")
    print(f"  Test Clean: {test_clean.shape}, Test Contaminated: {test_contaminated.shape}")

    train_clean = torch.tensor(train_clean, dtype=torch.float32).unsqueeze(1).to(device)
    test_clean = torch.tensor(test_clean, dtype=torch.float32).unsqueeze(1).to(device)
    train_contaminated = torch.tensor(train_contaminated, dtype=torch.float32).unsqueeze(1).to(device)
    test_contaminated = torch.tensor(test_contaminated, dtype=torch.float32).unsqueeze(1).to(device)

    train_dataset = TensorDataset(train_contaminated, train_clean)
    test_dataset = TensorDataset(test_contaminated, test_clean)
    train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

    input_length = train_contaminated.shape[2]
    model = AdvancedLSTM(input_length).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    scaler = torch.cuda.amp.GradScaler()

    early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

    num_epochs = 1000
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            with torch.cuda.amp.autocast():  # Mixed precision
                outputs = model(inputs)
                loss = criterion(outputs, targets.squeeze(1))
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            running_loss += loss.item()

        avg_train_loss = running_loss / len(train_loader)

        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for inputs, targets in test_loader:
                with torch.cuda.amp.autocast():
                    outputs = model(inputs)
                    loss = criterion(outputs, targets.squeeze(1))
                test_loss += loss.item()

        avg_test_loss = test_loss / len(test_loader)

        print(f"Epoch {epoch + 1}: Train Loss = {avg_train_loss:.4f}, Test Loss = {avg_test_loss:.4f}")

        early_stopping(avg_test_loss)
        if early_stopping.stop_training:
            print(f"🚀 Early stopping triggered for {band_name} at epoch {epoch + 1}")
            break

    # Process test data in smaller batches to reduce memory usage
    with torch.no_grad():
        denoised_batches = []
        batch_size = 256  # Adjust this batch size based on GPU memory
        for i in range(0, len(test_contaminated), batch_size):
            batch = test_contaminated[i:i+batch_size]
            denoised_batch = model(batch).squeeze(1).cpu().numpy()
            denoised_batches.append(denoised_batch)
        denoised_band = np.concatenate(denoised_batches, axis=0)

    return denoised_band, test_clean.cpu().numpy(), test_contaminated.cpu().numpy()

# %%
denoised_bands = []
clean_bands = []
contaminated_bands = []

for band in bands:
    print(f"🚀 Processing {band}...")

    # Load and split data
    train_clean, train_contaminated, test_clean, test_contaminated, _, _ = load_and_split_data(band)

    # Normalize signals
    train_clean = normalize_signals(train_clean)
    train_contaminated = normalize_signals(train_contaminated)
    test_clean = normalize_signals(test_clean)
    test_contaminated = normalize_signals(test_contaminated)

    # Train the model and denoise the test set
    denoised_band, clean_band_test, contaminated_band_test = train_and_denoise_band(
        train_clean, train_contaminated, test_clean, test_contaminated, band
    )

    denoised_bands.append(denoised_band)
    clean_bands.append(clean_band_test)
    contaminated_bands.append(contaminated_band_test)
# Out:
# 🚀 Processing Delta_band...
#
# 📌 Loading and Splitting Data for Delta_band...
# ✅ Delta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Delta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Delta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Delta_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 0.9712, Test Loss = 0.9545
# Epoch 2: Train Loss = 0.9575, Test Loss = 0.9532
# Epoch 3: Train Loss = 0.9533, Test Loss = 0.9434
# Epoch 4: Train Loss = 0.9493, Test Loss = 0.9415
# Epoch 5: Train Loss = 0.9468, Test Loss = 0.9397
# Epoch 6: Train Loss = 0.9401, Test Loss = 0.9432
# Epoch 7: Train Loss = 0.9344, Test Loss = 0.9204
# Epoch 8: Train Loss = 0.9226, Test Loss = 0.9067
# Epoch 9: Train Loss = 0.9068, Test Loss = 0.8901
# Epoch 10: Train Loss = 0.8931, Test Loss = 0.8838
# Epoch 11: Train Loss = 0.8825, Test Loss = 0.8843
# Epoch 12: Train Loss = 0.8612, Test Loss = 0.8422
# Epoch 13: Train Loss = 0.8223, Test Loss = 0.8006
# Epoch 14: Train Loss = 0.8088, Test Loss = 0.7876
# Epoch 15: Train Loss = 0.7935, Test Loss = 0.7795
# Epoch 16: Train Loss = 0.7820, Test Loss = 0.7822
# Epoch 17: Train Loss = 0.7698, Test Loss = 0.7569
# Epoch 18: Train Loss = 0.7580, Test Loss = 0.7462
# Epoch 19: Train Loss = 0.7450, Test Loss = 0.7352
# Epoch 20: Train Loss = 0.7330, Test Loss = 0.7344
# Epoch 21: Train Loss = 0.7256, Test Loss = 0.7241
# Epoch 22: Train Loss = 0.7135, Test Loss = 0.7140
# Epoch 23: Train Loss = 0.7045, Test Loss = 0.7172
# Epoch 24: Train Loss = 0.6956, Test Loss = 0.6969
# Epoch 25: Train Loss = 0.6795, Test Loss = 0.6966
# Epoch 26: Train Loss = 0.6701, Test Loss = 0.6792
# Epoch 27: Train Loss = 0.6629, Test Loss = 0.6795
# Epoch 28: Train Loss = 0.6552, Test Loss = 0.6642
# Epoch 29: Train Loss = 0.6457, Test Loss = 0.6569
# Epoch 30: Train Loss = 0.6284, Test Loss = 0.6386
# Epoch 31: Train Loss = 0.6165, Test Loss = 0.6581
# Epoch 32: Train Loss = 0.6071, Test Loss = 0.6239
# Epoch 33: Train Loss = 0.5926, Test Loss = 0.6195
# Epoch 34: Train Loss = 0.5845, Test Loss = 0.6047
# Epoch 35: Train Loss = 0.5744, Test Loss = 0.5988
# Epoch 36: Train Loss = 0.5582, Test Loss = 0.5755
# Epoch 37: Train Loss = 0.5453, Test Loss = 0.5613
# Epoch 38: Train Loss = 0.5304, Test Loss = 0.5625
# Epoch 39: Train Loss = 0.5211, Test Loss = 0.5561
# Epoch 40: Train Loss = 0.5017, Test Loss = 0.5648
# Epoch 41: Train Loss = 0.4899, Test Loss = 0.5414
# Epoch 42: Train Loss = 0.4820, Test Loss = 0.5184
# Epoch 43: Train Loss = 0.4632, Test Loss = 0.5044
# Epoch 44: Train Loss = 0.4490, Test Loss = 0.5091
# Epoch 45: Train Loss = 0.4353, Test Loss = 0.4853
# Epoch 46: Train Loss = 0.4277, Test Loss = 0.4714
# Epoch 47: Train Loss = 0.4051, Test Loss = 0.4656
# Epoch 48: Train Loss = 0.4011, Test Loss = 0.4437
# Epoch 49: Train Loss = 0.3791, Test Loss = 0.4539
# Epoch 50: Train Loss = 0.3635, Test Loss = 0.4408
# Epoch 51: Train Loss = 0.3509, Test Loss = 0.4242
# Epoch 52: Train Loss = 0.3518, Test Loss = 0.4129
# Epoch 53: Train Loss = 0.3254, Test Loss = 0.3904
# Epoch 54: Train Loss = 0.3313, Test Loss = 0.4144
# Epoch 55: Train Loss = 0.3137, Test Loss = 0.3875
# Epoch 56: Train Loss = 0.2909, Test Loss = 0.3694
# Epoch 57: Train Loss = 0.2846, Test Loss = 0.3533
# Epoch 58: Train Loss = 0.2724, Test Loss = 0.3460
# Epoch 59: Train Loss = 0.2658, Test Loss = 0.3367
# Epoch 60: Train Loss = 0.2441, Test Loss = 0.3420
# Epoch 61: Train Loss = 0.2424, Test Loss = 0.3243
# Epoch 62: Train Loss = 0.2312, Test Loss = 0.3217
# Epoch 63: Train Loss = 0.2169, Test Loss = 0.3340
# Epoch 64: Train Loss = 0.2165, Test Loss = 0.2862
# Epoch 65: Train Loss = 0.1985, Test Loss = 0.2946
# Epoch 66: Train Loss = 0.2003, Test Loss = 0.2948
# Epoch 67: Train Loss = 0.1972, Test Loss = 0.2866
# Epoch 68: Train Loss = 0.1851, Test Loss = 0.2813
# Epoch 69: Train Loss = 0.1890, Test Loss = 0.2624
# Epoch 70: Train Loss = 0.1687, Test Loss = 0.2500
# Epoch 71: Train Loss = 0.1733, Test Loss = 0.2879
# Epoch 72: Train Loss = 0.1670, Test Loss = 0.2668
# Epoch 73: Train Loss = 0.1577, Test Loss = 0.2456
# Epoch 74: Train Loss = 0.1491, Test Loss = 0.2407
# Epoch 75: Train Loss = 0.1443, Test Loss = 0.2396
# Epoch 76: Train Loss = 0.1345, Test Loss = 0.2329
# Epoch 77: Train Loss = 0.1321, Test Loss = 0.2335
# Epoch 78: Train Loss = 0.1354, Test Loss = 0.2570
# Epoch 79: Train Loss = 0.1432, Test Loss = 0.2766
# Epoch 80: Train Loss = 0.1532, Test Loss = 0.2256
# Epoch 81: Train Loss = 0.1174, Test Loss = 0.2237
# Epoch 82: Train Loss = 0.1121, Test Loss = 0.2122
# Epoch 83: Train Loss = 0.1180, Test Loss = 0.2265
# Epoch 84: Train Loss = 0.1112, Test Loss = 0.2038
# Epoch 85: Train Loss = 0.0957, Test Loss = 0.1921
# Epoch 86: Train Loss = 0.0940, Test Loss = 0.2135
# Epoch 87: Train Loss = 0.1040, Test Loss = 0.2109
# Epoch 88: Train Loss = 0.0984, Test Loss = 0.1999
# Epoch 89: Train Loss = 0.1048, Test Loss = 0.2201
# Epoch 90: Train Loss = 0.1123, Test Loss = 0.2076
# Epoch 91: Train Loss = 0.0972, Test Loss = 0.1869
# Epoch 92: Train Loss = 0.0851, Test Loss = 0.1850
# Epoch 93: Train Loss = 0.0825, Test Loss = 0.1724
# Epoch 94: Train Loss = 0.0740, Test Loss = 0.1883
# Epoch 95: Train Loss = 0.0752, Test Loss = 0.1671
# Epoch 96: Train Loss = 0.0694, Test Loss = 0.1744
# Epoch 97: Train Loss = 0.0632, Test Loss = 0.1715
# Epoch 98: Train Loss = 0.0754, Test Loss = 0.1738
# Epoch 99: Train Loss = 0.0702, Test Loss = 0.1663
# Epoch 100: Train Loss = 0.0880, Test Loss = 0.2220
# Epoch 101: Train Loss = 0.1150, Test Loss = 0.2044
# Epoch 102: Train Loss = 0.1057, Test Loss = 0.1917
# Epoch 103: Train Loss = 0.0684, Test Loss = 0.1569
# Epoch 104: Train Loss = 0.0559, Test Loss = 0.1500
# Epoch 105: Train Loss = 0.0481, Test Loss = 0.1485
# Epoch 106: Train Loss = 0.0483, Test Loss = 0.1573
# Epoch 107: Train Loss = 0.0540, Test Loss = 0.1461
# Epoch 108: Train Loss = 0.0432, Test Loss = 0.1590
# Epoch 109: Train Loss = 0.0468, Test Loss = 0.1526
# Epoch 110: Train Loss = 0.0471, Test Loss = 0.1409
# Epoch 111: Train Loss = 0.0545, Test Loss = 0.1675
# Epoch 112: Train Loss = 0.0584, Test Loss = 0.1475
# Epoch 113: Train Loss = 0.0513, Test Loss = 0.1571
# Epoch 114: Train Loss = 0.0733, Test Loss = 0.1871
# Epoch 115: Train Loss = 0.1140, Test Loss = 0.2510
# Epoch 116: Train Loss = 0.1174, Test Loss = 0.1936
# Epoch 117: Train Loss = 0.0716, Test Loss = 0.1631
# Epoch 118: Train Loss = 0.0520, Test Loss = 0.1375
# Epoch 119: Train Loss = 0.0351, Test Loss = 0.1295
# Epoch 120: Train Loss = 0.0325, Test Loss = 0.1277
# Epoch 121: Train Loss = 0.0297, Test Loss = 0.1278
# Epoch 122: Train Loss = 0.0280, Test Loss = 0.1234
# Epoch 123: Train Loss = 0.0302, Test Loss = 0.1348
# Epoch 124: Train Loss = 0.0322, Test Loss = 0.1229
# Epoch 125: Train Loss = 0.0268, Test Loss = 0.1346
# Epoch 126: Train Loss = 0.0393, Test Loss = 0.1478
# Epoch 127: Train Loss = 0.1023, Test Loss = 0.2844
# Epoch 128: Train Loss = 0.1544, Test Loss = 0.2242
# Epoch 129: Train Loss = 0.0776, Test Loss = 0.1521
# Epoch 130: Train Loss = 0.0431, Test Loss = 0.1359
# Epoch 131: Train Loss = 0.0321, Test Loss = 0.1275
# Epoch 132: Train Loss = 0.0274, Test Loss = 0.1167
# Epoch 133: Train Loss = 0.0237, Test Loss = 0.1182
# Epoch 134: Train Loss = 0.0222, Test Loss = 0.1165
# Epoch 135: Train Loss = 0.0212, Test Loss = 0.1127
# Epoch 136: Train Loss = 0.0195, Test Loss = 0.1190
# Epoch 137: Train Loss = 0.0356, Test Loss = 0.1307
# Epoch 138: Train Loss = 0.0446, Test Loss = 0.1343
# Epoch 139: Train Loss = 0.0566, Test Loss = 0.1903
# Epoch 140: Train Loss = 0.1368, Test Loss = 0.2164
# Epoch 141: Train Loss = 0.0976, Test Loss = 0.1558
# Epoch 142: Train Loss = 0.0419, Test Loss = 0.1276
# Epoch 143: Train Loss = 0.0253, Test Loss = 0.1139
# Epoch 144: Train Loss = 0.0202, Test Loss = 0.1084
# Epoch 145: Train Loss = 0.0184, Test Loss = 0.1082
# Epoch 146: Train Loss = 0.0163, Test Loss = 0.1075
# Epoch 147: Train Loss = 0.0159, Test Loss = 0.1086
# Epoch 148: Train Loss = 0.0181, Test Loss = 0.1075
# Epoch 149: Train Loss = 0.0182, Test Loss = 0.1122
# Epoch 150: Train Loss = 0.0199, Test Loss = 0.1171
# Epoch 151: Train Loss = 0.0206, Test Loss = 0.1087
# Epoch 152: Train Loss = 0.0156, Test Loss = 0.1053
# Epoch 153: Train Loss = 0.0147, Test Loss = 0.1060
# Epoch 154: Train Loss = 0.0144, Test Loss = 0.1073
# Epoch 155: Train Loss = 0.0148, Test Loss = 0.1053
# Epoch 156: Train Loss = 0.0151, Test Loss = 0.1053
# Epoch 157: Train Loss = 0.0231, Test Loss = 0.1787
# Epoch 158: Train Loss = 0.2204, Test Loss = 0.2822
# Epoch 159: Train Loss = 0.1116, Test Loss = 0.1604
# Epoch 160: Train Loss = 0.0545, Test Loss = 0.1345
# Epoch 161: Train Loss = 0.0344, Test Loss = 0.1217
# Epoch 162: Train Loss = 0.0239, Test Loss = 0.1100
# 🚀 Early stopping triggered for Delta_band at epoch 162
# 🚀 Processing Theta_band...
#
# 📌 Loading and Splitting Data for Theta_band...
# ✅ Theta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Theta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Theta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Theta_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 0.9680, Test Loss = 0.9483
# Epoch 2: Train Loss = 0.9368, Test Loss = 0.9271
# Epoch 3: Train Loss = 0.9219, Test Loss = 0.9407
# Epoch 4: Train Loss = 0.8840, Test Loss = 0.8700
# Epoch 5: Train Loss = 0.8599, Test Loss = 0.8396
# Epoch 6: Train Loss = 0.8397, Test Loss = 0.8284
# Epoch 7: Train Loss = 0.8191, Test Loss = 0.8081
# Epoch 8: Train Loss = 0.8141, Test Loss = 0.8442
# Epoch 9: Train Loss = 0.8329, Test Loss = 0.8200
# Epoch 10: Train Loss = 0.7893, Test Loss = 0.8000
# Epoch 11: Train Loss = 0.7751, Test Loss = 0.7836
# Epoch 12: Train Loss = 0.7495, Test Loss = 0.7243
# Epoch 13: Train Loss = 0.7011, Test Loss = 0.6888
# Epoch 14: Train Loss = 0.6911, Test Loss = 0.6758
# Epoch 15: Train Loss = 0.6687, Test Loss = 0.6799
# Epoch 16: Train Loss = 0.6512, Test Loss = 0.6554
# Epoch 17: Train Loss = 0.6289, Test Loss = 0.6279
# Epoch 18: Train Loss = 0.6115, Test Loss = 0.6242
# Epoch 19: Train Loss = 0.5930, Test Loss = 0.6014
# Epoch 20: Train Loss = 0.5867, Test Loss = 0.5882
# Epoch 21: Train Loss = 0.5540, Test Loss = 0.5719
# Epoch 22: Train Loss = 0.5388, Test Loss = 0.5505
# Epoch 23: Train Loss = 0.5197, Test Loss = 0.5559
# Epoch 24: Train Loss = 0.5002, Test Loss = 0.5303
# Epoch 25: Train Loss = 0.4828, Test Loss = 0.5491
# Epoch 26: Train Loss = 0.4632, Test Loss = 0.5372
# Epoch 27: Train Loss = 0.4441, Test Loss = 0.5343
# Epoch 28: Train Loss = 0.4225, Test Loss = 0.4596
# Epoch 29: Train Loss = 0.4011, Test Loss = 0.4615
# Epoch 30: Train Loss = 0.3786, Test Loss = 0.4757
# Epoch 31: Train Loss = 0.3728, Test Loss = 0.4091
# Epoch 32: Train Loss = 0.3465, Test Loss = 0.4071
# Epoch 33: Train Loss = 0.3281, Test Loss = 0.3948
# Epoch 34: Train Loss = 0.3115, Test Loss = 0.3641
# Epoch 35: Train Loss = 0.2985, Test Loss = 0.3809
# Epoch 36: Train Loss = 0.2821, Test Loss = 0.3423
# Epoch 37: Train Loss = 0.2594, Test Loss = 0.3259
# Epoch 38: Train Loss = 0.2504, Test Loss = 0.3532
# Epoch 39: Train Loss = 0.2283, Test Loss = 0.3113
# Epoch 40: Train Loss = 0.2198, Test Loss = 0.2949
# Epoch 41: Train Loss = 0.2090, Test Loss = 0.3161
# Epoch 42: Train Loss = 0.1992, Test Loss = 0.2751
# Epoch 43: Train Loss = 0.1969, Test Loss = 0.2752
# Epoch 44: Train Loss = 0.1752, Test Loss = 0.2739
# Epoch 45: Train Loss = 0.1860, Test Loss = 0.2628
# Epoch 46: Train Loss = 0.1589, Test Loss = 0.2355
# Epoch 47: Train Loss = 0.1463, Test Loss = 0.2134
# Epoch 48: Train Loss = 0.1326, Test Loss = 0.2097
# Epoch 49: Train Loss = 0.1334, Test Loss = 0.2096
# Epoch 50: Train Loss = 0.1274, Test Loss = 0.2437
# Epoch 51: Train Loss = 0.1319, Test Loss = 0.2783
# Epoch 52: Train Loss = 0.1389, Test Loss = 0.1996
# Epoch 53: Train Loss = 0.1040, Test Loss = 0.2304
# Epoch 54: Train Loss = 0.1069, Test Loss = 0.2072
# Epoch 55: Train Loss = 0.1067, Test Loss = 0.1796
# Epoch 56: Train Loss = 0.0853, Test Loss = 0.1590
# Epoch 57: Train Loss = 0.0890, Test Loss = 0.1889
# Epoch 58: Train Loss = 0.0928, Test Loss = 0.1691
# Epoch 59: Train Loss = 0.0889, Test Loss = 0.1635
# Epoch 60: Train Loss = 0.0797, Test Loss = 0.1531
# Epoch 61: Train Loss = 0.0733, Test Loss = 0.1530
# Epoch 62: Train Loss = 0.0844, Test Loss = 0.1539
# Epoch 63: Train Loss = 0.0684, Test Loss = 0.1836
# Epoch 64: Train Loss = 0.1561, Test Loss = 0.2018
# Epoch 65: Train Loss = 0.1062, Test Loss = 0.1790
# Epoch 66: Train Loss = 0.0660, Test Loss = 0.1364
# Epoch 67: Train Loss = 0.0503, Test Loss = 0.1271
# Epoch 68: Train Loss = 0.0454, Test Loss = 0.1186
# Epoch 69: Train Loss = 0.0424, Test Loss = 0.1148
# Epoch 70: Train Loss = 0.0393, Test Loss = 0.1113
# Epoch 71: Train Loss = 0.0458, Test Loss = 0.1174
# Epoch 72: Train Loss = 0.0457, Test Loss = 0.1365
# Epoch 73: Train Loss = 0.0481, Test Loss = 0.1203
# Epoch 74: Train Loss = 0.0487, Test Loss = 0.1305
# Epoch 75: Train Loss = 0.1540, Test Loss = 0.2245
# Epoch 76: Train Loss = 0.0794, Test Loss = 0.1243
# Epoch 77: Train Loss = 0.0422, Test Loss = 0.1104
# Epoch 78: Train Loss = 0.0371, Test Loss = 0.1011
# Epoch 79: Train Loss = 0.0297, Test Loss = 0.1027
# Epoch 80: Train Loss = 0.0267, Test Loss = 0.0913
# Epoch 81: Train Loss = 0.0254, Test Loss = 0.0943
# Epoch 82: Train Loss = 0.0261, Test Loss = 0.0971
# Epoch 83: Train Loss = 0.0288, Test Loss = 0.1070
# Epoch 84: Train Loss = 0.0403, Test Loss = 0.1232
# Epoch 85: Train Loss = 0.0376, Test Loss = 0.0999
# Epoch 86: Train Loss = 0.0332, Test Loss = 0.1192
# Epoch 87: Train Loss = 0.1467, Test Loss = 0.2916
# Epoch 88: Train Loss = 0.1282, Test Loss = 0.1462
# Epoch 89: Train Loss = 0.0644, Test Loss = 0.1094
# Epoch 90: Train Loss = 0.0323, Test Loss = 0.0896
# Epoch 91: Train Loss = 0.0226, Test Loss = 0.0875
# Epoch 92: Train Loss = 0.0203, Test Loss = 0.0859
# Epoch 93: Train Loss = 0.0219, Test Loss = 0.0851
# Epoch 94: Train Loss = 0.0189, Test Loss = 0.0837
# Epoch 95: Train Loss = 0.0168, Test Loss = 0.0806
# Epoch 96: Train Loss = 0.0164, Test Loss = 0.0812
# Epoch 97: Train Loss = 0.0161, Test Loss = 0.0802
# Epoch 98: Train Loss = 0.0157, Test Loss = 0.0845
# Epoch 99: Train Loss = 0.0157, Test Loss = 0.0850
# Epoch 100: Train Loss = 0.1638, Test Loss = 0.2926
# Epoch 101: Train Loss = 0.1406, Test Loss = 0.1596
# Epoch 102: Train Loss = 0.0528, Test Loss = 0.0937
# Epoch 103: Train Loss = 0.0223, Test Loss = 0.0809
# Epoch 104: Train Loss = 0.0208, Test Loss = 0.0840
# Epoch 105: Train Loss = 0.0165, Test Loss = 0.0769
# Epoch 106: Train Loss = 0.0153, Test Loss = 0.0751
# Epoch 107: Train Loss = 0.0130, Test Loss = 0.0737
# Epoch 108: Train Loss = 0.0123, Test Loss = 0.0739
# Epoch 109: Train Loss = 0.0125, Test Loss = 0.0742
# Epoch 110: Train Loss = 0.0136, Test Loss = 0.0768
# Epoch 111: Train Loss = 0.0133, Test Loss = 0.0750
# Epoch 112: Train Loss = 0.0125, Test Loss = 0.0737
# Epoch 113: Train Loss = 0.0123, Test Loss = 0.0758
# Epoch 114: Train Loss = 0.0185, Test Loss = 0.0871
# Epoch 115: Train Loss = 0.6768, Test Loss = 0.5594
# Epoch 116: Train Loss = 0.3268, Test Loss = 0.3729
# Epoch 117: Train Loss = 0.1629, Test Loss = 0.1638
# 🚀 Early stopping triggered for Theta_band at epoch 117
# 🚀 Processing Alpha_band...
#
# 📌 Loading and Splitting Data for Alpha_band...
# ✅ Alpha_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Alpha_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Alpha_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Alpha_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 0.9504, Test Loss = 0.9280
# Epoch 2: Train Loss = 0.8980, Test Loss = 0.8739
# Epoch 3: Train Loss = 0.8476, Test Loss = 0.8196
# Epoch 4: Train Loss = 0.8098, Test Loss = 0.7835
# Epoch 5: Train Loss = 0.7722, Test Loss = 0.7438
# Epoch 6: Train Loss = 0.7415, Test Loss = 0.8224
# Epoch 7: Train Loss = 0.7267, Test Loss = 0.7916
# Epoch 8: Train Loss = 0.6908, Test Loss = 0.6742
# Epoch 9: Train Loss = 0.6634, Test Loss = 0.6338
# Epoch 10: Train Loss = 0.6508, Test Loss = 0.6486
# Epoch 11: Train Loss = 0.6210, Test Loss = 0.6339
# Epoch 12: Train Loss = 0.6028, Test Loss = 0.5943
# Epoch 13: Train Loss = 0.5760, Test Loss = 0.5534
# Epoch 14: Train Loss = 0.5650, Test Loss = 0.5390
# Epoch 15: Train Loss = 0.5275, Test Loss = 0.5078
# Epoch 16: Train Loss = 0.4977, Test Loss = 0.4847
# Epoch 17: Train Loss = 0.4738, Test Loss = 0.4491
# Epoch 18: Train Loss = 0.4504, Test Loss = 0.4961
# Epoch 19: Train Loss = 0.4419, Test Loss = 0.4521
# Epoch 20: Train Loss = 0.4166, Test Loss = 0.4119
# Epoch 21: Train Loss = 0.3891, Test Loss = 0.4966
# Epoch 22: Train Loss = 0.3714, Test Loss = 0.3837
# Epoch 23: Train Loss = 0.3588, Test Loss = 0.3539
# Epoch 24: Train Loss = 0.3310, Test Loss = 0.4148
# Epoch 25: Train Loss = 0.3151, Test Loss = 0.3193
# Epoch 26: Train Loss = 0.2886, Test Loss = 0.3375
# Epoch 27: Train Loss = 0.2847, Test Loss = 0.2826
# Epoch 28: Train Loss = 0.2475, Test Loss = 0.2750
# Epoch 29: Train Loss = 0.2292, Test Loss = 0.2843
# Epoch 30: Train Loss = 0.2141, Test Loss = 0.2545
# Epoch 31: Train Loss = 0.2067, Test Loss = 0.2295
# Epoch 32: Train Loss = 0.1794, Test Loss = 0.3322
# Epoch 33: Train Loss = 0.1919, Test Loss = 0.2108
# Epoch 34: Train Loss = 0.1729, Test Loss = 0.2112
# Epoch 35: Train Loss = 0.1453, Test Loss = 0.2179
# Epoch 36: Train Loss = 0.1336, Test Loss = 0.1771
# Epoch 37: Train Loss = 0.1313, Test Loss = 0.1672
# Epoch 38: Train Loss = 0.1245, Test Loss = 0.1554
# Epoch 39: Train Loss = 0.1059, Test Loss = 0.1476
# Epoch 40: Train Loss = 0.1014, Test Loss = 0.1523
# Epoch 41: Train Loss = 0.0986, Test Loss = 0.1352
# Epoch 42: Train Loss = 0.1053, Test Loss = 0.1293
# Epoch 43: Train Loss = 0.0827, Test Loss = 0.1252
# Epoch 44: Train Loss = 0.0769, Test Loss = 0.1159
# Epoch 45: Train Loss = 0.0673, Test Loss = 0.1100
# Epoch 46: Train Loss = 0.0711, Test Loss = 0.1072
# Epoch 47: Train Loss = 0.1229, Test Loss = 0.3383
# Epoch 48: Train Loss = 0.0906, Test Loss = 0.0982
# Epoch 49: Train Loss = 0.0545, Test Loss = 0.0940
# Epoch 50: Train Loss = 0.0472, Test Loss = 0.0913
# Epoch 51: Train Loss = 0.0428, Test Loss = 0.0808
# Epoch 52: Train Loss = 0.0427, Test Loss = 0.0800
# Epoch 53: Train Loss = 0.1459, Test Loss = 0.1821
# Epoch 54: Train Loss = 0.0746, Test Loss = 0.0826
# Epoch 55: Train Loss = 0.0394, Test Loss = 0.0726
# Epoch 56: Train Loss = 0.0341, Test Loss = 0.0701
# Epoch 57: Train Loss = 0.0333, Test Loss = 0.0707
# Epoch 58: Train Loss = 0.0343, Test Loss = 0.0677
# Epoch 59: Train Loss = 0.0309, Test Loss = 0.0682
# Epoch 60: Train Loss = 0.0275, Test Loss = 0.0621
# Epoch 61: Train Loss = 0.0582, Test Loss = 0.5632
# Epoch 62: Train Loss = 0.2598, Test Loss = 0.1248
# Epoch 63: Train Loss = 0.0613, Test Loss = 0.0872
# Epoch 64: Train Loss = 0.0361, Test Loss = 0.0687
# Epoch 65: Train Loss = 0.0265, Test Loss = 0.0609
# Epoch 66: Train Loss = 0.0225, Test Loss = 0.0549
# Epoch 67: Train Loss = 0.0223, Test Loss = 0.0660
# Epoch 68: Train Loss = 0.0210, Test Loss = 0.0550
# Epoch 69: Train Loss = 0.0206, Test Loss = 0.0574
# Epoch 70: Train Loss = 0.0199, Test Loss = 0.0517
# Epoch 71: Train Loss = 0.0195, Test Loss = 0.0538
# Epoch 72: Train Loss = 0.0208, Test Loss = 0.0534
# Epoch 73: Train Loss = 0.0207, Test Loss = 0.0578
# Epoch 74: Train Loss = 0.7666, Test Loss = 0.7083
# Epoch 75: Train Loss = 0.6610, Test Loss = 0.6077
# Epoch 76: Train Loss = 0.5537, Test Loss = 0.5199
# Epoch 77: Train Loss = 0.4726, Test Loss = 0.4602
# Epoch 78: Train Loss = 0.4200, Test Loss = 0.4120
# Epoch 79: Train Loss = 0.3694, Test Loss = 0.4041
# Epoch 80: Train Loss = 0.3183, Test Loss = 0.3603
# 🚀 Early stopping triggered for Alpha_band at epoch 80
# 🚀 Processing Beta_band...
#
# 📌 Loading and Splitting Data for Beta_band...
# ✅ Beta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Beta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Beta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Beta_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 0.9227, Test Loss = 0.8522
# Epoch 2: Train Loss = 0.8421, Test Loss = 0.8522
# Epoch 3: Train Loss = 0.8042, Test Loss = 0.7544
# Epoch 4: Train Loss = 0.7407, Test Loss = 0.7128
# Epoch 5: Train Loss = 0.6758, Test Loss = 0.6094
# Epoch 6: Train Loss = 0.5884, Test Loss = 0.5289
# Epoch 7: Train Loss = 0.5010, Test Loss = 0.4531
# Epoch 8: Train Loss = 0.4447, Test Loss = 0.4658
# Epoch 9: Train Loss = 0.3552, Test Loss = 0.3128
# Epoch 10: Train Loss = 0.2951, Test Loss = 0.2751
# Epoch 11: Train Loss = 0.2587, Test Loss = 0.2708
# Epoch 12: Train Loss = 0.1992, Test Loss = 0.1869
# Epoch 13: Train Loss = 0.1628, Test Loss = 0.1517
# Epoch 14: Train Loss = 0.1338, Test Loss = 0.1329
# Epoch 15: Train Loss = 0.2670, Test Loss = 0.2435
# Epoch 16: Train Loss = 0.1157, Test Loss = 0.1100
# Epoch 17: Train Loss = 0.0820, Test Loss = 0.0982
# Epoch 18: Train Loss = 0.0826, Test Loss = 0.0889
# Epoch 19: Train Loss = 0.0801, Test Loss = 0.0760
# Epoch 20: Train Loss = 0.0553, Test Loss = 0.0647
# Epoch 21: Train Loss = 0.0471, Test Loss = 0.0586
# Epoch 22: Train Loss = 0.0450, Test Loss = 0.0593
# Epoch 23: Train Loss = 0.0408, Test Loss = 0.0581
# Epoch 24: Train Loss = 0.2040, Test Loss = 0.1332
# Epoch 25: Train Loss = 0.0675, Test Loss = 0.0783
# Epoch 26: Train Loss = 0.0407, Test Loss = 0.0483
# Epoch 27: Train Loss = 0.0292, Test Loss = 0.0395
# Epoch 28: Train Loss = 0.0254, Test Loss = 0.0385
# Epoch 29: Train Loss = 0.0239, Test Loss = 0.0353
# Epoch 30: Train Loss = 0.0232, Test Loss = 0.0320
# Epoch 31: Train Loss = 0.0198, Test Loss = 0.0305
# Epoch 32: Train Loss = 0.0195, Test Loss = 0.0290
# Epoch 33: Train Loss = 0.0185, Test Loss = 0.0316
# Epoch 34: Train Loss = 0.0169, Test Loss = 0.0257
# Epoch 35: Train Loss = 0.0167, Test Loss = 0.0257
# Epoch 36: Train Loss = 0.2952, Test Loss = 0.8838
# Epoch 37: Train Loss = 0.7313, Test Loss = 0.5927
# Epoch 38: Train Loss = 0.5439, Test Loss = 0.4600
# Epoch 39: Train Loss = 0.3947, Test Loss = 0.3462
# Epoch 40: Train Loss = 0.2994, Test Loss = 0.2727
# Epoch 41: Train Loss = 0.2278, Test Loss = 0.2518
# Epoch 42: Train Loss = 0.1844, Test Loss = 0.1764
# Epoch 43: Train Loss = 0.1383, Test Loss = 0.1460
# Epoch 44: Train Loss = 0.1148, Test Loss = 0.1288
# 🚀 Early stopping triggered for Beta_band at epoch 44
# 🚀 Processing Gamma_band...
#
# 📌 Loading and Splitting Data for Gamma_band...
# ✅ Gamma_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Gamma_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Gamma_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Gamma_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 0.9600, Test Loss = 0.8973
# Epoch 2: Train Loss = 0.8736, Test Loss = 0.8193
# Epoch 3: Train Loss = 0.7694, Test Loss = 0.6981
# Epoch 4: Train Loss = 0.6538, Test Loss = 0.5749
# Epoch 5: Train Loss = 0.5456, Test Loss = 0.4794
# Epoch 6: Train Loss = 0.4335, Test Loss = 0.3907
# Epoch 7: Train Loss = 0.3461, Test Loss = 0.3211
# Epoch 8: Train Loss = 0.2816, Test Loss = 0.2498
# Epoch 9: Train Loss = 0.2252, Test Loss = 0.2088
# Epoch 10: Train Loss = 0.1762, Test Loss = 0.1820
# Epoch 11: Train Loss = 0.1590, Test Loss = 0.1697
# Epoch 12: Train Loss = 0.1320, Test Loss = 0.1430
# Epoch 13: Train Loss = 0.1128, Test Loss = 0.1189
# Epoch 14: Train Loss = 0.0863, Test Loss = 0.0869
# Epoch 15: Train Loss = 0.0743, Test Loss = 0.0913
# Epoch 16: Train Loss = 0.0739, Test Loss = 0.0773
# Epoch 17: Train Loss = 0.0576, Test Loss = 0.0748
# Epoch 18: Train Loss = 0.0509, Test Loss = 0.0601
# Epoch 19: Train Loss = 0.0448, Test Loss = 0.0672
# Epoch 20: Train Loss = 0.0472, Test Loss = 0.0553
# Epoch 21: Train Loss = 0.0414, Test Loss = 0.0469
# Epoch 22: Train Loss = 0.0346, Test Loss = 0.0485
# Epoch 23: Train Loss = 0.1923, Test Loss = 0.1434
# Epoch 24: Train Loss = 0.0559, Test Loss = 0.0500
# Epoch 25: Train Loss = 0.0317, Test Loss = 0.0390
# Epoch 26: Train Loss = 0.0266, Test Loss = 0.0361
# Epoch 27: Train Loss = 0.0240, Test Loss = 0.0346
# Epoch 28: Train Loss = 0.0226, Test Loss = 0.0321
# Epoch 29: Train Loss = 0.0218, Test Loss = 0.0313
# Epoch 30: Train Loss = 0.0206, Test Loss = 0.0299
# Epoch 31: Train Loss = 0.0203, Test Loss = 0.0307
# Epoch 32: Train Loss = 0.0189, Test Loss = 0.0280
# Epoch 33: Train Loss = 0.0183, Test Loss = 0.0280
# Epoch 34: Train Loss = 0.0180, Test Loss = 0.0291
# Epoch 35: Train Loss = 0.0194, Test Loss = 0.0290
# Epoch 36: Train Loss = 0.2891, Test Loss = 0.1069
# Epoch 37: Train Loss = 0.0594, Test Loss = 0.0549
# Epoch 38: Train Loss = 0.0280, Test Loss = 0.0327
# Epoch 39: Train Loss = 0.0189, Test Loss = 0.0281
# Epoch 40: Train Loss = 0.0159, Test Loss = 0.0255
# Epoch 41: Train Loss = 0.0146, Test Loss = 0.0238
# Epoch 42: Train Loss = 0.0137, Test Loss = 0.0235
# Epoch 43: Train Loss = 0.0131, Test Loss = 0.0225
# Epoch 44: Train Loss = 0.0126, Test Loss = 0.0225
# Epoch 45: Train Loss = 0.0123, Test Loss = 0.0214
# Epoch 46: Train Loss = 0.0116, Test Loss = 0.0206
# Epoch 47: Train Loss = 0.0113, Test Loss = 0.0215
# Epoch 48: Train Loss = 0.0125, Test Loss = 0.0250
# Epoch 49: Train Loss = 0.0126, Test Loss = 0.0209
# Epoch 50: Train Loss = 0.0113, Test Loss = 0.0207
# Epoch 51: Train Loss = 0.0115, Test Loss = 0.0219
# Epoch 52: Train Loss = 0.0104, Test Loss = 0.0193
# Epoch 53: Train Loss = 0.0111, Test Loss = 0.0213
# Epoch 54: Train Loss = 0.0118, Test Loss = 0.0298
# Epoch 55: Train Loss = 0.3917, Test Loss = 0.2529
# Epoch 56: Train Loss = 0.1047, Test Loss = 0.0615
# Epoch 57: Train Loss = 0.0334, Test Loss = 0.0395
# Epoch 58: Train Loss = 0.0191, Test Loss = 0.0247
# Epoch 59: Train Loss = 0.0134, Test Loss = 0.0214
# Epoch 60: Train Loss = 0.0114, Test Loss = 0.0202
# Epoch 61: Train Loss = 0.0103, Test Loss = 0.0194
# Epoch 62: Train Loss = 0.0097, Test Loss = 0.0188
# Epoch 63: Train Loss = 0.0092, Test Loss = 0.0177
# Epoch 64: Train Loss = 0.0086, Test Loss = 0.0181
# Epoch 65: Train Loss = 0.0082, Test Loss = 0.0169
# Epoch 66: Train Loss = 0.0079, Test Loss = 0.0169
# Epoch 67: Train Loss = 0.0079, Test Loss = 0.0165
# Epoch 68: Train Loss = 0.0075, Test Loss = 0.0167
# Epoch 69: Train Loss = 0.0073, Test Loss = 0.0186
# Epoch 70: Train Loss = 0.0078, Test Loss = 0.0178
# Epoch 71: Train Loss = 0.0078, Test Loss = 0.0176
# Epoch 72: Train Loss = 0.0075, Test Loss = 0.0182
# Epoch 73: Train Loss = 0.0076, Test Loss = 0.0169
# Epoch 74: Train Loss = 0.0074, Test Loss = 0.0163
# Epoch 75: Train Loss = 0.0075, Test Loss = 0.0160
# Epoch 76: Train Loss = 0.0076, Test Loss = 0.0189
# Epoch 77: Train Loss = 0.0075, Test Loss = 0.0201
# Epoch 78: Train Loss = 0.7768, Test Loss = 0.6848
# Epoch 79: Train Loss = 0.5679, Test Loss = 0.4770
# Epoch 80: Train Loss = 0.3486, Test Loss = 0.2523
# Epoch 81: Train Loss = 0.1779, Test Loss = 0.1378
# Epoch 82: Train Loss = 0.0953, Test Loss = 0.0829
# Epoch 83: Train Loss = 0.0511, Test Loss = 0.0508
# Epoch 84: Train Loss = 0.0333, Test Loss = 0.0408
# Epoch 85: Train Loss = 0.0257, Test Loss = 0.0338
# 🚀 Early stopping triggered for Gamma_band at epoch 85
# 🚀 Processing High_Frequencies_band...
#
# 📌 Loading and Splitting Data for High_Frequencies_band...
# ✅ High_Frequencies_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ High_Frequencies_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ High_Frequencies_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 High_Frequencies_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 1.0017, Test Loss = 0.9829
# Epoch 2: Train Loss = 0.9576, Test Loss = 0.9309
# Epoch 3: Train Loss = 0.9003, Test Loss = 0.8698
# Epoch 4: Train Loss = 0.8017, Test Loss = 0.7328
# Epoch 5: Train Loss = 0.6778, Test Loss = 0.6213
# Epoch 6: Train Loss = 0.5626, Test Loss = 0.5095
# Epoch 7: Train Loss = 0.4618, Test Loss = 0.4236
# Epoch 8: Train Loss = 0.3801, Test Loss = 0.3569
# Epoch 9: Train Loss = 0.3191, Test Loss = 0.3043
# Epoch 10: Train Loss = 0.2742, Test Loss = 0.2664
# Epoch 11: Train Loss = 0.2384, Test Loss = 0.2379
# Epoch 12: Train Loss = 0.2114, Test Loss = 0.2136
# Epoch 13: Train Loss = 0.1910, Test Loss = 0.1971
# Epoch 14: Train Loss = 0.1698, Test Loss = 0.1716
# Epoch 15: Train Loss = 0.1544, Test Loss = 0.1602
# Epoch 16: Train Loss = 0.1423, Test Loss = 0.1480
# Epoch 17: Train Loss = 0.1315, Test Loss = 0.1400
# Epoch 18: Train Loss = 0.1224, Test Loss = 0.1278
# Epoch 19: Train Loss = 0.1265, Test Loss = 0.1413
# Epoch 20: Train Loss = 0.1113, Test Loss = 0.1153
# Epoch 21: Train Loss = 0.1000, Test Loss = 0.1085
# Epoch 22: Train Loss = 0.0960, Test Loss = 0.1046
# Epoch 23: Train Loss = 0.0915, Test Loss = 0.0992
# Epoch 24: Train Loss = 0.0871, Test Loss = 0.0968
# Epoch 25: Train Loss = 0.0871, Test Loss = 0.0957
# Epoch 26: Train Loss = 0.0804, Test Loss = 0.0889
# Epoch 27: Train Loss = 0.0761, Test Loss = 0.0828
# Epoch 28: Train Loss = 0.0724, Test Loss = 0.0798
# Epoch 29: Train Loss = 0.0713, Test Loss = 0.0788
# Epoch 30: Train Loss = 0.0684, Test Loss = 0.0764
# Epoch 31: Train Loss = 0.0672, Test Loss = 0.0758
# Epoch 32: Train Loss = 0.0649, Test Loss = 0.0732
# Epoch 33: Train Loss = 0.0625, Test Loss = 0.0730
# Epoch 34: Train Loss = 0.0603, Test Loss = 0.0697
# Epoch 35: Train Loss = 0.0590, Test Loss = 0.0649
# Epoch 36: Train Loss = 0.0568, Test Loss = 0.0642
# Epoch 37: Train Loss = 0.0545, Test Loss = 0.0625
# Epoch 38: Train Loss = 0.0540, Test Loss = 0.0615
# Epoch 39: Train Loss = 0.0536, Test Loss = 0.0638
# Epoch 40: Train Loss = 0.0509, Test Loss = 0.0590
# Epoch 41: Train Loss = 0.0498, Test Loss = 0.0573
# Epoch 42: Train Loss = 0.0486, Test Loss = 0.0614
# Epoch 43: Train Loss = 0.0485, Test Loss = 0.0560
# Epoch 44: Train Loss = 0.0503, Test Loss = 0.0585
# Epoch 45: Train Loss = 0.0471, Test Loss = 0.0551
# Epoch 46: Train Loss = 0.0437, Test Loss = 0.0514
# Epoch 47: Train Loss = 0.0431, Test Loss = 0.0520
# Epoch 48: Train Loss = 0.0425, Test Loss = 0.0489
# Epoch 49: Train Loss = 0.0414, Test Loss = 0.0479
# Epoch 50: Train Loss = 0.0449, Test Loss = 0.0583
# Epoch 51: Train Loss = 0.0431, Test Loss = 0.0487
# Epoch 52: Train Loss = 0.0388, Test Loss = 0.0470
# Epoch 53: Train Loss = 0.0390, Test Loss = 0.0468
# Epoch 54: Train Loss = 0.0371, Test Loss = 0.0445
# Epoch 55: Train Loss = 0.0366, Test Loss = 0.0452
# Epoch 56: Train Loss = 0.0369, Test Loss = 0.0444
# Epoch 57: Train Loss = 0.0354, Test Loss = 0.0426
# Epoch 58: Train Loss = 0.0346, Test Loss = 0.0430
# Epoch 59: Train Loss = 0.0349, Test Loss = 0.0452
# Epoch 60: Train Loss = 0.3735, Test Loss = 0.2247
# Epoch 61: Train Loss = 0.1281, Test Loss = 0.0855
# Epoch 62: Train Loss = 0.0584, Test Loss = 0.0594
# Epoch 63: Train Loss = 0.0445, Test Loss = 0.0500
# Epoch 64: Train Loss = 0.0388, Test Loss = 0.0460
# Epoch 65: Train Loss = 0.0358, Test Loss = 0.0436
# Epoch 66: Train Loss = 0.0340, Test Loss = 0.0414
# Epoch 67: Train Loss = 0.0325, Test Loss = 0.0405
# Epoch 68: Train Loss = 0.0315, Test Loss = 0.0393
# Epoch 69: Train Loss = 0.0307, Test Loss = 0.0385
# Epoch 70: Train Loss = 0.0300, Test Loss = 0.0382
# Epoch 71: Train Loss = 0.0295, Test Loss = 0.0369
# Epoch 72: Train Loss = 0.0290, Test Loss = 0.0372
# Epoch 73: Train Loss = 0.0287, Test Loss = 0.0368
# Epoch 74: Train Loss = 0.0282, Test Loss = 0.0367
# Epoch 75: Train Loss = 0.0279, Test Loss = 0.0365
# Epoch 76: Train Loss = 0.0278, Test Loss = 0.0371
# Epoch 77: Train Loss = 0.0280, Test Loss = 0.0364
# Epoch 78: Train Loss = 0.0282, Test Loss = 0.0366
# Epoch 79: Train Loss = 0.0280, Test Loss = 0.0363
# Epoch 80: Train Loss = 0.0275, Test Loss = 0.0350
# Epoch 81: Train Loss = 0.0275, Test Loss = 0.0352
# Epoch 82: Train Loss = 0.0275, Test Loss = 0.0354
# Epoch 83: Train Loss = 0.0265, Test Loss = 0.0344
# Epoch 84: Train Loss = 0.0263, Test Loss = 0.0349
# Epoch 85: Train Loss = 0.0263, Test Loss = 0.0339
# Epoch 86: Train Loss = 0.0271, Test Loss = 0.0389
# Epoch 87: Train Loss = 0.0284, Test Loss = 0.0382
# Epoch 88: Train Loss = 0.0278, Test Loss = 0.0372
# Epoch 89: Train Loss = 0.0254, Test Loss = 0.0346
# Epoch 90: Train Loss = 0.0255, Test Loss = 0.0332
# Epoch 91: Train Loss = 0.0251, Test Loss = 0.0373
# Epoch 92: Train Loss = 0.0254, Test Loss = 0.0363
# Epoch 93: Train Loss = 0.0272, Test Loss = 0.0338
# Epoch 94: Train Loss = 0.0266, Test Loss = 0.0349
# Epoch 95: Train Loss = 0.2512, Test Loss = 0.3479
# Epoch 96: Train Loss = 0.1634, Test Loss = 0.0988
# Epoch 97: Train Loss = 0.0603, Test Loss = 0.0561
# Epoch 98: Train Loss = 0.0401, Test Loss = 0.0442
# Epoch 99: Train Loss = 0.0319, Test Loss = 0.0386
# Epoch 100: Train Loss = 0.0286, Test Loss = 0.0365
# 🚀 Early stopping triggered for High_Frequencies_band at epoch 100

# %%
import numpy as np

def compute_rrmse(true, pred):
    """Compute Relative Root Mean Square Error (RRMSE)."""
    return np.sqrt(np.mean((true - pred) ** 2)) / np.sqrt(np.mean(true ** 2))

def compute_cc(true, pred):
    """Compute Correlation Coefficient (CC)."""
    true_mean = np.mean(true)
    pred_mean = np.mean(pred)
    return np.corrcoef(true.flatten(), pred.flatten())[0, 1]

def compute_ts_metric(rrmse_t, rrmse_s):
    """Compute T&S Metric in dB."""
    return 10 * np.log10(rrmse_t + rrmse_s)

# %%
import numpy as np

# Check if the denoised EEG data exists
try:
    print(f"✅ Number of EEG bands processed: {len(denoised_bands)}")
    print(f"✅ Type of first denoised band: {type(denoised_bands[0])}")
    print(f"✅ Shape of first denoised band: {denoised_bands[0].shape}")
except:
    print("❌ `denoised_bands` is empty or not defined. You may need to retrain.")
# Out:
# ✅ Number of EEG bands processed: 1
# ✅ Type of first denoised band: <class 'ellipsis'>
# ❌ `denoised_bands` is empty or not defined. You may need to retrain.
