# %%
import os
import numpy as np
import torch

# Check if GPU is available and set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Using device: {device}")

# Set paths for clean and contaminated EEG data
clean_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean"
contaminated_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated"

# Define EEG frequency bands
bands = ["Delta_band", "Theta_band", "Alpha_band", "Beta_band", "Gamma_band", "High_Frequencies_band"]

print(f"✅ Clean EEG Directory: {clean_dir}")
print(f"✅ Contaminated EEG Directory: {contaminated_dir}")
print(f"✅ EEG Bands: {bands}")
# Out:
# ✅ Using device: cuda
# ✅ Clean EEG Directory: /home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean
# ✅ Contaminated EEG Directory: /home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated
# ✅ EEG Bands: ['Delta_band', 'Theta_band', 'Alpha_band', 'Beta_band', 'Gamma_band', 'High_Frequencies_band']

# %%
import torch.nn as nn
import torch

class ResCNN1D(nn.Module):
    def __init__(self, input_length=512):
        super(ResCNN1D, self).__init__()

        # First Convolutional Layer
        self.conv1 = nn.Conv1d(1, 64, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm1d(64)

        # Residual Block with Two Convolutions
        self.conv2 = nn.Conv1d(64, 64, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm1d(64)
        self.conv3 = nn.Conv1d(64, 64, kernel_size=5, stride=1, padding=2)
        self.bn3 = nn.BatchNorm1d(64)

        # ✅ FIXED: Residual Connection Now Matches the Input Channels
        self.residual = nn.Conv1d(64, 64, kernel_size=1, stride=1)

        # Final Convolutional Refinement
        self.conv4 = nn.Conv1d(64, 64, kernel_size=3, stride=1, padding=1)
        self.bn4 = nn.BatchNorm1d(64)

        # Fully Connected Layer for Reconstruction
        self.fc = nn.Linear(input_length * 64, input_length)

    def forward(self, x):
        # Ensure input is 3D (batch, channels, sequence)
        if x.dim() == 2:
            x = x.unsqueeze(1)  # Add channel dimension if missing

        # First Conv Layer
        x = torch.relu(self.bn1(self.conv1(x)))

        # ✅ FIXED: Residual Path (Now Uses Correct Input Shape)
        residual = self.residual(x)  # Now it expects 64 channels

        # Residual Block (2 Conv Layers)
        x = torch.relu(self.bn2(self.conv2(x)))
        x = torch.relu(self.bn3(self.conv3(x)))

        # Merge Residual and Main Path
        x = x + residual  # Residual Learning

        # Final Convolutional Refinement
        x = torch.relu(self.bn4(self.conv4(x)))

        # Flatten before fully connected layer
        x = x.view(x.size(0), -1)

        # Fully Connected Layer for Reconstruction
        x = self.fc(x)

        return x

# Print confirmation
print("✅ Fixed ResCNN1D Model Defined Successfully!")
# Out:
# ✅ Fixed ResCNN1D Model Defined Successfully!

# %%
import torch.optim as optim

# Define Early Stopping Class
class EarlyStopping:
    def __init__(self, patience=10, min_delta=1e-4):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = None
        self.counter = 0
        self.stop_training = False

    def __call__(self, current_loss):
        if self.best_loss is None or current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.stop_training = True

# Define Loss Function (MSE)
criterion = nn.MSELoss()

# Define Optimizer (Adam)
input_length = 512  # EEG signal length
model = ResCNN1D().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Early stopping instance
early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

# Print confirmation
print("✅ Loss function, optimizer, and early stopping defined successfully!")
# Out:
# ✅ Loss function, optimizer, and early stopping defined successfully!

# %%
from sklearn.model_selection import train_test_split

def load_and_split_data(band_name):
    """
    Loads EEG data for a specific frequency band, splits into train and test sets based on SNR levels.
    """
    print(f"\n📌 Loading and Splitting Data for {band_name}...")

    # Load clean EEG data
    clean_band_path = os.path.join(clean_dir, f"{band_name}.npy")
    clean_band = np.load(clean_band_path)

    # Load contaminated EEG data across all SNR levels
    contaminated_band = []
    snr_labels = []

    for snr_folder in sorted(os.listdir(contaminated_dir)):  # Iterate through SNR folders
        contaminated_band_path = os.path.join(contaminated_dir, snr_folder, f"{band_name}.npy")
        contaminated_data = np.load(contaminated_band_path)

        contaminated_band.append(contaminated_data)
        snr_labels.extend([snr_folder] * len(contaminated_data))  # Track SNR levels

    # Convert lists to numpy arrays
    contaminated_band = np.concatenate(contaminated_band, axis=0)
    # Convert string labels ("SNR_-7") to integers (-7)
    
    snr_labels = np.array([int(snr.replace("SNR_", "")) for snr in snr_labels])


    # Ensure clean_band is correctly repeated to match contaminated EEG samples
    clean_band_repeated = np.tile(clean_band, (len(contaminated_band) // len(clean_band) + 1, 1))[:len(contaminated_band)]

    # Stratified Train-Test Split
    train_clean, test_clean, train_contaminated, test_contaminated, snr_labels_train, snr_labels_test = train_test_split(
        clean_band_repeated, contaminated_band, snr_labels, test_size=0.2, stratify=snr_labels, random_state=42
    )

    # Inspect data shapes
    print(f"✅ {band_name} Train Clean Shape: {train_clean.shape}, Test Clean Shape: {test_clean.shape}")
    print(f"✅ {band_name} Train Contaminated Shape: {train_contaminated.shape}, Test Contaminated Shape: {test_contaminated.shape}")
    print(f"✅ {band_name} SNR Labels Train: {np.unique(snr_labels_train)}, Test: {np.unique(snr_labels_test)}")

    return train_clean, train_contaminated, test_clean, test_contaminated, snr_labels_train, snr_labels_test

# Load and split data for each EEG band
train_data = {}
test_data = {}

for band in bands:
    train_clean, train_contaminated, test_clean, test_contaminated, snr_labels_train, snr_labels_test = load_and_split_data(band)
    train_data[band] = (train_clean, train_contaminated)
    test_data[band] = (test_clean, test_contaminated, snr_labels_test)

print("\n✅ All EEG bands successfully loaded and split!")
# Out:
# 📌 Loading and Splitting Data for Delta_band...
# ✅ Delta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Delta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Delta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Theta_band...
# ✅ Theta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Theta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Theta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Alpha_band...
# ✅ Alpha_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Alpha_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Alpha_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Beta_band...
# ✅ Beta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Beta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Beta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Gamma_band...
# ✅ Gamma_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Gamma_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Gamma_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for High_Frequencies_band...
# ✅ High_Frequencies_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ High_Frequencies_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ High_Frequencies_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# ✅ All EEG bands successfully loaded and split!

# %%
from torch.utils.data import DataLoader, TensorDataset

def train_cnn(train_clean, train_contaminated, test_clean, test_contaminated, band_name):
    """
    Trains the CNN model for EEG denoising on a specific frequency band.
    """
    print(f"\n🚀 Training CNN for {band_name}...")

    # Convert NumPy arrays to PyTorch tensors and move to GPU
    train_clean = torch.tensor(train_clean, dtype=torch.float32).unsqueeze(1).to(device)
    test_clean = torch.tensor(test_clean, dtype=torch.float32).unsqueeze(1).to(device)
    train_contaminated = torch.tensor(train_contaminated, dtype=torch.float32).unsqueeze(1).to(device)
    test_contaminated = torch.tensor(test_contaminated, dtype=torch.float32).unsqueeze(1).to(device)

    # Create DataLoader for training and testing
    train_dataset = TensorDataset(train_contaminated, train_clean)
    test_dataset = TensorDataset(test_contaminated, test_clean)
    train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

    # Define model, optimizer, and loss function
    input_length = train_contaminated.shape[2]  # EEG signal length
    model = ResCNN1D().to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

    # Train model
    num_epochs = 1000
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets.squeeze(1))
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        avg_train_loss = running_loss / len(train_loader)

        # Evaluate model
        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for inputs, targets in test_loader:
                outputs = model(inputs)
                loss = criterion(outputs, targets.squeeze(1))
                test_loss += loss.item()

        avg_test_loss = test_loss / len(test_loader)

        print(f"Epoch {epoch + 1}: Train Loss = {avg_train_loss:.4f}, Test Loss = {avg_test_loss:.4f}")

        # Early stopping condition
        early_stopping(avg_test_loss)
        if early_stopping.stop_training:
            print(f"✅ Early stopping triggered for {band_name} at epoch {epoch + 1}")
            break

    # Generate denoised test set predictions
    with torch.no_grad():
        denoised_band = model(test_contaminated).squeeze(1).cpu().numpy()

    return denoised_band, test_clean.cpu().numpy()

# %%
denoised_bands = []
clean_bands = []

for band in bands:
    train_clean, train_contaminated = train_data[band]
    test_clean, test_contaminated, _ = test_data[band]

    denoised_band, clean_band_test = train_cnn(train_clean, train_contaminated, test_clean, test_contaminated, band)
    
    denoised_bands.append(denoised_band)
    clean_bands.append(clean_band_test)

print("\n✅ All EEG bands successfully trained!")
# Out:
# 🚀 Training CNN for Delta_band...
# Epoch 1: Train Loss = 6295.9695, Test Loss = 6212.6928
# Epoch 2: Train Loss = 6007.1795, Test Loss = 6088.8335
# Epoch 3: Train Loss = 5926.4911, Test Loss = 5974.3587
# Epoch 4: Train Loss = 5833.8785, Test Loss = 5915.1102
# Epoch 5: Train Loss = 5769.3475, Test Loss = 5905.6041
# Epoch 6: Train Loss = 5731.0461, Test Loss = 5874.8400
# Epoch 7: Train Loss = 5671.8158, Test Loss = 5830.3735
# Epoch 8: Train Loss = 5622.3389, Test Loss = 5804.2018
# Epoch 9: Train Loss = 5593.3751, Test Loss = 5777.0574
# Epoch 10: Train Loss = 5553.2486, Test Loss = 5757.8943
# Epoch 11: Train Loss = 5515.4090, Test Loss = 5790.9214
# Epoch 12: Train Loss = 5474.2144, Test Loss = 5741.5352
# Epoch 13: Train Loss = 5446.4267, Test Loss = 5683.6362
# Epoch 14: Train Loss = 5406.3728, Test Loss = 5743.7519
# Epoch 15: Train Loss = 5396.0807, Test Loss = 5665.2430
# Epoch 16: Train Loss = 5358.5182, Test Loss = 5656.8240
# Epoch 17: Train Loss = 5337.9974, Test Loss = 5630.4342
# Epoch 18: Train Loss = 5302.8328, Test Loss = 5618.5167
# Epoch 19: Train Loss = 5254.0905, Test Loss = 5656.9362
# Epoch 96: Train Loss = 1460.4340, Test Loss = 2991.0999
# Epoch 97: Train Loss = 1460.4630, Test Loss = 2962.7217
# Epoch 98: Train Loss = 1458.3060, Test Loss = 2941.5944
# Epoch 99: Train Loss = 1438.0279, Test Loss = 2934.8034
# Epoch 100: Train Loss = 1428.3521, Test Loss = 2939.2268
# Epoch 101: Train Loss = 1411.3613, Test Loss = 2955.4453
# Epoch 102: Train Loss = 1404.8461, Test Loss = 2962.6962
# Epoch 103: Train Loss = 1397.3775, Test Loss = 2963.9146
# Epoch 104: Train Loss = 1393.3708, Test Loss = 2978.5375
# Epoch 105: Train Loss = 1383.3991, Test Loss = 2942.4935
# Epoch 106: Train Loss = 1374.1008, Test Loss = 2984.2905
# Epoch 107: Train Loss = 1366.0074, Test Loss = 2987.2079
# Epoch 108: Train Loss = 1343.3594, Test Loss = 2940.9493
# Epoch 109: Train Loss = 1354.6537, Test Loss = 3003.4137
# ✅ Early stopping triggered for Theta_band at epoch 109
#
# 🚀 Training CNN for Alpha_band...
# Epoch 1: Train Loss = 2176.5986, Test Loss = 1978.5960
# Epoch 2: Train Loss = 1903.4184, Test Loss = 1925.7361
# Epoch 3: Train Loss = 1843.2236, Test Loss = 1866.2904
# Epoch 4: Train Loss = 1776.4630, Test Loss = 1826.0531
# Epoch 5: Train Loss = 1719.3723, Test Loss = 1788.2169
# Epoch 6: Train Loss = 1664.1078, Test Loss = 1748.2349
# Epoch 7: Train Loss = 1611.8781, Test Loss = 1722.0005
# Epoch 8: Train Loss = 1565.6641, Test Loss = 1679.4286
# Epoch 9: Train Loss = 1516.4402, Test Loss = 1672.2794
# Epoch 10: Train Loss = 1476.3436, Test Loss = 1636.0124
# Epoch 11: Train Loss = 1431.5428, Test Loss = 1613.9572
# Epoch 12: Train Loss = 1387.2483, Test Loss = 1589.5880
# Epoch 13: Train Loss = 1348.6388, Test Loss = 1583.1421
# Epoch 14: Train Loss = 1307.4722, Test Loss = 1543.2065
# Epoch 15: Train Loss = 1270.9002, Test Loss = 1526.9248
# Epoch 16: Train Loss = 1229.7641, Test Loss = 1496.3162
# Epoch 17: Train Loss = 1195.3761, Test Loss = 1491.0022
# Epoch 18: Train Loss = 1163.8836, Test Loss = 1477.6012
# Epoch 19: Train Loss = 1130.0828, Test Loss = 1460.8784
# Epoch 20: Train Loss = 1094.1998, Test Loss = 1421.1147
# Epoch 21: Train Loss = 1064.2948, Test Loss = 1410.8186
# Epoch 22: Train Loss = 1036.8462, Test Loss = 1387.1452
# Epoch 23: Train Loss = 1013.7839, Test Loss = 1388.5245
# Epoch 24: Train Loss = 979.2374, Test Loss = 1402.5541
# Epoch 25: Train Loss = 950.7800, Test Loss = 1369.4113
# Epoch 26: Train Loss = 927.9431, Test Loss = 1346.4287
# Epoch 27: Train Loss = 903.9770, Test Loss = 1320.6556
# Epoch 28: Train Loss = 880.9667, Test Loss = 1320.5508
# Epoch 29: Train Loss = 860.8823, Test Loss = 1291.3715
# Epoch 30: Train Loss = 843.8066, Test Loss = 1289.4507
# Epoch 31: Train Loss = 819.1971, Test Loss = 1340.1826
# Epoch 32: Train Loss = 807.4652, Test Loss = 1272.6514
# Epoch 33: Train Loss = 785.4348, Test Loss = 1260.3493
# Epoch 34: Train Loss = 760.4380, Test Loss = 1353.8471
# Epoch 35: Train Loss = 745.1139, Test Loss = 1237.1380
# Epoch 36: Train Loss = 734.6138, Test Loss = 1259.4544
# Epoch 37: Train Loss = 720.2080, Test Loss = 1228.7893
# Epoch 38: Train Loss = 697.0094, Test Loss = 1203.7476
# Epoch 39: Train Loss = 686.6507, Test Loss = 1260.5783
# Epoch 40: Train Loss = 670.9457, Test Loss = 1268.1934
# Epoch 41: Train Loss = 657.6245, Test Loss = 1180.5501
# Epoch 42: Train Loss = 642.3680, Test Loss = 1174.7854
# Epoch 43: Train Loss = 625.5264, Test Loss = 1267.1716
# Epoch 44: Train Loss = 618.7035, Test Loss = 1191.5886
# Epoch 45: Train Loss = 602.8116, Test Loss = 1167.7962
# Epoch 46: Train Loss = 593.7323, Test Loss = 1166.8788
# Epoch 47: Train Loss = 581.0963, Test Loss = 1188.0469
# Epoch 48: Train Loss = 575.1035, Test Loss = 1169.4299
# Epoch 49: Train Loss = 557.2164, Test Loss = 1171.7286
# Epoch 50: Train Loss = 550.9978, Test Loss = 1205.0549
# Epoch 51: Train Loss = 543.8313, Test Loss = 1150.1672
# Epoch 52: Train Loss = 526.2861, Test Loss = 1122.8741
# Epoch 53: Train Loss = 519.2026, Test Loss = 1143.6784
# Epoch 54: Train Loss = 510.7302, Test Loss = 1199.9191
# Epoch 55: Train Loss = 505.6934, Test Loss = 1127.0156
# Epoch 56: Train Loss = 493.4269, Test Loss = 1128.1807
# Epoch 57: Train Loss = 482.3662, Test Loss = 1192.9574
# Epoch 58: Train Loss = 483.9433, Test Loss = 1126.6268
# Epoch 59: Train Loss = 476.4166, Test Loss = 1113.6970
# Epoch 60: Train Loss = 463.4854, Test Loss = 1112.3596
# Epoch 61: Train Loss = 449.2255, Test Loss = 1150.2285
# Epoch 62: Train Loss = 446.1914, Test Loss = 1118.3292
# Epoch 63: Train Loss = 448.9283, Test Loss = 1105.5403
# Epoch 64: Train Loss = 430.9489, Test Loss = 1154.6833
# Epoch 65: Train Loss = 432.6716, Test Loss = 1109.7667
# Epoch 66: Train Loss = 429.1141, Test Loss = 1132.6494
# Epoch 67: Train Loss = 419.6494, Test Loss = 1100.4714
# Epoch 68: Train Loss = 411.8252, Test Loss = 1088.3821
# Epoch 69: Train Loss = 405.9755, Test Loss = 1125.2970
# Epoch 70: Train Loss = 401.4164, Test Loss = 1107.7659
# Epoch 71: Train Loss = 393.0496, Test Loss = 1093.2729
# Epoch 72: Train Loss = 387.2866, Test Loss = 1129.1410
# Epoch 73: Train Loss = 385.8342, Test Loss = 1081.8217
# Epoch 74: Train Loss = 379.6404, Test Loss = 1168.4809
# Epoch 75: Train Loss = 366.7627, Test Loss = 1085.1794
# Epoch 76: Train Loss = 366.8787, Test Loss = 1061.6991
# Epoch 77: Train Loss = 362.5178, Test Loss = 1082.7710
# Epoch 78: Train Loss = 361.6911, Test Loss = 1061.3700
# Epoch 79: Train Loss = 359.8085, Test Loss = 1248.8610
# Epoch 80: Train Loss = 350.1953, Test Loss = 1181.4344
# Epoch 81: Train Loss = 348.6978, Test Loss = 1075.3116
# Epoch 82: Train Loss = 342.1387, Test Loss = 1079.2941
# Epoch 83: Train Loss = 339.4323, Test Loss = 1067.5116
# Epoch 84: Train Loss = 340.1681, Test Loss = 1063.4288
# Epoch 85: Train Loss = 336.9580, Test Loss = 1059.3998
# Epoch 86: Train Loss = 323.5802, Test Loss = 1064.2610
# Epoch 87: Train Loss = 323.6339, Test Loss = 1061.8734
# Epoch 88: Train Loss = 317.5670, Test Loss = 1050.1095
# Epoch 89: Train Loss = 316.6258, Test Loss = 1072.2337
# Epoch 90: Train Loss = 307.0800, Test Loss = 1087.5844
# Epoch 91: Train Loss = 306.7686, Test Loss = 1094.0662
# Epoch 92: Train Loss = 307.6276, Test Loss = 1062.0927
# Epoch 93: Train Loss = 297.5729, Test Loss = 1048.5270
# Epoch 94: Train Loss = 305.0135, Test Loss = 1046.4794
# Epoch 95: Train Loss = 294.0253, Test Loss = 1058.9551
# Epoch 96: Train Loss = 290.5520, Test Loss = 1090.0042
# Epoch 97: Train Loss = 290.9067, Test Loss = 1077.8990
# Epoch 98: Train Loss = 289.9882, Test Loss = 1121.2185
# Epoch 99: Train Loss = 291.9764, Test Loss = 1092.7159
# Epoch 100: Train Loss = 289.4313, Test Loss = 1062.8040
# Epoch 101: Train Loss = 284.4698, Test Loss = 1044.6462
# Epoch 102: Train Loss = 273.2928, Test Loss = 1042.9971
# Epoch 103: Train Loss = 280.4950, Test Loss = 1046.4283
# Epoch 104: Train Loss = 270.9769, Test Loss = 1039.0568
# Epoch 105: Train Loss = 260.3784, Test Loss = 1029.6082
# Epoch 106: Train Loss = 264.3507, Test Loss = 1124.5432
# Epoch 107: Train Loss = 269.5376, Test Loss = 1067.7317
# Epoch 108: Train Loss = 256.0916, Test Loss = 1081.4217
# Epoch 109: Train Loss = 261.8769, Test Loss = 1048.0000
# Epoch 110: Train Loss = 263.4290, Test Loss = 1069.5279
# Epoch 111: Train Loss = 253.6139, Test Loss = 1028.5755
# Epoch 112: Train Loss = 248.4209, Test Loss = 1049.7033
# Epoch 113: Train Loss = 253.8298, Test Loss = 1038.4222
# Epoch 114: Train Loss = 248.8279, Test Loss = 1060.2567
# Epoch 115: Train Loss = 254.2352, Test Loss = 1072.8934
# Epoch 116: Train Loss = 248.7907, Test Loss = 1072.4454
# Epoch 117: Train Loss = 257.0323, Test Loss = 1066.8935
# Epoch 118: Train Loss = 244.1716, Test Loss = 1032.9834
# Epoch 119: Train Loss = 253.0111, Test Loss = 1045.7122
# Epoch 120: Train Loss = 239.8300, Test Loss = 1028.3688
# Epoch 121: Train Loss = 231.6675, Test Loss = 1069.5647
# Epoch 122: Train Loss = 247.1858, Test Loss = 1054.9762
# Epoch 123: Train Loss = 240.4555, Test Loss = 1157.3760
# Epoch 124: Train Loss = 229.6733, Test Loss = 1157.4798
# Epoch 125: Train Loss = 228.1649, Test Loss = 1028.3184
# Epoch 126: Train Loss = 217.9801, Test Loss = 1025.3924
# Epoch 127: Train Loss = 224.6663, Test Loss = 1076.1621
# Epoch 128: Train Loss = 225.3314, Test Loss = 1045.4103
# Epoch 129: Train Loss = 216.9303, Test Loss = 1134.9012
# Epoch 130: Train Loss = 215.9571, Test Loss = 1051.1311
# Epoch 131: Train Loss = 224.2118, Test Loss = 1043.2114
# Epoch 132: Train Loss = 222.2830, Test Loss = 1028.8026
# Epoch 133: Train Loss = 221.7893, Test Loss = 1109.6655
# Epoch 134: Train Loss = 218.0768, Test Loss = 1054.0824
# Epoch 135: Train Loss = 206.9117, Test Loss = 1040.1971
# Epoch 136: Train Loss = 210.7272, Test Loss = 1035.6841
# ✅ Early stopping triggered for Alpha_band at epoch 136
#
# 🚀 Training CNN for Beta_band...
# Epoch 1: Train Loss = 9950.4394, Test Loss = 3743.0358
# Epoch 2: Train Loss = 2770.0845, Test Loss = 2374.6495
# Epoch 3: Train Loss = 2105.3215, Test Loss = 2738.3017
# Epoch 4: Train Loss = 1872.6648, Test Loss = 1916.6152
# Epoch 5: Train Loss = 1698.1140, Test Loss = 1977.8125
# Epoch 6: Train Loss = 1561.7395, Test Loss = 1579.9686
# Epoch 7: Train Loss = 1452.4013, Test Loss = 1534.3719
# Epoch 8: Train Loss = 1359.0299, Test Loss = 1417.9815
# Epoch 9: Train Loss = 1251.8761, Test Loss = 1356.4495
# Epoch 10: Train Loss = 1181.5681, Test Loss = 1271.0927
# Epoch 11: Train Loss = 1104.7834, Test Loss = 1284.3731
# Epoch 12: Train Loss = 1025.5903, Test Loss = 1193.4287
# Epoch 13: Train Loss = 947.1813, Test Loss = 1095.2755
# Epoch 14: Train Loss = 931.4021, Test Loss = 1040.7879
# Epoch 15: Train Loss = 833.7009, Test Loss = 1017.5156
# Epoch 16: Train Loss = 787.4993, Test Loss = 931.3037
# Epoch 17: Train Loss = 735.6012, Test Loss = 912.3924
# Epoch 18: Train Loss = 687.0917, Test Loss = 875.1244
# Epoch 19: Train Loss = 648.1547, Test Loss = 817.8896
# Epoch 20: Train Loss = 597.1079, Test Loss = 750.6558
# Epoch 21: Train Loss = 568.9023, Test Loss = 931.4145
# Epoch 22: Train Loss = 547.2348, Test Loss = 883.0131
# Epoch 23: Train Loss = 506.8181, Test Loss = 644.5450
# Epoch 24: Train Loss = 480.0751, Test Loss = 917.1484
# Epoch 25: Train Loss = 453.5305, Test Loss = 648.1782
# Epoch 26: Train Loss = 428.4010, Test Loss = 567.2011
# Epoch 27: Train Loss = 397.3066, Test Loss = 569.8346
# Epoch 28: Train Loss = 385.8329, Test Loss = 547.1787
# Epoch 29: Train Loss = 364.9779, Test Loss = 505.0772
# Epoch 78: Train Loss = 84.7679, Test Loss = 204.0347
# Epoch 79: Train Loss = 84.0521, Test Loss = 201.0387
# Epoch 80: Train Loss = 78.6369, Test Loss = 217.1947
# Epoch 81: Train Loss = 86.7391, Test Loss = 200.0877
# Epoch 82: Train Loss = 81.9780, Test Loss = 212.6456
# Epoch 83: Train Loss = 79.7021, Test Loss = 216.4579
# Epoch 84: Train Loss = 81.5225, Test Loss = 221.3919
# Epoch 85: Train Loss = 77.5204, Test Loss = 273.4606
# Epoch 86: Train Loss = 93.8742, Test Loss = 196.8425
# Epoch 87: Train Loss = 73.3858, Test Loss = 200.6016
# Epoch 88: Train Loss = 71.8810, Test Loss = 196.3125
# Epoch 89: Train Loss = 72.4228, Test Loss = 190.8703
# Epoch 90: Train Loss = 70.6366, Test Loss = 189.4197
# Epoch 91: Train Loss = 70.0285, Test Loss = 203.4037
# Epoch 92: Train Loss = 73.4911, Test Loss = 243.5199
# Epoch 93: Train Loss = 72.1348, Test Loss = 179.2673
# Epoch 94: Train Loss = 69.0083, Test Loss = 254.0368
# Epoch 95: Train Loss = 75.6430, Test Loss = 191.5824
# Epoch 96: Train Loss = 74.1260, Test Loss = 178.5198
# Epoch 97: Train Loss = 72.2756, Test Loss = 191.1720
# Epoch 98: Train Loss = 60.4406, Test Loss = 170.0111
# Epoch 99: Train Loss = 65.4684, Test Loss = 189.2710
# Epoch 100: Train Loss = 67.9193, Test Loss = 226.4794
# Epoch 101: Train Loss = 63.1823, Test Loss = 166.9102
# Epoch 102: Train Loss = 63.8165, Test Loss = 178.7439
# Epoch 103: Train Loss = 67.0088, Test Loss = 188.4821
# Epoch 104: Train Loss = 62.1243, Test Loss = 170.2307
# Epoch 105: Train Loss = 64.7855, Test Loss = 187.9047
# Epoch 106: Train Loss = 61.7207, Test Loss = 180.7574
# Epoch 107: Train Loss = 60.7178, Test Loss = 177.0070
# Epoch 108: Train Loss = 64.8543, Test Loss = 167.2625
# Epoch 109: Train Loss = 57.0953, Test Loss = 170.0552
# Epoch 110: Train Loss = 55.9436, Test Loss = 167.0866
# Epoch 111: Train Loss = 56.7328, Test Loss = 172.8131
# ✅ Early stopping triggered for Beta_band at epoch 111
#
# 🚀 Training CNN for Gamma_band...
# Epoch 1: Train Loss = 1502.6414, Test Loss = 379.4561
# Epoch 2: Train Loss = 303.6662, Test Loss = 284.7733
# Epoch 3: Train Loss = 265.9970, Test Loss = 280.0240
# Epoch 4: Train Loss = 239.2392, Test Loss = 264.9296
# Epoch 5: Train Loss = 215.5679, Test Loss = 236.0974
# Epoch 6: Train Loss = 196.9547, Test Loss = 200.5664
# Epoch 7: Train Loss = 176.0122, Test Loss = 184.6309
# Epoch 8: Train Loss = 158.9689, Test Loss = 184.7533
# Epoch 9: Train Loss = 144.4646, Test Loss = 181.9719
# Epoch 10: Train Loss = 128.5365, Test Loss = 167.9277
# Epoch 11: Train Loss = 116.0879, Test Loss = 140.8374
# Epoch 12: Train Loss = 104.4041, Test Loss = 120.5429
# Epoch 13: Train Loss = 95.4477, Test Loss = 156.2959
# Epoch 14: Train Loss = 86.0635, Test Loss = 116.6107
# Epoch 15: Train Loss = 77.2571, Test Loss = 96.1147
# Epoch 16: Train Loss = 71.1824, Test Loss = 91.1012
# Epoch 17: Train Loss = 65.4257, Test Loss = 84.6162
# Epoch 18: Train Loss = 61.5815, Test Loss = 83.3474
# Epoch 19: Train Loss = 57.9166, Test Loss = 74.8240
# Epoch 20: Train Loss = 50.3904, Test Loss = 75.1147
# Epoch 21: Train Loss = 48.1468, Test Loss = 66.6196
# Epoch 22: Train Loss = 46.5770, Test Loss = 69.5259
# Epoch 23: Train Loss = 44.7261, Test Loss = 61.0583
# Epoch 24: Train Loss = 39.0242, Test Loss = 59.4620
# Epoch 25: Train Loss = 37.3420, Test Loss = 56.7465
# Epoch 26: Train Loss = 32.9616, Test Loss = 77.2731
# Epoch 27: Train Loss = 35.0532, Test Loss = 63.3424
# Epoch 28: Train Loss = 31.7845, Test Loss = 50.2454
# Epoch 29: Train Loss = 30.2259, Test Loss = 47.8291
# Epoch 30: Train Loss = 27.3418, Test Loss = 53.0568
# Epoch 31: Train Loss = 27.6047, Test Loss = 47.1614
# Epoch 32: Train Loss = 25.1982, Test Loss = 46.5140
# Epoch 33: Train Loss = 24.8630, Test Loss = 48.2589
# Epoch 34: Train Loss = 23.7527, Test Loss = 48.7009
# Epoch 35: Train Loss = 24.1557, Test Loss = 43.7361
# Epoch 36: Train Loss = 21.1460, Test Loss = 39.1181
# Epoch 37: Train Loss = 20.8389, Test Loss = 39.4874
# Epoch 38: Train Loss = 19.3787, Test Loss = 42.1797
# Epoch 39: Train Loss = 19.3535, Test Loss = 35.5798
# Epoch 40: Train Loss = 20.0689, Test Loss = 38.3300
# Epoch 41: Train Loss = 18.6482, Test Loss = 35.2633
# Epoch 42: Train Loss = 18.0681, Test Loss = 44.7449
# Epoch 43: Train Loss = 18.8981, Test Loss = 42.2708
# Epoch 44: Train Loss = 17.4873, Test Loss = 39.2414
# Epoch 45: Train Loss = 14.7619, Test Loss = 32.4176
# Epoch 46: Train Loss = 16.0552, Test Loss = 33.0435
# Epoch 47: Train Loss = 17.0936, Test Loss = 37.5494
# Epoch 48: Train Loss = 14.3754, Test Loss = 30.0966
# Epoch 49: Train Loss = 14.2903, Test Loss = 32.4779
# Epoch 50: Train Loss = 12.9691, Test Loss = 31.2785
# Epoch 51: Train Loss = 14.2913, Test Loss = 31.1869
# Epoch 52: Train Loss = 13.2464, Test Loss = 33.5543
# Epoch 53: Train Loss = 13.9302, Test Loss = 40.3905
# Epoch 54: Train Loss = 14.3782, Test Loss = 28.6619
# Epoch 55: Train Loss = 12.2439, Test Loss = 30.4638
# Epoch 56: Train Loss = 13.0852, Test Loss = 27.4531
# Epoch 57: Train Loss = 12.1532, Test Loss = 32.4708
# Epoch 58: Train Loss = 11.9837, Test Loss = 29.5524
# Epoch 59: Train Loss = 10.8905, Test Loss = 26.1403
# Epoch 60: Train Loss = 12.1050, Test Loss = 26.6890
# Epoch 61: Train Loss = 12.1092, Test Loss = 28.3323
# Epoch 62: Train Loss = 10.8098, Test Loss = 25.5317
# Epoch 63: Train Loss = 11.9105, Test Loss = 28.8655
# Epoch 64: Train Loss = 10.4954, Test Loss = 27.5933
# Epoch 65: Train Loss = 10.3341, Test Loss = 25.0423
# Epoch 66: Train Loss = 11.1031, Test Loss = 26.1131
# Epoch 67: Train Loss = 10.1515, Test Loss = 24.8472
# Epoch 68: Train Loss = 10.6387, Test Loss = 23.4996
# Epoch 69: Train Loss = 8.6407, Test Loss = 24.2363
# Epoch 70: Train Loss = 9.9779, Test Loss = 24.0373
# Epoch 71: Train Loss = 9.7335, Test Loss = 24.3107
# Epoch 72: Train Loss = 10.1263, Test Loss = 23.5973
# Epoch 73: Train Loss = 8.8945, Test Loss = 23.4855
# Epoch 74: Train Loss = 9.8571, Test Loss = 23.5326
# Epoch 75: Train Loss = 9.3819, Test Loss = 21.9972
# Epoch 76: Train Loss = 8.9353, Test Loss = 23.5619
# Epoch 77: Train Loss = 10.3845, Test Loss = 24.5349
# Epoch 78: Train Loss = 8.6199, Test Loss = 24.3074
# Epoch 79: Train Loss = 9.1574, Test Loss = 24.7501
# Epoch 80: Train Loss = 9.0035, Test Loss = 22.2319
# Epoch 81: Train Loss = 8.9658, Test Loss = 24.0418
# Epoch 82: Train Loss = 9.5554, Test Loss = 23.1012
# Epoch 83: Train Loss = 8.9741, Test Loss = 24.0977
# Epoch 84: Train Loss = 8.3913, Test Loss = 25.7160
# Epoch 85: Train Loss = 8.9045, Test Loss = 22.8463
# ✅ Early stopping triggered for Gamma_band at epoch 85
#
# 🚀 Training CNN for High_Frequencies_band...
# Epoch 1: Train Loss = 1985.8077, Test Loss = 919.4538
# Epoch 2: Train Loss = 618.8911, Test Loss = 436.6164
# Epoch 3: Train Loss = 328.5303, Test Loss = 301.0472
# Epoch 4: Train Loss = 220.5721, Test Loss = 208.2124
# Epoch 5: Train Loss = 163.3004, Test Loss = 165.8211
# Epoch 6: Train Loss = 126.7018, Test Loss = 135.8403
# Epoch 7: Train Loss = 100.9595, Test Loss = 112.1775
# Epoch 8: Train Loss = 81.8939, Test Loss = 106.8798
# Epoch 9: Train Loss = 68.7974, Test Loss = 103.0582
# Epoch 10: Train Loss = 59.5426, Test Loss = 92.1974
# Epoch 11: Train Loss = 50.3486, Test Loss = 66.2758
# Epoch 12: Train Loss = 43.0946, Test Loss = 57.3245
# Epoch 13: Train Loss = 38.3678, Test Loss = 51.2703
# Epoch 14: Train Loss = 32.5285, Test Loss = 46.9368
# Epoch 15: Train Loss = 30.5210, Test Loss = 42.6159
# Epoch 16: Train Loss = 27.3600, Test Loss = 57.9108
# Epoch 17: Train Loss = 25.5477, Test Loss = 55.1739
# Epoch 18: Train Loss = 22.8661, Test Loss = 38.6622
# Epoch 19: Train Loss = 20.4786, Test Loss = 34.6716
# Epoch 20: Train Loss = 19.3980, Test Loss = 30.0926
# Epoch 21: Train Loss = 20.4370, Test Loss = 30.3563
# Epoch 22: Train Loss = 17.3683, Test Loss = 27.2008
# Epoch 23: Train Loss = 16.1159, Test Loss = 29.2623
# Epoch 24: Train Loss = 15.9609, Test Loss = 25.6125
# Epoch 25: Train Loss = 13.7738, Test Loss = 23.4644
# Epoch 26: Train Loss = 14.2630, Test Loss = 25.3274
# Epoch 27: Train Loss = 13.3890, Test Loss = 24.7522
# Epoch 28: Train Loss = 12.4545, Test Loss = 21.7440
# Epoch 29: Train Loss = 11.5088, Test Loss = 34.5046
# Epoch 30: Train Loss = 12.4448, Test Loss = 21.0043
# Epoch 31: Train Loss = 11.0021, Test Loss = 19.0442
# Epoch 32: Train Loss = 10.8417, Test Loss = 19.4136
# Epoch 33: Train Loss = 10.3209, Test Loss = 24.1175
# Epoch 34: Train Loss = 10.6959, Test Loss = 19.2301
# Epoch 35: Train Loss = 9.9307, Test Loss = 17.8189
# Epoch 36: Train Loss = 9.5742, Test Loss = 19.6351
# Epoch 37: Train Loss = 8.5529, Test Loss = 17.1902
# Epoch 38: Train Loss = 8.7431, Test Loss = 15.5559
# Epoch 39: Train Loss = 9.0334, Test Loss = 16.5255
# Epoch 40: Train Loss = 9.5945, Test Loss = 19.1704
# Epoch 41: Train Loss = 8.3730, Test Loss = 15.9660
# Epoch 42: Train Loss = 8.0632, Test Loss = 15.2035
# Epoch 43: Train Loss = 9.0672, Test Loss = 14.9994
# Epoch 44: Train Loss = 7.5711, Test Loss = 15.9846
# Epoch 45: Train Loss = 7.8450, Test Loss = 17.7893
# Epoch 46: Train Loss = 7.7603, Test Loss = 14.4021
# Epoch 47: Train Loss = 6.9265, Test Loss = 13.5737
# Epoch 48: Train Loss = 7.4466, Test Loss = 16.3986
# Epoch 49: Train Loss = 9.0271, Test Loss = 16.6379
# Epoch 50: Train Loss = 8.1136, Test Loss = 13.2480
# Epoch 51: Train Loss = 6.4712, Test Loss = 13.3114
# Epoch 52: Train Loss = 6.0450, Test Loss = 12.4225
# Epoch 53: Train Loss = 6.7305, Test Loss = 15.8488
# Epoch 54: Train Loss = 6.8824, Test Loss = 16.9541
# Epoch 55: Train Loss = 6.7677, Test Loss = 20.5518
# Epoch 56: Train Loss = 6.7866, Test Loss = 12.7257
# Epoch 57: Train Loss = 5.7545, Test Loss = 13.8334
# Epoch 58: Train Loss = 5.9075, Test Loss = 11.1186
# Epoch 59: Train Loss = 6.1068, Test Loss = 17.6993
# Epoch 60: Train Loss = 6.8461, Test Loss = 11.1571
# Epoch 61: Train Loss = 5.4592, Test Loss = 12.6054
# Epoch 62: Train Loss = 5.3766, Test Loss = 11.3647
# Epoch 63: Train Loss = 6.5577, Test Loss = 13.9031
# Epoch 64: Train Loss = 5.6524, Test Loss = 10.7141
# Epoch 65: Train Loss = 5.5753, Test Loss = 11.6688
# Epoch 66: Train Loss = 4.8355, Test Loss = 10.7830
# Epoch 67: Train Loss = 4.9879, Test Loss = 11.9677
# Epoch 68: Train Loss = 5.4132, Test Loss = 22.0943
# Epoch 69: Train Loss = 5.5372, Test Loss = 13.2366
# Epoch 70: Train Loss = 5.2066, Test Loss = 10.4643
# Epoch 71: Train Loss = 4.9418, Test Loss = 10.9569
# Epoch 72: Train Loss = 4.8382, Test Loss = 9.9563
# Epoch 73: Train Loss = 5.5092, Test Loss = 11.1896
# Epoch 74: Train Loss = 5.5031, Test Loss = 11.7236
# Epoch 75: Train Loss = 5.0845, Test Loss = 10.4899
# Epoch 76: Train Loss = 5.4326, Test Loss = 11.5690
# Epoch 77: Train Loss = 5.7876, Test Loss = 10.9846
# Epoch 78: Train Loss = 4.9240, Test Loss = 8.9709
# Epoch 79: Train Loss = 4.5334, Test Loss = 9.5698
# Epoch 80: Train Loss = 4.6347, Test Loss = 17.2371
# Epoch 81: Train Loss = 5.7295, Test Loss = 10.6339
# Epoch 82: Train Loss = 5.2729, Test Loss = 12.3026
# Epoch 83: Train Loss = 4.8245, Test Loss = 9.3763
# Epoch 84: Train Loss = 4.5076, Test Loss = 13.0842
# Epoch 85: Train Loss = 4.8424, Test Loss = 9.2855
# Epoch 86: Train Loss = 4.6283, Test Loss = 9.4622
# Epoch 87: Train Loss = 4.6736, Test Loss = 12.1293
# Epoch 88: Train Loss = 4.4592, Test Loss = 9.6784
# ✅ Early stopping triggered for High_Frequencies_band at epoch 88
#
# ✅ All EEG bands successfully trained!

# %%
# Reconstruct full EEG signals from denoised frequency bands
denoised_eeg = np.sum(denoised_bands, axis=0)  # Sum across frequency bands
clean_eeg = np.sum(clean_bands, axis=0)

# Ensure both arrays have the same shape
clean_eeg = clean_eeg.squeeze(1)  # Remove extra dimension if it exists

print(f"✅ Fixed EEG Reconstruction: Denoised EEG Shape: {denoised_eeg.shape}, Clean EEG Shape: {clean_eeg.shape}")
# Out:
# ✅ Fixed EEG Reconstruction: Denoised EEG Shape: (6800, 512), Clean EEG Shape: (6800, 512)

# %%
import numpy as np
from scipy.signal import welch

# Compute RRMSE in time domain
def compute_rrmse_t(clean, denoised):
    per_sample_rrmse = np.sqrt(np.sum((clean - denoised) ** 2, axis=1) / np.sum(clean ** 2, axis=1))
    return np.mean(per_sample_rrmse)

# Compute RRMSE in frequency domain using Power Spectral Density (PSD)
def compute_rrmse_s(clean, denoised, fs=512):
    f_clean, psd_clean = welch(clean.flatten(), fs=fs, nperseg=512)
    f_denoised, psd_denoised = welch(denoised.flatten(), fs=fs, nperseg=512)
    return np.sqrt(np.sum((psd_clean - psd_denoised) ** 2) / np.sum(psd_clean ** 2))

# Compute Correlation Coefficient (CC)
def compute_cc(clean, denoised):
    return np.corrcoef(clean.flatten(), denoised.flatten())[0, 1]

print("✅ Evaluation functions loaded!")
# Out:
# ✅ Evaluation functions loaded!

# %%
import pandas as pd

# Store evaluation results per SNR level
snr_metrics = {}

# Ensure snr_labels_test is a NumPy array
snr_labels_test = np.array(snr_labels_test).flatten()

# Evaluate each SNR level separately
for snr in np.unique(snr_labels_test):
    indices = np.where(snr_labels_test == snr)[0]  # Get test samples for this SNR

    clean_snr = clean_eeg[indices]
    denoised_snr = denoised_eeg[indices]

    # Compute evaluation metrics
    rrmse_t = compute_rrmse_t(clean_snr, denoised_snr)
    rrmse_s = compute_rrmse_s(clean_snr, denoised_snr, fs=512)
    cc = compute_cc(clean_snr, denoised_snr)
    ts_metric = 10 * np.log10(1 / (rrmse_t + rrmse_s))

    # Store metrics per SNR
    snr_metrics[snr] = {"RRMSE-T": rrmse_t, "RRMSE-S": rrmse_s, "CC": cc, "T&S Metric (dB)": ts_metric}

    print(f"  ✅ SNR {snr}: RRMSE-T = {rrmse_t:.4f}, RRMSE-S = {rrmse_s:.4f}, CC = {cc:.4f}, T&S Metric = {ts_metric:.4f} dB")

# Convert results to DataFrame for better visualization
df_snr_metrics = pd.DataFrame.from_dict(snr_metrics, orient="index")
df_snr_metrics.index.name = "SNR Level"

# Display results
# Out:
#   ✅ SNR -7: RRMSE-T = 0.5858, RRMSE-S = 0.1024, CC = 0.8386, T&S Metric = 1.6230 dB
#   ✅ SNR -6: RRMSE-T = 0.4309, RRMSE-S = 0.1832, CC = 0.9146, T&S Metric = 2.1180 dB
#   ✅ SNR -5: RRMSE-T = 0.4326, RRMSE-S = 0.2345, CC = 0.9149, T&S Metric = 1.7583 dB
#   ✅ SNR -4: RRMSE-T = 0.4257, RRMSE-S = 0.2696, CC = 0.9129, T&S Metric = 1.5781 dB
#   ✅ SNR -3: RRMSE-T = 0.4164, RRMSE-S = 0.2846, CC = 0.9159, T&S Metric = 1.5422 dB
#   ✅ SNR -2: RRMSE-T = 0.4166, RRMSE-S = 0.3309, CC = 0.9123, T&S Metric = 1.2635 dB
#   ✅ SNR -1: RRMSE-T = 0.3992, RRMSE-S = 0.3453, CC = 0.9189, T&S Metric = 1.2816 dB
#   ✅ SNR 0: RRMSE-T = 0.3816, RRMSE-S = 0.3247, CC = 0.9259, T&S Metric = 1.5099 dB
#   ✅ SNR 1: RRMSE-T = 0.3683, RRMSE-S = 0.3324, CC = 0.9286, T&S Metric = 1.5446 dB
#   ✅ SNR 2: RRMSE-T = 0.3844, RRMSE-S = 0.3783, CC = 0.9230, T&S Metric = 1.1765 dB

# %%
# Compute the average of all SNR-based metrics
avg_rrmse_t = np.mean([metrics["RRMSE-T"] for metrics in snr_metrics.values()])
avg_rrmse_s = np.mean([metrics["RRMSE-S"] for metrics in snr_metrics.values()])
avg_cc = np.mean([metrics["CC"] for metrics in snr_metrics.values()])
avg_ts_metric = np.mean([metrics["T&S Metric (dB)"] for metrics in snr_metrics.values()])

# Print the final summary
print("\n==== Final Evaluation Summary ====")
print(f"✅ Average RRMSE-T: {avg_rrmse_t:.4f}")
print(f"✅ Average RRMSE-S: {avg_rrmse_s:.4f}")
print(f"✅ Average CC: {avg_cc:.4f}")
print(f"✅ Average T&S Metric (dB): {avg_ts_metric:.4f}")

# Create DataFrame for display
# Out:
# ==== Final Evaluation Summary ====
# ✅ Average RRMSE-T: 0.4242
# ✅ Average RRMSE-S: 0.2786
# ✅ Average CC: 0.9106
# ✅ Average T&S Metric (dB): 1.5396

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ensure required variables are loaded
try:
    print(f"✅ SNR Labels Shape: {snr_labels_test.shape}, Clean EEG Shape: {clean_eeg.shape}, Denoised EEG Shape: {denoised_eeg.shape}")
except NameError:
    print("❌ Variables are not defined. Re-run the data preparation and evaluation cells.")

# ✅ Convert SNR labels to integers safely
try:
    snr_labels_test_int = np.array([int(str(snr).replace("SNR_", "")) for snr in snr_labels_test])
    print(f"✅ Converted SNR Labels: {snr_labels_test_int[:10]} ...")  # Show first 10 for debugging
except Exception as e:
    print(f"❌ Error converting SNR labels: {e}")

# Set SNR level to check
snr_level = -5  

# ✅ Extract indices of test samples for the selected SNR level
snr_indices = np.where(snr_labels_test_int == snr_level)[0]

# ✅ Handle missing SNR level
if len(snr_indices) == 0:
    print(f"❌ No test samples found for SNR Level {snr_level}.")
else:
    print(f"\n📊 Found {len(snr_indices)} test samples for SNR Level {snr_level}")
    print(f"✅ SNR Level {snr_level} indices in test set: {snr_indices.tolist()}")

    # ✅ Select the first segment
    first_segment_idx = snr_indices[0]

    # ✅ Extract EEG segments
    clean_segment = clean_eeg[first_segment_idx]
    denoised_segment = denoised_eeg[first_segment_idx]

    # ✅ Reconstruct Contaminated EEG by summing all frequency bands
    contaminated_bands = [test_data[band][1] for band in bands]
    contaminated_eeg = np.sum(contaminated_bands, axis=0)
    contaminated_segment = contaminated_eeg[first_segment_idx]

    # ✅ Plot EEG signals
    plt.figure(figsize=(12, 5))
    plt.plot(clean_segment, label="Clean EEG", linestyle="dashed", color="blue", linewidth=1.5)
    plt.plot(denoised_segment, label="Denoised EEG", linestyle="solid", color="red", linewidth=1.5)
    plt.plot(contaminated_segment, label="Contaminated EEG", linestyle="dotted", color="green", linewidth=1.5)
    
    plt.title(f"EEG Signal Comparison (SNR Level {snr_level}, First Segment)")
    plt.xlabel("Time (Samples)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# ✅ SNR Labels Shape: (6800,), Clean EEG Shape: (6800, 512), Denoised EEG Shape: (6800, 512)
# ✅ Converted SNR Labels: [-7 -7 -2 -4  2  1  2 -2 -2 -4] ...
#
# 📊 Found 680 test samples for SNR Level -5
# ✅ SNR Level -5 indices in test set: [26, 29, 51, 61, 79, 82, 89, 91, 94, 95, 108, 115, 120, 129, 136, 159, 161, 167, 186, 188, 194, 212, 220, 225, 235, 240, 248, 279, 284, 315, 318, 325, 331, 333, 336, 345, 354, 369, 371, 372, 379, 381, 386, 406, 408, 416, 419, 421, 433, 439, 453, 460, 484, 488, 490, 506, 508, 512, 549, 574, 598, 605, 620, 632, 635, 691, 695, 696, 713, 724, 726, 734, 738, 749, 750, 752, 753, 756, 767, 775, 783, 793, 800, 801, 817, 818, 831, 840, 858, 865, 882, 883, 902, 914, 936, 940, 960, 965, 969, 977, 978, 979, 981, 982, 1004, 1009, 1019, 1020, 
4798, 4805, 4811, 4837, 4846, 4854, 4856, 4878, 4905, 4910, 4933, 4940, 4942, 4961, 4971, 4996, 4999, 5018, 5024, 5027, 5052, 5057, 5073, 5087, 5105, 5110, 5114, 5147, 5152, 5164, 5169, 5176, 5187, 5191, 5214, 5225, 5227, 5230, 5232, 5236, 5243, 5271, 5293, 5302, 5304, 5307, 5312, 5316, 5331, 5336, 5347, 5351, 5371, 5378, 5380, 5402, 5415, 5436, 5445, 5446, 5448, 5455, 5465, 5485, 5500, 5502, 5512, 5523, 5526, 5528, 5529, 5533, 5535, 5539, 5545, 5554, 5559, 5562, 5564, 5578, 5579, 5582, 5615, 5621, 5624, 5626, 5627, 5658, 5662, 5672, 5683, 5707, 5727, 5730, 5739, 5762, 5767, 5768, 5780, 5791, 5812, 5814, 5821, 5844, 5868, 5872, 5890, 5902, 5913, 5928, 5931, 5933, 5942, 5953, 5966, 5969, 5973, 5977, 5978, 6011, 6016, 6021, 6037, 6038, 6045, 6048, 6055, 6058, 6061, 6067, 6069, 6072, 6098, 6112, 6116, 6127, 6154, 6179, 6207, 6208, 6219, 6223, 6229, 6250, 6254, 6269, 6277, 6283, 6303, 6308, 6310, 6312, 6338, 6355, 6376, 6380, 6385, 6393, 6398, 6413, 6435, 6446, 6448, 6462, 6469, 6470, 6475, 6506, 6512, 6522, 6526, 6533, 6537, 6540, 6553, 6588, 6594, 6600, 6608, 6618, 6619, 6627, 6632, 6655, 6671, 6683, 6703, 6709, 6713, 6715, 6729, 6790, 679 ...

# %%
# ✅ Get denoised EEG plotting points
x_points = list(range(len(denoised_segment)))      # X-axis: time/sample index
y_points = denoised_segment.tolist()               # Y-axis: denoised EEG values

# ✅ Print the plotting points
print("Denoised EEG Plotting Points:")
for x, y in zip(x_points, y_points):
    print(f"({x}, {y})")
# Out:
# Denoised EEG Plotting Points:
# (0, 802.7042236328125)
# (1, 1011.547119140625)
# (2, 662.06103515625)
# (3, 791.9271240234375)
# (4, 796.7257080078125)
# (5, 516.5006103515625)
# (6, 65.81320190429688)
# (7, -363.40008544921875)
# (8, -755.2138671875)
# (9, -820.282958984375)
# (10, -724.9365234375)
# (11, -875.201416015625)
# (12, -1030.278076171875)
# (13, -816.7106323242188)
# (14, -549.7471313476562)
# (15, -509.9530334472656)
# (16, -411.3746337890625)
# (17, -149.66400146484375)
# (18, 33.696651458740234)
# (19, 138.6459197998047)
# (20, 301.91845703125)
# (21, 451.80596923828125)
# (22, 455.66986083984375)
# (23, 378.64373779296875)
# (24, 415.03179931640625)
# (25, 609.209228515625)
# (26, 763.4298095703125)
# (27, 791.29736328125)
# (28, 860.41162109375)
# (29, 953.8699951171875)
# (30, 863.9053955078125)
# (31, 655.232177734375)
# (32, 464.23223876953125)
# (33, 162.6617431640625)
# (34, -207.6740264892578)
# (35, -393.37359619140625)
# (36, -432.08203125)
# (37, -508.8241882324219)
# (38, -576.8667602539062)
# (39, -605.3140869140625)
# (40, -656.0989990234375)
# (41, -581.8619995117188)
# (478, -238.47665405273438)
# (479, -369.54583740234375)
# (480, -174.21621704101562)
# (481, 148.76461791992188)
# (482, 166.1417694091797)
# (483, -13.330001831054688)
# (484, -49.53343200683594)
# (485, 30.438278198242188)
# (486, 118.8951416015625)
# (487, 274.3802795410156)
# (488, 389.44281005859375)
# (489, 243.5746612548828)
# (490, -37.61811828613281)
# (491, -105.89674377441406)
# (492, 85.11454772949219)
# (493, 237.0963134765625)
# (494, 171.54750061035156)
# (495, 6.027660369873047)
# (496, -123.6619873046875)
# (497, -249.04071044921875)
# (498, -368.08013916015625)
# (499, -395.773681640625)
# (500, -348.9560546875)
# (501, -267.3226318359375)
# (502, -125.5052719116211)
# (503, -29.675445556640625)
# (504, -149.96920776367188)
# (505, -312.3216857910156)
# (506, -224.13046264648438)
# (507, 10.103042602539062)
# (508, 37.76161193847656)
# (509, -137.54641723632812)
# (510, -251.46322631835938)
# (511, -39.548606872558594)

# %%
x_points = list(range(len(clean_segment)))      # X-axis: time/sample index
y_points = clean_segment.tolist()               # Y-axis: denoised EEG values

# ✅ Print the plotting points
print("Clean EEG Plotting Points:")
for x, y in zip(x_points, y_points):
    print(f"({x}, {y})")
# Out:
# Clean EEG Plotting Points:
# (0, 866.0310668945312)
# (1, 1079.484130859375)
# (2, 731.6409301757812)
# (3, 862.6738891601562)
# (4, 866.7140502929688)
# (5, 588.8504028320312)
# (6, 136.66143798828125)
# (7, -298.35662841796875)
# (8, -691.608642578125)
# (9, -754.778564453125)
# (10, -658.8089599609375)
# (11, -812.54345703125)
# (12, -974.6163940429688)
# (13, -764.3228759765625)
# (14, -497.63824462890625)
# (15, -456.69189453125)
# (16, -364.16766357421875)
# (17, -113.02513885498047)
# (18, 65.3680419921875)
# (19, 168.07069396972656)
# (20, 334.055419921875)
# (21, 487.0714416503906)
# (22, 495.9732360839844)
# (23, 423.62994384765625)
# (24, 460.7734375)
# (25, 654.1538696289062)
# (26, 806.8607788085938)
# (27, 831.9862670898438)
# (28, 895.39453125)
# (29, 980.781494140625)
# (30, 880.4319458007812)
# (31, 661.5908203125)
# (32, 461.5799255371094)
# (33, 154.7933349609375)
# (34, -231.58509826660156)
# (35, -433.34747314453125)
# (36, -481.13232421875)
# (37, -568.77734375)
# (38, -649.6075439453125)
# (39, -692.3427124023438)
# (40, -753.9926147460938)
# (41, -698.4561157226562)
# (42, -490.4478454589844)
# (43, -383.2445068359375)
# (44, -392.09423828125)
# (45, -278.7664794921875)
# (46, -100.5549087524414)
# (47, -23.42145538330078)
# (48, 72.37389373779297)
# (49, 235.53944396972656)
# (50, 224.925537109375)
# (51, -45.98872756958008)
# (52, -330.09686279296875)
# (53, -397.9757080078125)
# (54, -295.2097473144531)
# (55, -220.90126037597656)
# (56, -226.46929931640625)
# (57, -166.5471649169922)
# (58, -2.453725814819336)
# (59, 114.52298736572266)
# (60, 99.5409927368164)
# (61, -6.904523849487305)
# (62, -154.30517578125)
# (63, -281.9281921386719)
# (64, -379.5749206542969)
# (502, -190.4237518310547)
# (503, -95.10098266601562)
# (504, -216.89468383789062)
# (505, -379.2828369140625)
# (506, -289.0442810058594)
# (507, -53.72577667236328)
# (508, -22.9844970703125)
# (509, -188.67318725585938)
# (510, -297.11944580078125)
# (511, -92.98805236816406)

# %%
x_points = list(range(len(contaminated_segment)))      # X-axis: time/sample index
y_points = contaminated_segment.tolist()               # Y-axis: denoised EEG values

# ✅ Print the plotting points
print("Contaminated EEG Plotting Points:")
for x, y in zip(x_points, y_points):
    print(f"({x}, {y})")
# Out:
# Contaminated EEG Plotting Points:
# (0, 376.670188874805)
# (1, 410.31622600132704)
# (2, 119.4818911706754)
# (3, 202.17293545674943)
# (4, 253.06094761795939)
# (5, -19.556200305179345)
# (6, -519.0416695847294)
# (7, -1072.26102148189)
# (8, -1563.3573516376002)
# (9, -1720.370246559627)
# (10, -1754.3104653123644)
# (11, -2044.2768354031512)
# (12, -2292.7991845970987)
# (13, -2153.3006883563967)
# (14, -1990.357068452549)
# (15, -2054.757611000761)
# (16, -2052.7999659713437)
# (17, -1899.8263864513358)
# (18, -1804.9579912754734)
# (19, -1744.0127658459255)
# (20, -1612.0471579180064)
# (21, -1483.8930380379852)
# (22, -1454.6955047335553)
# (23, -1495.5388256765377)
# (24, -1459.8545807142682)
# (25, -1257.99884390659)
# (26, -1062.7707225912332)
# (27, -997.2508394588374)
# (28, -905.0569734139556)
# (29, -792.9648937103793)
# (30, -877.3091708660412)
# (31, -1061.21305944176)
# (32, -1198.041345787528)
# (33, -1474.9292753738396)
# (34, -1865.5084582648096)
# (35, -2031.8206293368537)
# (36, -2041.342462665656)
# (37, -2153.8978052719876)
# (38, -2240.453466089191)
# (39, -2211.6102162426064)
# (40, -2238.0867856799655)
# (41, -2213.3278987060985)
# (42, -1981.5905021275762)
# (43, -1807.613769384467)
# (44, -1825.3411870864306)
# (45, -1724.2478871124126)
# (46, -1433.237063444389)
# (47, -1227.660254078382)
# (48, -1141.0555771771608)
# (49, -1026.6938916853803)
# (50, -1001.1275885478306)
# (51, -1236.3809919697028)
# (52, -1546.6883214932727)
# (53, -1580.9254558098069)
# (54, -1367.5004411987707)
# (55, -1259.1233913554747)
# (56, -1307.6283687198911)
# (57, -1213.4502262122876)
# (58, -973.8450660105599)
# (59, -880.829651703666)
# (60, -943.3167602674197)
# (61, -976.2551302148855)
# (62, -1020.8747425885128)
# (63, -1154.1656646674746)
# (64, -1285.4193819005952)
# (65, -1340.9315800832278)
# (66, -1323.5977432241357)
# (67, -1235.861368518458)
# (68, -1105.4982416942576)
# (69, -931.219255620638)
# (70, -748.0226931840128)
# (71, -726.5878232867776)
# (72, -883.8817198797661)
# (73, -940.7204042834906)
# (74, -815.8647118204963)
# (75, -754.0694326701633)
# (76, -842.4858832096036)
# (77, -932.5204635066038)
# (78, -956.726002930571)
# (79, -945.8231449802774)
# (80, -960.6546456346556)
# (81, -1027.555701789241)
# (82, -1068.9462423652203)
# (83, -1104.170315313438)
# (84, -1269.3527795114005)
# (298, 401.19563691934957)
# (299, 566.0694569077015)
# (300, 730.7371403564962)
# (301, 718.7493791565242)
# (302, 684.4220991024106)
# (303, 777.2258159298505)
# (304, 845.6713957078198)
# (305, 763.4978760622735)
# (306, 660.0137382264058)
# (307, 645.3184237162595)
# (308, 612.9593899405122)
# (309, 482.0225335549035)
# (310, 370.6119319920168)
# (311, 406.048043024694)
# (312, 526.9552463125557)
# (313, 611.5088235277017)
# (314, 635.6395438217039)
# (315, 626.6866416761645)
# (316, 596.7104454614332)
# (317, 579.9430472951352)
# (318, 573.6806392171696)
# (319, 497.50400211428644)
# (320, 327.90053012253406)
# (321, 175.29871479524422)
# (322, 135.00739540297755)
# (323, 224.80005269418714)
# (324, 420.2530757931537)
# (325, 612.0248101479774)
# (326, 655.9790654230343)
# (327, 591.5335829571723)
# (328, 580.8872011397925)
# (329, 638.0804314983677)
# (330, 648.9222483970399)
# (331, 589.8815170802457)
# (332, 512.656082251231)
# (333, 467.94513785892275)
# (334, 500.26957837067084)
# (335, 585.6132706355648)
# (336, 636.4745190407327)
# (337, 665.2036295260674)
# (338, 724.1183233177476)
# (339, 747.8747644802429)
# (340, 700.3488258749459)
# (341, 690.0173951082941)
# (342, 702.3735782859399)
# (343, 584.4930487118237)
# (344, 389.95975146617354)
# (345, 308.8097821493054)
# (346, 276.8600959402393)
# (347, 145.71454102664322)
# (348, 55.12039238761014)
# (349, 192.08039223322118)
# (350, 396.34906953751323)
# (351, 423.30220578820513)
# (352, 343.7124553426217)
# (353, 356.55597813043164)
# (354, 422.26674806394095)
# (355, 417.39221342999315)
# (356, 408.1762508601167)
# (357, 466.14916553918385)
# (358, 446.59418371003096)
# (359, 272.9247620331777)
# (360, 144.3809142288677)
# (361, 235.04442321336927)
# (362, 453.17492967481974)
# (363, 622.722002272988)
# (364, 662.5691903597053)
# (365, 628.0417963535489)
# (366, 628.7604099732334)
# (367, 642.5933279025099)
# (368, 587.559879131022)
# (369, 601.9907186482498)
# (370, 780.6559534174029)
# (371, 850.8951042089037)
# (372, 679.1085111282985)
# (373, 587.9636091068048)
# (374, 679.4247021362712)
# (375, 711.5385343725195)
# (376, 752.5897046277757)
# (377, 943.4941338431481)
# (378, 995.9778914802636)
# (379, 868.0470339614328)
# (380, 983.2770369105468)
# (381, 1270.230623519517)
# (382, 1288.9484335663485)
# (383, 1266.3929470070882)
# (384, 1583.9721198235839)
# (385, 1887.685834443715)
# (386, 1850.3304133054726)
# (387, 1822.101267216228)
# (388, 2036.5815750353354)
# (389, 2256.635272434806)
# (390, 2336.0497911532048)
# (391, 2338.0144115205094)
# (392, 2315.322173917112)
# (393, 2338.045250314554)
# (394, 2370.5540952849633)
# (395, 2250.544613330042)
# (396, 2000.6470412077222)
# (397, 1793.8174354899652)
# (398, 1660.411228816045)
# (399, 1633.6188891756783)
# (400, 1795.586153845494)
# (401, 1979.9016724075632)
# (402, 1933.9374550688249)
# (403, 1755.5932921315266)
# (404, 1691.1373304304996)
# (405, 1759.443031183714)
# (406, 1848.03479293532)
# (407, 1901.4669799641063)
# (408, 1899.1294440263264)
# (409, 1861.341103356563)
# (410, 1860.7652242818501)
# (411, 1987.3164251482544)
# (412, 2250.4559825521687)
# (413, 2488.0107367235387)
# (414, 2500.5735436964765)
# (415, 2321.5277790433292)
# (416, 2119.7016834695555)
# (417, 1947.4763474764732)
# (418, 1776.9490073607099)
# (419, 1603.0413219133115)
# (420, 1434.8428877053643)
# (421, 1357.7667022700525)
# (422, 1398.97751766076)
# (423, 1375.7698431771692)
# (424, 1234.5752462726882)
# (425, 1222.1846649953816)
# (426, 1356.3367393469432)
# (427, 1407.218753141651)
# (428, 1483.0188358848718)
# (429, 1768.4259202267508)
# (430, 1959.7636523276578)
# (431, 1824.0141705630622)
# (432, 1642.622801281832)
# (433, 1583.8011865269661)
# (434, 1506.9572835399817)
# (435, 1478.7103560809303)
# (436, 1597.5247176050536)
# (437, 1655.3185183638952)
# (438, 1541.2677397545433)
# (439, 1440.5031140878777)
# (440, 1450.326696939426)
# (441, 1527.9814939169319)
# (442, 1599.473956402701)
# (443, 1507.1166499677402)
# (444, 1225.861788156814)
# (445, 992.4369159140116)
# (446, 877.6143508126158)
# (447, 732.1183094632456)
# (448, 610.8521482958538)
# (449, 634.8223306661737)
# (450, 663.6555119724294)
# (451, 630.1950521361797)
# (452, 656.2312700193207)
# (453, 662.8954624428274)
# (454, 537.6033199701884)
# (455, 506.70909123758594)
# (456, 665.7077952281918)
# (457, 707.2591254668159)
# (458, 581.3240968424541)
# (459, 623.8651253846344)
# (460, 786.4586430042265)
# (461, 700.7523162447532)
# (462, 461.03538219701034)
# (463, 430.08514698542706)
# (464, 530.2036034338629)
# (465, 536.4743079211559)
# (466, 568.0782952488779)
# (467, 711.355462245865)
# (468, 755.2289390683572)
# (469, 649.4745278770823)
# (470, 589.6302415986171)
# (471, 627.0187382440033)
# (472, 677.4904655617072)
# (473, 702.3222443323368)
# (474, 621.2203840718491)
# (475, 447.9792345095762)
# (476, 380.35696067195045)
# (477, 391.99167231397985)
# (478, 232.91242524485108)
# (479, 64.34250852498371)
# (480, 244.13405894463736)
# (481, 542.9415143316286)
# (482, 510.51481617006345)
# (483, 296.31146277140476)
# (484, 245.70288069000702)
# (485, 291.78375454011064)
# (486, 323.10694843188566)
# (487, 443.3806860277924)
# (488, 551.6711555114819)
# (489, 392.1667183315871)
# (490, 78.51301510776545)
# (491, -8.787928501642028)
# (492, 172.29695807440186)
# (493, 295.0040025254864)
# (494, 182.65805431174311)
# (495, -11.189388431286133)
# (496, -163.6452425995786)
# (497, -323.8074971660256)
# (498, -476.7802444062037)
# (499, -532.8160072647195)
# (500, -521.772717132512)
# (501, -468.26481672389036)
# (502, -334.65792811719535)
# (503, -260.12198654475793)
# (504, -415.64311975175445)
# (505, -594.4793674661385)
# (506, -504.54711667098456)
# (507, -291.7588186058238)
# (508, -278.7745244796005)
# (509, -470.881713070121)
# (510, -573.9978011139726)
# (511, -419.9626838732817)
