# %%
import os
import numpy as np
import torch

# Check if GPU is available and set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Using device: {device}")

# Set paths for clean and contaminated EEG data
clean_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean"
contaminated_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated"

# Define EEG frequency bands
bands = ["Delta_band", "Theta_band", "Alpha_band", "Beta_band", "Gamma_band", "High_Frequencies_band"]

print(f"✅ Clean EEG Directory: {clean_dir}")
print(f"✅ Contaminated EEG Directory: {contaminated_dir}")
print(f"✅ EEG Bands: {bands}")
# Out:
# ✅ Using device: cuda
# ✅ Clean EEG Directory: /home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean
# ✅ Contaminated EEG Directory: /home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated
# ✅ EEG Bands: ['Delta_band', 'Theta_band', 'Alpha_band', 'Beta_band', 'Gamma_band', 'High_Frequencies_band']

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class ResCNN_Modified(nn.Module):
    def __init__(self, input_length=512):
        super(ResCNN_Modified, self).__init__()
        self.conv1 = nn.Conv1d(1, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm1d(64)
        self.residual = nn.Conv1d(1, 64, kernel_size=1)  # Residual connection
        
        self.conv3 = nn.Conv1d(64, 64, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm1d(64)
        self.conv4 = nn.Conv1d(64, 64, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm1d(64)
        
        # Fully Connected Layer Added
        self.fc = nn.Linear(input_length * 64, input_length)
    
    def forward(self, x):
        residual = self.residual(x)  # Residual path
        
        x = torch.relu(self.bn1(self.conv1(x)))
        x = torch.relu(self.bn2(self.conv2(x)))
        x += residual  # Adding residual connection
        
        x = torch.relu(self.bn3(self.conv3(x)))
        x = torch.relu(self.bn4(self.conv4(x)))
        
        x = x.view(x.size(0), -1)  # Flatten before FC layer
        x = self.fc(x)  # Fully Connected Layer
        x = x.view(x.size(0), 1, -1)  # Reshape back to (batch, 1, 512)
        
        return x

# %%
import torch.optim as optim

# Define Early Stopping Class
class EarlyStopping:
    def __init__(self, patience=10, min_delta=1e-4):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = None
        self.counter = 0
        self.stop_training = False

    def __call__(self, current_loss):
        if self.best_loss is None or current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.stop_training = True

# Define Loss Function (MSE)
criterion = nn.MSELoss()

# Define Optimizer (Adam)
input_length = 512  # EEG signal length
model = ResCNN1D(input_length).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Early stopping instance
early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

# Print confirmation
print("✅ Loss function, optimizer, and early stopping defined successfully!")
# Out:
# ✅ Loss function, optimizer, and early stopping defined successfully!

# %%
from sklearn.model_selection import train_test_split

def load_and_split_data(band_name):
    """
    Loads EEG data for a specific frequency band, splits into train and test sets based on SNR levels.
    """
    print(f"\n📌 Loading and Splitting Data for {band_name}...")

    # Load clean EEG data
    clean_band_path = os.path.join(clean_dir, f"{band_name}.npy")
    clean_band = np.load(clean_band_path)

    # Load contaminated EEG data across all SNR levels
    contaminated_band = []
    snr_labels = []

    for snr_folder in sorted(os.listdir(contaminated_dir)):  # Iterate through SNR folders
        contaminated_band_path = os.path.join(contaminated_dir, snr_folder, f"{band_name}.npy")
        contaminated_data = np.load(contaminated_band_path)

        contaminated_band.append(contaminated_data)
        snr_labels.extend([snr_folder] * len(contaminated_data))  # Track SNR levels

    # Convert lists to numpy arrays
    contaminated_band = np.concatenate(contaminated_band, axis=0)
    # Convert string labels ("SNR_-7") to integers (-7)
    
    snr_labels = np.array([int(snr.replace("SNR_", "")) for snr in snr_labels])


    # Ensure clean_band is correctly repeated to match contaminated EEG samples
    clean_band_repeated = np.tile(clean_band, (len(contaminated_band) // len(clean_band) + 1, 1))[:len(contaminated_band)]

    # Stratified Train-Test Split
    train_clean, test_clean, train_contaminated, test_contaminated, snr_labels_train, snr_labels_test = train_test_split(
        clean_band_repeated, contaminated_band, snr_labels, test_size=0.2, stratify=snr_labels, random_state=42
    )

    # Inspect data shapes
    print(f"✅ {band_name} Train Clean Shape: {train_clean.shape}, Test Clean Shape: {test_clean.shape}")
    print(f"✅ {band_name} Train Contaminated Shape: {train_contaminated.shape}, Test Contaminated Shape: {test_contaminated.shape}")
    print(f"✅ {band_name} SNR Labels Train: {np.unique(snr_labels_train)}, Test: {np.unique(snr_labels_test)}")

    return train_clean, train_contaminated, test_clean, test_contaminated, snr_labels_train, snr_labels_test

# Load and split data for each EEG band
train_data = {}
test_data = {}

for band in bands:
    train_clean, train_contaminated, test_clean, test_contaminated, snr_labels_train, snr_labels_test = load_and_split_data(band)
    train_data[band] = (train_clean, train_contaminated)
    test_data[band] = (test_clean, test_contaminated, snr_labels_test)

print("\n✅ All EEG bands successfully loaded and split!")
# Out:
# 📌 Loading and Splitting Data for Delta_band...
# ✅ Delta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Delta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Delta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Theta_band...
# ✅ Theta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Theta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Theta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Alpha_band...
# ✅ Alpha_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Alpha_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Alpha_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Beta_band...
# ✅ Beta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Beta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Beta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Gamma_band...
# ✅ Gamma_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Gamma_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Gamma_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for High_Frequencies_band...
# ✅ High_Frequencies_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ High_Frequencies_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ High_Frequencies_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# ✅ All EEG bands successfully loaded and split!

# %%
from torch.utils.data import DataLoader, TensorDataset

def train_cnn(train_clean, train_contaminated, test_clean, test_contaminated, band_name):
    """
    Trains the CNN model for EEG denoising on a specific frequency band.
    """
    print(f"\n🚀 Training CNN for {band_name}...")

    # Convert NumPy arrays to PyTorch tensors and move to GPU
    train_clean = torch.tensor(train_clean, dtype=torch.float32).unsqueeze(1).to(device)
    test_clean = torch.tensor(test_clean, dtype=torch.float32).unsqueeze(1).to(device)
    train_contaminated = torch.tensor(train_contaminated, dtype=torch.float32).unsqueeze(1).to(device)
    test_contaminated = torch.tensor(test_contaminated, dtype=torch.float32).unsqueeze(1).to(device)

    # Create DataLoader for training and testing
    train_dataset = TensorDataset(train_contaminated, train_clean)
    test_dataset = TensorDataset(test_contaminated, test_clean)
    train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

    # Define model, optimizer, and loss function
    input_length = train_contaminated.shape[2]  # EEG signal length
    model = ResCNN1D(input_length).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

    # Train model
    num_epochs = 1000
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for inputs, targets in train_loader:
            #print(f"before squeeze{inputs.shape}")
            optimizer.zero_grad()
            outputs = model(inputs)
            inputs = inputs.squeeze(2).squeeze(1)
            #print(f"After squeeze{inputs.shape}")
            loss = criterion(outputs, targets.squeeze(1))
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        avg_train_loss = running_loss / len(train_loader)

        # Evaluate model
        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for inputs, targets in test_loader:
                outputs = model(inputs)
                loss = criterion(outputs, targets.squeeze(1))
                test_loss += loss.item()

        avg_test_loss = test_loss / len(test_loader)

        print(f"Epoch {epoch + 1}: Train Loss = {avg_train_loss:.4f}, Test Loss = {avg_test_loss:.4f}")

        # Early stopping condition
        early_stopping(avg_test_loss)
        if early_stopping.stop_training:
            print(f"✅ Early stopping triggered for {band_name} at epoch {epoch + 1}")
            break

    # Generate denoised test set predictions
    with torch.no_grad():
        denoised_band = model(test_contaminated).squeeze(1).cpu().numpy()

    return denoised_band, test_clean.cpu().numpy()

# %%
denoised_bands = []
clean_bands = []

for band in bands:
    train_clean, train_contaminated = train_data[band]
    test_clean, test_contaminated, _ = test_data[band]

    denoised_band, clean_band_test = train_cnn(train_clean, train_contaminated, test_clean, test_contaminated, band)
    
    denoised_bands.append(denoised_band)
    clean_bands.append(clean_band_test)

print("\n✅ All EEG bands successfully trained!")
# Out:
# 🚀 Training CNN for Delta_band...
# Epoch 1: Train Loss = 7405.5432, Test Loss = 7501.2007
# Epoch 2: Train Loss = 7312.4826, Test Loss = 7394.9359
# Epoch 3: Train Loss = 7106.6366, Test Loss = 7216.7835
# Epoch 4: Train Loss = 7093.7926, Test Loss = 7213.6508
# Epoch 5: Train Loss = 7080.8897, Test Loss = 7217.5344
# Epoch 6: Train Loss = 7075.8848, Test Loss = 7240.4281
# Epoch 7: Train Loss = 7062.4364, Test Loss = 7174.7944
# Epoch 8: Train Loss = 7065.2132, Test Loss = 7168.9036
# Epoch 9: Train Loss = 7045.6895, Test Loss = 7161.6913
# Epoch 10: Train Loss = 7051.5533, Test Loss = 7157.0064
# Epoch 11: Train Loss = 7046.0147, Test Loss = 7160.9871
# Epoch 12: Train Loss = 7051.2725, Test Loss = 7163.6771
# Epoch 13: Train Loss = 7041.1758, Test Loss = 7203.2184
# Epoch 14: Train Loss = 7040.1261, Test Loss = 7185.4742
# Epoch 15: Train Loss = 7030.9378, Test Loss = 7146.9864
# Epoch 16: Train Loss = 7028.1589, Test Loss = 7140.9712
# Epoch 17: Train Loss = 7027.7968, Test Loss = 7137.1023
# Epoch 18: Train Loss = 7014.8289, Test Loss = 7137.4863
# Epoch 19: Train Loss = 7028.0200, Test Loss = 7178.1441
# Epoch 20: Train Loss = 7022.5777, Test Loss = 7140.1825
# Epoch 21: Train Loss = 7028.4739, Test Loss = 7147.2413
# Epoch 22: Train Loss = 7028.1053, Test Loss = 7154.8486
# Epoch 23: Train Loss = 7011.7459, Test Loss = 7192.2802
# Epoch 24: Train Loss = 7023.2907, Test Loss = 7144.4623
# Epoch 25: Train Loss = 7014.5050, Test Loss = 7149.5302
# Epoch 26: Train Loss = 7005.8941, Test Loss = 7119.8817
# Epoch 27: Train Loss = 7009.6017, Test Loss = 7189.3707
# Epoch 28: Train Loss = 7000.0767, Test Loss = 7145.4935
# Epoch 29: Train Loss = 7004.4322, Test Loss = 7174.0747
# Epoch 30: Train Loss = 7019.7115, Test Loss = 7137.1944
# Epoch 31: Train Loss = 6998.4334, Test Loss = 7105.7906
# Epoch 32: Train Loss = 7003.5490, Test Loss = 7107.7333
# Epoch 33: Train Loss = 6986.3873, Test Loss = 7123.0786
# Epoch 34: Train Loss = 6986.6383, Test Loss = 7131.9947
# Epoch 35: Train Loss = 6986.9310, Test Loss = 7155.6776
# Epoch 36: Train Loss = 6976.9922, Test Loss = 7090.1989
# Epoch 37: Train Loss = 6993.7629, Test Loss = 7085.0609
# Epoch 38: Train Loss = 6977.4800, Test Loss = 7160.3088
# Epoch 39: Train Loss = 6965.2967, Test Loss = 7071.4232
# Epoch 40: Train Loss = 6975.3315, Test Loss = 7124.2315
# Epoch 41: Train Loss = 6960.8698, Test Loss = 7068.6641
# Epoch 42: Train Loss = 6978.9841, Test Loss = 7194.0530
# Epoch 43: Train Loss = 6956.6478, Test Loss = 7107.8683
# Epoch 44: Train Loss = 6967.9329, Test Loss = 7085.3137
# Epoch 45: Train Loss = 6970.5046, Test Loss = 7067.5604
# Epoch 46: Train Loss = 6965.6714, Test Loss = 7208.0222
# Epoch 47: Train Loss = 6962.3625, Test Loss = 7080.9766
# Epoch 48: Train Loss = 6953.1388, Test Loss = 7101.5316
# Epoch 49: Train Loss = 6951.4198, Test Loss = 7115.5668
# Epoch 50: Train Loss = 6967.9228, Test Loss = 7112.5809
# Epoch 51: Train Loss = 6958.8555, Test Loss = 7074.0728
# Epoch 52: Train Loss = 6952.8208, Test Loss = 7066.6446
# Epoch 53: Train Loss = 6953.9936, Test Loss = 7094.7670
# Epoch 54: Train Loss = 6951.7676, Test Loss = 7085.6900
# Epoch 55: Train Loss = 6946.9435, Test Loss = 7068.1283
# Epoch 56: Train Loss = 6950.2623, Test Loss = 7056.2221
# Epoch 57: Train Loss = 6946.8878, Test Loss = 7087.6484
# Epoch 58: Train Loss = 6945.3580, Test Loss = 7051.0375
# Epoch 59: Train Loss = 6951.5917, Test Loss = 7049.8770
# Epoch 60: Train Loss = 6941.5674, Test Loss = 7051.2059
# Epoch 61: Train Loss = 6945.5656, Test Loss = 7214.6957
# Epoch 62: Train Loss = 6943.8636, Test Loss = 7063.0903
# Epoch 63: Train Loss = 6947.8313, Test Loss = 7055.6349
# Epoch 64: Train Loss = 6941.2629, Test Loss = 7053.8009
# Epoch 65: Train Loss = 6934.2489, Test Loss = 7094.6579
# Epoch 66: Train Loss = 6949.9677, Test Loss = 7043.5191
# Epoch 67: Train Loss = 6947.1266, Test Loss = 7042.3944
# Epoch 68: Train Loss = 6938.2892, Test Loss = 7047.1120
# Epoch 69: Train Loss = 6930.8439, Test Loss = 7049.2705
# Epoch 70: Train Loss = 6934.2953, Test Loss = 7045.5365
# Epoch 71: Train Loss = 6945.3336, Test Loss = 7162.7683
# Epoch 72: Train Loss = 6941.4547, Test Loss = 7160.2604
# Epoch 73: Train Loss = 6934.9384, Test Loss = 7041.7382
# Epoch 74: Train Loss = 6937.7124, Test Loss = 7038.2767
# Epoch 75: Train Loss = 6934.6380, Test Loss = 7074.5218
# Epoch 76: Train Loss = 6932.0932, Test Loss = 7518.4400
# Epoch 77: Train Loss = 6943.9885, Test Loss = 7097.0758
# Epoch 78: Train Loss = 6929.8696, Test Loss = 7084.0932
# Epoch 79: Train Loss = 6940.4333, Test Loss = 7111.7880
# Epoch 80: Train Loss = 6933.4667, Test Loss = 7048.4001
# Epoch 81: Train Loss = 6925.3705, Test Loss = 7037.6864
# Epoch 82: Train Loss = 6942.4876, Test Loss = 7057.7430
# Epoch 83: Train Loss = 6929.3004, Test Loss = 7049.6854
# Epoch 84: Train Loss = 6937.7926, Test Loss = 7063.7270
# Epoch 85: Train Loss = 6937.4218, Test Loss = 7056.4244
# Epoch 86: Train Loss = 6940.2724, Test Loss = 7063.5511
# Epoch 87: Train Loss = 6927.4426, Test Loss = 7042.7860
# Epoch 88: Train Loss = 6922.0135, Test Loss = 7052.8960
# Epoch 89: Train Loss = 6935.1729, Test Loss = 7060.1238
# Epoch 90: Train Loss = 6929.1091, Test Loss = 7097.0093
# Epoch 91: Train Loss = 6930.5903, Test Loss = 7041.2334
# ✅ Early stopping triggered for Delta_band at epoch 91
#
# 🚀 Training CNN for Theta_band...
# Epoch 1: Train Loss = 5558.5519, Test Loss = 5610.3730
# Epoch 2: Train Loss = 5350.7424, Test Loss = 5164.1893
# Epoch 3: Train Loss = 4786.5845, Test Loss = 4887.9882
# Epoch 4: Train Loss = 4705.1513, Test Loss = 4841.2484
# Epoch 5: Train Loss = 4694.7244, Test Loss = 4855.7875
# Epoch 6: Train Loss = 4683.9493, Test Loss = 4825.4608
# Epoch 7: Train Loss = 4687.4449, Test Loss = 4854.1669
# Epoch 8: Train Loss = 4687.3830, Test Loss = 4841.3832
# Epoch 9: Train Loss = 4680.3612, Test Loss = 4844.2392
# Epoch 10: Train Loss = 4669.0293, Test Loss = 4858.3334
# Epoch 11: Train Loss = 4675.9633, Test Loss = 4891.5291
# Epoch 12: Train Loss = 4669.7668, Test Loss = 4823.9791
# Epoch 13: Train Loss = 4679.0998, Test Loss = 4813.4143
# Epoch 14: Train Loss = 4670.3432, Test Loss = 4911.9208
# Epoch 15: Train Loss = 4674.1585, Test Loss = 4803.9232
# Epoch 16: Train Loss = 4658.2876, Test Loss = 4801.4321
# Epoch 17: Train Loss = 4662.5829, Test Loss = 4814.7474
# Epoch 18: Train Loss = 4658.2167, Test Loss = 4849.9811
# Epoch 19: Train Loss = 4656.3510, Test Loss = 4814.2449
# Epoch 20: Train Loss = 4650.7270, Test Loss = 4826.0739
# Epoch 21: Train Loss = 4656.3978, Test Loss = 4794.6593
# Epoch 22: Train Loss = 4651.9136, Test Loss = 4878.4793
# Epoch 23: Train Loss = 4649.7324, Test Loss = 4814.9438
# Epoch 24: Train Loss = 4649.7577, Test Loss = 4790.6523
# Epoch 25: Train Loss = 4660.1459, Test Loss = 4790.9822
# Epoch 26: Train Loss = 4642.6406, Test Loss = 4787.4073
# Epoch 27: Train Loss = 4636.7806, Test Loss = 4777.2082
# Epoch 28: Train Loss = 4638.7833, Test Loss = 4797.4450
# Epoch 29: Train Loss = 4638.2972, Test Loss = 4812.0305
# Epoch 30: Train Loss = 4636.1489, Test Loss = 4794.8374
# Epoch 31: Train Loss = 4626.5521, Test Loss = 4785.6584
# Epoch 32: Train Loss = 4635.9790, Test Loss = 4801.4391
# Epoch 33: Train Loss = 4626.9545, Test Loss = 4775.3794
# Epoch 34: Train Loss = 4632.7953, Test Loss = 4770.4198
# Epoch 35: Train Loss = 4617.6691, Test Loss = 4815.0865
# Epoch 36: Train Loss = 4624.4953, Test Loss = 4768.1822
# Epoch 37: Train Loss = 4614.4215, Test Loss = 4789.9399
# Epoch 38: Train Loss = 4609.9279, Test Loss = 4760.2543
# Epoch 39: Train Loss = 4599.6652, Test Loss = 4835.9052
# Epoch 40: Train Loss = 4606.8220, Test Loss = 4831.2760
# Epoch 41: Train Loss = 4606.3632, Test Loss = 4821.0316
# Epoch 42: Train Loss = 4597.0261, Test Loss = 4748.3318
# Epoch 43: Train Loss = 4603.0127, Test Loss = 4850.4486
# Epoch 44: Train Loss = 4598.6070, Test Loss = 4804.2320
# Epoch 45: Train Loss = 4597.3512, Test Loss = 4798.0233
# Epoch 46: Train Loss = 4596.4682, Test Loss = 4780.8707
# Epoch 47: Train Loss = 4593.0487, Test Loss = 4863.6944
# Epoch 48: Train Loss = 4590.8305, Test Loss = 4799.0473
# Epoch 49: Train Loss = 4602.2941, Test Loss = 4730.6561
# Epoch 50: Train Loss = 4583.5073, Test Loss = 4780.9411
# Epoch 51: Train Loss = 4590.6808, Test Loss = 4806.9154
# Epoch 52: Train Loss = 4585.5690, Test Loss = 4723.1890
# Epoch 53: Train Loss = 4592.7837, Test Loss = 4741.7793
# Epoch 54: Train Loss = 4579.4369, Test Loss = 4738.2509
# Epoch 55: Train Loss = 4579.3450, Test Loss = 4718.9037
# Epoch 56: Train Loss = 4589.6659, Test Loss = 5017.8424
# Epoch 57: Train Loss = 4591.9566, Test Loss = 4767.7193
# Epoch 58: Train Loss = 4586.5103, Test Loss = 4723.8548
# Epoch 59: Train Loss = 4569.7627, Test Loss = 4753.1014
# Epoch 60: Train Loss = 4571.0871, Test Loss = 4721.4062
# Epoch 61: Train Loss = 4581.2737, Test Loss = 4747.7919
# Epoch 62: Train Loss = 4589.2746, Test Loss = 4723.2753
# Epoch 63: Train Loss = 4574.1062, Test Loss = 4751.7572
# Epoch 64: Train Loss = 4576.0908, Test Loss = 4773.9480
# Epoch 65: Train Loss = 4576.8077, Test Loss = 4718.8074
# Epoch 66: Train Loss = 4571.1985, Test Loss = 4792.4612
# Epoch 67: Train Loss = 4576.7182, Test Loss = 4719.4838
# Epoch 68: Train Loss = 4574.3159, Test Loss = 4774.7577
# Epoch 69: Train Loss = 4574.6984, Test Loss = 4809.3741
# Epoch 70: Train Loss = 4578.0064, Test Loss = 4731.4455
# Epoch 71: Train Loss = 4570.6976, Test Loss = 4719.6259
# Epoch 72: Train Loss = 4579.9011, Test Loss = 4770.9687
# Epoch 73: Train Loss = 4568.1112, Test Loss = 4760.6581
# Epoch 74: Train Loss = 4576.7811, Test Loss = 4736.6180
# Epoch 75: Train Loss = 4569.2216, Test Loss = 4908.2660
# ✅ Early stopping triggered for Theta_band at epoch 75
#
# 🚀 Training CNN for Alpha_band...
# Epoch 1: Train Loss = 3329.8089, Test Loss = 3200.5235
# Epoch 2: Train Loss = 3037.9076, Test Loss = 2881.8601
# Epoch 3: Train Loss = 2504.3505, Test Loss = 2453.8388
# Epoch 4: Train Loss = 2379.5604, Test Loss = 2411.0654
# Epoch 5: Train Loss = 2350.6295, Test Loss = 2373.4570
# Epoch 6: Train Loss = 2332.4901, Test Loss = 2371.1810
# Epoch 7: Train Loss = 2321.7762, Test Loss = 2363.6424
# Epoch 8: Train Loss = 2316.4927, Test Loss = 2348.9994
# Epoch 9: Train Loss = 2312.5776, Test Loss = 2343.6187
# Epoch 10: Train Loss = 2310.0242, Test Loss = 2341.9798
# Epoch 11: Train Loss = 2310.4270, Test Loss = 2357.3807
# Epoch 12: Train Loss = 2306.5631, Test Loss = 2332.1733
# Epoch 13: Train Loss = 2303.1729, Test Loss = 2330.6429
# Epoch 14: Train Loss = 2301.4390, Test Loss = 2325.3717
# Epoch 15: Train Loss = 2299.6979, Test Loss = 2330.7033
# Epoch 16: Train Loss = 2294.6022, Test Loss = 2357.9471
# Epoch 17: Train Loss = 2291.6544, Test Loss = 2320.6919
# Epoch 18: Train Loss = 2290.3746, Test Loss = 2329.0459
# Epoch 19: Train Loss = 2291.6016, Test Loss = 2337.9166
# Epoch 20: Train Loss = 2284.9293, Test Loss = 2328.4959
# Epoch 21: Train Loss = 2285.1127, Test Loss = 2322.5954
# Epoch 22: Train Loss = 2283.9154, Test Loss = 2312.1185
# Epoch 23: Train Loss = 2292.0058, Test Loss = 2316.9796
# Epoch 24: Train Loss = 2283.4147, Test Loss = 2335.1079
# Epoch 25: Train Loss = 2289.2860, Test Loss = 2321.3876
# Epoch 26: Train Loss = 2281.2202, Test Loss = 2340.5872
# Epoch 27: Train Loss = 2284.8049, Test Loss = 2314.0626
# Epoch 28: Train Loss = 2280.1559, Test Loss = 2308.6218
# Epoch 29: Train Loss = 2282.0513, Test Loss = 2306.7906
# Epoch 30: Train Loss = 2277.9598, Test Loss = 2304.7107
# Epoch 31: Train Loss = 2274.6009, Test Loss = 2302.7863
# Epoch 32: Train Loss = 2275.1115, Test Loss = 2302.9736
# Epoch 33: Train Loss = 2282.2843, Test Loss = 2308.2265
# Epoch 34: Train Loss = 2274.4785, Test Loss = 2329.7007
# Epoch 35: Train Loss = 2275.8293, Test Loss = 2337.8555
# Epoch 36: Train Loss = 2282.0161, Test Loss = 2306.4152
# Epoch 37: Train Loss = 2270.4444, Test Loss = 2311.5506
# Epoch 38: Train Loss = 2278.6618, Test Loss = 2305.4997
# Epoch 39: Train Loss = 2274.3888, Test Loss = 2302.2541
# Epoch 40: Train Loss = 2272.4422, Test Loss = 2307.8990
# Epoch 41: Train Loss = 2275.6492, Test Loss = 2316.3465
# Epoch 42: Train Loss = 2278.4350, Test Loss = 2301.7741
# Epoch 43: Train Loss = 2270.6582, Test Loss = 2327.6434
# Epoch 44: Train Loss = 2272.9865, Test Loss = 2301.2559
# Epoch 45: Train Loss = 2271.8073, Test Loss = 2303.4940
# Epoch 46: Train Loss = 2271.6174, Test Loss = 2299.7762
# Epoch 47: Train Loss = 2267.6143, Test Loss = 2298.7352
# Epoch 48: Train Loss = 2277.5073, Test Loss = 2312.7234
# Epoch 49: Train Loss = 2272.1595, Test Loss = 2300.7427
# Epoch 50: Train Loss = 2271.8854, Test Loss = 2298.6975
# Epoch 51: Train Loss = 2264.3625, Test Loss = 2307.2722
# Epoch 52: Train Loss = 2273.3594, Test Loss = 2303.3911
# Epoch 53: Train Loss = 2271.2279, Test Loss = 2297.8332
# Epoch 54: Train Loss = 2266.2465, Test Loss = 2302.6379
# Epoch 55: Train Loss = 2268.4773, Test Loss = 2310.4185
# Epoch 56: Train Loss = 2273.5714, Test Loss = 2365.8091
# Epoch 57: Train Loss = 2266.2708, Test Loss = 2294.2654
# Epoch 58: Train Loss = 2272.4920, Test Loss = 2310.8683
# Epoch 59: Train Loss = 2262.8547, Test Loss = 2297.9447
# Epoch 60: Train Loss = 2264.3591, Test Loss = 2307.1817
# Epoch 61: Train Loss = 2267.5669, Test Loss = 2293.9110
# Epoch 62: Train Loss = 2261.0069, Test Loss = 2298.2095
# Epoch 63: Train Loss = 2268.9087, Test Loss = 2352.1156
# Epoch 64: Train Loss = 2268.4933, Test Loss = 2295.7338
# Epoch 65: Train Loss = 2257.5444, Test Loss = 2299.4523
# Epoch 66: Train Loss = 2267.4650, Test Loss = 2291.1446
# Epoch 67: Train Loss = 2262.0356, Test Loss = 2304.5226
# Epoch 68: Train Loss = 2263.9562, Test Loss = 2292.3865
# Epoch 69: Train Loss = 2261.9379, Test Loss = 2290.4792
# Epoch 70: Train Loss = 2265.9178, Test Loss = 2306.8852
# Epoch 71: Train Loss = 2261.6048, Test Loss = 2290.4883
# Epoch 72: Train Loss = 2261.7010, Test Loss = 2288.2410
# Epoch 73: Train Loss = 2263.4862, Test Loss = 2294.4739
# Epoch 74: Train Loss = 2257.7943, Test Loss = 2325.3327
# Epoch 75: Train Loss = 2270.0265, Test Loss = 2291.2275
# Epoch 76: Train Loss = 2260.3268, Test Loss = 2305.1671
# Epoch 77: Train Loss = 2261.9899, Test Loss = 2287.2954
# Epoch 78: Train Loss = 2256.7398, Test Loss = 2300.1416
# Epoch 79: Train Loss = 2265.3132, Test Loss = 2293.4332
# Epoch 80: Train Loss = 2260.7742, Test Loss = 2287.8131
# Epoch 81: Train Loss = 2266.6565, Test Loss = 2302.3141
# Epoch 82: Train Loss = 2261.6671, Test Loss = 2316.7271
# Epoch 83: Train Loss = 2259.0591, Test Loss = 2301.7011
# Epoch 84: Train Loss = 2255.8007, Test Loss = 2292.2316
# Epoch 85: Train Loss = 2259.6779, Test Loss = 2284.6243
# Epoch 86: Train Loss = 2260.6211, Test Loss = 2292.6333
# Epoch 87: Train Loss = 2257.0176, Test Loss = 2310.6746
# Epoch 88: Train Loss = 2253.9326, Test Loss = 2282.0482
# Epoch 89: Train Loss = 2256.7872, Test Loss = 2292.3324
# Epoch 90: Train Loss = 2253.6873, Test Loss = 2288.0691
# Epoch 91: Train Loss = 2261.9249, Test Loss = 2299.6835
# Epoch 92: Train Loss = 2254.7501, Test Loss = 2288.0480
# Epoch 93: Train Loss = 2262.2979, Test Loss = 2299.0134
# Epoch 94: Train Loss = 2255.4810, Test Loss = 2287.6297
# Epoch 95: Train Loss = 2257.6588, Test Loss = 2279.5033
# Epoch 96: Train Loss = 2250.9289, Test Loss = 2280.1390
# Epoch 97: Train Loss = 2255.0486, Test Loss = 2297.1720
# Epoch 98: Train Loss = 2253.1233, Test Loss = 2288.6089
# Epoch 99: Train Loss = 2251.0901, Test Loss = 2278.8723
# Epoch 100: Train Loss = 2258.8870, Test Loss = 2281.1602
# Epoch 101: Train Loss = 2258.4115, Test Loss = 2289.2042
# Epoch 102: Train Loss = 2247.2694, Test Loss = 2283.1794
# Epoch 103: Train Loss = 2250.8639, Test Loss = 2280.2361
# Epoch 104: Train Loss = 2255.6778, Test Loss = 2302.9746
# Epoch 105: Train Loss = 2254.4817, Test Loss = 2279.4035
# Epoch 106: Train Loss = 2251.4323, Test Loss = 2284.2652
# Epoch 107: Train Loss = 2253.1989, Test Loss = 2284.9510
# Epoch 108: Train Loss = 2249.0587, Test Loss = 2304.3110
# Epoch 109: Train Loss = 2249.1474, Test Loss = 2302.1117
# ✅ Early stopping triggered for Alpha_band at epoch 109
#
# 🚀 Training CNN for Beta_band...
# Epoch 1: Train Loss = 9598.4775, Test Loss = 3839.7977
# Epoch 2: Train Loss = 3635.8201, Test Loss = 3467.2702
# Epoch 3: Train Loss = 3572.4978, Test Loss = 3428.7353
# Epoch 4: Train Loss = 3525.6377, Test Loss = 3384.2124
# Epoch 5: Train Loss = 3474.0710, Test Loss = 3344.3958
# Epoch 6: Train Loss = 3414.4567, Test Loss = 3287.5917
# Epoch 7: Train Loss = 3364.9717, Test Loss = 3241.6454
# Epoch 8: Train Loss = 3312.8942, Test Loss = 3198.2326
# Epoch 9: Train Loss = 3284.6239, Test Loss = 3158.3104
# Epoch 10: Train Loss = 3232.3386, Test Loss = 3157.0543
# Epoch 11: Train Loss = 3192.3779, Test Loss = 3151.1581
# Epoch 12: Train Loss = 3163.2100, Test Loss = 3084.4476
# Epoch 13: Train Loss = 3123.6200, Test Loss = 3100.8342
# Epoch 14: Train Loss = 3094.5000, Test Loss = 3065.7100
# Epoch 15: Train Loss = 3061.9075, Test Loss = 2983.4646
# Epoch 16: Train Loss = 3029.4404, Test Loss = 2963.2309
# Epoch 17: Train Loss = 3006.0880, Test Loss = 3018.6386
# Epoch 18: Train Loss = 2981.9294, Test Loss = 2928.8020
# Epoch 19: Train Loss = 2970.7744, Test Loss = 2941.1559
# Epoch 20: Train Loss = 2945.1212, Test Loss = 2901.0485
# Epoch 21: Train Loss = 2925.1175, Test Loss = 2880.8243
# Epoch 22: Train Loss = 2925.7040, Test Loss = 2926.6479
# Epoch 23: Train Loss = 2907.0126, Test Loss = 2875.8245
# Epoch 24: Train Loss = 2884.3967, Test Loss = 2841.2264
# Epoch 25: Train Loss = 2866.7719, Test Loss = 2832.4848
# Epoch 26: Train Loss = 2858.7433, Test Loss = 2853.4896
# Epoch 27: Train Loss = 2846.7273, Test Loss = 2872.4783
# Epoch 28: Train Loss = 2844.4283, Test Loss = 2881.1494
# Epoch 29: Train Loss = 2845.9546, Test Loss = 2798.3779
# Epoch 30: Train Loss = 2827.8948, Test Loss = 2794.6146
# Epoch 31: Train Loss = 2824.2099, Test Loss = 2784.2103
# Epoch 32: Train Loss = 2806.3352, Test Loss = 2786.7882
# Epoch 33: Train Loss = 2811.0861, Test Loss = 2803.1701
# Epoch 34: Train Loss = 2803.0141, Test Loss = 2783.2815
# Epoch 35: Train Loss = 2798.6822, Test Loss = 2831.4691
# Epoch 36: Train Loss = 2821.0309, Test Loss = 2780.0301
# Epoch 37: Train Loss = 2785.2243, Test Loss = 2790.8841
# Epoch 38: Train Loss = 2787.7123, Test Loss = 2770.9706
# Epoch 39: Train Loss = 2772.3955, Test Loss = 2760.2262
# Epoch 40: Train Loss = 2776.0108, Test Loss = 2751.9602
# Epoch 41: Train Loss = 2769.0071, Test Loss = 2833.1406
# Epoch 42: Train Loss = 2779.1444, Test Loss = 2757.7912
# Epoch 43: Train Loss = 2764.5638, Test Loss = 2789.6101
# Epoch 44: Train Loss = 2769.0128, Test Loss = 2749.2461
# Epoch 45: Train Loss = 2779.8717, Test Loss = 2743.6068
# Epoch 46: Train Loss = 2756.4643, Test Loss = 2750.7914
# Epoch 47: Train Loss = 2757.0480, Test Loss = 2758.6614
# Epoch 48: Train Loss = 2757.5279, Test Loss = 2737.2326
# Epoch 49: Train Loss = 2772.8276, Test Loss = 2749.6183
# Epoch 50: Train Loss = 2758.2225, Test Loss = 2744.7307
# Epoch 51: Train Loss = 2763.3158, Test Loss = 2749.9335
# Epoch 52: Train Loss = 2753.8967, Test Loss = 2786.7473
# Epoch 53: Train Loss = 2762.5815, Test Loss = 2817.8614
# Epoch 54: Train Loss = 2755.8588, Test Loss = 2831.0285
# Epoch 55: Train Loss = 2748.4799, Test Loss = 2740.5578
# Epoch 56: Train Loss = 2740.8967, Test Loss = 2736.4744
# Epoch 57: Train Loss = 2748.0392, Test Loss = 2727.7705
# Epoch 58: Train Loss = 2745.9704, Test Loss = 2733.7183
# Epoch 59: Train Loss = 2744.8384, Test Loss = 2759.2800
# Epoch 60: Train Loss = 2746.5361, Test Loss = 2728.4939
# Epoch 61: Train Loss = 2752.9630, Test Loss = 2766.2977
# Epoch 62: Train Loss = 2748.8804, Test Loss = 2719.8784
# Epoch 63: Train Loss = 2745.7611, Test Loss = 2727.7340
# Epoch 64: Train Loss = 2735.7478, Test Loss = 2721.2431
# Epoch 65: Train Loss = 2744.0139, Test Loss = 2731.4746
# Epoch 66: Train Loss = 2749.0942, Test Loss = 2720.5550
# Epoch 67: Train Loss = 2740.0321, Test Loss = 2732.3188
# Epoch 68: Train Loss = 2739.7320, Test Loss = 2759.9177
# Epoch 69: Train Loss = 2730.6120, Test Loss = 2772.4412
# Epoch 70: Train Loss = 2734.8371, Test Loss = 2715.9984
# Epoch 71: Train Loss = 2734.0887, Test Loss = 2712.7112
# Epoch 72: Train Loss = 2734.6379, Test Loss = 2716.5297
# Epoch 73: Train Loss = 2739.2846, Test Loss = 2775.2634
# Epoch 74: Train Loss = 2734.0725, Test Loss = 2730.3870
# Epoch 75: Train Loss = 2736.7337, Test Loss = 2717.2484
# Epoch 76: Train Loss = 2725.6433, Test Loss = 2708.9472
# Epoch 77: Train Loss = 2737.4590, Test Loss = 2794.7714
# Epoch 78: Train Loss = 2734.7671, Test Loss = 2711.5934
# Epoch 79: Train Loss = 2724.2649, Test Loss = 2710.6837
# Epoch 80: Train Loss = 2721.5312, Test Loss = 2706.2392
# Epoch 81: Train Loss = 2716.4485, Test Loss = 2774.8937
# Epoch 82: Train Loss = 2732.1456, Test Loss = 2705.6514
# Epoch 83: Train Loss = 2724.7695, Test Loss = 2722.5243
# Epoch 84: Train Loss = 2728.1575, Test Loss = 2707.5121
# Epoch 85: Train Loss = 2724.1959, Test Loss = 2709.5713
# Epoch 86: Train Loss = 2721.3195, Test Loss = 2725.3558
# Epoch 87: Train Loss = 2731.8255, Test Loss = 2741.2202
# Epoch 88: Train Loss = 2715.9552, Test Loss = 2735.1711
# Epoch 89: Train Loss = 2718.1303, Test Loss = 2781.7782
# Epoch 90: Train Loss = 2717.7434, Test Loss = 2702.3149
# Epoch 91: Train Loss = 2716.7070, Test Loss = 2748.7930
# Epoch 92: Train Loss = 2714.4745, Test Loss = 2742.8057
# Epoch 93: Train Loss = 2715.2043, Test Loss = 2699.9726
# Epoch 94: Train Loss = 2719.2716, Test Loss = 2709.4556
# Epoch 95: Train Loss = 2713.7705, Test Loss = 2712.7761
# Epoch 96: Train Loss = 2714.4253, Test Loss = 2704.5088
# Epoch 97: Train Loss = 2720.2258, Test Loss = 2720.9848
# Epoch 98: Train Loss = 2727.9801, Test Loss = 2702.0099
# Epoch 99: Train Loss = 2709.6734, Test Loss = 2787.4964
# Epoch 100: Train Loss = 2720.7635, Test Loss = 2702.4594
# Epoch 101: Train Loss = 2711.1788, Test Loss = 2699.1256
# Epoch 102: Train Loss = 2719.8446, Test Loss = 2692.5989
# Epoch 103: Train Loss = 2707.7003, Test Loss = 2724.8034
# Epoch 104: Train Loss = 2711.2955, Test Loss = 2696.5348
# Epoch 105: Train Loss = 2701.6603, Test Loss = 2691.9856
# Epoch 106: Train Loss = 2711.9193, Test Loss = 2701.4893
# Epoch 107: Train Loss = 2714.4290, Test Loss = 2695.9815
# Epoch 108: Train Loss = 2707.9742, Test Loss = 2717.1325
# Epoch 109: Train Loss = 2706.3332, Test Loss = 2757.8837
# Epoch 110: Train Loss = 2705.4149, Test Loss = 2710.8264
# Epoch 111: Train Loss = 2699.3429, Test Loss = 2690.1529
# Epoch 112: Train Loss = 2696.6610, Test Loss = 2687.2820
# Epoch 113: Train Loss = 2698.0741, Test Loss = 2701.6170
# Epoch 114: Train Loss = 2700.0580, Test Loss = 2719.3810
# Epoch 115: Train Loss = 2709.1788, Test Loss = 2705.7581
# Epoch 116: Train Loss = 2695.5713, Test Loss = 2679.4952
# Epoch 117: Train Loss = 2688.4675, Test Loss = 2695.5307
# Epoch 118: Train Loss = 2698.4262, Test Loss = 2690.7428
# Epoch 119: Train Loss = 2690.0603, Test Loss = 2684.5108
# Epoch 120: Train Loss = 2691.1310, Test Loss = 2710.2325
# Epoch 121: Train Loss = 2692.0954, Test Loss = 2706.1256
# Epoch 122: Train Loss = 2693.9228, Test Loss = 2772.7283
# Epoch 123: Train Loss = 2691.4026, Test Loss = 2683.3892
# Epoch 124: Train Loss = 2691.7829, Test Loss = 2682.5821
# Epoch 125: Train Loss = 2697.5901, Test Loss = 2679.1562
# Epoch 126: Train Loss = 2693.2295, Test Loss = 2713.2849
# Epoch 127: Train Loss = 2708.4463, Test Loss = 2680.5236
# Epoch 128: Train Loss = 2692.7366, Test Loss = 2697.5097
# Epoch 129: Train Loss = 2692.7163, Test Loss = 2710.1818
# Epoch 130: Train Loss = 2703.5789, Test Loss = 2684.4462
# Epoch 131: Train Loss = 2681.3336, Test Loss = 2694.4710
# Epoch 132: Train Loss = 2690.5062, Test Loss = 2671.9766
# Epoch 133: Train Loss = 2686.3476, Test Loss = 2713.9074
# Epoch 134: Train Loss = 2702.4665, Test Loss = 2686.8665
# Epoch 135: Train Loss = 2682.5639, Test Loss = 2670.3931
# Epoch 136: Train Loss = 2685.7597, Test Loss = 2684.8568
# Epoch 137: Train Loss = 2696.6814, Test Loss = 2675.6772
# Epoch 138: Train Loss = 2680.6686, Test Loss = 2671.9429
# Epoch 139: Train Loss = 2677.9694, Test Loss = 2666.1296
# Epoch 140: Train Loss = 2674.1025, Test Loss = 2677.3005
# Epoch 141: Train Loss = 2686.2602, Test Loss = 2672.2641
# Epoch 142: Train Loss = 2678.4350, Test Loss = 2684.1731
# Epoch 143: Train Loss = 2686.0928, Test Loss = 2671.2801
# Epoch 144: Train Loss = 2677.1668, Test Loss = 2687.2838
# Epoch 145: Train Loss = 2682.7479, Test Loss = 2673.8544
# Epoch 146: Train Loss = 2682.9372, Test Loss = 2682.4114
# Epoch 147: Train Loss = 2681.4454, Test Loss = 2677.8565
# Epoch 148: Train Loss = 2692.7342, Test Loss = 2670.2242
# Epoch 149: Train Loss = 2685.2344, Test Loss = 2670.1755
# ✅ Early stopping triggered for Beta_band at epoch 149
#
# 🚀 Training CNN for Gamma_band...
# Epoch 1: Train Loss = 1547.3671, Test Loss = 365.1809
# Epoch 2: Train Loss = 363.4957, Test Loss = 363.7757
# Epoch 3: Train Loss = 364.9550, Test Loss = 364.5340
# Epoch 4: Train Loss = 362.7291, Test Loss = 361.7441
# Epoch 5: Train Loss = 362.2416, Test Loss = 361.5143
# Epoch 6: Train Loss = 361.8208, Test Loss = 363.9611
# Epoch 7: Train Loss = 361.4711, Test Loss = 364.0962
# Epoch 8: Train Loss = 362.9067, Test Loss = 359.0534
# Epoch 9: Train Loss = 360.1834, Test Loss = 359.4535
# Epoch 10: Train Loss = 357.9858, Test Loss = 357.1955
# Epoch 11: Train Loss = 359.1528, Test Loss = 357.3551
# Epoch 12: Train Loss = 356.8834, Test Loss = 358.4645
# Epoch 13: Train Loss = 357.7409, Test Loss = 356.3242
# Epoch 14: Train Loss = 358.4140, Test Loss = 356.5502
# Epoch 15: Train Loss = 357.1729, Test Loss = 366.5823
# Epoch 16: Train Loss = 355.9763, Test Loss = 354.6586
# Epoch 17: Train Loss = 356.6998, Test Loss = 355.7612
# Epoch 18: Train Loss = 356.9954, Test Loss = 356.2206
# Epoch 19: Train Loss = 354.4845, Test Loss = 360.9725
# Epoch 20: Train Loss = 354.2609, Test Loss = 360.4058
# Epoch 21: Train Loss = 356.9102, Test Loss = 355.6192
# Epoch 22: Train Loss = 355.5990, Test Loss = 358.4307
# Epoch 23: Train Loss = 354.5463, Test Loss = 354.5288
# Epoch 24: Train Loss = 353.9335, Test Loss = 353.9146
# Epoch 25: Train Loss = 354.5006, Test Loss = 354.8124
# Epoch 26: Train Loss = 353.9089, Test Loss = 353.3009
# Epoch 27: Train Loss = 355.8449, Test Loss = 352.8512
# Epoch 28: Train Loss = 355.5091, Test Loss = 358.4415
# Epoch 29: Train Loss = 354.3426, Test Loss = 352.2111
# Epoch 30: Train Loss = 353.8509, Test Loss = 352.9052
# Epoch 31: Train Loss = 352.5895, Test Loss = 356.0563
# Epoch 32: Train Loss = 353.8968, Test Loss = 351.8735
# Epoch 33: Train Loss = 353.0408, Test Loss = 356.8061
# Epoch 34: Train Loss = 354.7228, Test Loss = 353.2752
# Epoch 35: Train Loss = 353.6764, Test Loss = 352.0596
# Epoch 36: Train Loss = 353.0716, Test Loss = 351.7572
# Epoch 37: Train Loss = 354.4668, Test Loss = 353.1417
# Epoch 38: Train Loss = 354.3522, Test Loss = 352.6021
# Epoch 39: Train Loss = 353.8452, Test Loss = 352.0004
# Epoch 40: Train Loss = 352.9795, Test Loss = 362.6688
# Epoch 41: Train Loss = 352.5773, Test Loss = 353.3052
# Epoch 42: Train Loss = 353.7213, Test Loss = 351.7800
# Epoch 43: Train Loss = 352.8313, Test Loss = 351.9621
# Epoch 44: Train Loss = 351.4387, Test Loss = 351.9013
# Epoch 45: Train Loss = 352.0712, Test Loss = 354.4010
# Epoch 46: Train Loss = 354.1076, Test Loss = 350.6428
# Epoch 47: Train Loss = 352.0873, Test Loss = 356.9359
# Epoch 48: Train Loss = 352.6493, Test Loss = 353.2200
# Epoch 49: Train Loss = 352.4865, Test Loss = 358.8684
# Epoch 50: Train Loss = 350.1053, Test Loss = 350.3080
# Epoch 51: Train Loss = 351.8740, Test Loss = 355.3537
# Epoch 52: Train Loss = 352.0286, Test Loss = 358.9588
# Epoch 53: Train Loss = 351.7243, Test Loss = 364.0013
# Epoch 54: Train Loss = 352.2380, Test Loss = 349.9778
# Epoch 55: Train Loss = 352.1464, Test Loss = 350.0834
# Epoch 56: Train Loss = 351.8545, Test Loss = 353.0005
# Epoch 57: Train Loss = 351.0171, Test Loss = 349.6257
# Epoch 58: Train Loss = 352.0638, Test Loss = 349.4748
# Epoch 59: Train Loss = 351.7120, Test Loss = 349.8558
# Epoch 60: Train Loss = 351.0864, Test Loss = 350.2390
# Epoch 61: Train Loss = 353.2038, Test Loss = 349.6760
# Epoch 62: Train Loss = 351.7414, Test Loss = 349.6064
# Epoch 63: Train Loss = 351.0202, Test Loss = 363.2192
# Epoch 64: Train Loss = 348.7873, Test Loss = 351.3910
# Epoch 65: Train Loss = 350.7379, Test Loss = 349.4765
# Epoch 66: Train Loss = 351.5792, Test Loss = 350.2117
# Epoch 67: Train Loss = 348.7622, Test Loss = 348.1121
# Epoch 68: Train Loss = 350.0869, Test Loss = 353.2871
# Epoch 69: Train Loss = 350.0662, Test Loss = 353.8037
# Epoch 70: Train Loss = 351.9161, Test Loss = 350.4306
# Epoch 71: Train Loss = 350.8945, Test Loss = 354.7559
# Epoch 72: Train Loss = 349.6214, Test Loss = 352.6997
# Epoch 73: Train Loss = 348.8015, Test Loss = 347.9915
# Epoch 74: Train Loss = 349.7999, Test Loss = 347.8220
# Epoch 75: Train Loss = 350.1305, Test Loss = 348.5303
# Epoch 76: Train Loss = 352.2381, Test Loss = 347.8158
# Epoch 77: Train Loss = 347.7014, Test Loss = 348.5729
# Epoch 78: Train Loss = 348.4419, Test Loss = 359.5669
# Epoch 79: Train Loss = 350.9019, Test Loss = 354.2790
# Epoch 80: Train Loss = 349.3417, Test Loss = 350.1950
# Epoch 81: Train Loss = 348.1902, Test Loss = 346.5342
# Epoch 82: Train Loss = 347.2434, Test Loss = 347.6540
# Epoch 83: Train Loss = 348.0181, Test Loss = 348.9888
# Epoch 84: Train Loss = 347.3308, Test Loss = 349.3411
# Epoch 85: Train Loss = 350.5167, Test Loss = 352.0007
# Epoch 86: Train Loss = 350.2011, Test Loss = 346.8105
# Epoch 87: Train Loss = 346.2457, Test Loss = 345.7136
# Epoch 88: Train Loss = 346.0718, Test Loss = 347.5686
# Epoch 89: Train Loss = 347.0725, Test Loss = 346.0697
# Epoch 90: Train Loss = 347.9830, Test Loss = 345.8033
# Epoch 91: Train Loss = 347.1742, Test Loss = 354.3705
# Epoch 92: Train Loss = 347.0504, Test Loss = 346.6886
# Epoch 93: Train Loss = 346.8417, Test Loss = 345.3108
# Epoch 94: Train Loss = 345.4680, Test Loss = 345.3532
# Epoch 95: Train Loss = 346.5916, Test Loss = 345.8812
# Epoch 96: Train Loss = 348.0601, Test Loss = 351.4222
# Epoch 97: Train Loss = 345.5312, Test Loss = 345.9708
# Epoch 98: Train Loss = 346.7352, Test Loss = 345.5323
# Epoch 99: Train Loss = 346.2896, Test Loss = 345.1847
# Epoch 100: Train Loss = 346.8349, Test Loss = 354.5848
# Epoch 101: Train Loss = 347.8200, Test Loss = 349.4149
# Epoch 102: Train Loss = 347.5214, Test Loss = 346.4466
# Epoch 103: Train Loss = 346.5344, Test Loss = 343.7496
# Epoch 104: Train Loss = 344.9179, Test Loss = 347.0346
# Epoch 105: Train Loss = 346.0558, Test Loss = 347.0111
# Epoch 106: Train Loss = 346.3091, Test Loss = 343.4564
# Epoch 107: Train Loss = 346.5006, Test Loss = 345.6558
# Epoch 108: Train Loss = 344.8677, Test Loss = 343.7095
# Epoch 109: Train Loss = 344.5251, Test Loss = 343.4490
# Epoch 110: Train Loss = 345.8625, Test Loss = 345.6256
# Epoch 111: Train Loss = 344.5070, Test Loss = 346.3340
# Epoch 112: Train Loss = 345.1077, Test Loss = 342.8436
# Epoch 113: Train Loss = 343.5533, Test Loss = 342.9944
# Epoch 114: Train Loss = 344.1345, Test Loss = 352.7521
# Epoch 115: Train Loss = 345.4450, Test Loss = 342.4356
# Epoch 116: Train Loss = 344.1955, Test Loss = 346.0546
# Epoch 117: Train Loss = 346.0667, Test Loss = 343.2463
# Epoch 118: Train Loss = 343.1140, Test Loss = 342.1364
# Epoch 119: Train Loss = 344.0791, Test Loss = 341.8207
# Epoch 120: Train Loss = 342.9685, Test Loss = 341.9716
# Epoch 121: Train Loss = 343.5717, Test Loss = 343.8107
# Epoch 122: Train Loss = 342.8340, Test Loss = 341.6042
# Epoch 123: Train Loss = 342.8509, Test Loss = 341.5364
# Epoch 124: Train Loss = 345.0954, Test Loss = 341.2766
# Epoch 125: Train Loss = 342.1275, Test Loss = 343.8285
# Epoch 126: Train Loss = 343.5837, Test Loss = 341.2323
# Epoch 127: Train Loss = 343.4279, Test Loss = 341.2903
# Epoch 128: Train Loss = 344.2170, Test Loss = 341.2574
# Epoch 129: Train Loss = 342.9179, Test Loss = 344.2651
# Epoch 130: Train Loss = 342.8618, Test Loss = 341.9656
# Epoch 131: Train Loss = 342.4526, Test Loss = 340.9269
# Epoch 132: Train Loss = 343.9500, Test Loss = 347.8963
# Epoch 133: Train Loss = 341.8067, Test Loss = 340.6337
# Epoch 134: Train Loss = 342.8495, Test Loss = 340.3505
# Epoch 135: Train Loss = 342.6596, Test Loss = 342.4559
# Epoch 136: Train Loss = 341.4931, Test Loss = 340.8371
# Epoch 137: Train Loss = 342.5296, Test Loss = 344.1614
# Epoch 138: Train Loss = 342.9372, Test Loss = 355.5057
# Epoch 139: Train Loss = 343.1325, Test Loss = 340.3555
# Epoch 140: Train Loss = 342.7220, Test Loss = 345.5869
# Epoch 141: Train Loss = 342.8214, Test Loss = 340.3934
# Epoch 142: Train Loss = 341.8264, Test Loss = 340.1774
# Epoch 143: Train Loss = 343.0573, Test Loss = 347.1687
# Epoch 144: Train Loss = 341.3262, Test Loss = 340.0481
# Epoch 145: Train Loss = 342.8842, Test Loss = 343.0680
# Epoch 146: Train Loss = 340.9606, Test Loss = 340.2337
# Epoch 147: Train Loss = 340.9196, Test Loss = 341.0102
# Epoch 148: Train Loss = 341.2897, Test Loss = 339.5088
# Epoch 149: Train Loss = 340.8987, Test Loss = 339.2790
# Epoch 150: Train Loss = 340.5926, Test Loss = 344.0770
# Epoch 151: Train Loss = 341.4880, Test Loss = 341.6040
# Epoch 152: Train Loss = 342.5998, Test Loss = 339.3143
# Epoch 153: Train Loss = 342.3578, Test Loss = 339.4629
# Epoch 154: Train Loss = 341.2693, Test Loss = 339.7687
# Epoch 155: Train Loss = 340.6084, Test Loss = 339.1732
# Epoch 156: Train Loss = 340.7297, Test Loss = 340.2452
# Epoch 157: Train Loss = 340.0906, Test Loss = 339.8100
# Epoch 158: Train Loss = 339.7572, Test Loss = 343.3745
# Epoch 159: Train Loss = 341.7506, Test Loss = 344.0539
# Epoch 160: Train Loss = 340.8603, Test Loss = 340.9181
# Epoch 161: Train Loss = 342.1273, Test Loss = 340.7251
# Epoch 162: Train Loss = 340.4794, Test Loss = 339.8564
# Epoch 163: Train Loss = 343.1496, Test Loss = 339.0409
# Epoch 164: Train Loss = 341.9708, Test Loss = 341.0082
# Epoch 165: Train Loss = 340.3016, Test Loss = 349.8248
# Epoch 166: Train Loss = 341.0989, Test Loss = 338.9478
# Epoch 167: Train Loss = 341.0894, Test Loss = 339.9210
# Epoch 168: Train Loss = 340.7018, Test Loss = 339.1089
# Epoch 169: Train Loss = 341.7798, Test Loss = 339.3946
# Epoch 170: Train Loss = 340.1590, Test Loss = 339.4196
# Epoch 171: Train Loss = 342.3509, Test Loss = 342.3629
# Epoch 172: Train Loss = 340.9912, Test Loss = 340.9830
# Epoch 173: Train Loss = 340.7792, Test Loss = 340.1215
# Epoch 174: Train Loss = 341.9604, Test Loss = 342.0290
# Epoch 175: Train Loss = 340.2341, Test Loss = 338.4588
# Epoch 176: Train Loss = 342.8154, Test Loss = 340.5632
# Epoch 177: Train Loss = 341.4875, Test Loss = 338.3333
# Epoch 178: Train Loss = 341.5150, Test Loss = 340.2454
# Epoch 179: Train Loss = 339.9462, Test Loss = 340.2191
# Epoch 180: Train Loss = 341.7645, Test Loss = 345.4209
# Epoch 181: Train Loss = 341.8516, Test Loss = 339.1175
# Epoch 182: Train Loss = 340.7918, Test Loss = 338.5216
# Epoch 183: Train Loss = 341.1083, Test Loss = 342.3260
# Epoch 184: Train Loss = 340.0059, Test Loss = 341.9397
# Epoch 185: Train Loss = 340.0752, Test Loss = 357.3562
# Epoch 186: Train Loss = 341.2703, Test Loss = 341.6176
# Epoch 187: Train Loss = 341.0044, Test Loss = 338.8824
# ✅ Early stopping triggered for Gamma_band at epoch 187
#
# 🚀 Training CNN for High_Frequencies_band...
# Epoch 1: Train Loss = 1693.8148, Test Loss = 576.5935
# Epoch 2: Train Loss = 566.4085, Test Loss = 564.1053
# Epoch 3: Train Loss = 555.8476, Test Loss = 555.1819
# Epoch 4: Train Loss = 545.6836, Test Loss = 546.7456
# Epoch 5: Train Loss = 541.5514, Test Loss = 542.4205
# Epoch 6: Train Loss = 538.0203, Test Loss = 540.5060
# Epoch 7: Train Loss = 535.9380, Test Loss = 539.0811
# Epoch 8: Train Loss = 535.4404, Test Loss = 537.7076
# Epoch 9: Train Loss = 534.0469, Test Loss = 536.0862
# Epoch 10: Train Loss = 533.2835, Test Loss = 537.3798
# Epoch 11: Train Loss = 531.4534, Test Loss = 534.2001
# Epoch 12: Train Loss = 530.3810, Test Loss = 533.3012
# Epoch 13: Train Loss = 531.1687, Test Loss = 532.7178
# Epoch 14: Train Loss = 530.6041, Test Loss = 532.0588
# Epoch 15: Train Loss = 528.3439, Test Loss = 533.8686
# Epoch 16: Train Loss = 527.7207, Test Loss = 531.0956
# Epoch 17: Train Loss = 526.1103, Test Loss = 531.6807
# Epoch 18: Train Loss = 527.8388, Test Loss = 530.5713
# Epoch 19: Train Loss = 526.2999, Test Loss = 528.6429
# Epoch 20: Train Loss = 524.8787, Test Loss = 528.7348
# Epoch 21: Train Loss = 525.5832, Test Loss = 527.4360
# Epoch 22: Train Loss = 524.8648, Test Loss = 530.3844
# Epoch 23: Train Loss = 524.1302, Test Loss = 528.9121
# Epoch 24: Train Loss = 523.8924, Test Loss = 524.7086
# Epoch 25: Train Loss = 519.9601, Test Loss = 524.9509
# Epoch 26: Train Loss = 520.9905, Test Loss = 530.1648
# Epoch 27: Train Loss = 522.7351, Test Loss = 521.8864
# Epoch 28: Train Loss = 517.7710, Test Loss = 520.6262
# Epoch 29: Train Loss = 519.3154, Test Loss = 520.1725
# Epoch 30: Train Loss = 516.4085, Test Loss = 519.0478
# Epoch 31: Train Loss = 516.8887, Test Loss = 519.2883
# Epoch 32: Train Loss = 514.5019, Test Loss = 517.3938
# Epoch 33: Train Loss = 513.7973, Test Loss = 516.2275
# Epoch 34: Train Loss = 512.5251, Test Loss = 515.9515
# Epoch 35: Train Loss = 512.2172, Test Loss = 515.0995
# Epoch 36: Train Loss = 510.3842, Test Loss = 514.6664
# Epoch 37: Train Loss = 509.6999, Test Loss = 513.7710
# Epoch 38: Train Loss = 509.9037, Test Loss = 514.7753
# Epoch 39: Train Loss = 509.5800, Test Loss = 511.7296
# Epoch 40: Train Loss = 507.8957, Test Loss = 511.1016
# Epoch 41: Train Loss = 508.5170, Test Loss = 510.3775
# Epoch 42: Train Loss = 507.7600, Test Loss = 511.2679
# Epoch 43: Train Loss = 507.0575, Test Loss = 512.4168
# Epoch 44: Train Loss = 505.2474, Test Loss = 508.1245
# Epoch 45: Train Loss = 506.0311, Test Loss = 507.6609
# Epoch 46: Train Loss = 505.0024, Test Loss = 507.0711
# Epoch 47: Train Loss = 502.7976, Test Loss = 507.0050
# Epoch 48: Train Loss = 504.2417, Test Loss = 505.8872
# Epoch 49: Train Loss = 503.0530, Test Loss = 505.2956
# Epoch 50: Train Loss = 501.8727, Test Loss = 504.9514
# Epoch 51: Train Loss = 501.8562, Test Loss = 504.3923
# Epoch 52: Train Loss = 502.1123, Test Loss = 504.9930
# Epoch 53: Train Loss = 502.3423, Test Loss = 505.2325
# Epoch 54: Train Loss = 501.2651, Test Loss = 505.1199
# Epoch 55: Train Loss = 504.2418, Test Loss = 504.4515
# Epoch 56: Train Loss = 501.3507, Test Loss = 503.8970
# Epoch 57: Train Loss = 499.8605, Test Loss = 503.3544
# Epoch 58: Train Loss = 498.5161, Test Loss = 502.1537
# Epoch 59: Train Loss = 497.6828, Test Loss = 502.5186
# Epoch 60: Train Loss = 499.0059, Test Loss = 508.6054
# Epoch 61: Train Loss = 498.0240, Test Loss = 501.5355
# Epoch 62: Train Loss = 497.3735, Test Loss = 503.9501
# Epoch 63: Train Loss = 499.8767, Test Loss = 502.5072
# Epoch 64: Train Loss = 496.9824, Test Loss = 501.4412
# Epoch 65: Train Loss = 497.4045, Test Loss = 501.9747
# Epoch 66: Train Loss = 498.2127, Test Loss = 501.0841
# Epoch 67: Train Loss = 496.4517, Test Loss = 500.8035
# Epoch 68: Train Loss = 497.2307, Test Loss = 501.9915
# Epoch 69: Train Loss = 497.8758, Test Loss = 506.7789
# Epoch 70: Train Loss = 499.5521, Test Loss = 499.9766
# Epoch 71: Train Loss = 497.8854, Test Loss = 504.4184
# Epoch 72: Train Loss = 497.9708, Test Loss = 499.9963
# Epoch 73: Train Loss = 495.3294, Test Loss = 500.4239
# Epoch 74: Train Loss = 497.4109, Test Loss = 508.5756
# Epoch 75: Train Loss = 497.3321, Test Loss = 508.3086
# Epoch 76: Train Loss = 496.2004, Test Loss = 499.2457
# Epoch 77: Train Loss = 495.6587, Test Loss = 498.8254
# Epoch 78: Train Loss = 496.5767, Test Loss = 499.0874
# Epoch 79: Train Loss = 495.1212, Test Loss = 499.6762
# Epoch 80: Train Loss = 495.6165, Test Loss = 499.0745
# Epoch 81: Train Loss = 494.5809, Test Loss = 499.3090
# Epoch 82: Train Loss = 494.6364, Test Loss = 498.6411
# Epoch 83: Train Loss = 495.3801, Test Loss = 498.2214
# Epoch 84: Train Loss = 496.0413, Test Loss = 498.7183
# Epoch 85: Train Loss = 496.5155, Test Loss = 505.4864
# Epoch 86: Train Loss = 495.2147, Test Loss = 498.4005
# Epoch 87: Train Loss = 494.3875, Test Loss = 499.5690
# Epoch 88: Train Loss = 494.1600, Test Loss = 498.5792
# Epoch 89: Train Loss = 495.8759, Test Loss = 503.6720
# Epoch 90: Train Loss = 495.5210, Test Loss = 499.3047
# Epoch 91: Train Loss = 496.6393, Test Loss = 498.3565
# Epoch 92: Train Loss = 493.6217, Test Loss = 498.3569
# Epoch 93: Train Loss = 494.1261, Test Loss = 498.0522
# Epoch 94: Train Loss = 494.6548, Test Loss = 498.7335
# Epoch 95: Train Loss = 495.6830, Test Loss = 500.7519
# Epoch 96: Train Loss = 494.8086, Test Loss = 500.2069
# Epoch 97: Train Loss = 494.8893, Test Loss = 497.3794
# Epoch 98: Train Loss = 494.7685, Test Loss = 498.2572
# Epoch 99: Train Loss = 494.4620, Test Loss = 497.7198
# Epoch 100: Train Loss = 494.3477, Test Loss = 501.9634
# Epoch 101: Train Loss = 496.9839, Test Loss = 496.9092
# Epoch 102: Train Loss = 492.6959, Test Loss = 496.7504
# Epoch 103: Train Loss = 494.5394, Test Loss = 496.2842
# Epoch 104: Train Loss = 493.9334, Test Loss = 496.6315
# Epoch 105: Train Loss = 495.8468, Test Loss = 504.7955
# Epoch 106: Train Loss = 492.4901, Test Loss = 497.6549
# Epoch 107: Train Loss = 493.0479, Test Loss = 503.0970
# Epoch 108: Train Loss = 493.1602, Test Loss = 495.9226
# Epoch 109: Train Loss = 494.4880, Test Loss = 502.2295
# Epoch 110: Train Loss = 493.3844, Test Loss = 496.1002
# Epoch 111: Train Loss = 493.7190, Test Loss = 497.5284
# Epoch 112: Train Loss = 492.9733, Test Loss = 499.0254
# Epoch 113: Train Loss = 493.4024, Test Loss = 497.7773
# Epoch 114: Train Loss = 492.6595, Test Loss = 499.0224
# Epoch 115: Train Loss = 491.7472, Test Loss = 495.9796
# Epoch 116: Train Loss = 490.6956, Test Loss = 495.9571
# Epoch 117: Train Loss = 494.3629, Test Loss = 498.9098
# Epoch 118: Train Loss = 493.5488, Test Loss = 496.2401
# ✅ Early stopping triggered for High_Frequencies_band at epoch 118
#
# ✅ All EEG bands successfully trained!

# %%
# Reconstruct full EEG signals from denoised frequency bands
denoised_eeg = np.sum(denoised_bands, axis=0)  # Sum across frequency bands
clean_eeg = np.sum(clean_bands, axis=0)

# Ensure both arrays have the same shape
clean_eeg = clean_eeg.squeeze(1)  # Remove extra dimension if it exists

print(f"✅ Fixed EEG Reconstruction: Denoised EEG Shape: {denoised_eeg.shape}, Clean EEG Shape: {clean_eeg.shape}")
# Out:
# ✅ Fixed EEG Reconstruction: Denoised EEG Shape: (6800, 512), Clean EEG Shape: (6800, 512)

# %%
import numpy as np
from scipy.signal import welch

# Compute RRMSE in time domain
def compute_rrmse_t(clean, denoised):
    per_sample_rrmse = np.sqrt(np.sum((clean - denoised) ** 2, axis=1) / np.sum(clean ** 2, axis=1))
    return np.mean(per_sample_rrmse)

# Compute RRMSE in frequency domain using Power Spectral Density (PSD)
def compute_rrmse_s(clean, denoised, fs=512):
    f_clean, psd_clean = welch(clean.flatten(), fs=fs, nperseg=512)
    f_denoised, psd_denoised = welch(denoised.flatten(), fs=fs, nperseg=512)
    return np.sqrt(np.sum((psd_clean - psd_denoised) ** 2) / np.sum(psd_clean ** 2))

# Compute Correlation Coefficient (CC)
def compute_cc(clean, denoised):
    return np.corrcoef(clean.flatten(), denoised.flatten())[0, 1]

print("✅ Evaluation functions loaded!")
# Out:
# ✅ Evaluation functions loaded!

# %%
import pandas as pd

# Store evaluation results per SNR level
snr_metrics = {}

# Ensure snr_labels_test is a NumPy array
snr_labels_test = np.array(snr_labels_test).flatten()

# Evaluate each SNR level separately
for snr in np.unique(snr_labels_test):
    indices = np.where(snr_labels_test == snr)[0]  # Get test samples for this SNR

    clean_snr = clean_eeg[indices]
    denoised_snr = denoised_eeg[indices]

    # Compute evaluation metrics
    rrmse_t = compute_rrmse_t(clean_snr, denoised_snr)
    rrmse_s = compute_rrmse_s(clean_snr, denoised_snr, fs=512)
    cc = compute_cc(clean_snr, denoised_snr)
    ts_metric = 10 * np.log10(1 / (rrmse_t + rrmse_s))

    # Store metrics per SNR
    snr_metrics[snr] = {"RRMSE-T": rrmse_t, "RRMSE-S": rrmse_s, "CC": cc, "T&S Metric (dB)": ts_metric}

    print(f"  ✅ SNR {snr}: RRMSE-T = {rrmse_t:.4f}, RRMSE-S = {rrmse_s:.4f}, CC = {cc:.4f}, T&S Metric = {ts_metric:.4f} dB")

# Convert results to DataFrame for better visualization
df_snr_metrics = pd.DataFrame.from_dict(snr_metrics, orient="index")
df_snr_metrics.index.name = "SNR Level"

# Display results
# Out:
#   ✅ SNR -7: RRMSE-T = 0.7022, RRMSE-S = 0.5392, CC = 0.7216, T&S Metric = -0.9389 dB
#   ✅ SNR -6: RRMSE-T = 0.6653, RRMSE-S = 0.5543, CC = 0.7511, T&S Metric = -0.8619 dB
#   ✅ SNR -5: RRMSE-T = 0.6340, RRMSE-S = 0.5677, CC = 0.7752, T&S Metric = -0.7979 dB
#   ✅ SNR -4: RRMSE-T = 0.5970, RRMSE-S = 0.5705, CC = 0.7979, T&S Metric = -0.6724 dB
#   ✅ SNR -3: RRMSE-T = 0.5654, RRMSE-S = 0.5608, CC = 0.8219, T&S Metric = -0.5159 dB
#   ✅ SNR -2: RRMSE-T = 0.5442, RRMSE-S = 0.5912, CC = 0.8325, T&S Metric = -0.5515 dB
#   ✅ SNR -1: RRMSE-T = 0.5158, RRMSE-S = 0.5837, CC = 0.8508, T&S Metric = -0.4116 dB
#   ✅ SNR 0: RRMSE-T = 0.4847, RRMSE-S = 0.5603, CC = 0.8697, T&S Metric = -0.1913 dB
#   ✅ SNR 1: RRMSE-T = 0.4697, RRMSE-S = 0.5674, CC = 0.8784, T&S Metric = -0.1579 dB
#   ✅ SNR 2: RRMSE-T = 0.4524, RRMSE-S = 0.5885, CC = 0.8877, T&S Metric = -0.1742 dB

# %%
# Compute the average of all SNR-based metrics
avg_rrmse_t = np.mean([metrics["RRMSE-T"] for metrics in snr_metrics.values()])
avg_rrmse_s = np.mean([metrics["RRMSE-S"] for metrics in snr_metrics.values()])
avg_cc = np.mean([metrics["CC"] for metrics in snr_metrics.values()])
avg_ts_metric = np.mean([metrics["T&S Metric (dB)"] for metrics in snr_metrics.values()])

# Print the final summary
print("\n==== Final Evaluation Summary ====")
print(f"✅ Average RRMSE-T: {avg_rrmse_t:.4f}")
print(f"✅ Average RRMSE-S: {avg_rrmse_s:.4f}")
print(f"✅ Average CC: {avg_cc:.4f}")
print(f"✅ Average T&S Metric (dB): {avg_ts_metric:.4f}")

# Create DataFrame for display
# Out:
# ==== Final Evaluation Summary ====
# ✅ Average RRMSE-T: 0.5631
# ✅ Average RRMSE-S: 0.5683
# ✅ Average CC: 0.8187
# ✅ Average T&S Metric (dB): -0.5274

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ensure required variables are loaded
try:
    print(f"✅ SNR Labels Shape: {snr_labels_test.shape}, Clean EEG Shape: {clean_eeg.shape}, Denoised EEG Shape: {denoised_eeg.shape}")
except NameError:
    print("❌ Variables are not defined. Re-run the data preparation and evaluation cells.")

# ✅ Convert SNR labels to integers safely
try:
    snr_labels_test_int = np.array([int(str(snr).replace("SNR_", "")) for snr in snr_labels_test])
    print(f"✅ Converted SNR Labels: {snr_labels_test_int[:10]} ...")  # Show first 10 for debugging
except Exception as e:
    print(f"❌ Error converting SNR labels: {e}")

# Set SNR level to check
snr_level = -5  

# ✅ Extract indices of test samples for the selected SNR level
snr_indices = np.where(snr_labels_test_int == snr_level)[0]

# ✅ Handle missing SNR level
if len(snr_indices) == 0:
    print(f"❌ No test samples found for SNR Level {snr_level}.")
else:
    print(f"\n📊 Found {len(snr_indices)} test samples for SNR Level {snr_level}")
    print(f"✅ SNR Level {snr_level} indices in test set: {snr_indices.tolist()}")

    # ✅ Select the first segment
    first_segment_idx = snr_indices[0]

    # ✅ Extract EEG segments
    clean_segment = clean_eeg[first_segment_idx]
    denoised_segment = denoised_eeg[first_segment_idx]

    # ✅ Reconstruct Contaminated EEG by summing all frequency bands
    contaminated_bands = [test_data[band][1] for band in bands]
    contaminated_eeg = np.sum(contaminated_bands, axis=0)
    contaminated_segment = contaminated_eeg[first_segment_idx]

    # ✅ Plot EEG signals
    plt.figure(figsize=(12, 5))
    plt.plot(clean_segment, label="Clean EEG", linestyle="dashed", color="blue", linewidth=1.5)
    plt.plot(denoised_segment, label="Denoised EEG", linestyle="solid", color="red", linewidth=1.5)
    plt.plot(contaminated_segment, label="Contaminated EEG", linestyle="dotted", color="green", linewidth=1.5)
    
    plt.title(f"EEG Signal Comparison (SNR Level {snr_level}, First Segment)")
    plt.xlabel("Time (Samples)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# ✅ SNR Labels Shape: (6800,), Clean EEG Shape: (6800, 512), Denoised EEG Shape: (6800, 512)
# ✅ Converted SNR Labels: [-7 -7 -2 -4  2  1  2 -2 -2 -4] ...
#
# 📊 Found 680 test samples for SNR Level -5
# ✅ SNR Level -5 indices in test set: [26, 29, 51, 61, 79, 82, 89, 91, 94, 95, 108, 115, 120, 129, 136, 159, 161, 167, 186, 188, 194, 212, 220, 225, 235, 240, 248, 279, 284, 315, 318, 325, 331, 333, 336, 345, 354, 369, 371, 372, 379, 381, 386, 406, 408, 416, 419, 421, 433, 439, 453, 460, 484, 488, 490, 506, 508, 512, 549, 574, 598, 605, 620, 632, 635, 691, 695, 696, 713, 724, 726, 734, 738, 749, 750, 752, 753, 756, 767, 775, 783, 793, 800, 801, 817, 818, 831, 840, 858, 865, 882, 883, 902, 914, 936, 940, 960, 965, 969, 977, 978, 979, 981, 982, 1004, 1009, 1019, 1020, 1036, 1044, 1052, 1070, 1079, 1084, 1086, 1088, 1108, 1111, 1112, 1116, 1117, 1129, 1151, 1158, 1168, 1191, 1194, 1208, 1216, 1244, 1245, 1251, 1267, 1276, 1292, 1293, 1308, 1316, 1331, 1359, 1363, 1365, 1377, 1384, 1447, 1450, 1457, 1484, 1510, 1512, 1516, 1540, 1559, 1582, 1584, 1607, 1608, 1616, 1627, 1638, 1655, 1658, 1664, 1671, 1678, 1691, 1693, 1697, 1704, 1707, 1711, 1714, 1760, 1764, 1768, 1770, 1786, 1810, 1816, 1822, 1825, 1829, 1843, 1846, 1868, 1870, 1872, 1915, 1920, 1929, 1951, 1955, 1962, 1986, 1990, 2000, 2006, 2014, 2017, 2019, 2029, 2032, 2042, 2049, 2052, 2053, 2062, 2065, 2068, 2075, 2092, 2107, 2117, 2126, 2127, 2151, 2162, 2179, 2182, 2185, 2195, 2209, 2215, 2218, 2222, 2229, 2235, 2247, 2251, 2255, 2260, 2271, 2277, 2295, 2304, 2310, 2311, 2319, 2331, 2332, 2342, 2362, 2363, 2369, 2371, 2404, 2410, 2413, 2422, 2431, 2437, 2459, 2469, 2479, 2501, 2508, 2546, 2557, 2563, 2576, 2578, 2584, 2594, 2598, 2602, 2610, 2626, 2644, 2656, 2668, 2670, 2686, 2700, 2702, 2708, 2729, 2736, 2746, 2749, 2750, 2767, 2782, 2783, 2788, 2810, 2818, 2822, 2829, 2831, 2846, 2851, 2853, 2856, 2886, 2887, 2889, 2896, 2900, 2914, 2922, 2930, 2945, 2961, 2976, 2985, 2987, 2998, 3001, 3013, 3017, 3020, 3032, 3033, 3049, 3071, 3076, 3084, 3096, 3097, 3103, 3148, 3159, 3169, 3176, 3179, 3189, 3209, 3219, 3224, 3225, 3250, 3269, 3283, 3289, 3292, 3300, 3308, 3312, 3332, 3345, 3348, 3358, 3359, 3366, 3375, 3379, 3400, 3431, 3441, 3479, 3482, 3520, 3527, 3529, 3553, 3557, 3561, 3563, 3577, 3611, 3620, 3630, 3638, 3642, 3646, 3648, 3669, 3697, 3713, 3732, 3733, 3742, 3745, 3758, 3762, 3766, 3771, 3773, 3788, 3802, 3804, 3833, 3836, 3837, 3856, 3866, 3869, 3873, 3877, 3902, 3908, 3912, 3915, 3922, 3934, 3935, 3940, 3949, 3962, 3970, 3992, 4002, 4004, 4009, 4010, 4018, 4019, 4023, 4032, 4044, 4045, 4049, 4053, 4054, 4067, 4073, 4079, 4082, 4085, 4101, 4104, 4108, 4117, 4119, 4133, 4138, 4160, 4162, 4164, 4171, 4175, 4176, 4189, 4197, 4214, 4215, 4233, 4237, 4241, 4244, 4270, 4289, 4293, 4300, 4337, 4352, 4380, 4384, 4402, 4433, 4472, 4489, 4490, 4497, 4499, 4532, 4533, 4535, 4560, 4578, 4586, 4587, 4594, 4600, 4610, 4612, 4613, 4637, 4643, 4646, 4662, 4684, 4697, 4708, 4710, 4718, 4727, 4737, 4744, 4773, 4774, 4775, 4777, 4785, 4786, 4788, 4789, 4798, 4805, 4811, 4837, 4846, 4854, 4856, 4878, 4905, 4910, 4933, 4940, 4942, 4961, 4971, 4996, 4999, 5018, 5024, 5027, 5052, 5057, 5073, 5087, 5105, 5110, 5114, 5147, 5152, 5164, 5169, 5176, 5187, 5191, 5214, 5225, 5227, 5230, 5232, 5236, 5243, 5271, 5293, 5302, 5304, 5307, 5312, 5316, 5331, 5336, 5347, 5351, 5371, 5378, 5380, 5402, 5415, 5436, 5445, 5446, 5448, 5455, 5465, 5485, 5500, 5502, 5512, 5523, 5526, 5528, 5529, 5533, 5535, 5539, 5545, 5554, 5559, 5562, 5564, 5578, 5579, 5582, 5615, 5621, 5624, 5626, 5627, 5658, 5662, 5672, 5683, 5707, 5727, 5730, 5739, 5762, 5767, 5768, 5780, 5791, 5812, 5814, 5821, 5844, 5868, 5872, 5890, 5902, 5913, 5928, 5931, 5933, 5942, 5953, 5966, 5969, 5973, 5977, 5978, 6011, 6016, 6021, 6037, 6038, 6045, 6048, 6055, 6058, 6061, 6067, 6069, 6072, 6098, 6112, 6116, 6127, 6154, 6179, 6207, 6208, 6219, 6223, 6229, 6250, 6254, 6269, 6277, 6283, 6303, 6308, 6310, 6312, 6338, 6355, 6376, 6380, 6385, 6393, 6398, 6413, 6435, 6446, 6448, 6462, 6469, 6470, 6475, 6506, 6512, 6522, 6526, 6533, 6537, 6540, 6553, 6588, 6594, 6600, 6608, 6618, 6619, 6627, 6632, 6655, 6671, 6683, 6703, 6709, 6713, 6715, 6729, 6790, 679 ...
