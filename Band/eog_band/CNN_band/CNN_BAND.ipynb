# %%
import os
import numpy as np
import torch

# Check if GPU is available and set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Using device: {device}")

# Set paths for clean and contaminated EEG data
clean_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean"
contaminated_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated"

# Define EEG frequency bands
bands = ["Delta_band", "Theta_band", "Alpha_band", "Beta_band", "Gamma_band", "High_Frequencies_band"]

print(f"✅ Clean EEG Directory: {clean_dir}")
print(f"✅ Contaminated EEG Directory: {contaminated_dir}")
print(f"✅ EEG Bands: {bands}")
# Out:
# ✅ Using device: cuda
# ✅ Clean EEG Directory: /home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean
# ✅ Contaminated EEG Directory: /home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated
# ✅ EEG Bands: ['Delta_band', 'Theta_band', 'Alpha_band', 'Beta_band', 'Gamma_band', 'High_Frequencies_band']

# %%
import torch.nn as nn

class SimpleCNN(nn.Module):
    def __init__(self, input_length):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv1d(1, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm1d(64)
        self.conv3 = nn.Conv1d(64, 64, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm1d(64)
        self.conv4 = nn.Conv1d(64, 64, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm1d(64)
        self.fc = nn.Linear(input_length * 64, input_length)

    def forward(self, x):
        x = torch.relu(self.bn1(self.conv1(x)))
        x = torch.relu(self.bn2(self.conv2(x)))
        x = torch.relu(self.bn3(self.conv3(x)))
        x = torch.relu(self.bn4(self.conv4(x)))
        x = x.view(x.size(0), -1)  # Flatten before fully connected layer
        x = self.fc(x)
        return x

# %%
import torch.optim as optim

# Define Early Stopping Class
class EarlyStopping:
    def __init__(self, patience=10, min_delta=1e-4):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = None
        self.counter = 0
        self.stop_training = False

    def __call__(self, current_loss):
        if self.best_loss is None or current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.stop_training = True

# Define Loss Function (MSE)
criterion = nn.MSELoss()

# Define Optimizer (Adam)
input_length = 512  # EEG signal length
model = SimpleCNN(input_length).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Early stopping instance
early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

# Print confirmation
print("✅ Loss function, optimizer, and early stopping defined successfully!")
# Out:
# ✅ Loss function, optimizer, and early stopping defined successfully!

# %%
from sklearn.model_selection import train_test_split

def load_and_split_data(band_name):
    """
    Loads EEG data for a specific frequency band, splits into train and test sets based on SNR levels.
    """
    print(f"\n📌 Loading and Splitting Data for {band_name}...")

    # Load clean EEG data
    clean_band_path = os.path.join(clean_dir, f"{band_name}.npy")
    clean_band = np.load(clean_band_path)

    # Load contaminated EEG data across all SNR levels
    contaminated_band = []
    snr_labels = []

    for snr_folder in sorted(os.listdir(contaminated_dir)):  # Iterate through SNR folders
        contaminated_band_path = os.path.join(contaminated_dir, snr_folder, f"{band_name}.npy")
        contaminated_data = np.load(contaminated_band_path)

        contaminated_band.append(contaminated_data)
        snr_labels.extend([snr_folder] * len(contaminated_data))  # Track SNR levels

    # Convert lists to numpy arrays
    contaminated_band = np.concatenate(contaminated_band, axis=0)
    # Convert string labels ("SNR_-7") to integers (-7)
    
    snr_labels = np.array([int(snr.replace("SNR_", "")) for snr in snr_labels])


    # Ensure clean_band is correctly repeated to match contaminated EEG samples
    clean_band_repeated = np.tile(clean_band, (len(contaminated_band) // len(clean_band) + 1, 1))[:len(contaminated_band)]

    # Stratified Train-Test Split
    train_clean, test_clean, train_contaminated, test_contaminated, snr_labels_train, snr_labels_test = train_test_split(
        clean_band_repeated, contaminated_band, snr_labels, test_size=0.2, stratify=snr_labels, random_state=42
    )

    # Inspect data shapes
    print(f"✅ {band_name} Train Clean Shape: {train_clean.shape}, Test Clean Shape: {test_clean.shape}")
    print(f"✅ {band_name} Train Contaminated Shape: {train_contaminated.shape}, Test Contaminated Shape: {test_contaminated.shape}")
    print(f"✅ {band_name} SNR Labels Train: {np.unique(snr_labels_train)}, Test: {np.unique(snr_labels_test)}")

    return train_clean, train_contaminated, test_clean, test_contaminated, snr_labels_train, snr_labels_test

# Load and split data for each EEG band
train_data = {}
test_data = {}

for band in bands:
    train_clean, train_contaminated, test_clean, test_contaminated, snr_labels_train, snr_labels_test = load_and_split_data(band)
    train_data[band] = (train_clean, train_contaminated)
    test_data[band] = (test_clean, test_contaminated, snr_labels_test)

print("\n✅ All EEG bands successfully loaded and split!")
# Out:
# 📌 Loading and Splitting Data for Delta_band...
# ✅ Delta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Delta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Delta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Theta_band...
# ✅ Theta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Theta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Theta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Alpha_band...
# ✅ Alpha_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Alpha_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Alpha_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Beta_band...
# ✅ Beta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Beta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Beta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Gamma_band...
# ✅ Gamma_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Gamma_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Gamma_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for High_Frequencies_band...
# ✅ High_Frequencies_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ High_Frequencies_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ High_Frequencies_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# ✅ All EEG bands successfully loaded and split!

# %%
from torch.utils.data import DataLoader, TensorDataset

def train_cnn(train_clean, train_contaminated, test_clean, test_contaminated, band_name):
    """
    Trains the CNN model for EEG denoising on a specific frequency band.
    """
    print(f"\n🚀 Training CNN for {band_name}...")

    # Convert NumPy arrays to PyTorch tensors and move to GPU
    train_clean = torch.tensor(train_clean, dtype=torch.float32).unsqueeze(1).to(device)
    test_clean = torch.tensor(test_clean, dtype=torch.float32).unsqueeze(1).to(device)
    train_contaminated = torch.tensor(train_contaminated, dtype=torch.float32).unsqueeze(1).to(device)
    test_contaminated = torch.tensor(test_contaminated, dtype=torch.float32).unsqueeze(1).to(device)

    # Create DataLoader for training and testing
    train_dataset = TensorDataset(train_contaminated, train_clean)
    test_dataset = TensorDataset(test_contaminated, test_clean)
    train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

    # Define model, optimizer, and loss function
    input_length = train_contaminated.shape[2]  # EEG signal length
    model = SimpleCNN(input_length).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

    # Train model
    num_epochs = 1000
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets.squeeze(1))
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        avg_train_loss = running_loss / len(train_loader)

        # Evaluate model
        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for inputs, targets in test_loader:
                outputs = model(inputs)
                loss = criterion(outputs, targets.squeeze(1))
                test_loss += loss.item()

        avg_test_loss = test_loss / len(test_loader)

        print(f"Epoch {epoch + 1}: Train Loss = {avg_train_loss:.4f}, Test Loss = {avg_test_loss:.4f}")

        # Early stopping condition
        early_stopping(avg_test_loss)
        if early_stopping.stop_training:
            print(f"✅ Early stopping triggered for {band_name} at epoch {epoch + 1}")
            break

    # Generate denoised test set predictions
    with torch.no_grad():
        denoised_band = model(test_contaminated).squeeze(1).cpu().numpy()

    return denoised_band, test_clean.cpu().numpy()

# %%
denoised_bands = []
clean_bands = []

for band in bands:
    train_clean, train_contaminated = train_data[band]
    test_clean, test_contaminated, _ = test_data[band]

    denoised_band, clean_band_test = train_cnn(train_clean, train_contaminated, test_clean, test_contaminated, band)
    
    denoised_bands.append(denoised_band)
    clean_bands.append(clean_band_test)

print("\n✅ All EEG bands successfully trained!")
# Out:
# 🚀 Training CNN for Delta_band...
# Epoch 1: Train Loss = 6280.9183, Test Loss = 6143.2897
# Epoch 2: Train Loss = 5995.2735, Test Loss = 6051.0392
# Epoch 3: Train Loss = 5922.8465, Test Loss = 6004.2573
# Epoch 4: Train Loss = 5856.2785, Test Loss = 5976.7403
# Epoch 5: Train Loss = 5807.0558, Test Loss = 5943.2023
# Epoch 6: Train Loss = 5754.3047, Test Loss = 5947.3617
# Epoch 7: Train Loss = 5704.4202, Test Loss = 5848.1187
# Epoch 8: Train Loss = 5662.1864, Test Loss = 5845.3588
# Epoch 9: Train Loss = 5625.5278, Test Loss = 5915.7561
# Epoch 10: Train Loss = 5591.1604, Test Loss = 5854.2908
# Epoch 11: Train Loss = 5556.2598, Test Loss = 5758.1974
# Epoch 12: Train Loss = 5535.9325, Test Loss = 5768.5269
# Epoch 13: Train Loss = 5499.2939, Test Loss = 5786.3832
# Epoch 14: Train Loss = 5465.0345, Test Loss = 5713.3395
# Epoch 15: Train Loss = 5446.2135, Test Loss = 5727.2112
# Epoch 16: Train Loss = 5403.9980, Test Loss = 5713.7839
# Epoch 17: Train Loss = 5376.0377, Test Loss = 5702.4993
# Epoch 18: Train Loss = 5351.0580, Test Loss = 5633.7219
# Epoch 19: Train Loss = 5324.4964, Test Loss = 5648.6731
# Epoch 20: Train Loss = 5312.2906, Test Loss = 5671.2223
# Epoch 21: Train Loss = 5282.3837, Test Loss = 5618.1598
# Epoch 22: Train Loss = 5262.4954, Test Loss = 5709.8573
# Epoch 23: Train Loss = 5240.0670, Test Loss = 5598.6792
# Epoch 24: Train Loss = 5224.0876, Test Loss = 5559.2002
# Epoch 25: Train Loss = 5192.4114, Test Loss = 5571.9523
# Epoch 26: Train Loss = 5175.3076, Test Loss = 5623.7060
# Epoch 27: Train Loss = 5175.1814, Test Loss = 5523.5888
# Epoch 28: Train Loss = 5126.5069, Test Loss = 5547.3391
# Epoch 29: Train Loss = 5104.7764, Test Loss = 5535.1718
# Epoch 30: Train Loss = 5094.9228, Test Loss = 5514.8101
# Epoch 31: Train Loss = 5113.2205, Test Loss = 5504.1802
# Epoch 32: Train Loss = 5057.8113, Test Loss = 5491.2212
# Epoch 33: Train Loss = 5027.5236, Test Loss = 5564.8697
# Epoch 34: Train Loss = 5014.5181, Test Loss = 5449.8421
# Epoch 35: Train Loss = 5010.2448, Test Loss = 5503.3621
# Epoch 52: Train Loss = 2076.9797, Test Loss = 3106.9788
# Epoch 53: Train Loss = 2061.2698, Test Loss = 3097.1004
# Epoch 54: Train Loss = 2039.2132, Test Loss = 3029.5801
# Epoch 55: Train Loss = 2024.5892, Test Loss = 3039.6488
# Epoch 56: Train Loss = 1998.3734, Test Loss = 3049.5569
# Epoch 57: Train Loss = 1968.3520, Test Loss = 3013.4619
# Epoch 58: Train Loss = 1962.1584, Test Loss = 3055.6147
# Epoch 59: Train Loss = 1931.1625, Test Loss = 3028.2766
# Epoch 60: Train Loss = 1927.1012, Test Loss = 3014.1120
# Epoch 61: Train Loss = 1899.1681, Test Loss = 3037.1753
# Epoch 62: Train Loss = 1875.9092, Test Loss = 3002.4359
# Epoch 63: Train Loss = 1856.8037, Test Loss = 2994.6504
# Epoch 64: Train Loss = 1846.1174, Test Loss = 2990.6090
# Epoch 65: Train Loss = 1832.9720, Test Loss = 2982.0789
# Epoch 66: Train Loss = 1822.9120, Test Loss = 3010.5348
# Epoch 67: Train Loss = 1793.1562, Test Loss = 2936.5065
# Epoch 68: Train Loss = 1780.4586, Test Loss = 2977.8659
# Epoch 69: Train Loss = 1766.2317, Test Loss = 2974.1756
# Epoch 70: Train Loss = 1745.2824, Test Loss = 2952.1652
# Epoch 71: Train Loss = 1731.5006, Test Loss = 2942.6558
# Epoch 72: Train Loss = 1720.4894, Test Loss = 2961.5176
# Epoch 73: Train Loss = 1701.6571, Test Loss = 2930.2341
# Epoch 74: Train Loss = 1697.1807, Test Loss = 2951.2321
# Epoch 75: Train Loss = 1685.2199, Test Loss = 2942.8056
# Epoch 76: Train Loss = 1656.6914, Test Loss = 3014.1283
# Epoch 77: Train Loss = 1652.2226, Test Loss = 2941.4526
# Epoch 78: Train Loss = 1632.7414, Test Loss = 2912.8657
# Epoch 79: Train Loss = 1633.7859, Test Loss = 2949.5596
# Epoch 80: Train Loss = 1599.8846, Test Loss = 2934.4808
# Epoch 81: Train Loss = 1591.3632, Test Loss = 2928.4635
# Epoch 82: Train Loss = 1579.3962, Test Loss = 2961.6363
# Epoch 83: Train Loss = 1564.1698, Test Loss = 2921.1809
# Epoch 84: Train Loss = 1572.4996, Test Loss = 2933.4454
# Epoch 85: Train Loss = 1543.6354, Test Loss = 2916.8840
# Epoch 86: Train Loss = 1539.3880, Test Loss = 2927.0835
# Epoch 87: Train Loss = 1532.2259, Test Loss = 2962.6917
# Epoch 88: Train Loss = 1531.6141, Test Loss = 2943.6591
# ✅ Early stopping triggered for Theta_band at epoch 88
#
# 🚀 Training CNN for Alpha_band...
# Epoch 1: Train Loss = 2170.6049, Test Loss = 1972.3752
# Epoch 2: Train Loss = 1902.4261, Test Loss = 1918.7011
# Epoch 3: Train Loss = 1841.5370, Test Loss = 1876.0878
# Epoch 4: Train Loss = 1783.5840, Test Loss = 1836.0631
# Epoch 5: Train Loss = 1721.3816, Test Loss = 1797.0421
# Epoch 6: Train Loss = 1667.7183, Test Loss = 1765.0442
# Epoch 7: Train Loss = 1619.1334, Test Loss = 1743.8803
# Epoch 8: Train Loss = 1569.5846, Test Loss = 1714.8346
# Epoch 9: Train Loss = 1521.6127, Test Loss = 1689.4980
# Epoch 10: Train Loss = 1479.8082, Test Loss = 1672.0242
# Epoch 11: Train Loss = 1435.5357, Test Loss = 1652.3183
# Epoch 12: Train Loss = 1396.9998, Test Loss = 1642.8576
# Epoch 13: Train Loss = 1366.4975, Test Loss = 1641.5108
# Epoch 14: Train Loss = 1330.2545, Test Loss = 1616.4340
# Epoch 15: Train Loss = 1295.5842, Test Loss = 1592.9949
# Epoch 16: Train Loss = 1264.5250, Test Loss = 1605.0829
# Epoch 17: Train Loss = 1234.2020, Test Loss = 1544.9417
# Epoch 18: Train Loss = 1207.3662, Test Loss = 1543.8348
# Epoch 19: Train Loss = 1172.9069, Test Loss = 1539.0168
# Epoch 20: Train Loss = 1146.2863, Test Loss = 1529.4989
# Epoch 21: Train Loss = 1117.8323, Test Loss = 1507.2063
# Epoch 22: Train Loss = 1085.0656, Test Loss = 1543.0632
# Epoch 23: Train Loss = 1059.0769, Test Loss = 1471.6445
# Epoch 24: Train Loss = 1030.0259, Test Loss = 1483.2928
# Epoch 25: Train Loss = 1009.1611, Test Loss = 1444.1492
# Epoch 26: Train Loss = 983.8730, Test Loss = 1457.4812
# Epoch 27: Train Loss = 958.9911, Test Loss = 1410.3759
# Epoch 28: Train Loss = 935.3819, Test Loss = 1408.3710
# Epoch 29: Train Loss = 913.7807, Test Loss = 1392.8001
# Epoch 30: Train Loss = 892.7538, Test Loss = 1399.8214
# Epoch 31: Train Loss = 872.1558, Test Loss = 1395.1092
# Epoch 32: Train Loss = 851.1103, Test Loss = 1397.1861
# Epoch 33: Train Loss = 831.9662, Test Loss = 1393.9877
# Epoch 34: Train Loss = 815.2704, Test Loss = 1357.1888
# Epoch 35: Train Loss = 798.8667, Test Loss = 1579.0898
# Epoch 36: Train Loss = 777.1015, Test Loss = 1356.7073
# Epoch 37: Train Loss = 765.8264, Test Loss = 1360.6638
# Epoch 38: Train Loss = 747.2695, Test Loss = 1349.2566
# Epoch 39: Train Loss = 735.1760, Test Loss = 1345.3778
# Epoch 40: Train Loss = 722.9651, Test Loss = 1358.0821
# Epoch 41: Train Loss = 709.6425, Test Loss = 1418.0508
# Epoch 42: Train Loss = 689.3689, Test Loss = 1358.2365
# Epoch 43: Train Loss = 681.0896, Test Loss = 1320.9563
# Epoch 44: Train Loss = 668.5573, Test Loss = 1293.7109
# Epoch 45: Train Loss = 658.9660, Test Loss = 1448.5267
# Epoch 46: Train Loss = 648.0232, Test Loss = 1296.0257
# Epoch 47: Train Loss = 629.7855, Test Loss = 1308.3208
# Epoch 48: Train Loss = 622.1419, Test Loss = 1305.9265
# Epoch 49: Train Loss = 607.0275, Test Loss = 1281.3683
# Epoch 50: Train Loss = 603.3620, Test Loss = 1328.0973
# Epoch 51: Train Loss = 592.8773, Test Loss = 1276.0524
# Epoch 52: Train Loss = 575.9866, Test Loss = 1273.3281
# Epoch 53: Train Loss = 565.9329, Test Loss = 1276.2436
# Epoch 54: Train Loss = 559.5206, Test Loss = 1266.2443
# Epoch 55: Train Loss = 554.0754, Test Loss = 1295.4833
# Epoch 56: Train Loss = 544.3252, Test Loss = 1294.1332
# Epoch 57: Train Loss = 536.6421, Test Loss = 1283.7965
# Epoch 58: Train Loss = 520.6188, Test Loss = 1279.6175
# Epoch 59: Train Loss = 526.2358, Test Loss = 1298.8700
# Epoch 60: Train Loss = 504.3560, Test Loss = 1393.7081
# Epoch 61: Train Loss = 509.2431, Test Loss = 1282.0605
# Epoch 62: Train Loss = 506.6567, Test Loss = 1323.7556
# Epoch 63: Train Loss = 490.5900, Test Loss = 1377.9199
# Epoch 64: Train Loss = 479.8374, Test Loss = 1263.5205
# Epoch 65: Train Loss = 468.1853, Test Loss = 1280.7466
# Epoch 66: Train Loss = 465.5921, Test Loss = 1326.8918
# Epoch 67: Train Loss = 460.1359, Test Loss = 1374.4279
# Epoch 68: Train Loss = 462.0765, Test Loss = 1276.3824
# Epoch 69: Train Loss = 455.0615, Test Loss = 1247.1151
# Epoch 70: Train Loss = 445.6665, Test Loss = 1395.1542
# Epoch 71: Train Loss = 438.6631, Test Loss = 1260.0006
# Epoch 72: Train Loss = 437.1393, Test Loss = 1269.8131
# Epoch 73: Train Loss = 433.5411, Test Loss = 1250.1920
# Epoch 74: Train Loss = 427.6074, Test Loss = 1372.0583
# Epoch 75: Train Loss = 418.8185, Test Loss = 1290.2281
# Epoch 76: Train Loss = 410.9980, Test Loss = 1282.8126
# Epoch 77: Train Loss = 411.4276, Test Loss = 1236.3765
# Epoch 78: Train Loss = 412.8874, Test Loss = 1320.1440
# Epoch 79: Train Loss = 410.0728, Test Loss = 1247.4205
# Epoch 80: Train Loss = 394.3057, Test Loss = 1230.0910
# Epoch 81: Train Loss = 399.1940, Test Loss = 1261.9965
# Epoch 82: Train Loss = 381.5042, Test Loss = 1265.5000
# Epoch 83: Train Loss = 392.0608, Test Loss = 1412.5232
# Epoch 84: Train Loss = 374.9440, Test Loss = 1232.3107
# Epoch 85: Train Loss = 379.9195, Test Loss = 1373.4020
# Epoch 86: Train Loss = 383.7007, Test Loss = 1332.6345
# Epoch 87: Train Loss = 374.0694, Test Loss = 1241.3805
# Epoch 88: Train Loss = 352.8771, Test Loss = 1227.7848
# Epoch 89: Train Loss = 362.2516, Test Loss = 1238.4311
# Epoch 90: Train Loss = 359.3291, Test Loss = 1310.1895
# Epoch 91: Train Loss = 352.2987, Test Loss = 1209.1888
# Epoch 92: Train Loss = 363.2846, Test Loss = 1234.6824
# Epoch 93: Train Loss = 343.3637, Test Loss = 1261.3806
# Epoch 94: Train Loss = 346.7019, Test Loss = 1215.1812
# Epoch 95: Train Loss = 337.4013, Test Loss = 1286.3004
# Epoch 96: Train Loss = 333.9783, Test Loss = 1250.5334
# Epoch 97: Train Loss = 333.9871, Test Loss = 1360.5960
# Epoch 98: Train Loss = 328.0764, Test Loss = 1288.8981
# Epoch 99: Train Loss = 321.0844, Test Loss = 1234.4620
# Epoch 100: Train Loss = 313.2340, Test Loss = 1290.0362
# Epoch 101: Train Loss = 326.4099, Test Loss = 1245.7198
# ✅ Early stopping triggered for Alpha_band at epoch 101
#
# 🚀 Training CNN for Beta_band...
# Epoch 1: Train Loss = 9929.6747, Test Loss = 3742.2709
# Epoch 2: Train Loss = 2783.5238, Test Loss = 2361.2675
# Epoch 3: Train Loss = 2108.1124, Test Loss = 2010.6535
# Epoch 4: Train Loss = 1869.0007, Test Loss = 1988.3767
# Epoch 5: Train Loss = 1695.7814, Test Loss = 1785.6870
# Epoch 6: Train Loss = 1563.1572, Test Loss = 1862.4754
# Epoch 7: Train Loss = 1439.9639, Test Loss = 1466.2044
# Epoch 8: Train Loss = 1340.8312, Test Loss = 1462.1243
# Epoch 9: Train Loss = 1249.6225, Test Loss = 1327.0014
# Epoch 10: Train Loss = 1153.5401, Test Loss = 1349.9066
# Epoch 11: Train Loss = 1074.0603, Test Loss = 1453.4656
# Epoch 12: Train Loss = 1004.4196, Test Loss = 1207.0872
# Epoch 13: Train Loss = 940.8295, Test Loss = 1507.7973
# Epoch 14: Train Loss = 874.7927, Test Loss = 1010.9403
# Epoch 15: Train Loss = 819.3607, Test Loss = 1122.4304
# Epoch 16: Train Loss = 773.4146, Test Loss = 882.5063
# Epoch 17: Train Loss = 722.6200, Test Loss = 866.6426
# Epoch 18: Train Loss = 675.8024, Test Loss = 918.0216
# Epoch 19: Train Loss = 632.5231, Test Loss = 813.4294
# Epoch 20: Train Loss = 621.1581, Test Loss = 768.6999
# Epoch 21: Train Loss = 561.9659, Test Loss = 760.0936
# Epoch 22: Train Loss = 538.9557, Test Loss = 710.9945
# Epoch 23: Train Loss = 504.6465, Test Loss = 654.7874
# Epoch 24: Train Loss = 475.4021, Test Loss = 663.2845
# Epoch 25: Train Loss = 452.0536, Test Loss = 639.9731
# Epoch 26: Train Loss = 417.7328, Test Loss = 603.3238
# Epoch 27: Train Loss = 398.9308, Test Loss = 597.2104
# Epoch 28: Train Loss = 378.8429, Test Loss = 551.3376
# Epoch 29: Train Loss = 364.8068, Test Loss = 527.7353
# Epoch 30: Train Loss = 344.8473, Test Loss = 552.1632
# Epoch 31: Train Loss = 338.2691, Test Loss = 496.9881
# Epoch 32: Train Loss = 311.2666, Test Loss = 498.7630
# Epoch 33: Train Loss = 301.1725, Test Loss = 449.2151
# Epoch 34: Train Loss = 288.8731, Test Loss = 433.1529
# Epoch 35: Train Loss = 285.6645, Test Loss = 430.5977
# Epoch 36: Train Loss = 268.3938, Test Loss = 422.0949
# Epoch 37: Train Loss = 255.7499, Test Loss = 442.9411
# Epoch 38: Train Loss = 251.3620, Test Loss = 408.4735
# Epoch 39: Train Loss = 243.8279, Test Loss = 392.2249
# Epoch 40: Train Loss = 234.8633, Test Loss = 374.6435
# Epoch 41: Train Loss = 222.2247, Test Loss = 436.4786
# Epoch 42: Train Loss = 212.9338, Test Loss = 428.2001
# Epoch 43: Train Loss = 205.2940, Test Loss = 376.5348
# Epoch 44: Train Loss = 190.6831, Test Loss = 334.4392
# Epoch 45: Train Loss = 191.6289, Test Loss = 371.2699
# Epoch 95: Train Loss = 84.9459, Test Loss = 204.5414
# Epoch 96: Train Loss = 71.4252, Test Loss = 178.8978
# Epoch 97: Train Loss = 67.5931, Test Loss = 188.3719
# Epoch 98: Train Loss = 67.4826, Test Loss = 178.3251
# Epoch 99: Train Loss = 67.4530, Test Loss = 189.0869
# Epoch 100: Train Loss = 70.0605, Test Loss = 246.8408
# Epoch 101: Train Loss = 65.2807, Test Loss = 205.8393
# Epoch 102: Train Loss = 62.2305, Test Loss = 172.3554
# Epoch 103: Train Loss = 65.9262, Test Loss = 189.2988
# Epoch 104: Train Loss = 61.6538, Test Loss = 178.6698
# Epoch 105: Train Loss = 60.2993, Test Loss = 208.5794
# Epoch 106: Train Loss = 59.5793, Test Loss = 179.7452
# Epoch 107: Train Loss = 68.2978, Test Loss = 175.9834
# Epoch 108: Train Loss = 68.9118, Test Loss = 204.9178
# Epoch 109: Train Loss = 61.3045, Test Loss = 173.8858
# Epoch 110: Train Loss = 60.3303, Test Loss = 181.2194
# Epoch 111: Train Loss = 60.7027, Test Loss = 170.5414
# Epoch 112: Train Loss = 60.8782, Test Loss = 186.5932
# Epoch 113: Train Loss = 62.1451, Test Loss = 215.7410
# Epoch 114: Train Loss = 65.4447, Test Loss = 178.7748
# Epoch 115: Train Loss = 55.6445, Test Loss = 160.3367
# Epoch 116: Train Loss = 55.2925, Test Loss = 171.5169
# Epoch 117: Train Loss = 54.6638, Test Loss = 162.5790
# Epoch 118: Train Loss = 64.8967, Test Loss = 269.7501
# Epoch 119: Train Loss = 62.8250, Test Loss = 179.5892
# Epoch 120: Train Loss = 60.6109, Test Loss = 159.4419
# Epoch 121: Train Loss = 56.4701, Test Loss = 249.2363
# Epoch 122: Train Loss = 57.5422, Test Loss = 202.0459
# Epoch 123: Train Loss = 57.9463, Test Loss = 167.5292
# Epoch 124: Train Loss = 57.3128, Test Loss = 168.3518
# Epoch 125: Train Loss = 49.9657, Test Loss = 168.3421
# Epoch 126: Train Loss = 50.8074, Test Loss = 157.8395
# Epoch 127: Train Loss = 52.9159, Test Loss = 153.1984
# Epoch 128: Train Loss = 54.8628, Test Loss = 210.4834
# Epoch 129: Train Loss = 55.4479, Test Loss = 187.3773
# Epoch 130: Train Loss = 49.8160, Test Loss = 169.4023
# Epoch 131: Train Loss = 59.3822, Test Loss = 160.3284
# Epoch 132: Train Loss = 52.5992, Test Loss = 151.3639
# Epoch 133: Train Loss = 52.1417, Test Loss = 162.1668
# Epoch 134: Train Loss = 53.7569, Test Loss = 170.8980
# Epoch 135: Train Loss = 49.2936, Test Loss = 176.0395
# Epoch 136: Train Loss = 49.8363, Test Loss = 164.7697
# Epoch 137: Train Loss = 52.4034, Test Loss = 148.5910
# Epoch 138: Train Loss = 52.9942, Test Loss = 162.8577
# Epoch 139: Train Loss = 45.3848, Test Loss = 154.0253
# Epoch 140: Train Loss = 47.9033, Test Loss = 173.4556
# Epoch 141: Train Loss = 50.6711, Test Loss = 152.5352
# Epoch 142: Train Loss = 49.7541, Test Loss = 160.2452
# Epoch 143: Train Loss = 48.8612, Test Loss = 166.2753
# Epoch 144: Train Loss = 47.2311, Test Loss = 160.7284
# Epoch 145: Train Loss = 51.9068, Test Loss = 152.5843
# Epoch 146: Train Loss = 45.0200, Test Loss = 144.9197
# Epoch 147: Train Loss = 49.9445, Test Loss = 165.7838
# Epoch 148: Train Loss = 46.5456, Test Loss = 151.8853
# Epoch 149: Train Loss = 43.3123, Test Loss = 149.8054
# Epoch 150: Train Loss = 47.2351, Test Loss = 170.8870
# Epoch 151: Train Loss = 48.8028, Test Loss = 157.5802
# Epoch 152: Train Loss = 43.9691, Test Loss = 146.6723
# Epoch 153: Train Loss = 45.8512, Test Loss = 163.3696
# Epoch 154: Train Loss = 45.2709, Test Loss = 172.5777
# Epoch 155: Train Loss = 42.6370, Test Loss = 152.5942
# Epoch 156: Train Loss = 47.0210, Test Loss = 187.7794
# ✅ Early stopping triggered for Beta_band at epoch 156
#
# 🚀 Training CNN for Gamma_band...
# Epoch 1: Train Loss = 1512.1448, Test Loss = 366.4565
# Epoch 2: Train Loss = 304.3004, Test Loss = 281.8088
# Epoch 3: Train Loss = 265.2166, Test Loss = 254.5904
# Epoch 4: Train Loss = 237.4153, Test Loss = 232.8790
# Epoch 5: Train Loss = 216.5522, Test Loss = 225.0507
# Epoch 6: Train Loss = 195.5712, Test Loss = 201.1494
# Epoch 7: Train Loss = 179.7127, Test Loss = 186.1303
# Epoch 8: Train Loss = 160.9182, Test Loss = 222.9059
# Epoch 9: Train Loss = 146.9927, Test Loss = 158.9724
# Epoch 10: Train Loss = 131.4125, Test Loss = 189.7627
# Epoch 11: Train Loss = 122.5377, Test Loss = 201.3893
# Epoch 12: Train Loss = 114.3973, Test Loss = 125.7247
# Epoch 13: Train Loss = 100.6607, Test Loss = 122.3137
# Epoch 14: Train Loss = 91.2470, Test Loss = 112.8275
# Epoch 15: Train Loss = 84.1724, Test Loss = 142.0839
# Epoch 16: Train Loss = 79.1993, Test Loss = 102.0386
# Epoch 17: Train Loss = 74.0996, Test Loss = 92.5470
# Epoch 18: Train Loss = 65.3402, Test Loss = 88.4916
# Epoch 19: Train Loss = 61.0253, Test Loss = 84.0565
# Epoch 20: Train Loss = 56.4893, Test Loss = 79.0815
# Epoch 21: Train Loss = 52.4419, Test Loss = 79.0224
# Epoch 22: Train Loss = 48.8358, Test Loss = 73.6380
# Epoch 23: Train Loss = 44.7324, Test Loss = 70.0659
# Epoch 24: Train Loss = 43.8323, Test Loss = 63.1644
# Epoch 25: Train Loss = 40.5075, Test Loss = 61.0321
# Epoch 26: Train Loss = 37.2808, Test Loss = 60.2345
# Epoch 27: Train Loss = 34.5438, Test Loss = 59.4040
# Epoch 28: Train Loss = 34.2098, Test Loss = 53.7610
# Epoch 29: Train Loss = 33.3903, Test Loss = 56.2715
# Epoch 30: Train Loss = 30.8794, Test Loss = 55.9709
# Epoch 31: Train Loss = 31.5618, Test Loss = 69.6484
# Epoch 32: Train Loss = 31.4837, Test Loss = 53.8992
# Epoch 33: Train Loss = 25.7808, Test Loss = 44.8972
# Epoch 34: Train Loss = 24.2960, Test Loss = 50.7712
# Epoch 35: Train Loss = 25.1526, Test Loss = 48.6011
# Epoch 36: Train Loss = 25.1813, Test Loss = 48.4326
# Epoch 37: Train Loss = 24.0004, Test Loss = 50.6216
# Epoch 38: Train Loss = 22.8158, Test Loss = 43.3756
# Epoch 39: Train Loss = 21.7188, Test Loss = 46.6421
# Epoch 40: Train Loss = 21.9475, Test Loss = 40.0218
# Epoch 41: Train Loss = 18.7541, Test Loss = 39.3273
# Epoch 42: Train Loss = 17.5882, Test Loss = 35.6821
# Epoch 43: Train Loss = 18.9572, Test Loss = 37.8253
# Epoch 44: Train Loss = 16.9678, Test Loss = 34.9973
# Epoch 45: Train Loss = 16.5869, Test Loss = 38.9563
# Epoch 46: Train Loss = 17.5872, Test Loss = 35.0569
# Epoch 47: Train Loss = 16.7530, Test Loss = 36.4157
# Epoch 48: Train Loss = 14.7354, Test Loss = 39.1555
# Epoch 49: Train Loss = 15.7506, Test Loss = 32.5608
# Epoch 50: Train Loss = 16.9086, Test Loss = 36.9202
# Epoch 51: Train Loss = 14.3172, Test Loss = 30.4053
# Epoch 52: Train Loss = 14.8628, Test Loss = 30.3742
# Epoch 53: Train Loss = 14.5773, Test Loss = 37.5437
# Epoch 54: Train Loss = 16.3151, Test Loss = 31.6511
# Epoch 55: Train Loss = 14.0149, Test Loss = 34.0690
# Epoch 56: Train Loss = 15.2359, Test Loss = 30.4822
# Epoch 57: Train Loss = 13.1836, Test Loss = 31.8386
# Epoch 58: Train Loss = 13.3837, Test Loss = 30.9866
# Epoch 59: Train Loss = 12.9622, Test Loss = 28.3801
# Epoch 60: Train Loss = 12.8292, Test Loss = 28.6711
# Epoch 61: Train Loss = 12.7867, Test Loss = 28.6556
# Epoch 62: Train Loss = 12.0793, Test Loss = 28.6398
# Epoch 63: Train Loss = 12.5218, Test Loss = 29.6874
# Epoch 64: Train Loss = 11.4582, Test Loss = 35.9149
# Epoch 65: Train Loss = 11.4781, Test Loss = 28.1052
# Epoch 66: Train Loss = 12.3779, Test Loss = 32.8073
# Epoch 67: Train Loss = 12.8286, Test Loss = 28.9426
# Epoch 68: Train Loss = 10.3180, Test Loss = 29.5723
# Epoch 69: Train Loss = 11.2315, Test Loss = 26.8504
# Epoch 70: Train Loss = 10.5425, Test Loss = 26.7838
# Epoch 71: Train Loss = 10.5658, Test Loss = 27.2243
# Epoch 72: Train Loss = 9.3030, Test Loss = 27.4705
# Epoch 73: Train Loss = 11.1051, Test Loss = 31.1601
# Epoch 74: Train Loss = 10.2693, Test Loss = 33.4943
# Epoch 75: Train Loss = 10.0259, Test Loss = 25.0295
# Epoch 76: Train Loss = 9.3208, Test Loss = 24.1047
# Epoch 77: Train Loss = 9.8925, Test Loss = 30.9488
# Epoch 78: Train Loss = 10.3723, Test Loss = 25.4684
# Epoch 79: Train Loss = 10.2159, Test Loss = 27.1349
# Epoch 80: Train Loss = 8.8757, Test Loss = 22.4600
# Epoch 81: Train Loss = 8.5667, Test Loss = 23.7421
# Epoch 82: Train Loss = 10.9176, Test Loss = 26.9857
# Epoch 83: Train Loss = 8.8879, Test Loss = 22.8381
# Epoch 84: Train Loss = 8.5186, Test Loss = 28.4224
# Epoch 85: Train Loss = 8.2420, Test Loss = 23.4553
# Epoch 86: Train Loss = 8.4137, Test Loss = 23.2605
# Epoch 87: Train Loss = 8.7123, Test Loss = 22.4649
# Epoch 88: Train Loss = 8.1857, Test Loss = 28.0216
# Epoch 89: Train Loss = 7.4098, Test Loss = 25.3978
# Epoch 90: Train Loss = 7.8509, Test Loss = 24.0662
# ✅ Early stopping triggered for Gamma_band at epoch 90
#
# 🚀 Training CNN for High_Frequencies_band...
# Epoch 1: Train Loss = 1989.5598, Test Loss = 985.8557
# Epoch 2: Train Loss = 635.2096, Test Loss = 465.4795
# Epoch 3: Train Loss = 340.0807, Test Loss = 288.9260
# Epoch 4: Train Loss = 225.2582, Test Loss = 213.0078
# Epoch 5: Train Loss = 165.4394, Test Loss = 188.1522
# Epoch 6: Train Loss = 128.9040, Test Loss = 134.2663
# Epoch 7: Train Loss = 101.2754, Test Loss = 118.1640
# Epoch 8: Train Loss = 83.7791, Test Loss = 102.5244
# Epoch 9: Train Loss = 69.0551, Test Loss = 95.0832
# Epoch 10: Train Loss = 59.6473, Test Loss = 75.7996
# Epoch 11: Train Loss = 50.2513, Test Loss = 75.4689
# Epoch 12: Train Loss = 43.2808, Test Loss = 64.6862
# Epoch 13: Train Loss = 37.9111, Test Loss = 51.6944
# Epoch 14: Train Loss = 33.7341, Test Loss = 71.0171
# Epoch 15: Train Loss = 31.7740, Test Loss = 43.6452
# Epoch 16: Train Loss = 27.3438, Test Loss = 41.6469
# Epoch 17: Train Loss = 24.2815, Test Loss = 37.0012
# Epoch 18: Train Loss = 23.4592, Test Loss = 38.1167
# Epoch 19: Train Loss = 21.1139, Test Loss = 47.4229
# Epoch 20: Train Loss = 20.2449, Test Loss = 31.4604
# Epoch 21: Train Loss = 18.5569, Test Loss = 50.0975
# Epoch 22: Train Loss = 17.0039, Test Loss = 36.2335
# Epoch 23: Train Loss = 16.3955, Test Loss = 26.8609
# Epoch 24: Train Loss = 14.1781, Test Loss = 44.6352
# Epoch 25: Train Loss = 14.6900, Test Loss = 35.4972
# Epoch 26: Train Loss = 14.2383, Test Loss = 23.8863
# Epoch 27: Train Loss = 14.9337, Test Loss = 26.6636
# Epoch 28: Train Loss = 13.0766, Test Loss = 22.3652
# Epoch 29: Train Loss = 11.4112, Test Loss = 21.6489
# Epoch 30: Train Loss = 11.5292, Test Loss = 23.7961
# Epoch 31: Train Loss = 11.3091, Test Loss = 19.9198
# Epoch 32: Train Loss = 11.5381, Test Loss = 23.3821
# Epoch 33: Train Loss = 10.5717, Test Loss = 20.7380
# Epoch 34: Train Loss = 10.0740, Test Loss = 21.2057
# Epoch 35: Train Loss = 10.3243, Test Loss = 18.1051
# Epoch 36: Train Loss = 9.9246, Test Loss = 19.4338
# Epoch 37: Train Loss = 9.0494, Test Loss = 20.6259
# Epoch 38: Train Loss = 10.5293, Test Loss = 20.9545
# Epoch 39: Train Loss = 9.8438, Test Loss = 18.5990
# Epoch 40: Train Loss = 9.0280, Test Loss = 16.9268
# Epoch 41: Train Loss = 9.2099, Test Loss = 15.3314
# Epoch 42: Train Loss = 8.4416, Test Loss = 25.6919
# Epoch 43: Train Loss = 8.3197, Test Loss = 17.3814
# Epoch 44: Train Loss = 8.0755, Test Loss = 19.7991
# Epoch 45: Train Loss = 8.0725, Test Loss = 14.6262
# Epoch 46: Train Loss = 7.5140, Test Loss = 23.5194
# Epoch 47: Train Loss = 6.8061, Test Loss = 15.6749
# Epoch 48: Train Loss = 6.7560, Test Loss = 13.6183
# Epoch 49: Train Loss = 6.2020, Test Loss = 20.7029
# Epoch 50: Train Loss = 6.8248, Test Loss = 21.1763
# Epoch 51: Train Loss = 7.8564, Test Loss = 18.1629
# Epoch 52: Train Loss = 7.3372, Test Loss = 19.2082
# Epoch 53: Train Loss = 7.7725, Test Loss = 14.8632
# Epoch 54: Train Loss = 6.7895, Test Loss = 15.2424
# Epoch 55: Train Loss = 6.7214, Test Loss = 12.7455
# Epoch 56: Train Loss = 5.8753, Test Loss = 13.3665
# Epoch 57: Train Loss = 6.5207, Test Loss = 16.6658
# Epoch 58: Train Loss = 7.0277, Test Loss = 12.3551
# Epoch 59: Train Loss = 6.4469, Test Loss = 14.6543
# Epoch 60: Train Loss = 5.9145, Test Loss = 13.9036
# Epoch 61: Train Loss = 6.0636, Test Loss = 14.7753
# Epoch 62: Train Loss = 6.4908, Test Loss = 17.5244
# Epoch 63: Train Loss = 6.2552, Test Loss = 13.2532
# Epoch 64: Train Loss = 5.3976, Test Loss = 12.2506
# Epoch 65: Train Loss = 5.5961, Test Loss = 12.1245
# Epoch 66: Train Loss = 5.1793, Test Loss = 10.7059
# Epoch 67: Train Loss = 5.6478, Test Loss = 11.7999
# Epoch 68: Train Loss = 6.8041, Test Loss = 18.1953
# Epoch 69: Train Loss = 5.9215, Test Loss = 10.9839
# Epoch 70: Train Loss = 5.4541, Test Loss = 11.4531
# Epoch 71: Train Loss = 5.2782, Test Loss = 13.3951
# Epoch 72: Train Loss = 5.7592, Test Loss = 12.7619
# Epoch 73: Train Loss = 6.0185, Test Loss = 11.5620
# Epoch 74: Train Loss = 4.8053, Test Loss = 16.0450
# Epoch 75: Train Loss = 5.2773, Test Loss = 11.0143
# Epoch 76: Train Loss = 5.4061, Test Loss = 15.9352
# ✅ Early stopping triggered for High_Frequencies_band at epoch 76
#
# ✅ All EEG bands successfully trained!

# %%
# Reconstruct full EEG signals from denoised frequency bands
denoised_eeg = np.sum(denoised_bands, axis=0)  # Sum across frequency bands
clean_eeg = np.sum(clean_bands, axis=0)

# Ensure both arrays have the same shape
clean_eeg = clean_eeg.squeeze(1)  # Remove extra dimension if it exists

print(f"✅ Fixed EEG Reconstruction: Denoised EEG Shape: {denoised_eeg.shape}, Clean EEG Shape: {clean_eeg.shape}")
# Out:
# ✅ Fixed EEG Reconstruction: Denoised EEG Shape: (6800, 512), Clean EEG Shape: (6800, 512)

# %%
import numpy as np
from scipy.signal import welch

# Compute RRMSE in time domain
def compute_rrmse_t(clean, denoised):
    per_sample_rrmse = np.sqrt(np.sum((clean - denoised) ** 2, axis=1) / np.sum(clean ** 2, axis=1))
    return np.mean(per_sample_rrmse)

# Compute RRMSE in frequency domain using Power Spectral Density (PSD)
def compute_rrmse_s(clean, denoised, fs=512):
    f_clean, psd_clean = welch(clean.flatten(), fs=fs, nperseg=512)
    f_denoised, psd_denoised = welch(denoised.flatten(), fs=fs, nperseg=512)
    return np.sqrt(np.sum((psd_clean - psd_denoised) ** 2) / np.sum(psd_clean ** 2))

# Compute Correlation Coefficient (CC)
def compute_cc(clean, denoised):
    return np.corrcoef(clean.flatten(), denoised.flatten())[0, 1]

print("✅ Evaluation functions loaded!")
# Out:
# ✅ Evaluation functions loaded!

# %%
import pandas as pd

# Store evaluation results per SNR level
snr_metrics = {}

# Ensure snr_labels_test is a NumPy array
snr_labels_test = np.array(snr_labels_test).flatten()

# Evaluate each SNR level separately
for snr in np.unique(snr_labels_test):
    indices = np.where(snr_labels_test == snr)[0]  # Get test samples for this SNR

    clean_snr = clean_eeg[indices]
    denoised_snr = denoised_eeg[indices]

    # Compute evaluation metrics
    rrmse_t = compute_rrmse_t(clean_snr, denoised_snr)
    rrmse_s = compute_rrmse_s(clean_snr, denoised_snr, fs=512)
    cc = compute_cc(clean_snr, denoised_snr)
    ts_metric = 10 * np.log10(1 / (rrmse_t + rrmse_s))

    # Store metrics per SNR
    snr_metrics[snr] = {"RRMSE-T": rrmse_t, "RRMSE-S": rrmse_s, "CC": cc, "T&S Metric (dB)": ts_metric}

    print(f"  ✅ SNR {snr}: RRMSE-T = {rrmse_t:.4f}, RRMSE-S = {rrmse_s:.4f}, CC = {cc:.4f}, T&S Metric = {ts_metric:.4f} dB")

# Convert results to DataFrame for better visualization
df_snr_metrics = pd.DataFrame.from_dict(snr_metrics, orient="index")
df_snr_metrics.index.name = "SNR Level"

# Display results
# Out:
#   ✅ SNR -7: RRMSE-T = 0.5950, RRMSE-S = 0.1433, CC = 0.8313, T&S Metric = 1.3173 dB
#   ✅ SNR -6: RRMSE-T = 0.4480, RRMSE-S = 0.2101, CC = 0.9071, T&S Metric = 1.8172 dB
#   ✅ SNR -5: RRMSE-T = 0.4577, RRMSE-S = 0.2624, CC = 0.9053, T&S Metric = 1.4258 dB
#   ✅ SNR -4: RRMSE-T = 0.4432, RRMSE-S = 0.2911, CC = 0.9049, T&S Metric = 1.3417 dB
#   ✅ SNR -3: RRMSE-T = 0.4337, RRMSE-S = 0.2980, CC = 0.9090, T&S Metric = 1.3563 dB
#   ✅ SNR -2: RRMSE-T = 0.4293, RRMSE-S = 0.3385, CC = 0.9078, T&S Metric = 1.1476 dB
#   ✅ SNR -1: RRMSE-T = 0.4102, RRMSE-S = 0.3508, CC = 0.9141, T&S Metric = 1.1860 dB
#   ✅ SNR 0: RRMSE-T = 0.3932, RRMSE-S = 0.3164, CC = 0.9216, T&S Metric = 1.4897 dB
#   ✅ SNR 1: RRMSE-T = 0.3765, RRMSE-S = 0.3235, CC = 0.9259, T&S Metric = 1.5488 dB
#   ✅ SNR 2: RRMSE-T = 0.3841, RRMSE-S = 0.3645, CC = 0.9234, T&S Metric = 1.2573 dB

# %%
# Compute the average of all SNR-based metrics
avg_rrmse_t = np.mean([metrics["RRMSE-T"] for metrics in snr_metrics.values()])
avg_rrmse_s = np.mean([metrics["RRMSE-S"] for metrics in snr_metrics.values()])
avg_cc = np.mean([metrics["CC"] for metrics in snr_metrics.values()])
avg_ts_metric = np.mean([metrics["T&S Metric (dB)"] for metrics in snr_metrics.values()])

# Print the final summary
print("\n==== Final Evaluation Summary ====")
print(f"✅ Average RRMSE-T: {avg_rrmse_t:.4f}")
print(f"✅ Average RRMSE-S: {avg_rrmse_s:.4f}")
print(f"✅ Average CC: {avg_cc:.4f}")
print(f"✅ Average T&S Metric (dB): {avg_ts_metric:.4f}")

# Create DataFrame for display
# Out:
# ==== Final Evaluation Summary ====
# ✅ Average RRMSE-T: 0.4371
# ✅ Average RRMSE-S: 0.2899
# ✅ Average CC: 0.9050
# ✅ Average T&S Metric (dB): 1.3888

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ensure required variables are loaded
try:
    print(f"✅ SNR Labels Shape: {snr_labels_test.shape}, Clean EEG Shape: {clean_eeg.shape}, Denoised EEG Shape: {denoised_eeg.shape}")
except NameError:
    print("❌ Variables are not defined. Re-run the data preparation and evaluation cells.")

# ✅ Convert SNR labels to integers safely
try:
    snr_labels_test_int = np.array([int(str(snr).replace("SNR_", "")) for snr in snr_labels_test])
    print(f"✅ Converted SNR Labels: {snr_labels_test_int[:10]} ...")  # Show first 10 for debugging
except Exception as e:
    print(f"❌ Error converting SNR labels: {e}")

# Set SNR level to check
snr_level = -5  

# ✅ Extract indices of test samples for the selected SNR level
snr_indices = np.where(snr_labels_test_int == snr_level)[0]

# ✅ Handle missing SNR level
if len(snr_indices) == 0:
    print(f"❌ No test samples found for SNR Level {snr_level}.")
else:
    print(f"\n📊 Found {len(snr_indices)} test samples for SNR Level {snr_level}")
    print(f"✅ SNR Level {snr_level} indices in test set: {snr_indices.tolist()}")

    # ✅ Select the first segment
    first_segment_idx = snr_indices[0]

    # ✅ Extract EEG segments
    clean_segment = clean_eeg[first_segment_idx]
    denoised_segment = denoised_eeg[first_segment_idx]

    # ✅ Reconstruct Contaminated EEG by summing all frequency bands
    contaminated_bands = [test_data[band][1] for band in bands]
    contaminated_eeg = np.sum(contaminated_bands, axis=0)
    contaminated_segment = contaminated_eeg[first_segment_idx]

    # ✅ Plot EEG signals
    plt.figure(figsize=(12, 5))
    plt.plot(clean_segment, label="Clean EEG", linestyle="dashed", color="blue", linewidth=1.5)
    plt.plot(denoised_segment, label="Denoised EEG", linestyle="solid", color="red", linewidth=1.5)
    plt.plot(contaminated_segment, label="Contaminated EEG", linestyle="dotted", color="green", linewidth=1.5)
    
    plt.title(f"EEG Signal Comparison (SNR Level {snr_level}, First Segment)")
    plt.xlabel("Time (Samples)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# (456, -162.75599670410156)
# (457, -86.095458984375)
# (458, -158.1593017578125)
# (459, -83.60054016113281)
# (460, 101.0482406616211)
# (461, 59.710304260253906)
# (462, -136.8372802734375)
# (463, -157.435302734375)
# (464, -43.185359954833984)
# (465, 20.847797393798828)
# (466, 98.02088928222656)
# (467, 223.4010009765625)
# (468, 233.4922637939453)
# (469, 117.06297302246094)
# (470, 31.70514678955078)
# (471, 31.962615966796875)
# (472, 68.49065399169922)
# (473, 98.43716430664062)
# (474, 23.578079223632812)
# (475, -133.75018310546875)
# (476, -177.24977111816406)
# (477, -135.3054962158203)
# (478, -233.780517578125)
# (479, -336.4626770019531)
# (480, -139.4969024658203)
# (481, 170.62432861328125)
# (482, 190.53993225097656)
# (483, 37.68089294433594)
# (484, 8.651138305664062)
# (485, 87.82071685791016)
# (486, 182.84097290039062)
# (487, 339.6817626953125)
# (488, 447.82421875)
# (489, 312.0733947753906)
# (490, 51.028411865234375)
# (491, -11.4918212890625)
# (492, 165.58908081054688)
# (493, 300.66766357421875)
# (494, 225.34475708007812)
# (495, 61.852447509765625)
# (496, -64.60340118408203)
# (497, -198.26544189453125)
# (498, -324.6443786621094)
# (499, -353.426025390625)
# (500, -304.783203125)
# (501, -229.39419555664062)
# (502, -94.48274230957031)
# (503, -0.9764556884765625)
# (504, -122.25581359863281)
# (505, -283.2601623535156)
# (506, -202.35818481445312)
# (507, 20.66364288330078)
# (508, 54.339874267578125)
# (509, -104.5985336303711)
# (510, -213.64395141601562)
# (511, -20.432762145996094)

# %%
x_points = list(range(len(clean_segment)))      # X-axis: time/sample index
y_points = clean_segment.tolist()               # Y-axis: denoised EEG values

# ✅ Print the plotting points
print("Clean EEG Plotting Points:")
for x, y in zip(x_points, y_points):
    print(f"({x}, {y})")
# Out:
# Clean EEG Plotting Points:
# (0, 866.0310668945312)
# (1, 1079.484130859375)
# (2, 731.6409301757812)
# (3, 862.6738891601562)
# (4, 866.7140502929688)
# (5, 588.8504028320312)
# (6, 136.66143798828125)
# (7, -298.35662841796875)
# (8, -691.608642578125)
# (9, -754.778564453125)
# (10, -658.8089599609375)
# (11, -812.54345703125)
# (12, -974.6163940429688)
# (13, -764.3228759765625)
# (14, -497.63824462890625)
# (15, -456.69189453125)
# (16, -364.16766357421875)
# (17, -113.02513885498047)
# (18, 65.3680419921875)
# (19, 168.07069396972656)
# (20, 334.055419921875)
# (21, 487.0714416503906)
# (22, 495.9732360839844)
# (23, 423.62994384765625)
# (24, 460.7734375)
# (25, 654.1538696289062)
# (26, 806.8607788085938)
# (27, 831.9862670898438)
# (28, 895.39453125)
# (29, 980.781494140625)
# (30, 880.4319458007812)
# (31, 661.5908203125)
# (32, 461.5799255371094)
# (33, 154.7933349609375)
# (34, -231.58509826660156)
# (35, -433.34747314453125)
# (36, -481.13232421875)
# (37, -568.77734375)
# (38, -649.6075439453125)
# (39, -692.3427124023438)
# (40, -753.9926147460938)
# (41, -698.4561157226562)
# (42, -490.4478454589844)
# (43, -383.2445068359375)
# (44, -392.09423828125)
# (45, -278.7664794921875)
# (268, 65.64724731445312)
# (269, -30.28588104248047)
# (270, -208.3074493408203)
# (271, -293.97015380859375)
# (272, -280.6976013183594)
# (273, -291.53900146484375)
# (274, -251.59864807128906)
# (275, -48.01298904418945)
# (276, 151.62730407714844)
# (277, 236.58370971679688)
# (278, 399.3594665527344)
# (279, 640.1990356445312)
# (280, 680.5205078125)
# (281, 567.2587890625)
# (282, 546.3631591796875)
# (283, 482.0318908691406)
# (284, 234.69415283203125)
# (285, 109.44432830810547)
# (286, 221.78106689453125)
# (287, 200.32940673828125)
# (288, -52.245086669921875)
# (289, -198.5204315185547)
# (290, -174.50877380371094)
# (291, -215.71878051757812)
# (292, -334.21044921875)
# (293, -387.6930847167969)
# (294, -379.07373046875)
# (295, -368.07373046875)
# (296, -382.35809326171875)
# (297, -430.7313537597656)
# (298, -418.96917724609375)
# (299, -259.5869445800781)
# (300, -98.51121520996094)
# (301, -98.90431213378906)
# (302, -131.1729736328125)
# (303, -36.41362380981445)
# (304, 49.88705825805664)
# (305, -19.497467041015625)
# (306, -114.3572998046875)
# (307, -111.7965087890625)
# (308, -138.39324951171875)
# (309, -278.774658203125)
# (310, -375.59503173828125)
# (311, -315.90521240234375)
# (312, -210.02308654785156)
# (313, -155.453369140625)
# (314, -122.94514465332031)
# (315, -112.40072631835938)
# (316, -143.86212158203125)
# (317, -152.18722534179688)
# (318, -130.005615234375)
# (319, -201.5044403076172)
# (320, -383.3306884765625)
# (321, -517.2307739257812)
# (322, -517.5880737304688)
# (323, -415.4578552246094)
# (324, -227.16213989257812)
# (325, -27.896697998046875)
# (326, 33.650535583496094)
# (327, -24.99191665649414)
# (328, -35.024940490722656)
# (329, 24.970735549926758)
# (330, 36.00978469848633)
# (331, -27.98285484313965)
# (332, -109.97901916503906)
# (333, -157.6514129638672)
# (334, -121.13591003417969)
# (335, -32.52130126953125)
# (336, 2.7542953491210938)
# (337, -0.780651330947876)
# (338, 33.35660934448242)
# (339, 45.31730651855469)
# (340, 1.5724334716796875)
# (341, 19.02320098876953)
# (342, 72.45707702636719)
# (343, -8.281295776367188)
# (344, -160.98175048828125)
# (345, -211.71829223632812)
# (346, -249.62014770507812)
# (347, -384.9573669433594)
# (348, -446.6896057128906)
# (349, -309.763671875)
# (350, -143.99697875976562)
# (351, -110.5201187133789)
# (352, -151.96115112304688)
# (353, -153.5152587890625)
# (354, -100.41121673583984)
# (355, -55.74494171142578)
# (356, -45.13253402709961)
# (357, -28.73717498779297)
# (358, -41.103538513183594)
# (359, -165.37765502929688)
# (360, -292.5384826660156)
# (361, -210.09237670898438)
# (362, 33.85221862792969)
# (363, 196.2642822265625)
# (364, 209.80044555664062)
# (365, 198.69554138183594)
# (366, 224.09652709960938)
# (367, 231.3795623779297)
# (368, 211.46133422851562)
# (369, 261.4588317871094)
# (370, 376.0990295410156)
# (371, 359.1436767578125)
# (372, 165.68154907226562)
# (373, 22.65569305419922)
# (374, -8.691314697265625)
# (375, -67.49958801269531)
# (376, -77.03447723388672)
# (377, 25.903900146484375)
# (378, -19.428390502929688)
# (491, -122.50296783447266)
# (492, 63.61440658569336)
# (493, 209.0049591064453)
# (494, 133.71859741210938)
# (495, -34.40025329589844)
# (496, -164.72027587890625)
# (497, -297.7940673828125)
# (498, -428.018798828125)
# (499, -459.90032958984375)
# (500, -411.7402648925781)
# (501, -332.11328125)
# (502, -190.4237518310547)
# (503, -95.10098266601562)
# (504, -216.89468383789062)
# (505, -379.2828369140625)
# (506, -289.0442810058594)
# (507, -53.72577667236328)
# (508, -22.9844970703125)
# (509, -188.67318725585938)
# (510, -297.11944580078125)
# (511, -92.98805236816406)

# %%
x_points = list(range(len(contaminated_segment)))      # X-axis: time/sample index
y_points = contaminated_segment.tolist()               # Y-axis: denoised EEG values

# ✅ Print the plotting points
print("Contaminated EEG Plotting Points:")
for x, y in zip(x_points, y_points):
    print(f"({x}, {y})")
# Out:
# Contaminated EEG Plotting Points:
# (0, 376.670188874805)
# (1, 410.31622600132704)
# (2, 119.4818911706754)
# (3, 202.17293545674943)
# (4, 253.06094761795939)
# (5, -19.556200305179345)
# (6, -519.0416695847294)
# (7, -1072.26102148189)
# (8, -1563.3573516376002)
# (9, -1720.370246559627)
# (10, -1754.3104653123644)
# (11, -2044.2768354031512)
# (12, -2292.7991845970987)
# (13, -2153.3006883563967)
# (14, -1990.357068452549)
# (15, -2054.757611000761)
# (16, -2052.7999659713437)
# (17, -1899.8263864513358)
# (18, -1804.9579912754734)
# (19, -1744.0127658459255)
# (20, -1612.0471579180064)
# (21, -1483.8930380379852)
# (22, -1454.6955047335553)
# (23, -1495.5388256765377)
# (24, -1459.8545807142682)
# (25, -1257.99884390659)
# (26, -1062.7707225912332)
# (27, -997.2508394588374)
# (28, -905.0569734139556)
# (29, -792.9648937103793)
# (30, -877.3091708660412)
# (31, -1061.21305944176)
# (32, -1198.041345787528)
# (33, -1474.9292753738396)
# (34, -1865.5084582648096)
# (35, -2031.8206293368537)
# (36, -2041.342462665656)
# (37, -2153.8978052719876)
# (38, -2240.453466089191)
# (39, -2211.6102162426064)
# (40, -2238.0867856799655)
# (41, -2213.3278987060985)
# (42, -1981.5905021275762)
# (43, -1807.613769384467)
# (44, -1825.3411870864306)
# (45, -1724.2478871124126)
# (46, -1433.237063444389)
# (47, -1227.660254078382)
# (48, -1141.0555771771608)
# (49, -1026.6938916853803)
# (50, -1001.1275885478306)
# (51, -1236.3809919697028)
# (52, -1546.6883214932727)
# (53, -1580.9254558098069)
# (54, -1367.5004411987707)
# (55, -1259.1233913554747)
# (56, -1307.6283687198911)
# (57, -1213.4502262122876)
# (58, -973.8450660105599)
# (59, -880.829651703666)
# (60, -943.3167602674197)
# (61, -976.2551302148855)
# (62, -1020.8747425885128)
# (63, -1154.1656646674746)
# (64, -1285.4193819005952)
# (65, -1340.9315800832278)
# (66, -1323.5977432241357)
# (67, -1235.861368518458)
# (68, -1105.4982416942576)
# (69, -931.219255620638)
# (70, -748.0226931840128)
# (71, -726.5878232867776)
# (72, -883.8817198797661)
# (73, -940.7204042834906)
# (74, -815.8647118204963)
# (75, -754.0694326701633)
# (184, 599.3690613935746)
# (185, 766.284511807637)
# (186, 808.4547673127764)
# (187, 732.7576397807695)
# (188, 544.1188103166107)
# (189, 335.4205833626646)
# (190, 433.23508807431085)
# (191, 757.8624150611649)
# (192, 769.1774417812992)
# (193, 457.4321814868671)
# (194, 293.3686829118917)
# (195, 304.2704788325522)
# (196, 240.37755647214777)
# (197, 168.6062630873321)
# (198, 177.079705649192)
# (199, 181.74857465976106)
# (200, 194.60319282890055)
# (201, 227.88127179046688)
# (202, 206.9651402110791)
# (203, 235.6211566979025)
# (204, 387.5331283462869)
# (205, 449.9755904410352)
# (206, 391.56644670630124)
# (207, 511.2498705431802)
# (208, 804.775509273055)
# (209, 988.1832382207905)
# (210, 1088.5636527947336)
# (211, 1245.6567969165458)
# (212, 1279.060419217559)
# (213, 1091.9592761275592)
# (214, 961.8214043284593)
# (215, 1056.1773219779511)
# (216, 1158.4661449065325)
# (217, 1082.881618448685)
# (218, 950.8388420469732)
# (219, 924.049792521117)
# (220, 882.9890743833819)
# (221, 641.7526060301241)
# (222, 351.730641551403)
# (223, 290.3359045943385)
# (224, 372.9131814986956)
# (225, 428.108628615004)
# (226, 601.5507333717761)
# (227, 922.7162139551602)
# (228, 1046.8689611574246)
# (229, 898.7076239119492)
# (230, 786.8445461679888)
# (231, 768.0665224431252)
# (232, 724.137610943564)
# (233, 800.9889960720351)
# (234, 995.5991043052638)
# (235, 950.314090048628)
# (236, 647.3590888778789)
# (237, 493.5585162299949)
# (238, 539.455409360717)
# (239, 487.36518041490933)
# (240, 321.0761666808169)
# (241, 225.90346783021653)
# (242, 175.14989967619735)
# (243, 97.28414556868593)
# (244, 105.28883983894215)
# (245, 286.087647296608)
# (246, 483.1706068324916)
# (247, 508.4299840625651)
# (248, 466.5378585762392)
# (249, 639.6228825641329)
# (250, 1010.6667164174745)
# (251, 1275.0781999670312)
# (252, 1342.6030648535236)
# (253, 1369.633265201307)
# (254, 1339.2753987530446)
# (255, 1152.8506203547802)
# (256, 942.2159641454718)
# (257, 859.5998064901794)
# (258, 831.0918171078162)
# (259, 794.3566164203831)
# (260, 805.8677688774937)
# (261, 852.0384950210915)
# (262, 864.7922750263477)
# (263, 872.0183824568647)
# (264, 905.5596345495037)
# (265, 935.2605268850673)
# (266, 967.2357677591759)
# (267, 1028.8772451249915)
# (268, 1042.5527261390876)
# (269, 933.9574683734857)
# (270, 800.2755477223177)
# (271, 765.7633201088582)
# (272, 755.3174349364264)
# (273, 697.9017850732215)
# (274, 746.9949274991648)
# (275, 971.4819994423226)
# (276, 1143.986994015339)
# (277, 1207.658258394817)
# (278, 1405.3504694321132)
# (279, 1688.8756429959049)
# (280, 1722.1524390160516)
# (281, 1568.1523153355743)
# (282, 1511.373443446443)
# (283, 1436.342878541603)
# (284, 1197.8152869832236)
# (285, 1078.6913609289488)
# (286, 1184.410815950487)
# (287, 1164.3067522773458)
# (288, 920.6629561194436)
# (289, 770.2399384685469)
# (290, 793.0355310800369)
# (291, 779.5273136086146)
# (292, 668.8838190630688)
# (293, 559.2181798368315)
# (294, 508.6367698922577)
# (295, 520.7849926755791)
# (296, 512.6526318104704)
# (297, 424.73143510089903)
# (298, 401.19563691934957)
# (299, 566.0694569077015)
# (300, 730.7371403564962)
# (301, 718.7493791565242)
# (302, 684.4220991024106)
# (303, 777.2258159298505)
# (304, 845.6713957078198)
# (305, 763.4978760622735)
# (306, 660.0137382264058)
# (307, 645.3184237162595)
# (308, 612.9593899405122)
# (309, 482.0225335549035)
# (310, 370.6119319920168)
# (311, 406.048043024694)
# (312, 526.9552463125557)
# (313, 611.5088235277017)
# (314, 635.6395438217039)
# (315, 626.6866416761645)
# (316, 596.7104454614332)
# (317, 579.9430472951352)
# (318, 573.6806392171696)
# (319, 497.50400211428644)
# (320, 327.90053012253406)
# (321, 175.29871479524422)
# (322, 135.00739540297755)
# (323, 224.80005269418714)
# (324, 420.2530757931537)
# (325, 612.0248101479774)
# (326, 655.9790654230343)
# (327, 591.5335829571723)
# (328, 580.8872011397925)
# (329, 638.0804314983677)
# (330, 648.9222483970399)
# (331, 589.8815170802457)
# (332, 512.656082251231)
# (333, 467.94513785892275)
# (334, 500.26957837067084)
# (335, 585.6132706355648)
# (336, 636.4745190407327)
# (337, 665.2036295260674)
# (338, 724.1183233177476)
# (339, 747.8747644802429)
# (340, 700.3488258749459)
# (341, 690.0173951082941)
# (342, 702.3735782859399)
# (343, 584.4930487118237)
# (344, 389.95975146617354)
# (345, 308.8097821493054)
# (346, 276.8600959402393)
# (347, 145.71454102664322)
# (348, 55.12039238761014)
# (349, 192.08039223322118)
# (350, 396.34906953751323)
# (351, 423.30220578820513)
# (352, 343.7124553426217)
# (353, 356.55597813043164)
# (354, 422.26674806394095)
# (355, 417.39221342999315)
# (356, 408.1762508601167)
# (357, 466.14916553918385)
# (358, 446.59418371003096)
# (359, 272.9247620331777)
# (360, 144.3809142288677)
# (361, 235.04442321336927)
# (362, 453.17492967481974)
# (363, 622.722002272988)
# (364, 662.5691903597053)
# (365, 628.0417963535489)
# (366, 628.7604099732334)
# (367, 642.5933279025099)
# (368, 587.559879131022)
# (369, 601.9907186482498)
# (370, 780.6559534174029)
# (371, 850.8951042089037)
# (372, 679.1085111282985)
# (373, 587.9636091068048)
# (374, 679.4247021362712)
# (375, 711.5385343725195)
# (376, 752.5897046277757)
# (377, 943.4941338431481)
# (378, 995.9778914802636)
# (379, 868.0470339614328)
# (380, 983.2770369105468)
# (381, 1270.230623519517)
# (382, 1288.9484335663485)
# (383, 1266.3929470070882)
# (384, 1583.9721198235839)
# (385, 1887.685834443715)
# (386, 1850.3304133054726)
# (387, 1822.101267216228)
# (388, 2036.5815750353354)
# (389, 2256.635272434806)
# (390, 2336.0497911532048)
# (391, 2338.0144115205094)
# (392, 2315.322173917112)
# (393, 2338.045250314554)
# (394, 2370.5540952849633)
# (395, 2250.544613330042)
# (396, 2000.6470412077222)
# (397, 1793.8174354899652)
# (398, 1660.411228816045)
# (399, 1633.6188891756783)
# (400, 1795.586153845494)
# (401, 1979.9016724075632)
# (402, 1933.9374550688249)
# (403, 1755.5932921315266)
# (404, 1691.1373304304996)
# (405, 1759.443031183714)
# (406, 1848.03479293532)
# (407, 1901.4669799641063)
# (408, 1899.1294440263264)
# (409, 1861.341103356563)
# (410, 1860.7652242818501)
# (411, 1987.3164251482544)
# (412, 2250.4559825521687)
# (413, 2488.0107367235387)
# (414, 2500.5735436964765)
# (415, 2321.5277790433292)
# (416, 2119.7016834695555)
# (417, 1947.4763474764732)
# (418, 1776.9490073607099)
# (419, 1603.0413219133115)
# (420, 1434.8428877053643)
# (421, 1357.7667022700525)
# (422, 1398.97751766076)
# (423, 1375.7698431771692)
# (424, 1234.5752462726882)
# (425, 1222.1846649953816)
# (426, 1356.3367393469432)
# (427, 1407.218753141651)
# (428, 1483.0188358848718)
# (429, 1768.4259202267508)
# (430, 1959.7636523276578)
# (431, 1824.0141705630622)
# (432, 1642.622801281832)
# (433, 1583.8011865269661)
# (434, 1506.9572835399817)
# (435, 1478.7103560809303)
# (436, 1597.5247176050536)
# (437, 1655.3185183638952)
# (438, 1541.2677397545433)
# (439, 1440.5031140878777)
# (440, 1450.326696939426)
# (441, 1527.9814939169319)
# (442, 1599.473956402701)
# (443, 1507.1166499677402)
# (444, 1225.861788156814)
# (445, 992.4369159140116)
# (446, 877.6143508126158)
# (447, 732.1183094632456)
# (448, 610.8521482958538)
# (449, 634.8223306661737)
# (450, 663.6555119724294)
# (451, 630.1950521361797)
# (452, 656.2312700193207)
# (453, 662.8954624428274)
# (454, 537.6033199701884)
# (455, 506.70909123758594)
# (456, 665.7077952281918)
# (457, 707.2591254668159)
# (458, 581.3240968424541)
# (459, 623.8651253846344)
# (460, 786.4586430042265)
# (461, 700.7523162447532)
# (462, 461.03538219701034)
# (463, 430.08514698542706)
# (464, 530.2036034338629)
# (465, 536.4743079211559)
# (466, 568.0782952488779)
# (467, 711.355462245865)
# (468, 755.2289390683572)
# (469, 649.4745278770823)
# (470, 589.6302415986171)
# (471, 627.0187382440033)
# (472, 677.4904655617072)
# (473, 702.3222443323368)
# (474, 621.2203840718491)
# (475, 447.9792345095762)
# (476, 380.35696067195045)
# (477, 391.99167231397985)
# (478, 232.91242524485108)
# (479, 64.34250852498371)
# (480, 244.13405894463736)
# (481, 542.9415143316286)
# (482, 510.51481617006345)
# (483, 296.31146277140476)
# (484, 245.70288069000702)
# (485, 291.78375454011064)
# (486, 323.10694843188566)
# (487, 443.3806860277924)
# (488, 551.6711555114819)
# (489, 392.1667183315871)
# (490, 78.51301510776545)
# (491, -8.787928501642028)
# (492, 172.29695807440186)
# (493, 295.0040025254864)
# (494, 182.65805431174311)
# (495, -11.189388431286133)
# (496, -163.6452425995786)
# (497, -323.8074971660256)
# (498, -476.7802444062037)
# (499, -532.8160072647195)
# (500, -521.772717132512)
# (501, -468.26481672389036)
# (502, -334.65792811719535)
# (503, -260.12198654475793)
# (504, -415.64311975175445)
# (505, -594.4793674661385)
# (506, -504.54711667098456)
# (507, -291.7588186058238)
# (508, -278.7745244796005)
# (509, -470.881713070121)
# (510, -573.9978011139726)
# (511, -419.9626838732817)
