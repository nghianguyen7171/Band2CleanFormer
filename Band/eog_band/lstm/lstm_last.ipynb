# %%
import os
import numpy as np
import torch
import torch.nn as nn

# Check if GPU is available and set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Using device: {device}")

# Set paths for clean and contaminated EEG data
clean_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean"
contaminated_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated"

# Define EEG frequency bands
bands = ["Delta_band", "Theta_band", "Alpha_band", "Beta_band", "Gamma_band", "High_Frequencies_band"]

print(f"✅ Clean EEG Directory: {clean_dir}")
print(f"✅ Contaminated EEG Directory: {contaminated_dir}")
print(f"✅ EEG Bands: {bands}")
# Out:
# ✅ Using device: cuda
# ✅ Clean EEG Directory: /home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean
# ✅ Contaminated EEG Directory: /home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated
# ✅ EEG Bands: ['Delta_band', 'Theta_band', 'Alpha_band', 'Beta_band', 'Gamma_band', 'High_Frequencies_band']

# %%
class AdvancedLSTM(nn.Module):
    def __init__(self, input_length):
        super(AdvancedLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size=1, hidden_size=512, num_layers=2, batch_first=True, dropout=0.3)
        self.layer_norm = nn.LayerNorm(512)  # Match hidden_size
        self.fc = nn.Linear(512, input_length)  # Match hidden_size

    def forward(self, x):
        x = x.permute(0, 2, 1)  # (batch_size, seq_len, input_size=1)
        x, _ = self.lstm(x)
        x = self.layer_norm(x[:, -1, :])  # Normalize last time step
        x = self.fc(x)
        return x

# %%
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = None
        self.counter = 0
        self.stop_training = False

    def __call__(self, current_loss):
        if self.best_loss is None or current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.stop_training = True

# %%
def normalize_signals(data):
    """Normalize the signals to zero mean and unit variance per sample."""
    return (data - np.mean(data, axis=1, keepdims=True)) / np.std(data, axis=1, keepdims=True)
bands = ["Delta_band", "Theta_band", "Alpha_band", "Beta_band", "Gamma_band", "High_Frequencies_band"]
clean_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Clean"
contaminated_dir = "/home/tulgaa/Desktop/eeg_last/eeg_last/Extracted_Bands/Contaminated"

# %%
from sklearn.model_selection import train_test_split

def load_and_split_data(band_name):
    """
    Loads EEG data for a specific frequency band, splits into train and test sets based on SNR levels.
    """
    print(f"\n📌 Loading and Splitting Data for {band_name}...")

    # Load clean EEG data
    clean_band_path = os.path.join(clean_dir, f"{band_name}.npy")
    clean_band = np.load(clean_band_path)

    # Load contaminated EEG data across all SNR levels
    contaminated_band = []
    snr_labels = []

    for snr_folder in sorted(os.listdir(contaminated_dir)):  # Iterate through SNR folders
        contaminated_band_path = os.path.join(contaminated_dir, snr_folder, f"{band_name}.npy")
        contaminated_data = np.load(contaminated_band_path)

        contaminated_band.append(contaminated_data)
        snr_labels.extend([snr_folder] * len(contaminated_data))  # Track SNR levels

    # Convert lists to numpy arrays
    contaminated_band = np.concatenate(contaminated_band, axis=0)
    # Convert string labels ("SNR_-7") to integers (-7)
    
    snr_labels = np.array([int(snr.replace("SNR_", "")) for snr in snr_labels])


    # Ensure clean_band is correctly repeated to match contaminated EEG samples
    clean_band_repeated = np.tile(clean_band, (len(contaminated_band) // len(clean_band) + 1, 1))[:len(contaminated_band)]

    # Stratified Train-Test Split
    train_clean, test_clean, train_contaminated, test_contaminated, snr_labels_train, snr_labels_test = train_test_split(
        clean_band_repeated, contaminated_band, snr_labels, test_size=0.2, stratify=snr_labels, random_state=42
    )

    # Inspect data shapes
    print(f"✅ {band_name} Train Clean Shape: {train_clean.shape}, Test Clean Shape: {test_clean.shape}")
    print(f"✅ {band_name} Train Contaminated Shape: {train_contaminated.shape}, Test Contaminated Shape: {test_contaminated.shape}")
    print(f"✅ {band_name} SNR Labels Train: {np.unique(snr_labels_train)}, Test: {np.unique(snr_labels_test)}")

    return train_clean, train_contaminated, test_clean, test_contaminated, snr_labels_train, snr_labels_test

# Load and split data for each EEG band
train_data = {}
test_data = {}

for band in bands:
    train_clean, train_contaminated, test_clean, test_contaminated, snr_labels_train, snr_labels_test = load_and_split_data(band)
    train_data[band] = (train_clean, train_contaminated)
    test_data[band] = (test_clean, test_contaminated, snr_labels_test)

print("\n✅ All EEG bands successfully loaded and split!")
# Out:
# 📌 Loading and Splitting Data for Delta_band...
# ✅ Delta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Delta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Delta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Theta_band...
# ✅ Theta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Theta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Theta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Alpha_band...
# ✅ Alpha_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Alpha_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Alpha_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Beta_band...
# ✅ Beta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Beta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Beta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for Gamma_band...
# ✅ Gamma_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Gamma_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Gamma_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Loading and Splitting Data for High_Frequencies_band...
# ✅ High_Frequencies_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ High_Frequencies_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ High_Frequencies_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# ✅ All EEG bands successfully loaded and split!

# %%
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
import torch.nn as nn
import torch
def train_and_denoise_band(train_clean, train_contaminated, test_clean, test_contaminated, band_name):
    print(f"\n📌 {band_name} Dataset Shapes:")
    print(f"  Train Clean: {train_clean.shape}, Train Contaminated: {train_contaminated.shape}")
    print(f"  Test Clean: {test_clean.shape}, Test Contaminated: {test_contaminated.shape}")

    train_clean = torch.tensor(train_clean, dtype=torch.float32).unsqueeze(1).to(device)
    test_clean = torch.tensor(test_clean, dtype=torch.float32).unsqueeze(1).to(device)
    train_contaminated = torch.tensor(train_contaminated, dtype=torch.float32).unsqueeze(1).to(device)
    test_contaminated = torch.tensor(test_contaminated, dtype=torch.float32).unsqueeze(1).to(device)

    train_dataset = TensorDataset(train_contaminated, train_clean)
    test_dataset = TensorDataset(test_contaminated, test_clean)
    train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

    input_length = train_contaminated.shape[2]
    model = AdvancedLSTM(input_length).to(device)  # ✅ Define the model
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    scaler = torch.cuda.amp.GradScaler()

    early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

    num_epochs = 1000
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            with torch.cuda.amp.autocast():
                outputs = model(inputs)
                loss = criterion(outputs, targets.squeeze(1))
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            running_loss += loss.item()

        avg_train_loss = running_loss / len(train_loader)

        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for inputs, targets in test_loader:
                with torch.cuda.amp.autocast():
                    outputs = model(inputs)
                    loss = criterion(outputs, targets.squeeze(1))
                test_loss += loss.item()

        avg_test_loss = test_loss / len(test_loader)

        print(f"Epoch {epoch + 1}: Train Loss = {avg_train_loss:.4f}, Test Loss = {avg_test_loss:.4f}")

        early_stopping(avg_test_loss)
        if early_stopping.stop_training:
            print(f"🚀 Early stopping triggered for {band_name} at epoch {epoch + 1}")
            break

    # ✅ Save the trained model for later use
    torch.save(model.state_dict(), f"{band_name}_trained_model.pth")

    # Process test data in smaller batches to reduce memory usage
    with torch.no_grad():
        denoised_batches = []
        batch_size = 256
        for i in range(0, len(test_contaminated), batch_size):
            batch = test_contaminated[i:i+batch_size]
            denoised_batch = model(batch).squeeze(1).cpu().numpy()
            denoised_batches.append(denoised_batch)
        denoised_band = np.concatenate(denoised_batches, axis=0)

    return model, denoised_band, test_clean.cpu().numpy(), test_contaminated.cpu().numpy()

# %%
denoised_bands = []
clean_bands = []
contaminated_bands = []
trained_models = {}

print("\n🚀 Training and Denoising Each Band...")

for band in bands:
    print(f"🟢 Processing {band}...")

    # ✅ Load and split data
    train_clean, train_contaminated, test_clean, test_contaminated, _, _ = load_and_split_data(band)

    # ✅ Normalize signals
    #train_clean = normalize_signals(train_clean)
    #train_contaminated = normalize_signals(train_contaminated)
    #test_clean = normalize_signals(test_clean)
    #test_contaminated = normalize_signals(test_contaminated)

    # ✅ Train the LSTM model and denoise the test set
    model, denoised_band, clean_band_test, contaminated_band_test = train_and_denoise_band(
        train_clean, train_contaminated, test_clean, test_contaminated, band
    )

    # ✅ Store trained model
    trained_models[band] = model

    # ✅ Store denoised EEG results
    if denoised_band is not None:
        denoised_bands.append(denoised_band)
        clean_bands.append(clean_band_test)
        contaminated_bands.append(contaminated_band_test)
        print(f"✅ {band} Training & Denoising Completed!\n")
    else:
        print(f"❌ {band} failed to produce a denoised signal!")

print("\n✅ All EEG Bands Processed Successfully!")
# Out:
# 🚀 Training and Denoising Each Band...
# 🟢 Processing Delta_band...
#
# 📌 Loading and Splitting Data for Delta_band...
# ✅ Delta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Delta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Delta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Delta_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 7389.2757, Test Loss = 7395.0726
# Epoch 2: Train Loss = 7230.0847, Test Loss = 7302.5564
# Epoch 3: Train Loss = 7164.1928, Test Loss = 7220.3883
# Epoch 4: Train Loss = 7084.2673, Test Loss = 7160.2326
# Epoch 5: Train Loss = 7137.2185, Test Loss = 7170.3193
# Epoch 6: Train Loss = 7084.0463, Test Loss = 7188.9800
# Epoch 7: Train Loss = 7023.7912, Test Loss = 7124.5815
# Epoch 8: Train Loss = 7011.7415, Test Loss = 7057.8998
# Epoch 9: Train Loss = 7053.2363, Test Loss = 7121.6312
# Epoch 10: Train Loss = 6992.3958, Test Loss = 7196.4670
# Epoch 11: Train Loss = 7019.5605, Test Loss = 7132.6709
# Epoch 12: Train Loss = 6975.8653, Test Loss = 7087.8790
# Epoch 13: Train Loss = 6960.0165, Test Loss = 6999.5328
# Epoch 14: Train Loss = 6839.1827, Test Loss = 6949.3382
# Epoch 15: Train Loss = 6992.1999, Test Loss = 7329.3702
# Epoch 16: Train Loss = 7150.9806, Test Loss = 7222.4444
# Epoch 17: Train Loss = 7056.5583, Test Loss = 7138.0910
# Epoch 18: Train Loss = 6979.4638, Test Loss = 7101.7075
# Epoch 19: Train Loss = 6902.8077, Test Loss = 6962.7978
# Epoch 20: Train Loss = 6855.8154, Test Loss = 7092.7737
# Epoch 21: Train Loss = 6740.6232, Test Loss = 6788.0849
# Epoch 22: Train Loss = 6804.0652, Test Loss = 6834.0167
# Epoch 23: Train Loss = 6741.1276, Test Loss = 6947.7880
# Epoch 24: Train Loss = 6772.7277, Test Loss = 6915.4208
# Epoch 25: Train Loss = 6681.2129, Test Loss = 6832.5807
# Epoch 26: Train Loss = 6667.4076, Test Loss = 6826.4476
# Epoch 27: Train Loss = 6626.6626, Test Loss = 6843.1402
# Epoch 28: Train Loss = 6607.6097, Test Loss = 6798.7780
# Epoch 29: Train Loss = 6586.7953, Test Loss = 6611.6391
# Epoch 30: Train Loss = 6452.3107, Test Loss = 6594.5817
# Epoch 31: Train Loss = 6452.4185, Test Loss = 6623.5791
# Epoch 32: Train Loss = 6508.2208, Test Loss = 6754.2607
# Epoch 33: Train Loss = 6397.3957, Test Loss = 6475.7172
# Epoch 34: Train Loss = 6491.8411, Test Loss = 6506.7765
# Epoch 35: Train Loss = 6415.8690, Test Loss = 6691.1260
# Epoch 36: Train Loss = 6810.4382, Test Loss = 6791.1434
# Epoch 37: Train Loss = 6553.4570, Test Loss = 6674.3579
# Epoch 38: Train Loss = 6344.4180, Test Loss = 6477.2179
# Epoch 39: Train Loss = 6311.4246, Test Loss = 6393.6720
# Epoch 40: Train Loss = 6270.6656, Test Loss = 6444.8528
# Epoch 41: Train Loss = 6200.1774, Test Loss = 6346.6655
# Epoch 42: Train Loss = 6472.5373, Test Loss = 6805.8412
# Epoch 43: Train Loss = 6619.8212, Test Loss = 6742.6668
# Epoch 44: Train Loss = 6493.0173, Test Loss = 6660.7198
# Epoch 45: Train Loss = 6402.5212, Test Loss = 6397.5117
# Epoch 46: Train Loss = 6236.7117, Test Loss = 6483.1223
# Epoch 47: Train Loss = 6170.8713, Test Loss = 6314.3513
# Epoch 48: Train Loss = 6117.1548, Test Loss = 6234.7380
# Epoch 49: Train Loss = 6073.2356, Test Loss = 6112.0537
# Epoch 50: Train Loss = 6007.7023, Test Loss = 6130.6253
# Epoch 51: Train Loss = 5897.5521, Test Loss = 6059.2606
# Epoch 52: Train Loss = 5864.3025, Test Loss = 6194.2451
# Epoch 53: Train Loss = 5870.0425, Test Loss = 5938.1285
# Epoch 54: Train Loss = 5865.8775, Test Loss = 6110.8832
# Epoch 55: Train Loss = 5894.7042, Test Loss = 5933.1659
# Epoch 56: Train Loss = 5769.2615, Test Loss = 5871.7586
# Epoch 57: Train Loss = 5755.5600, Test Loss = 5941.8142
# Epoch 58: Train Loss = 5804.1272, Test Loss = 5984.7596
# Epoch 59: Train Loss = 5785.3573, Test Loss = 5888.8573
# Epoch 60: Train Loss = 5656.5654, Test Loss = 5747.5241
# Epoch 61: Train Loss = 5587.1585, Test Loss = 5944.2883
# Epoch 62: Train Loss = 5550.3771, Test Loss = 5700.2052
# Epoch 63: Train Loss = 5461.4969, Test Loss = 5770.3089
# Epoch 64: Train Loss = 5391.8145, Test Loss = 5602.5084
# Epoch 65: Train Loss = 5357.0177, Test Loss = 5777.1391
# Epoch 66: Train Loss = 5319.1740, Test Loss = 5567.3891
# Epoch 67: Train Loss = 5257.6060, Test Loss = 5454.9493
# Epoch 68: Train Loss = 5237.3188, Test Loss = 5460.4646
# Epoch 69: Train Loss = 5169.6876, Test Loss = 5533.1341
# Epoch 70: Train Loss = 5160.0646, Test Loss = 5400.4737
# Epoch 71: Train Loss = 5052.0922, Test Loss = 5334.1776
# Epoch 72: Train Loss = 5071.3710, Test Loss = 5351.5730
# Epoch 73: Train Loss = 5018.1272, Test Loss = 5303.2911
# Epoch 74: Train Loss = 4929.7490, Test Loss = 5267.7358
# Epoch 75: Train Loss = 4875.1727, Test Loss = 5305.1490
# Epoch 76: Train Loss = 4828.3164, Test Loss = 5200.1426
# Epoch 77: Train Loss = 4726.8129, Test Loss = 5406.3750
# Epoch 78: Train Loss = 4734.8357, Test Loss = 5176.4548
# Epoch 79: Train Loss = 4644.5965, Test Loss = 5015.0857
# Epoch 80: Train Loss = 4558.7880, Test Loss = 5371.0595
# Epoch 81: Train Loss = 4530.9751, Test Loss = 4931.8642
# Epoch 82: Train Loss = 4479.6507, Test Loss = 5106.3045
# Epoch 83: Train Loss = 4451.7287, Test Loss = 5011.5807
# Epoch 84: Train Loss = 4305.1746, Test Loss = 4773.1874
# Epoch 85: Train Loss = 4259.6386, Test Loss = 4899.2656
# Epoch 86: Train Loss = 4150.9508, Test Loss = 4833.5792
# Epoch 87: Train Loss = 4123.9964, Test Loss = 4691.8386
# Epoch 88: Train Loss = 4024.1888, Test Loss = 4626.5180
# Epoch 89: Train Loss = 4012.4925, Test Loss = 4656.6617
# Epoch 90: Train Loss = 3900.0436, Test Loss = 4662.0160
# Epoch 91: Train Loss = 3853.5104, Test Loss = 4536.6426
# Epoch 92: Train Loss = 3861.5208, Test Loss = 4758.1146
# Epoch 93: Train Loss = 3721.1301, Test Loss = 4386.7907
# Epoch 94: Train Loss = 3571.3410, Test Loss = 4454.8553
# Epoch 95: Train Loss = 3511.6899, Test Loss = 4511.1989
# Epoch 96: Train Loss = 3505.7388, Test Loss = 4389.2202
# Epoch 97: Train Loss = 3422.3307, Test Loss = 4515.8167
# Epoch 98: Train Loss = 3406.9658, Test Loss = 4270.6206
# Epoch 99: Train Loss = 3224.4111, Test Loss = 4113.6209
# Epoch 100: Train Loss = 3146.1554, Test Loss = 3949.4678
# Epoch 101: Train Loss = 3058.1140, Test Loss = 4148.9167
# Epoch 102: Train Loss = 3044.8406, Test Loss = 4023.8364
# Epoch 103: Train Loss = 2968.0042, Test Loss = 4011.1668
# Epoch 104: Train Loss = 2847.7371, Test Loss = 3886.3506
# Epoch 105: Train Loss = 2763.1645, Test Loss = 3854.4006
# Epoch 106: Train Loss = 2736.7767, Test Loss = 3838.8601
# Epoch 107: Train Loss = 2634.0132, Test Loss = 3695.2057
# Epoch 108: Train Loss = 2614.1871, Test Loss = 3583.0292
# Epoch 109: Train Loss = 2484.5165, Test Loss = 3930.1468
# Epoch 110: Train Loss = 2576.7835, Test Loss = 3777.6826
# Epoch 111: Train Loss = 2515.3137, Test Loss = 3653.2840
# Epoch 112: Train Loss = 2346.3097, Test Loss = 3555.1518
# Epoch 113: Train Loss = 2257.3361, Test Loss = 3384.9484
# Epoch 114: Train Loss = 2150.6018, Test Loss = 3254.6153
# Epoch 115: Train Loss = 2245.0410, Test Loss = 3326.8846
# Epoch 116: Train Loss = 2065.2887, Test Loss = 3328.3604
# Epoch 117: Train Loss = 2033.9757, Test Loss = 3177.9381
# Epoch 118: Train Loss = 1991.1361, Test Loss = 3146.9137
# Epoch 119: Train Loss = 1915.5803, Test Loss = 3237.9975
# Epoch 120: Train Loss = 1834.9065, Test Loss = 3329.8422
# Epoch 121: Train Loss = 1962.5925, Test Loss = 3137.4333
# Epoch 122: Train Loss = 1808.4995, Test Loss = 2997.8864
# Epoch 123: Train Loss = 1690.0999, Test Loss = 3237.2901
# Epoch 124: Train Loss = 1730.2183, Test Loss = 3141.1975
# Epoch 125: Train Loss = 1644.2049, Test Loss = 2853.6056
# Epoch 126: Train Loss = 1548.5295, Test Loss = 2926.0869
# Epoch 127: Train Loss = 1554.9666, Test Loss = 2818.5433
# Epoch 128: Train Loss = 1548.7813, Test Loss = 2991.6265
# Epoch 129: Train Loss = 1543.3286, Test Loss = 2727.1596
# Epoch 130: Train Loss = 1442.6528, Test Loss = 2827.7584
# Epoch 131: Train Loss = 1418.1096, Test Loss = 2913.5711
# Epoch 132: Train Loss = 1355.8469, Test Loss = 2717.7854
# Epoch 133: Train Loss = 1354.2784, Test Loss = 2706.2673
# Epoch 134: Train Loss = 1306.4794, Test Loss = 2747.9781
# Epoch 135: Train Loss = 1346.2028, Test Loss = 2527.7468
# Epoch 136: Train Loss = 1344.6071, Test Loss = 2789.4014
# Epoch 137: Train Loss = 1445.2779, Test Loss = 2713.1609
# Epoch 138: Train Loss = 1222.6053, Test Loss = 2694.0776
# Epoch 139: Train Loss = 1147.7895, Test Loss = 2458.3834
# Epoch 140: Train Loss = 1105.4851, Test Loss = 2484.3765
# Epoch 141: Train Loss = 1117.6829, Test Loss = 2542.7267
# Epoch 142: Train Loss = 1207.5892, Test Loss = 3033.0056
# Epoch 143: Train Loss = 1318.4327, Test Loss = 2541.4534
# Epoch 144: Train Loss = 1077.2681, Test Loss = 2508.2809
# Epoch 145: Train Loss = 991.7060, Test Loss = 2267.8029
# Epoch 146: Train Loss = 932.8090, Test Loss = 2305.1898
# Epoch 147: Train Loss = 901.8814, Test Loss = 2211.2729
# Epoch 148: Train Loss = 970.4295, Test Loss = 2450.8765
# Epoch 149: Train Loss = 940.5869, Test Loss = 2304.4643
# Epoch 150: Train Loss = 871.2802, Test Loss = 2345.9300
# Epoch 151: Train Loss = 922.0134, Test Loss = 2190.5893
# Epoch 152: Train Loss = 855.2073, Test Loss = 2184.4748
# Epoch 153: Train Loss = 824.5585, Test Loss = 2292.5288
# Epoch 154: Train Loss = 863.0035, Test Loss = 2270.9407
# Epoch 155: Train Loss = 935.6245, Test Loss = 2582.7709
# Epoch 156: Train Loss = 904.1253, Test Loss = 2247.2290
# Epoch 157: Train Loss = 795.5464, Test Loss = 2361.9946
# Epoch 158: Train Loss = 801.2630, Test Loss = 2126.1170
# Epoch 159: Train Loss = 724.5816, Test Loss = 2184.9571
# Epoch 160: Train Loss = 721.2546, Test Loss = 2017.2925
# Epoch 161: Train Loss = 681.9123, Test Loss = 2154.3600
# Epoch 162: Train Loss = 728.5643, Test Loss = 2037.3298
# Epoch 163: Train Loss = 716.6886, Test Loss = 1986.9711
# Epoch 164: Train Loss = 813.6677, Test Loss = 2362.3098
# Epoch 165: Train Loss = 1339.7731, Test Loss = 2912.1109
# Epoch 166: Train Loss = 1456.7340, Test Loss = 2625.7358
# Epoch 167: Train Loss = 1194.1892, Test Loss = 2168.2638
# Epoch 168: Train Loss = 786.3590, Test Loss = 2060.4380
# Epoch 169: Train Loss = 671.8317, Test Loss = 2100.8003
# Epoch 170: Train Loss = 618.2987, Test Loss = 1945.3351
# Epoch 171: Train Loss = 571.1482, Test Loss = 1856.6863
# Epoch 172: Train Loss = 557.1192, Test Loss = 1992.1855
# Epoch 173: Train Loss = 543.7931, Test Loss = 1885.8022
# Epoch 174: Train Loss = 529.1088, Test Loss = 1830.8689
# Epoch 175: Train Loss = 487.1660, Test Loss = 1829.9231
# Epoch 176: Train Loss = 476.2951, Test Loss = 1840.1880
# Epoch 177: Train Loss = 459.4435, Test Loss = 1763.5222
# Epoch 178: Train Loss = 445.7806, Test Loss = 1758.8399
# Epoch 179: Train Loss = 451.8197, Test Loss = 1775.3903
# Epoch 180: Train Loss = 461.4384, Test Loss = 1724.9556
# Epoch 181: Train Loss = 496.4240, Test Loss = 1819.7244
# Epoch 182: Train Loss = 589.7323, Test Loss = 2222.8219
# Epoch 183: Train Loss = 619.9636, Test Loss = 2170.6159
# Epoch 184: Train Loss = 992.2564, Test Loss = 2326.2723
# Epoch 185: Train Loss = 755.1335, Test Loss = 1920.7306
# Epoch 186: Train Loss = 1041.5317, Test Loss = 2275.5887
# Epoch 187: Train Loss = 755.1461, Test Loss = 2010.5875
# Epoch 188: Train Loss = 674.2903, Test Loss = 1985.5487
# Epoch 189: Train Loss = 503.1955, Test Loss = 1680.1735
# Epoch 190: Train Loss = 446.5029, Test Loss = 1697.7397
# Epoch 191: Train Loss = 398.1931, Test Loss = 1642.1544
# Epoch 192: Train Loss = 374.0808, Test Loss = 1644.0692
# Epoch 193: Train Loss = 356.7455, Test Loss = 1669.6593
# Epoch 194: Train Loss = 339.6183, Test Loss = 1549.5939
# Epoch 195: Train Loss = 334.3557, Test Loss = 1583.2828
# Epoch 196: Train Loss = 421.9888, Test Loss = 1870.5961
# Epoch 197: Train Loss = 470.1620, Test Loss = 1923.3253
# Epoch 198: Train Loss = 894.2757, Test Loss = 2165.7218
# Epoch 199: Train Loss = 797.6298, Test Loss = 1990.1352
# Epoch 200: Train Loss = 503.2541, Test Loss = 1760.9314
# Epoch 201: Train Loss = 393.4559, Test Loss = 2017.0273
# Epoch 202: Train Loss = 723.3153, Test Loss = 1908.7612
# Epoch 203: Train Loss = 552.7766, Test Loss = 1717.9809
# Epoch 204: Train Loss = 402.4290, Test Loss = 1602.1154
# 🚀 Early stopping triggered for Delta_band at epoch 204
# ✅ Delta_band Training & Denoising Completed!
#
# 🟢 Processing Theta_band...
#
# 📌 Loading and Splitting Data for Theta_band...
# ✅ Theta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Theta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Theta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Theta_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 5830.9167, Test Loss = 5853.9151
# Epoch 2: Train Loss = 5642.2839, Test Loss = 5701.5303
# Epoch 3: Train Loss = 5563.6136, Test Loss = 5617.9198
# Epoch 4: Train Loss = 5410.5983, Test Loss = 5515.8516
# Epoch 5: Train Loss = 5389.3811, Test Loss = 5541.9475
# Epoch 6: Train Loss = 5260.7268, Test Loss = 5425.0711
# Epoch 7: Train Loss = 5216.5927, Test Loss = 5447.8159
# Epoch 8: Train Loss = 5203.0692, Test Loss = 5309.9720
# Epoch 9: Train Loss = 5163.0076, Test Loss = 5252.9348
# Epoch 10: Train Loss = 5152.8388, Test Loss = 5303.6699
# Epoch 11: Train Loss = 5145.7447, Test Loss = 5279.4355
# Epoch 12: Train Loss = 5092.4784, Test Loss = 5395.7320
# Epoch 13: Train Loss = 5011.3225, Test Loss = 5139.1160
# Epoch 14: Train Loss = 4952.7684, Test Loss = 5082.4994
# Epoch 15: Train Loss = 4939.1491, Test Loss = 5103.4398
# Epoch 16: Train Loss = 4914.5481, Test Loss = 5010.4538
# Epoch 17: Train Loss = 4908.7249, Test Loss = 4991.0860
# Epoch 18: Train Loss = 4908.2294, Test Loss = 5135.7671
# Epoch 19: Train Loss = 4980.0466, Test Loss = 5150.3697
# Epoch 20: Train Loss = 5108.7874, Test Loss = 5346.4768
# Epoch 21: Train Loss = 4926.6293, Test Loss = 5063.8035
# Epoch 22: Train Loss = 4800.5941, Test Loss = 4871.1917
# Epoch 23: Train Loss = 4821.0511, Test Loss = 4986.1225
# Epoch 24: Train Loss = 4752.4227, Test Loss = 5440.8389
# Epoch 25: Train Loss = 4755.0540, Test Loss = 5009.4002
# Epoch 26: Train Loss = 4699.8586, Test Loss = 4974.5932
# Epoch 27: Train Loss = 4678.1516, Test Loss = 4861.0669
# Epoch 28: Train Loss = 4589.3211, Test Loss = 4746.2468
# Epoch 29: Train Loss = 4532.9733, Test Loss = 5120.5028
# Epoch 30: Train Loss = 4550.7711, Test Loss = 4717.3223
# Epoch 31: Train Loss = 4503.6566, Test Loss = 4678.0296
# Epoch 32: Train Loss = 4396.2120, Test Loss = 4644.1500
# Epoch 33: Train Loss = 4469.6046, Test Loss = 4728.8055
# Epoch 34: Train Loss = 4340.6393, Test Loss = 4794.3135
# Epoch 35: Train Loss = 4346.4602, Test Loss = 4658.2970
# Epoch 36: Train Loss = 4250.2406, Test Loss = 4460.6752
# Epoch 37: Train Loss = 4236.5013, Test Loss = 4790.3691
# Epoch 38: Train Loss = 4244.8993, Test Loss = 4496.9773
# Epoch 39: Train Loss = 4186.0208, Test Loss = 4451.8400
# Epoch 40: Train Loss = 4077.1764, Test Loss = 4365.0383
# Epoch 41: Train Loss = 4060.0002, Test Loss = 4297.4697
# Epoch 42: Train Loss = 3929.1131, Test Loss = 4363.7800
# Epoch 43: Train Loss = 3917.7978, Test Loss = 4476.1124
# Epoch 44: Train Loss = 4015.9102, Test Loss = 4286.1524
# Epoch 45: Train Loss = 3967.5147, Test Loss = 4339.0417
# Epoch 46: Train Loss = 3775.4321, Test Loss = 4118.8058
# Epoch 47: Train Loss = 3681.3450, Test Loss = 4170.1885
# Epoch 48: Train Loss = 3660.4927, Test Loss = 4150.6490
# Epoch 49: Train Loss = 3615.0292, Test Loss = 3949.5649
# Epoch 50: Train Loss = 3486.4790, Test Loss = 4058.1329
# Epoch 51: Train Loss = 3406.7015, Test Loss = 3888.4036
# Epoch 52: Train Loss = 3388.7696, Test Loss = 3959.3768
# Epoch 53: Train Loss = 3296.8983, Test Loss = 3752.4502
# Epoch 54: Train Loss = 3169.9447, Test Loss = 3696.0377
# Epoch 55: Train Loss = 3163.1503, Test Loss = 3645.8043
# Epoch 56: Train Loss = 3050.2282, Test Loss = 3547.9083
# Epoch 57: Train Loss = 2973.7635, Test Loss = 3615.5548
# Epoch 58: Train Loss = 2929.5543, Test Loss = 3623.0640
# Epoch 59: Train Loss = 2980.2507, Test Loss = 3522.7882
# Epoch 60: Train Loss = 2851.8719, Test Loss = 3470.8105
# Epoch 61: Train Loss = 2684.1882, Test Loss = 3298.3144
# Epoch 62: Train Loss = 2565.9377, Test Loss = 3230.1778
# Epoch 63: Train Loss = 2539.8618, Test Loss = 3384.8725
# Epoch 64: Train Loss = 2570.3929, Test Loss = 3690.2415
# Epoch 65: Train Loss = 2661.6860, Test Loss = 3238.9486
# Epoch 66: Train Loss = 2418.3879, Test Loss = 3517.1798
# Epoch 67: Train Loss = 2341.0438, Test Loss = 3389.4366
# Epoch 68: Train Loss = 2252.8696, Test Loss = 3347.2399
# Epoch 69: Train Loss = 2169.9492, Test Loss = 3039.5205
# Epoch 70: Train Loss = 2104.9993, Test Loss = 2851.5856
# Epoch 71: Train Loss = 1999.1042, Test Loss = 2939.5423
# Epoch 72: Train Loss = 2130.1641, Test Loss = 3231.7845
# Epoch 73: Train Loss = 1990.7983, Test Loss = 2778.5450
# Epoch 74: Train Loss = 1887.3538, Test Loss = 2686.1742
# Epoch 75: Train Loss = 1794.2143, Test Loss = 2708.7561
# Epoch 76: Train Loss = 1753.2542, Test Loss = 2706.9389
# Epoch 77: Train Loss = 1729.4060, Test Loss = 2669.0299
# Epoch 78: Train Loss = 1605.4644, Test Loss = 2694.6340
# Epoch 79: Train Loss = 1523.8231, Test Loss = 2514.1795
# Epoch 80: Train Loss = 1473.9123, Test Loss = 2399.1916
# Epoch 81: Train Loss = 1416.7535, Test Loss = 2454.2234
# Epoch 82: Train Loss = 1383.3009, Test Loss = 2508.7024
# Epoch 83: Train Loss = 1343.0271, Test Loss = 2323.7770
# Epoch 84: Train Loss = 1331.3297, Test Loss = 2549.5658
# Epoch 85: Train Loss = 1412.8105, Test Loss = 2430.7645
# Epoch 86: Train Loss = 1297.7580, Test Loss = 2355.4618
# Epoch 87: Train Loss = 1213.9649, Test Loss = 2456.0063
# Epoch 88: Train Loss = 1175.5365, Test Loss = 2184.6612
# Epoch 89: Train Loss = 1103.1499, Test Loss = 2183.7021
# Epoch 90: Train Loss = 1059.9445, Test Loss = 2131.2421
# Epoch 91: Train Loss = 1075.4456, Test Loss = 2238.8394
# Epoch 92: Train Loss = 1065.9813, Test Loss = 2076.8110
# Epoch 93: Train Loss = 949.6489, Test Loss = 2070.2054
# Epoch 94: Train Loss = 961.1041, Test Loss = 2129.6370
# Epoch 95: Train Loss = 925.7888, Test Loss = 2073.0963
# Epoch 96: Train Loss = 915.6801, Test Loss = 2116.6869
# Epoch 97: Train Loss = 855.0273, Test Loss = 2001.1735
# Epoch 98: Train Loss = 813.3875, Test Loss = 2018.1453
# Epoch 99: Train Loss = 822.4337, Test Loss = 1946.7887
# Epoch 100: Train Loss = 764.4878, Test Loss = 1874.2025
# Epoch 101: Train Loss = 714.6037, Test Loss = 1917.0600
# Epoch 102: Train Loss = 739.4154, Test Loss = 1852.7243
# Epoch 103: Train Loss = 687.0936, Test Loss = 1830.5017
# Epoch 104: Train Loss = 665.7144, Test Loss = 1930.7929
# Epoch 105: Train Loss = 667.7652, Test Loss = 1922.1489
# Epoch 106: Train Loss = 658.9055, Test Loss = 1801.0670
# Epoch 107: Train Loss = 638.0476, Test Loss = 1901.7885
# Epoch 108: Train Loss = 612.6515, Test Loss = 1955.4426
# Epoch 109: Train Loss = 666.1949, Test Loss = 1906.1788
# Epoch 110: Train Loss = 803.4706, Test Loss = 2464.9168
# Epoch 111: Train Loss = 833.7565, Test Loss = 1930.2673
# Epoch 112: Train Loss = 669.9228, Test Loss = 1839.6274
# Epoch 113: Train Loss = 572.0973, Test Loss = 1731.6400
# Epoch 114: Train Loss = 524.9337, Test Loss = 1712.1120
# Epoch 115: Train Loss = 476.9017, Test Loss = 1705.2803
# Epoch 116: Train Loss = 465.0649, Test Loss = 1657.0799
# Epoch 117: Train Loss = 482.4789, Test Loss = 1628.2036
# Epoch 118: Train Loss = 464.2034, Test Loss = 1624.6131
# Epoch 119: Train Loss = 423.7125, Test Loss = 1760.5404
# Epoch 120: Train Loss = 458.8357, Test Loss = 1686.2491
# Epoch 121: Train Loss = 517.3387, Test Loss = 1766.3742
# Epoch 122: Train Loss = 515.4186, Test Loss = 1691.8980
# Epoch 123: Train Loss = 446.2785, Test Loss = 1738.0892
# Epoch 124: Train Loss = 392.8396, Test Loss = 1543.2022
# Epoch 125: Train Loss = 382.1400, Test Loss = 1562.3845
# Epoch 126: Train Loss = 419.1454, Test Loss = 1616.1730
# Epoch 127: Train Loss = 386.2042, Test Loss = 1719.4249
# Epoch 128: Train Loss = 348.5233, Test Loss = 1584.9362
# Epoch 129: Train Loss = 321.4317, Test Loss = 1504.0993
# Epoch 130: Train Loss = 313.2703, Test Loss = 1653.6721
# Epoch 131: Train Loss = 327.2150, Test Loss = 1575.2351
# Epoch 132: Train Loss = 323.6095, Test Loss = 1554.4018
# Epoch 133: Train Loss = 304.1634, Test Loss = 1491.2458
# Epoch 134: Train Loss = 306.3243, Test Loss = 1633.0084
# Epoch 135: Train Loss = 422.6801, Test Loss = 1584.5109
# Epoch 136: Train Loss = 434.9471, Test Loss = 1582.8037
# Epoch 137: Train Loss = 554.3994, Test Loss = 1668.6154
# Epoch 138: Train Loss = 930.7766, Test Loss = 2058.7591
# Epoch 139: Train Loss = 670.8737, Test Loss = 1628.2501
# Epoch 140: Train Loss = 415.6663, Test Loss = 1589.1112
# Epoch 141: Train Loss = 329.2073, Test Loss = 1462.8952
# Epoch 142: Train Loss = 287.1203, Test Loss = 1402.3574
# Epoch 143: Train Loss = 260.4336, Test Loss = 1384.8713
# Epoch 144: Train Loss = 238.4620, Test Loss = 1417.2659
# Epoch 145: Train Loss = 226.6009, Test Loss = 1396.1774
# Epoch 146: Train Loss = 267.5097, Test Loss = 1473.5162
# Epoch 147: Train Loss = 326.0604, Test Loss = 1510.2404
# Epoch 148: Train Loss = 257.9808, Test Loss = 1384.9897
# Epoch 149: Train Loss = 227.2412, Test Loss = 1358.3125
# Epoch 150: Train Loss = 211.2010, Test Loss = 1387.2558
# Epoch 151: Train Loss = 203.8097, Test Loss = 1416.4904
# Epoch 152: Train Loss = 210.9755, Test Loss = 1507.4119
# Epoch 153: Train Loss = 199.6520, Test Loss = 1352.6239
# Epoch 154: Train Loss = 191.6630, Test Loss = 1421.4932
# Epoch 155: Train Loss = 183.2101, Test Loss = 1383.8017
# Epoch 156: Train Loss = 180.3011, Test Loss = 1552.3865
# Epoch 157: Train Loss = 185.4403, Test Loss = 1389.9176
# Epoch 158: Train Loss = 187.3159, Test Loss = 1409.0662
# Epoch 159: Train Loss = 196.3181, Test Loss = 1418.6371
# Epoch 160: Train Loss = 214.1755, Test Loss = 1403.1909
# Epoch 161: Train Loss = 225.5951, Test Loss = 1516.1264
# Epoch 162: Train Loss = 250.2150, Test Loss = 1508.5723
# Epoch 163: Train Loss = 397.2475, Test Loss = 1739.0625
# 🚀 Early stopping triggered for Theta_band at epoch 163
# ✅ Theta_band Training & Denoising Completed!
#
# 🟢 Processing Alpha_band...
#
# 📌 Loading and Splitting Data for Alpha_band...
# ✅ Alpha_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Alpha_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Alpha_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Alpha_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 3866.8774, Test Loss = 3869.3215
# Epoch 2: Train Loss = 3748.0090, Test Loss = 3749.7324
# Epoch 3: Train Loss = 3726.3125, Test Loss = 3811.9437
# Epoch 4: Train Loss = 3656.5266, Test Loss = 3657.6451
# Epoch 5: Train Loss = 3538.7520, Test Loss = 3676.5716
# Epoch 6: Train Loss = 3471.9461, Test Loss = 3488.0562
# Epoch 7: Train Loss = 3501.2011, Test Loss = 3503.4129
# Epoch 8: Train Loss = 3425.9608, Test Loss = 3417.4701
# Epoch 9: Train Loss = 3344.4229, Test Loss = 3350.8317
# Epoch 10: Train Loss = 3306.8668, Test Loss = 3443.4149
# Epoch 11: Train Loss = 3285.4579, Test Loss = 3241.9844
# Epoch 12: Train Loss = 3175.7947, Test Loss = 3150.5438
# Epoch 13: Train Loss = 3113.7997, Test Loss = 3198.8042
# Epoch 14: Train Loss = 3062.9955, Test Loss = 3091.7167
# Epoch 15: Train Loss = 3051.7441, Test Loss = 3101.4935
# Epoch 16: Train Loss = 2974.3628, Test Loss = 3155.0724
# Epoch 17: Train Loss = 3068.4421, Test Loss = 3042.0912
# Epoch 18: Train Loss = 2946.4498, Test Loss = 3122.2633
# Epoch 19: Train Loss = 2860.8309, Test Loss = 2915.5777
# Epoch 20: Train Loss = 2824.7723, Test Loss = 2907.9375
# Epoch 21: Train Loss = 2716.6929, Test Loss = 2817.9002
# Epoch 22: Train Loss = 2657.2134, Test Loss = 2708.9000
# Epoch 23: Train Loss = 2691.2583, Test Loss = 2848.3481
# Epoch 24: Train Loss = 2589.0224, Test Loss = 2623.9525
# Epoch 25: Train Loss = 2529.1119, Test Loss = 2649.8414
# Epoch 26: Train Loss = 2423.5726, Test Loss = 2494.1585
# Epoch 27: Train Loss = 2406.3816, Test Loss = 2738.2791
# Epoch 28: Train Loss = 2647.5746, Test Loss = 2577.0201
# Epoch 29: Train Loss = 2444.3007, Test Loss = 2484.9237
# Epoch 30: Train Loss = 2334.8064, Test Loss = 2401.0465
# Epoch 31: Train Loss = 2257.7099, Test Loss = 2412.9040
# Epoch 32: Train Loss = 2162.2342, Test Loss = 2274.0075
# Epoch 33: Train Loss = 2094.9839, Test Loss = 2218.6106
# Epoch 34: Train Loss = 2005.2209, Test Loss = 2210.6733
# Epoch 35: Train Loss = 1960.5620, Test Loss = 2115.9567
# Epoch 36: Train Loss = 1857.5667, Test Loss = 2079.9393
# Epoch 37: Train Loss = 1820.4827, Test Loss = 2221.9867
# Epoch 38: Train Loss = 1795.8138, Test Loss = 2036.5408
# Epoch 39: Train Loss = 1726.4023, Test Loss = 1960.9195
# Epoch 40: Train Loss = 1645.6794, Test Loss = 2040.0424
# Epoch 41: Train Loss = 1625.3294, Test Loss = 1863.3457
# Epoch 42: Train Loss = 1538.1121, Test Loss = 1820.4628
# Epoch 43: Train Loss = 1480.9736, Test Loss = 1845.7991
# Epoch 44: Train Loss = 1425.1094, Test Loss = 1700.2838
# Epoch 45: Train Loss = 1337.4695, Test Loss = 1686.1450
# Epoch 46: Train Loss = 1384.9749, Test Loss = 1705.6397
# Epoch 47: Train Loss = 1256.2169, Test Loss = 1598.6126
# Epoch 48: Train Loss = 1189.9830, Test Loss = 1690.4015
# Epoch 49: Train Loss = 1170.2015, Test Loss = 1599.7223
# Epoch 50: Train Loss = 1256.8929, Test Loss = 1648.4260
# Epoch 51: Train Loss = 1132.9431, Test Loss = 1494.3977
# Epoch 52: Train Loss = 1051.9999, Test Loss = 1484.9057
# Epoch 53: Train Loss = 1001.4897, Test Loss = 1534.7939
# Epoch 54: Train Loss = 1003.3817, Test Loss = 1553.0285
# Epoch 55: Train Loss = 941.5178, Test Loss = 1411.6146
# Epoch 56: Train Loss = 925.1802, Test Loss = 1714.6042
# Epoch 57: Train Loss = 871.0865, Test Loss = 1311.4660
# Epoch 58: Train Loss = 864.0694, Test Loss = 1310.6635
# Epoch 59: Train Loss = 806.3722, Test Loss = 1318.0518
# Epoch 60: Train Loss = 787.8987, Test Loss = 1291.4115
# Epoch 61: Train Loss = 739.9272, Test Loss = 1188.6533
# Epoch 62: Train Loss = 680.4912, Test Loss = 1228.2069
# Epoch 63: Train Loss = 684.2622, Test Loss = 1170.8407
# Epoch 64: Train Loss = 644.0533, Test Loss = 1126.5601
# Epoch 65: Train Loss = 620.3503, Test Loss = 1191.8182
# Epoch 66: Train Loss = 735.2329, Test Loss = 1132.1887
# Epoch 67: Train Loss = 579.8619, Test Loss = 1105.7094
# Epoch 68: Train Loss = 547.0362, Test Loss = 1102.5024
# Epoch 69: Train Loss = 651.6876, Test Loss = 1122.0518
# Epoch 70: Train Loss = 571.3045, Test Loss = 1109.4344
# Epoch 71: Train Loss = 526.3307, Test Loss = 1028.0261
# Epoch 72: Train Loss = 481.3235, Test Loss = 993.3803
# Epoch 73: Train Loss = 452.0673, Test Loss = 999.2050
# Epoch 74: Train Loss = 442.5881, Test Loss = 1031.7326
# Epoch 75: Train Loss = 404.2634, Test Loss = 951.1152
# Epoch 76: Train Loss = 378.5847, Test Loss = 972.4256
# Epoch 77: Train Loss = 384.2763, Test Loss = 947.4528
# Epoch 78: Train Loss = 380.7207, Test Loss = 923.8912
# Epoch 79: Train Loss = 395.4961, Test Loss = 952.3827
# Epoch 80: Train Loss = 526.5555, Test Loss = 1069.1003
# Epoch 81: Train Loss = 505.9667, Test Loss = 925.2728
# Epoch 82: Train Loss = 352.1574, Test Loss = 925.6952
# Epoch 83: Train Loss = 338.6682, Test Loss = 963.6508
# Epoch 84: Train Loss = 310.0383, Test Loss = 903.7478
# Epoch 85: Train Loss = 284.8078, Test Loss = 870.4096
# Epoch 86: Train Loss = 268.7142, Test Loss = 812.7542
# Epoch 87: Train Loss = 256.7607, Test Loss = 843.9646
# Epoch 88: Train Loss = 249.6887, Test Loss = 818.7224
# Epoch 89: Train Loss = 487.7220, Test Loss = 1139.5254
# Epoch 90: Train Loss = 721.9680, Test Loss = 1099.5214
# Epoch 91: Train Loss = 485.9319, Test Loss = 1033.7170
# Epoch 92: Train Loss = 324.4870, Test Loss = 834.7066
# Epoch 93: Train Loss = 266.2701, Test Loss = 803.5259
# Epoch 94: Train Loss = 249.1076, Test Loss = 794.5377
# Epoch 95: Train Loss = 216.1653, Test Loss = 760.2209
# Epoch 96: Train Loss = 205.7340, Test Loss = 785.5034
# Epoch 97: Train Loss = 192.9095, Test Loss = 752.0764
# Epoch 98: Train Loss = 185.2447, Test Loss = 750.0167
# Epoch 99: Train Loss = 188.2488, Test Loss = 780.9170
# Epoch 100: Train Loss = 197.5785, Test Loss = 775.1254
# Epoch 101: Train Loss = 181.7136, Test Loss = 767.7690
# Epoch 102: Train Loss = 188.8495, Test Loss = 782.9666
# Epoch 103: Train Loss = 233.1058, Test Loss = 1037.8126
# Epoch 104: Train Loss = 482.7537, Test Loss = 1122.2334
# Epoch 105: Train Loss = 455.1592, Test Loss = 866.0269
# Epoch 106: Train Loss = 280.4800, Test Loss = 798.9841
# Epoch 107: Train Loss = 200.2256, Test Loss = 746.2650
# Epoch 108: Train Loss = 172.8770, Test Loss = 755.1503
# Epoch 109: Train Loss = 154.9719, Test Loss = 706.7229
# Epoch 110: Train Loss = 144.9197, Test Loss = 711.2663
# Epoch 111: Train Loss = 137.5358, Test Loss = 743.3956
# Epoch 112: Train Loss = 133.9090, Test Loss = 726.6207
# Epoch 113: Train Loss = 132.1641, Test Loss = 735.6554
# Epoch 114: Train Loss = 127.8320, Test Loss = 727.3294
# Epoch 115: Train Loss = 121.5658, Test Loss = 690.3998
# Epoch 116: Train Loss = 121.4024, Test Loss = 729.3793
# Epoch 117: Train Loss = 189.1601, Test Loss = 922.4407
# Epoch 118: Train Loss = 355.3711, Test Loss = 1191.4292
# Epoch 119: Train Loss = 591.9633, Test Loss = 1026.8425
# Epoch 120: Train Loss = 296.3013, Test Loss = 758.4964
# Epoch 121: Train Loss = 194.4423, Test Loss = 768.9539
# Epoch 122: Train Loss = 156.4082, Test Loss = 696.8233
# Epoch 123: Train Loss = 126.0659, Test Loss = 671.3030
# Epoch 124: Train Loss = 116.4676, Test Loss = 675.7376
# Epoch 125: Train Loss = 108.3450, Test Loss = 659.0635
# Epoch 126: Train Loss = 105.1256, Test Loss = 685.7942
# Epoch 127: Train Loss = 103.6096, Test Loss = 664.1153
# Epoch 128: Train Loss = 97.7753, Test Loss = 648.2273
# Epoch 129: Train Loss = 93.7631, Test Loss = 647.5210
# Epoch 130: Train Loss = 91.8645, Test Loss = 642.9401
# Epoch 131: Train Loss = 90.4070, Test Loss = 643.9260
# Epoch 132: Train Loss = 93.4243, Test Loss = 655.0347
# Epoch 133: Train Loss = 88.9419, Test Loss = 677.0884
# Epoch 134: Train Loss = 88.2541, Test Loss = 671.6201
# Epoch 135: Train Loss = 89.9523, Test Loss = 649.6754
# Epoch 136: Train Loss = 88.4305, Test Loss = 648.0603
# Epoch 137: Train Loss = 90.9973, Test Loss = 654.4329
# Epoch 138: Train Loss = 150.2783, Test Loss = 793.5444
# Epoch 139: Train Loss = 420.3996, Test Loss = 1251.7382
# Epoch 140: Train Loss = 724.1042, Test Loss = 1124.2726
# 🚀 Early stopping triggered for Alpha_band at epoch 140
# ✅ Alpha_band Training & Denoising Completed!
#
# 🟢 Processing Beta_band...
#
# 📌 Loading and Splitting Data for Beta_band...
# ✅ Beta_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Beta_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Beta_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Beta_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 23309.3065, Test Loss = 23612.8802
# Epoch 2: Train Loss = 22759.9360, Test Loss = 22552.6100
# Epoch 3: Train Loss = 22173.5973, Test Loss = 22114.5332
# Epoch 4: Train Loss = 22126.2482, Test Loss = 22239.6507
# Epoch 5: Train Loss = 22428.1653, Test Loss = 22627.9252
# Epoch 6: Train Loss = 21982.2081, Test Loss = 22012.2109
# Epoch 7: Train Loss = 21261.0816, Test Loss = 21239.1416
# Epoch 8: Train Loss = 20524.8121, Test Loss = 20553.3832
# Epoch 9: Train Loss = 19935.4533, Test Loss = 19947.6734
# Epoch 10: Train Loss = 19353.2885, Test Loss = 19395.7023
# Epoch 11: Train Loss = 18781.2010, Test Loss = 18783.5815
# Epoch 12: Train Loss = 18128.4150, Test Loss = 18949.7860
# Epoch 13: Train Loss = 17543.7416, Test Loss = 17337.3726
# Epoch 14: Train Loss = 16859.4573, Test Loss = 16671.9841
# Epoch 15: Train Loss = 16124.4799, Test Loss = 15876.5583
# Epoch 16: Train Loss = 15423.8412, Test Loss = 16128.2115
# Epoch 17: Train Loss = 14957.8230, Test Loss = 14490.2946
# Epoch 18: Train Loss = 13754.7039, Test Loss = 13688.0781
# Epoch 19: Train Loss = 13290.0120, Test Loss = 12996.1462
# Epoch 20: Train Loss = 12177.5200, Test Loss = 12329.1446
# Epoch 21: Train Loss = 11336.3287, Test Loss = 11796.2554
# Epoch 22: Train Loss = 10670.4385, Test Loss = 10912.9190
# Epoch 23: Train Loss = 10506.3350, Test Loss = 10042.2063
# Epoch 24: Train Loss = 9066.5935, Test Loss = 9283.7458
# Epoch 25: Train Loss = 8463.4989, Test Loss = 8707.4010
# Epoch 26: Train Loss = 7915.9549, Test Loss = 7941.4595
# Epoch 27: Train Loss = 7206.6050, Test Loss = 7691.8308
# Epoch 28: Train Loss = 6800.5221, Test Loss = 7133.6604
# Epoch 29: Train Loss = 6082.9069, Test Loss = 6978.5706
# Epoch 30: Train Loss = 5902.7691, Test Loss = 7732.7980
# Epoch 31: Train Loss = 5959.7924, Test Loss = 6221.5925
# Epoch 32: Train Loss = 5535.8994, Test Loss = 5421.9745
# Epoch 33: Train Loss = 4576.9195, Test Loss = 5164.1492
# Epoch 34: Train Loss = 4091.3710, Test Loss = 4621.7451
# Epoch 35: Train Loss = 3799.2637, Test Loss = 4269.5513
# Epoch 36: Train Loss = 3708.8175, Test Loss = 4208.1945
# Epoch 37: Train Loss = 3331.0258, Test Loss = 4766.3782
# Epoch 38: Train Loss = 3322.9244, Test Loss = 3756.3246
# Epoch 39: Train Loss = 3565.7784, Test Loss = 4510.2632
# Epoch 40: Train Loss = 3235.2857, Test Loss = 3563.5271
# Epoch 41: Train Loss = 2563.4198, Test Loss = 3148.4270
# Epoch 42: Train Loss = 2351.5498, Test Loss = 2912.5023
# Epoch 43: Train Loss = 2113.2468, Test Loss = 2745.6899
# Epoch 44: Train Loss = 1960.7624, Test Loss = 2700.7424
# Epoch 45: Train Loss = 1835.2809, Test Loss = 2615.3018
# Epoch 46: Train Loss = 1725.3328, Test Loss = 2460.8949
# Epoch 47: Train Loss = 1603.9442, Test Loss = 2449.7540
# Epoch 48: Train Loss = 1521.9811, Test Loss = 2478.6427
# Epoch 49: Train Loss = 1428.0630, Test Loss = 2134.7481
# Epoch 50: Train Loss = 1459.7196, Test Loss = 2175.6244
# Epoch 51: Train Loss = 2091.5820, Test Loss = 4600.5692
# Epoch 52: Train Loss = 3371.2298, Test Loss = 3376.0363
# Epoch 53: Train Loss = 2635.7721, Test Loss = 3052.1209
# Epoch 54: Train Loss = 1889.5842, Test Loss = 2314.5577
# Epoch 55: Train Loss = 1330.9807, Test Loss = 1909.8552
# Epoch 56: Train Loss = 1136.2493, Test Loss = 1801.5136
# Epoch 57: Train Loss = 1046.1502, Test Loss = 1717.6915
# Epoch 58: Train Loss = 978.5452, Test Loss = 1715.4396
# Epoch 59: Train Loss = 922.6577, Test Loss = 1569.4324
# Epoch 60: Train Loss = 856.2477, Test Loss = 1531.9216
# Epoch 61: Train Loss = 820.2456, Test Loss = 1488.9356
# Epoch 62: Train Loss = 773.0825, Test Loss = 1430.2603
# Epoch 63: Train Loss = 739.8131, Test Loss = 1406.8984
# Epoch 64: Train Loss = 706.7892, Test Loss = 1336.3130
# Epoch 65: Train Loss = 685.2535, Test Loss = 1305.1341
# Epoch 66: Train Loss = 652.5009, Test Loss = 1249.9942
# Epoch 67: Train Loss = 627.8325, Test Loss = 1318.2919
# Epoch 68: Train Loss = 604.6701, Test Loss = 1293.1203
# Epoch 69: Train Loss = 582.5582, Test Loss = 1228.1697
# Epoch 70: Train Loss = 573.7592, Test Loss = 1248.9227
# Epoch 71: Train Loss = 550.7602, Test Loss = 1174.9177
# Epoch 72: Train Loss = 6582.6880, Test Loss = 21270.5297
# Epoch 73: Train Loss = 18704.1728, Test Loss = 16265.9743
# Epoch 74: Train Loss = 14528.3683, Test Loss = 13684.8289
# Epoch 75: Train Loss = 11410.1290, Test Loss = 10997.7454
# Epoch 76: Train Loss = 8966.2386, Test Loss = 8477.4191
# Epoch 77: Train Loss = 7239.4712, Test Loss = 6971.8189
# Epoch 78: Train Loss = 5985.4680, Test Loss = 5665.7651
# Epoch 79: Train Loss = 4653.8843, Test Loss = 4940.6502
# Epoch 80: Train Loss = 3940.5500, Test Loss = 4381.3574
# Epoch 81: Train Loss = 3344.8950, Test Loss = 3732.6940
# 🚀 Early stopping triggered for Beta_band at epoch 81
# ✅ Beta_band Training & Denoising Completed!
#
# 🟢 Processing Gamma_band...
#
# 📌 Loading and Splitting Data for Gamma_band...
# ✅ Gamma_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ Gamma_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ Gamma_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 Gamma_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 5206.0643, Test Loss = 5161.7459
# Epoch 2: Train Loss = 4971.1466, Test Loss = 4923.8235
# Epoch 3: Train Loss = 4726.2039, Test Loss = 4682.0008
# Epoch 4: Train Loss = 4457.3897, Test Loss = 4410.0378
# Epoch 5: Train Loss = 4178.0650, Test Loss = 4102.3444
# Epoch 6: Train Loss = 3882.7248, Test Loss = 3795.8833
# Epoch 7: Train Loss = 3550.0892, Test Loss = 3453.6252
# Epoch 8: Train Loss = 3227.2785, Test Loss = 3195.6858
# Epoch 9: Train Loss = 2921.5189, Test Loss = 2892.9883
# Epoch 10: Train Loss = 2595.7990, Test Loss = 2503.4528
# Epoch 11: Train Loss = 2272.2505, Test Loss = 2248.1075
# Epoch 12: Train Loss = 2007.9193, Test Loss = 2115.3760
# Epoch 13: Train Loss = 1801.7306, Test Loss = 1804.9005
# Epoch 14: Train Loss = 1539.4712, Test Loss = 1567.8782
# Epoch 15: Train Loss = 1346.2603, Test Loss = 1420.9820
# Epoch 16: Train Loss = 1244.3950, Test Loss = 1393.7633
# Epoch 17: Train Loss = 1180.0523, Test Loss = 1175.0264
# Epoch 18: Train Loss = 939.1257, Test Loss = 1016.0878
# Epoch 19: Train Loss = 817.3135, Test Loss = 909.7245
# Epoch 20: Train Loss = 714.8739, Test Loss = 830.5110
# Epoch 21: Train Loss = 664.2829, Test Loss = 745.1430
# Epoch 22: Train Loss = 614.8975, Test Loss = 701.7857
# Epoch 23: Train Loss = 552.8550, Test Loss = 665.0704
# Epoch 24: Train Loss = 481.1158, Test Loss = 597.3202
# Epoch 25: Train Loss = 438.0048, Test Loss = 602.4077
# Epoch 26: Train Loss = 418.7879, Test Loss = 507.2221
# Epoch 27: Train Loss = 352.2298, Test Loss = 465.8163
# Epoch 28: Train Loss = 320.5659, Test Loss = 444.7338
# Epoch 29: Train Loss = 293.8514, Test Loss = 397.0312
# Epoch 30: Train Loss = 287.6629, Test Loss = 476.6918
# Epoch 31: Train Loss = 412.7310, Test Loss = 632.5508
# Epoch 32: Train Loss = 617.2533, Test Loss = 1126.2254
# Epoch 33: Train Loss = 545.3629, Test Loss = 495.4970
# Epoch 34: Train Loss = 291.8391, Test Loss = 371.2808
# Epoch 35: Train Loss = 228.2505, Test Loss = 329.3887
# Epoch 36: Train Loss = 201.5641, Test Loss = 311.8721
# Epoch 37: Train Loss = 183.9055, Test Loss = 293.1979
# Epoch 38: Train Loss = 171.5323, Test Loss = 279.4443
# Epoch 39: Train Loss = 160.2714, Test Loss = 270.2003
# Epoch 40: Train Loss = 151.3271, Test Loss = 264.5224
# Epoch 41: Train Loss = 143.4263, Test Loss = 250.8843
# Epoch 42: Train Loss = 136.4220, Test Loss = 249.2211
# Epoch 43: Train Loss = 135.8999, Test Loss = 246.8582
# Epoch 44: Train Loss = 126.2533, Test Loss = 236.1206
# Epoch 45: Train Loss = 120.2605, Test Loss = 228.1483
# Epoch 46: Train Loss = 131.0935, Test Loss = 256.1528
# Epoch 47: Train Loss = 123.9036, Test Loss = 221.3543
# Epoch 48: Train Loss = 418.4893, Test Loss = 1674.5894
# Epoch 49: Train Loss = 884.6487, Test Loss = 581.4023
# Epoch 50: Train Loss = 295.2672, Test Loss = 369.9655
# Epoch 51: Train Loss = 190.3281, Test Loss = 282.5805
# Epoch 52: Train Loss = 141.3785, Test Loss = 244.3679
# Epoch 53: Train Loss = 122.0005, Test Loss = 231.1677
# Epoch 54: Train Loss = 111.0324, Test Loss = 219.9981
# Epoch 55: Train Loss = 103.7049, Test Loss = 217.2921
# Epoch 56: Train Loss = 97.5213, Test Loss = 206.9417
# Epoch 57: Train Loss = 91.7967, Test Loss = 201.7532
# Epoch 58: Train Loss = 91.0115, Test Loss = 199.4281
# Epoch 59: Train Loss = 85.1593, Test Loss = 193.3586
# Epoch 60: Train Loss = 81.7872, Test Loss = 193.6194
# Epoch 61: Train Loss = 82.2728, Test Loss = 196.6728
# Epoch 62: Train Loss = 77.4818, Test Loss = 188.6668
# Epoch 63: Train Loss = 76.0554, Test Loss = 191.8833
# Epoch 64: Train Loss = 75.3908, Test Loss = 185.8493
# Epoch 65: Train Loss = 81.7518, Test Loss = 205.8886
# Epoch 66: Train Loss = 87.0798, Test Loss = 184.3365
# Epoch 67: Train Loss = 69.6648, Test Loss = 177.0448
# Epoch 68: Train Loss = 68.3320, Test Loss = 173.6141
# Epoch 69: Train Loss = 63.9701, Test Loss = 170.9148
# Epoch 70: Train Loss = 61.8930, Test Loss = 175.9463
# Epoch 71: Train Loss = 60.8211, Test Loss = 168.8945
# Epoch 72: Train Loss = 60.9491, Test Loss = 177.9786
# Epoch 73: Train Loss = 62.8207, Test Loss = 169.4886
# Epoch 74: Train Loss = 57.5248, Test Loss = 167.2315
# Epoch 75: Train Loss = 57.6464, Test Loss = 163.1009
# Epoch 76: Train Loss = 58.1638, Test Loss = 177.4084
# Epoch 77: Train Loss = 63.0793, Test Loss = 171.9345
# Epoch 78: Train Loss = 677.7283, Test Loss = 2297.4069
# Epoch 79: Train Loss = 1192.2015, Test Loss = 644.7949
# Epoch 80: Train Loss = 339.7568, Test Loss = 355.7227
# Epoch 81: Train Loss = 191.1081, Test Loss = 260.7047
# Epoch 82: Train Loss = 122.4410, Test Loss = 220.0422
# Epoch 83: Train Loss = 99.5335, Test Loss = 202.9793
# Epoch 84: Train Loss = 84.7192, Test Loss = 189.6875
# Epoch 85: Train Loss = 74.8828, Test Loss = 181.3286
# 🚀 Early stopping triggered for Gamma_band at epoch 85
# ✅ Gamma_band Training & Denoising Completed!
#
# 🟢 Processing High_Frequencies_band...
#
# 📌 Loading and Splitting Data for High_Frequencies_band...
# ✅ High_Frequencies_band Train Clean Shape: (27200, 512), Test Clean Shape: (6800, 512)
# ✅ High_Frequencies_band Train Contaminated Shape: (27200, 512), Test Contaminated Shape: (6800, 512)
# ✅ High_Frequencies_band SNR Labels Train: [-7 -6 -5 -4 -3 -2 -1  0  1  2], Test: [-7 -6 -5 -4 -3 -2 -1  0  1  2]
#
# 📌 High_Frequencies_band Dataset Shapes:
#   Train Clean: (27200, 512), Train Contaminated: (27200, 512)
#   Test Clean: (6800, 512), Test Contaminated: (6800, 512)
# Epoch 1: Train Loss = 4281.9460, Test Loss = 4278.8569
# Epoch 2: Train Loss = 4145.8867, Test Loss = 4137.2893
# Epoch 3: Train Loss = 4005.1515, Test Loss = 3979.5022
# Epoch 4: Train Loss = 3820.5927, Test Loss = 3774.7865
# Epoch 5: Train Loss = 3576.7009, Test Loss = 3519.8641
# Epoch 6: Train Loss = 3298.7112, Test Loss = 3223.6044
# Epoch 7: Train Loss = 2999.4924, Test Loss = 2928.1485
# Epoch 8: Train Loss = 2718.6393, Test Loss = 2683.6674
# Epoch 9: Train Loss = 2448.5301, Test Loss = 2440.3979
# Epoch 10: Train Loss = 2227.3974, Test Loss = 2186.2943
# Epoch 11: Train Loss = 1998.1063, Test Loss = 1981.6940
# Epoch 12: Train Loss = 1807.3781, Test Loss = 1810.2736
# Epoch 13: Train Loss = 1637.8334, Test Loss = 1662.3812
# Epoch 14: Train Loss = 1495.6628, Test Loss = 1515.1614
# Epoch 15: Train Loss = 1361.2685, Test Loss = 1377.3900
# Epoch 16: Train Loss = 1244.1457, Test Loss = 1293.3981
# Epoch 17: Train Loss = 1157.9512, Test Loss = 1209.8574
# Epoch 18: Train Loss = 1067.3723, Test Loss = 1116.3963
# Epoch 19: Train Loss = 986.1744, Test Loss = 1023.4853
# Epoch 20: Train Loss = 897.9091, Test Loss = 944.8098
# Epoch 21: Train Loss = 828.9221, Test Loss = 882.5606
# Epoch 22: Train Loss = 771.8758, Test Loss = 829.7507
# Epoch 23: Train Loss = 723.9981, Test Loss = 803.6415
# Epoch 24: Train Loss = 677.7548, Test Loss = 736.9710
# Epoch 25: Train Loss = 633.8007, Test Loss = 698.5631
# Epoch 26: Train Loss = 597.0494, Test Loss = 679.5309
# Epoch 27: Train Loss = 563.3794, Test Loss = 635.1030
# Epoch 28: Train Loss = 535.4888, Test Loss = 629.5754
# Epoch 29: Train Loss = 514.3882, Test Loss = 571.5105
# Epoch 30: Train Loss = 478.8622, Test Loss = 545.1301
# Epoch 31: Train Loss = 454.5586, Test Loss = 525.8228
# Epoch 32: Train Loss = 427.1083, Test Loss = 504.6287
# Epoch 33: Train Loss = 413.7700, Test Loss = 495.6522
# Epoch 34: Train Loss = 396.8366, Test Loss = 468.0449
# Epoch 35: Train Loss = 376.5027, Test Loss = 453.1049
# Epoch 36: Train Loss = 379.1823, Test Loss = 520.3232
# Epoch 37: Train Loss = 402.8998, Test Loss = 443.1672
# Epoch 38: Train Loss = 342.1486, Test Loss = 459.5068
# Epoch 39: Train Loss = 354.6268, Test Loss = 400.6759
# Epoch 40: Train Loss = 308.6583, Test Loss = 384.2170
# Epoch 41: Train Loss = 296.5029, Test Loss = 363.8829
# Epoch 42: Train Loss = 285.6385, Test Loss = 362.3165
# Epoch 43: Train Loss = 272.9804, Test Loss = 352.1125
# Epoch 44: Train Loss = 264.0466, Test Loss = 342.2340
# Epoch 45: Train Loss = 255.2304, Test Loss = 333.2520
# Epoch 46: Train Loss = 259.7759, Test Loss = 416.6902
# Epoch 47: Train Loss = 916.2125, Test Loss = 629.0698
# Epoch 48: Train Loss = 419.3534, Test Loss = 421.1784
# Epoch 49: Train Loss = 307.1271, Test Loss = 364.9348
# Epoch 50: Train Loss = 271.9374, Test Loss = 340.6504
# Epoch 51: Train Loss = 253.1896, Test Loss = 326.2323
# Epoch 52: Train Loss = 240.6236, Test Loss = 311.3093
# Epoch 53: Train Loss = 230.1691, Test Loss = 302.8115
# Epoch 54: Train Loss = 221.4641, Test Loss = 295.0640
# Epoch 55: Train Loss = 214.4834, Test Loss = 287.9198
# Epoch 56: Train Loss = 208.2612, Test Loss = 283.8128
# Epoch 57: Train Loss = 202.5939, Test Loss = 280.2467
# Epoch 58: Train Loss = 197.9471, Test Loss = 274.6362
# Epoch 59: Train Loss = 193.1682, Test Loss = 272.8638
# Epoch 60: Train Loss = 193.3523, Test Loss = 277.3088
# Epoch 61: Train Loss = 187.5284, Test Loss = 264.6452
# Epoch 62: Train Loss = 181.6288, Test Loss = 265.0278
# Epoch 63: Train Loss = 178.4853, Test Loss = 259.5492
# Epoch 64: Train Loss = 176.5489, Test Loss = 259.6549
# Epoch 65: Train Loss = 174.3094, Test Loss = 258.8443
# Epoch 66: Train Loss = 172.8480, Test Loss = 252.9338
# Epoch 67: Train Loss = 167.2572, Test Loss = 249.4946
# Epoch 68: Train Loss = 170.5420, Test Loss = 260.9162
# Epoch 69: Train Loss = 166.4408, Test Loss = 255.5722
# Epoch 70: Train Loss = 163.7324, Test Loss = 244.4757
# Epoch 71: Train Loss = 158.4063, Test Loss = 246.6477
# Epoch 72: Train Loss = 156.8405, Test Loss = 242.0092
# Epoch 73: Train Loss = 154.2716, Test Loss = 237.5947
# Epoch 74: Train Loss = 152.1088, Test Loss = 238.3054
# Epoch 75: Train Loss = 149.1352, Test Loss = 236.7142
# Epoch 76: Train Loss = 168.4868, Test Loss = 266.6193
# Epoch 77: Train Loss = 877.4280, Test Loss = 1094.6919
# Epoch 78: Train Loss = 746.1279, Test Loss = 620.3364
# Epoch 79: Train Loss = 391.3329, Test Loss = 392.8235
# Epoch 80: Train Loss = 271.5543, Test Loss = 328.8692
# Epoch 81: Train Loss = 229.3984, Test Loss = 303.4047
# Epoch 82: Train Loss = 204.7461, Test Loss = 275.7278
# Epoch 83: Train Loss = 188.2756, Test Loss = 261.0956
# Epoch 84: Train Loss = 177.4468, Test Loss = 252.6852
# Epoch 85: Train Loss = 168.5427, Test Loss = 244.7169
# 🚀 Early stopping triggered for High_Frequencies_band at epoch 85
# ✅ High_Frequencies_band Training & Denoising Completed!
#
#
# ✅ All EEG Bands Processed Successfully!

# %%
print(len(contaminated_bands ))  # Prints number of elements in the list
# Out:
# 6

# %%
# ✅ Check shapes of stored bands
print("\n🚀 Checking stored EEG data shapes...")

# Clean EEG
if len(clean_bands) > 0:
    print(f"✅ First clean EEG shape: {clean_bands[0].shape}")
else:
    print("❌ clean_bands is empty!")

# Denoised EEG
if len(denoised_bands) > 0:
    print(f"✅ First denoised EEG shape: {denoised_bands[0].shape}")
else:
    print("❌ denoised_bands is empty!")

# Contaminated EEG
if len(contaminated_bands) > 0:
    print(f"✅ First contaminated EEG shape: {contaminated_bands[0].shape}")
else:
    print("❌ contaminated_bands is empty!")
# Out:
# 🚀 Checking stored EEG data shapes...
# ✅ First clean EEG shape: (6800, 1, 512)
# ✅ First denoised EEG shape: (6800, 512)
# ✅ First contaminated EEG shape: (6800, 1, 512)

# %%
import numpy as np

# ✅ Convert lists to NumPy arrays
clean_bands = np.array(clean_bands)  # Shape: (6, samples, 512)
denoised_bands = np.array(denoised_bands)  # Shape: (6, samples, 512)

# ✅ Reconstruct full EEG signals by summing across frequency bands
denoised_eeg = np.sum(denoised_bands, axis=0)  # Sum across frequency bands
clean_eeg = np.sum(clean_bands, axis=0)

# ✅ Ensure correct shape
if clean_eeg.ndim == 3:
    clean_eeg = clean_eeg.squeeze(1)  # Only squeeze if it has an extra dimension

print(f"✅ Reconstructed EEG: Denoised EEG Shape: {denoised_eeg.shape}, Clean EEG Shape: {clean_eeg.shape}")
# Out:
# ✅ Reconstructed EEG: Denoised EEG Shape: (6800, 512), Clean EEG Shape: (6800, 512)

# %%
import numpy as np
from scipy.signal import welch

# Compute RRMSE in time domain
def compute_rrmse_t(clean, denoised):
    per_sample_rrmse = np.sqrt(np.sum((clean - denoised) ** 2, axis=1) / np.sum(clean ** 2, axis=1))
    return np.mean(per_sample_rrmse)

# Compute RRMSE in frequency domain using Power Spectral Density (PSD)
def compute_rrmse_s(clean, denoised, fs=512):
    f_clean, psd_clean = welch(clean.flatten(), fs=fs, nperseg=512)
    f_denoised, psd_denoised = welch(denoised.flatten(), fs=fs, nperseg=512)
    return np.sqrt(np.sum((psd_clean - psd_denoised) ** 2) / np.sum(psd_clean ** 2))

# Compute Correlation Coefficient (CC)
def compute_cc(clean, denoised):
    return np.corrcoef(clean.flatten(), denoised.flatten())[0, 1]

print("✅ Evaluation functions loaded!")
# Out:
# ✅ Evaluation functions loaded!

# %%
import pandas as pd

# Store evaluation results per SNR level
snr_metrics = {}

# Ensure snr_labels_test is a NumPy array
snr_labels_test = np.array(snr_labels_test).flatten()

# Evaluate each SNR level separately
for snr in np.unique(snr_labels_test):
    indices = np.where(snr_labels_test == snr)[0]  # Get test samples for this SNR

    clean_snr = clean_eeg[indices]
    denoised_snr = denoised_eeg[indices]

    # Compute evaluation metrics
    rrmse_t = compute_rrmse_t(clean_snr, denoised_snr)
    rrmse_s = compute_rrmse_s(clean_snr, denoised_snr, fs=512)
    cc = compute_cc(clean_snr, denoised_snr)
    ts_metric = 10 * np.log10(1 / (rrmse_t + rrmse_s))

    # Store metrics per SNR
    snr_metrics[snr] = {"RRMSE-T": rrmse_t, "RRMSE-S": rrmse_s, "CC": cc, "T&S Metric (dB)": ts_metric}

    print(f"  ✅ SNR {snr}: RRMSE-T = {rrmse_t:.4f}, RRMSE-S = {rrmse_s:.4f}, CC = {cc:.4f}, T&S Metric = {ts_metric:.4f} dB")

# Convert results to DataFrame for better visualization
df_snr_metrics = pd.DataFrame.from_dict(snr_metrics, orient="index")
df_snr_metrics.index.name = "SNR Level"

# Display results
# Out:
#   ✅ SNR -7: RRMSE-T = 0.6363, RRMSE-S = 0.2874, CC = 0.7900, T&S Metric = 0.3449 dB
#   ✅ SNR -6: RRMSE-T = 0.4646, RRMSE-S = 0.1986, CC = 0.8979, T&S Metric = 1.7837 dB
#   ✅ SNR -5: RRMSE-T = 0.4319, RRMSE-S = 0.1824, CC = 0.9167, T&S Metric = 2.1162 dB
#   ✅ SNR -4: RRMSE-T = 0.3930, RRMSE-S = 0.1694, CC = 0.9287, T&S Metric = 2.5000 dB
#   ✅ SNR -3: RRMSE-T = 0.3867, RRMSE-S = 0.1747, CC = 0.9316, T&S Metric = 2.5072 dB
#   ✅ SNR -2: RRMSE-T = 0.3724, RRMSE-S = 0.1611, CC = 0.9364, T&S Metric = 2.7288 dB
#   ✅ SNR -1: RRMSE-T = 0.3681, RRMSE-S = 0.1666, CC = 0.9373, T&S Metric = 2.7191 dB
#   ✅ SNR 0: RRMSE-T = 0.3649, RRMSE-S = 0.1496, CC = 0.9415, T&S Metric = 2.8859 dB
#   ✅ SNR 1: RRMSE-T = 0.3558, RRMSE-S = 0.1786, CC = 0.9409, T&S Metric = 2.7221 dB
#   ✅ SNR 2: RRMSE-T = 0.4242, RRMSE-S = 0.2783, CC = 0.9134, T&S Metric = 1.5333 dB

# %%
# Compute the average of all SNR-based metrics
avg_rrmse_t = np.mean([metrics["RRMSE-T"] for metrics in snr_metrics.values()])
avg_rrmse_s = np.mean([metrics["RRMSE-S"] for metrics in snr_metrics.values()])
avg_cc = np.mean([metrics["CC"] for metrics in snr_metrics.values()])
avg_ts_metric = np.mean([metrics["T&S Metric (dB)"] for metrics in snr_metrics.values()])

# Print the final summary
print("\n==== Final Evaluation Summary ====")
print(f"✅ Average RRMSE-T: {avg_rrmse_t:.4f}")
print(f"✅ Average RRMSE-S: {avg_rrmse_s:.4f}")
print(f"✅ Average CC: {avg_cc:.4f}")
print(f"✅ Average T&S Metric (dB): {avg_ts_metric:.4f}")

# Create DataFrame for display
# Out:
# ==== Final Evaluation Summary ====
# ✅ Average RRMSE-T: 0.4198
# ✅ Average RRMSE-S: 0.1946
# ✅ Average CC: 0.9134
# ✅ Average T&S Metric (dB): 2.1841

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ensure required variables are loaded
try:
    print(f"✅ SNR Labels Shape: {snr_labels_test.shape}, Clean EEG Shape: {clean_eeg.shape}, Denoised EEG Shape: {denoised_eeg.shape}")
except NameError:
    print("❌ Variables are not defined. Re-run the data preparation and evaluation cells.")

# ✅ Convert SNR labels to integers safely
try:
    snr_labels_test_int = np.array([int(str(snr).replace("SNR_", "")) for snr in snr_labels_test])
    print(f"✅ Converted SNR Labels: {snr_labels_test_int[:10]} ...")  # Show first 10 for debugging
except Exception as e:
    print(f"❌ Error converting SNR labels: {e}")

# Set SNR level to check
snr_level = -5 

# ✅ Extract indices of test samples for the selected SNR level
snr_indices = np.where(snr_labels_test_int == snr_level)[0]

# ✅ Handle missing SNR level
if len(snr_indices) == 0:
    print(f"❌ No test samples found for SNR Level {snr_level}.")
else:
    print(f"\n📊 Found {len(snr_indices)} test samples for SNR Level {snr_level}")
    print(f"✅ SNR Level {snr_level} indices in test set: {snr_indices.tolist()}")

    # ✅ Select the first segment
    first_segment_idx = snr_indices[0]

    # ✅ Extract EEG segments
    clean_segment = clean_eeg[first_segment_idx]
    denoised_segment = denoised_eeg[first_segment_idx]

    # ✅ Reconstruct Contaminated EEG by summing all frequency bands
    contaminated_bands = [test_data[band][1] for band in bands]
    contaminated_eeg = np.sum(contaminated_bands, axis=0)
    contaminated_segment = contaminated_eeg[first_segment_idx]

    # ✅ Plot EEG signals
    plt.figure(figsize=(12, 5))
    plt.plot(clean_segment, label="Clean EEG", linestyle="dashed", color="blue", linewidth=1.5)
    plt.plot(denoised_segment, label="Denoised EEG", linestyle="solid", color="red", linewidth=1.5)
    #plt.plot(contaminated_segment, label="Contaminated EEG", linestyle="dotted", color="green", linewidth=1.5)
    
    plt.title(f"EEG Signal Comparison (SNR Level {snr_level}, First Segment)")
    plt.xlabel("Time (Samples)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# ✅ SNR Labels Shape: (6800,), Clean EEG Shape: (6800, 512), Denoised EEG Shape: (6800, 512)
# ✅ Converted SNR Labels: [-7 -7 -2 -4  2  1  2 -2 -2 -4] ...
#
# 📊 Found 680 test samples for SNR Level -5
# ✅ SNR Level -5 indices in test set: [26, 29, 51, 61, 79, 82, 89, 91, 94, 95, 108, 115, 120, 129, 136, 159, 161, 167, 186, 188, 194, 212, 220, 225, 235, 240, 248, 279, 284, 315, 318, 325, 331, 333, 336, 345, 354, 369, 371, 372, 379, 381, 386, 406, 408, 416, 419, 421, 433, 439, 453, 460, 484, 488, 490, 506, 508, 512, 549, 574, 598, 605, 620, 632, 635, 691, 695, 696, 713, 724, 726, 734, 738, 749, 750, 752, 753, 756, 767, 775, 783, 793, 800, 801, 817, 818, 831, 840, 858, 865, 882, 883, 902, 914, 936, 940, 960, 965, 969, 977, 978, 979, 981, 982, 1004, 1009, 1019, 1020, 1036, 1044, 1052, 1070, 1079, 1084, 1086, 1088, 1108, 1111, 1112, 1116, 1117, 1129, 1151, 1158, 1168, 1191, 1194, 1208, 1216, 1244, 1245, 1251, 1267, 1276, 1292, 1293, 1308, 1316, 1331, 1359, 1363, 1365, 1377, 1384, 1447, 1450, 1457, 1484, 1510, 1512, 1516, 1540, 1559, 1582, 1584, 1607, 1608, 1616, 1627, 1638, 1655, 1658, 1664, 1671, 1678, 1691, 1693, 1697, 1704, 1707, 1711, 1714, 1760, 1764, 1768, 1770, 1786, 1810, 1816, 1822, 1825, 1829, 1843, 1846, 1868, 1870, 1872, 1915, 1920, 1929, 1951, 1955, 1962, 1986, 1990, 2000, 2006, 2014, 2017, 2019, 2029, 2032, 2042, 2049, 2052, 2053, 2062, 2065, 2068, 2075, 2092, 2107, 2117, 2126, 2127, 2151, 2162, 2179, 2182, 2185, 2195, 2209, 2215, 2218, 2222, 2229, 2235, 2247, 2251, 2255, 2260, 2271, 2277, 2295, 2304, 2310, 2311, 2319, 2331, 2332, 2342, 2362, 2363, 2369, 2371, 2404, 2410, 2413, 2422, 2431, 2437, 2459, 2469, 2479, 2501, 2508, 2546, 2557, 2563, 2576, 2578, 2584, 2594, 2598, 2602, 2610, 2626, 2644, 2656, 2668, 2670, 2686, 2700, 2702, 2708, 2729, 2736, 2746, 2749, 2750, 2767, 2782, 2783, 2788, 2810, 2818, 2822, 2829, 2831, 2846, 2851, 2853, 2856, 2886, 2887, 2889, 2896, 2900, 2914, 2922, 2930, 2945, 2961, 2976, 2985, 2987, 2998, 3001, 3013, 3017, 3020, 3032, 3033, 3049, 3071, 3076, 3084, 3096, 3097, 3103, 3148, 3159, 3169, 3176, 3179, 3189, 3209, 3219, 3224, 3225, 3250, 3269, 3283, 3289, 3292, 3300, 3308, 3312, 3332, 3345, 3348, 3358, 3359, 3366, 3375, 3379, 3400, 3431, 3441, 3479, 3482, 3520, 3527, 3529, 3553, 3557, 3561, 3563, 3577, 3611, 3620, 3630, 3638, 3642, 3646, 3648, 3669, 3697, 3713, 3732, 3733, 3742, 3745, 3758, 3762, 3766, 3771, 3773, 3788, 3802, 3804, 3833, 3836, 3837, 3856, 3866, 3869, 3873, 3877, 3902, 3908, 3912, 3915, 3922, 3934, 3935, 3940, 3949, 3962, 3970, 3992, 4002, 4004, 4009, 4010, 4018, 4019, 4023, 4032, 4044, 4045, 4049, 4053, 4054, 4067, 4073, 4079, 4082, 4085, 4101, 4104, 4108, 4117, 4119, 4133, 4138, 4160, 4162, 4164, 4171, 4175, 4176, 4189, 4197, 4214, 4215, 4233, 4237, 4241, 4244, 4270, 4289, 4293, 4300, 4337, 4352, 4380, 4384, 4402, 4433, 4472, 4489, 4490, 4497, 4499, 4532, 4533, 4535, 4560, 4578, 4586, 4587, 4594, 4600, 4610, 4612, 4613, 4637, 4643, 4646, 4662, 4684, 4697, 4708, 4710, 4718, 4727, 4737, 4744, 4773, 4774, 4775, 4777, 4785, 4786, 4788, 4789, 4798, 4805, 4811, 4837, 4846, 4854, 4856, 4878, 4905, 4910, 4933, 4940, 4942, 4961, 4971, 4996, 4999, 5018, 5024, 5027, 5052, 5057, 5073, 5087, 5105, 5110, 5114, 5147, 5152, 5164, 5169, 5176, 5187, 5191, 5214, 5225, 5227, 5230, 5232, 5236, 5243, 5271, 5293, 5302, 5304, 5307, 5312, 5316, 5331, 5336, 5347, 5351, 5371, 5378, 5380, 5402, 5415, 5436, 5445, 5446, 5448, 5455, 5465, 5485, 5500, 5502, 5512, 5523, 5526, 5528, 5529, 5533, 5535, 5539, 5545, 5554, 5559, 5562, 5564, 5578, 5579, 5582, 5615, 5621, 5624, 5626, 5627, 5658, 5662, 5672, 5683, 5707, 5727, 5730, 5739, 5762, 5767, 5768, 5780, 5791, 5812, 5814, 5821, 5844, 5868, 5872, 5890, 5902, 5913, 5928, 5931, 5933, 5942, 5953, 5966, 5969, 5973, 5977, 5978, 6011, 6016, 6021, 6037, 6038, 6045, 6048, 6055, 6058, 6061, 6067, 6069, 6072, 6098, 6112, 6116, 6127, 6154, 6179, 6207, 6208, 6219, 6223, 6229, 6250, 6254, 6269, 6277, 6283, 6303, 6308, 6310, 6312, 6338, 6355, 6376, 6380, 6385, 6393, 6398, 6413, 6435, 6446, 6448, 6462, 6469, 6470, 6475, 6506, 6512, 6522, 6526, 6533, 6537, 6540, 6553, 6588, 6594, 6600, 6608, 6618, 6619, 6627, 6632, 6655, 6671, 6683, 6703, 6709, 6713, 6715, 6729, 6790, 679 ...

# %%
# ✅ Get denoised EEG plotting points
x_points = list(range(len(denoised_segment)))      # X-axis: time/sample index
y_points = denoised_segment.tolist()               # Y-axis: denoised EEG values

# ✅ Print the plotting points
print("Denoised EEG Plotting Points:")
for x, y in zip(x_points, y_points):
    print(f"({x}, {y})")
# Out:
# Denoised EEG Plotting Points:
# (0, 657.1886596679688)
# (1, 852.43798828125)
# (2, 562.0908203125)
# (3, 679.3780517578125)
# (4, 703.5309448242188)
# (5, 486.9898986816406)
# (6, 104.67577362060547)
# (7, -278.9789733886719)
# (8, -618.5543823242188)
# (9, -653.9256591796875)
# (10, -544.8233642578125)
# (11, -667.6282958984375)
# (12, -813.12255859375)
# (13, -618.8348999023438)
# (14, -361.3650207519531)
# (15, -316.0457458496094)
# (16, -249.8921356201172)
# (17, -43.37907409667969)
# (18, 109.02386474609375)
# (19, 189.03489685058594)
# (20, 315.0327453613281)
# (21, 439.279052734375)
# (22, 446.8822021484375)
# (23, 375.32318115234375)
# (24, 399.513916015625)
# (25, 588.2628173828125)
# (26, 757.6398315429688)
# (27, 805.0187377929688)
# (28, 880.1046142578125)
# (29, 977.3635864257812)
# (30, 894.7244262695312)
# (31, 686.7328491210938)
# (32, 496.8918151855469)
# (33, 207.9848175048828)
# (34, -164.57183837890625)
# (35, -364.3109130859375)
# (36, -410.4025573730469)
# (37, -489.46966552734375)
# (38, -559.593505859375)
# (39, -585.5653686523438)
# (40, -628.0857543945312)
# (41, -563.5433959960938)
# (42, -349.5616760253906)
# (43, -215.944091796875)
# (44, -193.57882690429688)
# (45, -79.50077056884766)
# (46, 78.83456420898438)
# (47, 158.17095947265625)
# (48, 270.48223876953125)
# (49, 427.82757568359375)
# (50, 405.158447265625)
# (51, 146.31874084472656)
# (52, -133.37396240234375)
# (53, -237.07803344726562)
# (54, -171.31857299804688)
# (55, -114.4042739868164)
# (56, -150.62725830078125)
# (57, -126.98516082763672)
# (58, 32.37258529663086)
# (59, 147.5142822265625)
# (60, 107.75746154785156)
# (61, 2.7062997817993164)
# (62, -109.32279205322266)
# (63, -223.87210083007812)
# (64, -335.3032531738281)
# (65, -451.8497009277344)
# (66, -503.3638610839844)
# (67, -386.409912109375)
# (68, -170.9141082763672)
# (69, 6.983665466308594)
# (70, 139.77337646484375)
# (71, 211.95999145507812)
# (72, 169.79115295410156)
# (73, 119.98133850097656)
# (74, 182.5867919921875)
# (75, 259.9688720703125)
# (76, 223.18971252441406)
# (77, 122.58834075927734)
# (78, 76.40269470214844)
# (79, 110.27511596679688)
# (80, 135.35235595703125)
# (81, 102.11558532714844)
# (82, 77.9887466430664)
# (83, 39.80134963989258)
# (84, -102.02483367919922)
# (85, -195.49728393554688)
# (86, -90.6706771850586)
# (87, -47.35160827636719)
# (88, -208.81971740722656)
# (89, -244.32603454589844)
# (90, -69.29367065429688)
# (91, -0.6589431762695312)
# (92, -9.751617431640625)
# (93, 147.55186462402344)
# (94, 312.7875671386719)
# (95, 301.01959228515625)
# (96, 246.18753051757812)
# (97, 174.59994506835938)
# (98, 30.21832275390625)
# (99, -17.54620361328125)
# (100, 76.93751525878906)
# (101, 67.344970703125)
# (102, -113.25406646728516)
# (103, -263.5601806640625)
# (104, -252.7666473388672)
# (105, -115.7513427734375)
# (106, -32.937255859375)
# (107, -132.98538208007812)
# (108, -263.57879638671875)
# (109, -281.2103576660156)
# (110, -340.2461853027344)
# (111, -442.9742431640625)
# (112, -367.35400390625)
# (113, -205.62142944335938)
# (114, -203.4000701904297)
# (115, -231.83062744140625)
# (116, -150.19297790527344)
# (117, -96.272705078125)
# (118, -101.058349609375)
# (119, -67.7933578491211)
# (120, -54.8399772644043)
# (121, -89.10331726074219)
# (122, -110.71820831298828)
# (123, -180.25875854492188)
# (124, -295.514404296875)
# (125, -281.26983642578125)
# (126, -160.15530395507812)
# (127, -148.693115234375)
# (128, -291.2029113769531)
# (129, -474.11614990234375)
# (130, -582.7967529296875)
# (131, -543.9832763671875)
# (132, -472.71258544921875)
# (133, -543.3440551757812)
# (134, -691.4895629882812)
# (135, -752.2200317382812)
# (136, -671.717529296875)
# (137, -430.2810974121094)
# (138, -175.61593627929688)
# (139, -157.56112670898438)
# (140, -219.14703369140625)
# (141, -45.30695343017578)
# (142, 148.11358642578125)
# (143, 106.54975128173828)
# (144, 125.98603057861328)
# (145, 338.67022705078125)
# (146, 377.98468017578125)
# (147, 207.14601135253906)
# (148, 141.740966796875)
# (149, 161.19674682617188)
# (150, 114.92204284667969)
# (151, 86.13551330566406)
# (152, 110.64881896972656)
# (153, 138.869384765625)
# (154, 210.02145385742188)
# (155, 254.66891479492188)
# (156, 188.5657501220703)
# (157, 159.39138793945312)
# (158, 210.8495330810547)
# (159, 176.98731994628906)
# (160, 85.4724349975586)
# (161, 64.20149230957031)
# (162, 65.93942260742188)
# (163, 117.7510757446289)
# (164, 254.5973358154297)
# (165, 256.2541198730469)
# (166, 92.75855255126953)
# (167, 64.69713592529297)
# (168, 139.22059631347656)
# (169, 57.894981384277344)
# (170, -44.55735778808594)
# (171, -35.98609161376953)
# (172, -121.31195831298828)
# (173, -240.3401641845703)
# (174, -175.65390014648438)
# (175, -173.32315063476562)
# (176, -395.5379333496094)
# (177, -462.1396484375)
# (178, -285.7740783691406)
# (179, -223.65756225585938)
# (180, -229.021728515625)
# (181, -50.728370666503906)
# (182, 117.97607421875)
# (183, 119.08345794677734)
# (184, 173.89871215820312)
# (185, 320.109375)
# (186, 361.1783142089844)
# (187, 269.5115051269531)
# (188, 84.50091552734375)
# (189, -113.39820861816406)
# (190, -57.196998596191406)
# (191, 238.00250244140625)
# (192, 299.0710754394531)
# (193, 8.395366668701172)
# (194, -205.52566528320312)
# (195, -190.4384002685547)
# (196, -188.0302734375)
# (197, -240.27056884765625)
# (198, -236.8872833251953)
# (199, -203.88037109375)
# (200, -185.71279907226562)
# (201, -193.79115295410156)
# (202, -244.8028564453125)
# (203, -220.171630859375)
# (204, -62.276187896728516)
# (205, 6.688179016113281)
# (206, -74.25003051757812)
# (207, -23.54876708984375)
# (208, 196.6503143310547)
# (209, 335.49420166015625)
# (210, 411.633544921875)
# (211, 550.564208984375)
# (212, 563.2743530273438)
# (213, 361.7619934082031)
# (214, 240.38723754882812)
# (215, 350.3643493652344)
# (216, 472.4197082519531)
# (217, 454.01641845703125)
# (218, 391.32965087890625)
# (219, 370.9770812988281)
# (220, 310.26568603515625)
# (221, 100.99996948242188)
# (222, -133.75222778320312)
# (223, -173.4553985595703)
# (224, -87.63858795166016)
# (225, -37.60032653808594)
# (226, 117.1629867553711)
# (227, 430.8297424316406)
# (228, 558.2210693359375)
# (229, 403.2371520996094)
# (230, 309.948974609375)
# (231, 345.56329345703125)
# (232, 323.9409484863281)
# (233, 373.7227478027344)
# (234, 555.1663208007812)
# (235, 537.0953369140625)
# (236, 282.7265930175781)
# (237, 164.70578002929688)
# (238, 197.82656860351562)
# (239, 105.78910064697266)
# (240, -48.766971588134766)
# (241, -108.20506286621094)
# (242, -180.59893798828125)
# (243, -310.8711242675781)
# (244, -328.6391296386719)
# (245, -206.253662109375)
# (246, -122.13020324707031)
# (247, -172.06710815429688)
# (248, -234.98880004882812)
# (249, -113.4609603881836)
# (250, 185.66134643554688)
# (251, 417.40283203125)
# (252, 463.1615905761719)
# (253, 453.6003112792969)
# (254, 440.203369140625)
# (255, 320.1354675292969)
# (256, 119.86616516113281)
# (257, -21.245849609375)
# (258, -71.81706237792969)
# (259, -82.4449462890625)
# (260, -68.34170532226562)
# (261, -30.81134033203125)
# (262, -5.672813415527344)
# (263, -8.293781280517578)
# (264, -19.718704223632812)
# (265, -10.657394409179688)
# (266, 28.828895568847656)
# (267, 84.03787231445312)
# (268, 96.8375473022461)
# (269, 5.1617431640625)
# (270, -150.80459594726562)
# (271, -232.66351318359375)
# (272, -231.63047790527344)
# (273, -243.779052734375)
# (274, -197.39987182617188)
# (275, 4.67034912109375)
# (276, 179.69309997558594)
# (277, 217.92189025878906)
# (278, 340.01385498046875)
# (279, 567.0132446289062)
# (280, 604.1092529296875)
# (281, 486.225341796875)
# (282, 466.2547607421875)
# (283, 411.1896667480469)
# (284, 176.79249572753906)
# (285, 75.89471435546875)
# (286, 221.2830810546875)
# (287, 233.4176025390625)
# (288, 28.542112350463867)
# (289, -53.9204216003418)
# (290, 10.208209991455078)
# (291, -26.836977005004883)
# (292, -135.08154296875)
# (293, -154.69766235351562)
# (294, -122.97779083251953)
# (295, -118.4922103881836)
# (296, -158.0747528076172)
# (297, -243.05496215820312)
# (298, -273.99407958984375)
# (299, -155.86599731445312)
# (300, -43.983436584472656)
# (301, -104.23589324951172)
# (302, -182.98822021484375)
# (303, -101.02703857421875)
# (304, -3.2707176208496094)
# (305, -56.14064025878906)
# (306, -147.80068969726562)
# (307, -157.90687561035156)
# (308, -177.00885009765625)
# (309, -267.2088928222656)
# (310, -318.9814758300781)
# (311, -253.48504638671875)
# (312, -144.81141662597656)
# (313, -65.44107818603516)
# (314, -14.765048027038574)
# (315, -1.2500362396240234)
# (316, -36.22721481323242)
# (317, -64.38853454589844)
# (318, -64.60875701904297)
# (319, -131.48715209960938)
# (320, -308.8648376464844)
# (321, -461.5062561035156)
# (322, -471.9040832519531)
# (323, -363.88372802734375)
# (324, -185.751220703125)
# (325, -1.7841644287109375)
# (326, 61.41753387451172)
# (327, -5.629034042358398)
# (328, -38.51532745361328)
# (329, 13.977264404296875)
# (330, 18.793888092041016)
# (331, -68.40636444091797)
# (332, -166.22430419921875)
# (333, -226.6145782470703)
# (334, -230.24569702148438)
# (335, -181.08474731445312)
# (336, -150.46865844726562)
# (337, -161.99765014648438)
# (338, -151.87904357910156)
# (339, -146.70504760742188)
# (340, -181.7041015625)
# (341, -167.3319854736328)
# (342, -114.03221130371094)
# (343, -174.55072021484375)
# (344, -302.5765380859375)
# (345, -336.8762512207031)
# (346, -367.04022216796875)
# (347, -490.1559143066406)
# (348, -525.595458984375)
# (349, -374.9986572265625)
# (350, -225.59793090820312)
# (351, -199.5770263671875)
# (352, -217.9896697998047)
# (353, -213.6482696533203)
# (354, -180.17544555664062)
# (355, -138.7301483154297)
# (356, -128.17697143554688)
# (357, -137.79913330078125)
# (358, -169.06211853027344)
# (359, -275.3218688964844)
# (360, -379.6543273925781)
# (361, -295.132568359375)
# (362, -60.32923126220703)
# (363, 88.29072570800781)
# (364, 92.72760772705078)
# (365, 75.5338363647461)
# (366, 75.63526916503906)
# (367, 52.53852081298828)
# (368, 25.78369903564453)
# (369, 74.23432922363281)
# (370, 173.09420776367188)
# (371, 162.88507080078125)
# (372, 3.2848072052001953)
# (373, -123.95802307128906)
# (374, -153.9024658203125)
# (375, -189.65472412109375)
# (376, -167.97755432128906)
# (377, -30.34044647216797)
# (378, -16.52869415283203)
# (379, -158.5258331298828)
# (380, -121.90130615234375)
# (381, 45.32900619506836)
# (382, -9.639458656311035)
# (383, -95.81766510009766)
# (384, 122.59164428710938)
# (385, 334.63372802734375)
# (386, 232.38572692871094)
# (387, 128.42852783203125)
# (388, 248.3597412109375)
# (389, 376.4301452636719)
# (390, 396.0865783691406)
# (391, 389.2594909667969)
# (392, 367.52764892578125)
# (393, 346.5566711425781)
# (394, 332.29632568359375)
# (395, 222.32704162597656)
# (396, 8.945112228393555)
# (397, -180.5182647705078)
# (398, -293.1062316894531)
# (399, -282.2727966308594)
# (400, -98.2584228515625)
# (401, 80.59867858886719)
# (402, 25.60340118408203)
# (403, -166.8946990966797)
# (404, -257.9541015625)
# (405, -202.83126831054688)
# (406, -103.8526382446289)
# (407, -44.47407531738281)
# (408, -47.357418060302734)
# (409, -72.80706787109375)
# (410, -81.89096069335938)
# (411, -5.3862457275390625)
# (412, 243.90980529785156)
# (413, 533.4481811523438)
# (414, 591.8535766601562)
# (415, 448.3378601074219)
# (416, 337.4609375)
# (417, 248.2008056640625)
# (418, 87.38848114013672)
# (419, -53.86054992675781)
# (420, -134.95571899414062)
# (421, -196.87893676757812)
# (422, -195.6425018310547)
# (423, -182.4501190185547)
# (424, -277.63323974609375)
# (425, -347.95086669921875)
# (426, -262.930419921875)
# (427, -160.70620727539062)
# (428, -50.77214050292969)
# (429, 191.21658325195312)
# (430, 365.03302001953125)
# (431, 263.01593017578125)
# (432, 113.60408020019531)
# (433, 76.63314819335938)
# (434, 26.060287475585938)
# (435, 43.247215270996094)
# (436, 245.35301208496094)
# (437, 380.9643859863281)
# (438, 301.86981201171875)
# (439, 235.44534301757812)
# (440, 299.7181091308594)
# (441, 403.3528747558594)
# (442, 495.77154541015625)
# (443, 472.135009765625)
# (444, 253.9614715576172)
# (445, 25.63018035888672)
# (446, -73.91584777832031)
# (447, -162.98951721191406)
# (448, -247.27882385253906)
# (449, -207.6205596923828)
# (450, -136.940673828125)
# (451, -130.5452117919922)
# (452, -102.19156646728516)
# (453, -91.25302124023438)
# (454, -178.42776489257812)
# (455, -183.08753967285156)
# (456, -22.669225692749023)
# (457, 49.65071105957031)
# (458, -2.429729461669922)
# (459, 93.68898010253906)
# (460, 274.64178466796875)
# (461, 220.5664520263672)
# (462, 19.91960906982422)
# (463, -18.276763916015625)
# (464, 70.94336700439453)
# (465, 135.13026428222656)
# (466, 228.21200561523438)
# (467, 339.6553955078125)
# (468, 308.84259033203125)
# (469, 168.58834838867188)
# (470, 95.56749725341797)
# (471, 96.43525695800781)
# (472, 102.24931335449219)
# (473, 113.45979309082031)
# (474, 69.44712829589844)
# (475, -62.050559997558594)
# (476, -135.8979949951172)
# (477, -127.3091812133789)
# (478, -222.32589721679688)
# (479, -332.520263671875)
# (480, -167.44378662109375)
# (481, 131.49008178710938)
# (482, 169.18382263183594)
# (483, 6.721778869628906)
# (484, -39.58709716796875)
# (485, 38.16375732421875)
# (486, 135.58717346191406)
# (487, 298.3016357421875)
# (488, 432.1550598144531)
# (489, 314.5902404785156)
# (490, 48.76969909667969)
# (491, -5.1759185791015625)
# (492, 199.87344360351562)
# (493, 349.8833923339844)
# (494, 277.55767822265625)
# (495, 115.43486022949219)
# (496, -21.95272445678711)
# (497, -166.34176635742188)
# (498, -288.0939025878906)
# (499, -310.38031005859375)
# (500, -270.58868408203125)
# (501, -211.03958129882812)
# (502, -96.07080841064453)
# (503, -21.888687133789062)
# (504, -141.08326721191406)
# (505, -296.172119140625)
# (506, -216.76341247558594)
# (507, -7.031578063964844)
# (508, 15.694694519042969)
# (509, -126.32485961914062)
# (510, -175.03854370117188)
# (511, -12.192533493041992)

# %%
# ✅ Get denoised EEG plotting points
x_points = list(range(len(clean_segment)))      # X-axis: time/sample index
y_points = clean_segment.tolist()               # Y-axis: denoised EEG values

# ✅ Print the plotting points
print("Clean EEG Plotting Points:")
for x, y in zip(x_points, y_points):
    print(f"({x}, {y})")
# Out:
# Clean EEG Plotting Points:
# (0, 866.0310668945312)
# (1, 1079.484130859375)
# (2, 731.6409301757812)
# (3, 862.6738891601562)
# (4, 866.7140502929688)
# (5, 588.8504028320312)
# (6, 136.66143798828125)
# (7, -298.35662841796875)
# (8, -691.608642578125)
# (9, -754.778564453125)
# (10, -658.8089599609375)
# (11, -812.54345703125)
# (12, -974.6163940429688)
# (13, -764.3228759765625)
# (14, -497.63824462890625)
# (15, -456.69189453125)
# (16, -364.16766357421875)
# (17, -113.02513885498047)
# (18, 65.3680419921875)
# (19, 168.07069396972656)
# (20, 334.055419921875)
# (21, 487.0714416503906)
# (22, 495.9732360839844)
# (23, 423.62994384765625)
# (24, 460.7734375)
# (25, 654.1538696289062)
# (26, 806.8607788085938)
# (27, 831.9862670898438)
# (28, 895.39453125)
# (29, 980.781494140625)
# (30, 880.4319458007812)
# (31, 661.5908203125)
# (32, 461.5799255371094)
# (33, 154.7933349609375)
# (34, -231.58509826660156)
# (35, -433.34747314453125)
# (36, -481.13232421875)
# (37, -568.77734375)
# (38, -649.6075439453125)
# (39, -692.3427124023438)
# (40, -753.9926147460938)
# (41, -698.4561157226562)
# (42, -490.4478454589844)
# (43, -383.2445068359375)
# (44, -392.09423828125)
# (45, -278.7664794921875)
# (46, -100.5549087524414)
# (47, -23.42145538330078)
# (48, 72.37389373779297)
# (49, 235.53944396972656)
# (50, 224.925537109375)
# (51, -45.98872756958008)
# (52, -330.09686279296875)
# (53, -397.9757080078125)
# (54, -295.2097473144531)
# (55, -220.90126037597656)
# (56, -226.46929931640625)
# (57, -166.5471649169922)
# (58, -2.453725814819336)
# (59, 114.52298736572266)
# (60, 99.5409927368164)
# (61, -6.904523849487305)
# (62, -154.30517578125)
# (63, -281.9281921386719)
# (64, -379.5749206542969)
# (65, -498.3936462402344)
# (66, -562.5078125)
# (67, -438.6131591796875)
# (68, -204.3082275390625)
# (69, -6.706581115722656)
# (70, 145.40289306640625)
# (71, 222.8783721923828)
# (72, 178.22801208496094)
# (73, 143.34085083007812)
# (74, 237.42762756347656)
# (75, 335.26129150390625)
# (76, 293.89739990234375)
# (77, 185.3545379638672)
# (78, 162.46678161621094)
# (79, 229.51058959960938)
# (80, 240.0173797607422)
# (81, 161.77159118652344)
# (82, 124.51690673828125)
# (83, 82.82814025878906)
# (84, -98.97560119628906)
# (85, -212.76487731933594)
# (86, -79.89956665039062)
# (87, -28.148910522460938)
# (88, -215.35922241210938)
# (89, -250.94580078125)
# (90, -59.83243942260742)
# (91, 7.045108795166016)
# (92, 15.453208923339844)
# (93, 210.18014526367188)
# (94, 383.2618103027344)
# (95, 371.00933837890625)
# (96, 337.6310119628906)
# (97, 265.3305358886719)
# (98, 92.42816925048828)
# (99, 50.181251525878906)
# (100, 170.0555877685547)
# (101, 147.9476318359375)
# (102, -65.12066650390625)
# (103, -230.17852783203125)
# (104, -213.33734130859375)
# (105, -53.570274353027344)
# (106, 45.988922119140625)
# (107, -75.53951263427734)
# (108, -223.4794464111328)
# (109, -219.787353515625)
# (110, -263.4938659667969)
# (111, -383.95037841796875)
# (112, -310.7479553222656)
# (113, -134.34556579589844)
# (114, -130.86708068847656)
# (115, -165.8415069580078)
# (116, -89.37335968017578)
# (117, -55.71221923828125)
# (118, -73.38877868652344)
# (119, -26.530681610107422)
# (120, -1.0170783996582031)
# (121, -33.222267150878906)
# (122, -48.909114837646484)
# (123, -122.95794677734375)
# (124, -242.3829345703125)
# (125, -208.11326599121094)
# (126, -80.47928619384766)
# (127, -100.91075134277344)
# (128, -264.62841796875)
# (129, -451.14935302734375)
# (130, -582.9364624023438)
# (131, -561.9356079101562)
# (132, -484.2176208496094)
# (133, -580.2328491210938)
# (134, -771.3147583007812)
# (135, -824.3897705078125)
# (136, -726.2554321289062)
# (137, -517.3241577148438)
# (138, -284.4591064453125)
# (139, -242.885009765625)
# (140, -296.9495849609375)
# (141, -131.7236328125)
# (142, 82.35942077636719)
# (143, 62.85282897949219)
# (144, 90.45368194580078)
# (145, 332.9176025390625)
# (146, 416.44342041015625)
# (147, 268.74169921875)
# (148, 220.0652618408203)
# (149, 259.03814697265625)
# (150, 209.30401611328125)
# (151, 165.868896484375)
# (152, 193.87539672851562)
# (153, 239.430419921875)
# (154, 313.51397705078125)
# (155, 338.685791015625)
# (156, 247.08969116210938)
# (157, 203.48829650878906)
# (158, 243.17962646484375)
# (159, 181.69276428222656)
# (160, 65.12809753417969)
# (161, 31.17664337158203)
# (162, 11.839096069335938)
# (163, 44.60155487060547)
# (164, 187.57498168945312)
# (165, 190.8805694580078)
# (166, 8.802570343017578)
# (167, -27.20702362060547)
# (168, 40.403629302978516)
# (169, -54.53249740600586)
# (170, -131.0265350341797)
# (171, -83.52867126464844)
# (172, -184.56661987304688)
# (173, -310.83349609375)
# (174, -186.56021118164062)
# (175, -159.38136291503906)
# (176, -423.3023681640625)
# (177, -482.400146484375)
# (178, -251.9771728515625)
# (179, -190.4217071533203)
# (180, -214.80368041992188)
# (181, -13.513082504272461)
# (182, 168.5804901123047)
# (183, 169.0188446044922)
# (184, 255.13934326171875)
# (185, 419.5451354980469)
# (186, 430.7599182128906)
# (187, 324.137451171875)
# (188, 145.9095916748047)
# (189, -63.335784912109375)
# (190, -7.379364013671875)
# (191, 300.3249206542969)
# (192, 328.9095458984375)
# (193, -4.01434326171875)
# (194, -203.46600341796875)
# (195, -178.37106323242188)
# (196, -223.13558959960938)
# (197, -313.4929504394531)
# (198, -305.1673583984375)
# (199, -279.0218505859375)
# (200, -282.95721435546875)
# (201, -283.8257751464844)
# (202, -301.1920471191406)
# (203, -262.3290710449219)
# (204, -120.74169921875)
# (205, -57.839561462402344)
# (206, -108.70861053466797)
# (207, -20.21142578125)
# (208, 220.85882568359375)
# (209, 383.6026306152344)
# (210, 490.1604919433594)
# (211, 630.3085327148438)
# (212, 623.0027465820312)
# (213, 418.1778564453125)
# (214, 307.50830078125)
# (215, 419.66558837890625)
# (216, 529.289306640625)
# (217, 475.8887634277344)
# (218, 371.23126220703125)
# (219, 349.01934814453125)
# (220, 314.181396484375)
# (221, 102.8257827758789)
# (222, -158.24029541015625)
# (223, -202.33682250976562)
# (224, -92.53649139404297)
# (225, -11.5389404296875)
# (226, 168.7764892578125)
# (227, 491.126220703125)
# (228, 617.8145751953125)
# (229, 466.36956787109375)
# (230, 368.70050048828125)
# (231, 389.061767578125)
# (232, 368.0955505371094)
# (233, 424.8864440917969)
# (234, 587.8954467773438)
# (235, 536.6594848632812)
# (236, 257.5740051269531)
# (237, 117.38353729248047)
# (238, 130.75445556640625)
# (239, 35.638572692871094)
# (240, -121.55088806152344)
# (241, -188.69570922851562)
# (242, -256.7654113769531)
# (243, -367.5902404785156)
# (244, -362.9091491699219)
# (245, -205.01071166992188)
# (246, -79.44160461425781)
# (247, -118.76200866699219)
# (248, -194.33897399902344)
# (249, -62.04136657714844)
# (250, 263.7342834472656)
# (251, 494.4071960449219)
# (252, 520.0494384765625)
# (253, 510.7643127441406)
# (254, 501.05718994140625)
# (255, 355.752685546875)
# (256, 123.97801971435547)
# (257, -22.62322998046875)
# (258, -74.89093017578125)
# (259, -94.3246078491211)
# (260, -69.72987365722656)
# (261, -24.371002197265625)
# (262, -25.80590057373047)
# (263, -53.1258544921875)
# (264, -45.95942687988281)
# (265, -19.43402862548828)
# (266, 0.8268814086914062)
# (267, 41.08893585205078)
# (268, 65.64724731445312)
# (269, -30.28588104248047)
# (270, -208.3074493408203)
# (271, -293.97015380859375)
# (272, -280.6976013183594)
# (273, -291.53900146484375)
# (274, -251.59864807128906)
# (275, -48.01298904418945)
# (276, 151.62730407714844)
# (277, 236.58370971679688)
# (278, 399.3594665527344)
# (279, 640.1990356445312)
# (280, 680.5205078125)
# (281, 567.2587890625)
# (282, 546.3631591796875)
# (283, 482.0318908691406)
# (284, 234.69415283203125)
# (285, 109.44432830810547)
# (286, 221.78106689453125)
# (287, 200.32940673828125)
# (288, -52.245086669921875)
# (289, -198.5204315185547)
# (290, -174.50877380371094)
# (291, -215.71878051757812)
# (292, -334.21044921875)
# (293, -387.6930847167969)
# (294, -379.07373046875)
# (295, -368.07373046875)
# (296, -382.35809326171875)
# (297, -430.7313537597656)
# (298, -418.96917724609375)
# (299, -259.5869445800781)
# (300, -98.51121520996094)
# (301, -98.90431213378906)
# (302, -131.1729736328125)
# (303, -36.41362380981445)
# (304, 49.88705825805664)
# (305, -19.497467041015625)
# (306, -114.3572998046875)
# (307, -111.7965087890625)
# (308, -138.39324951171875)
# (309, -278.774658203125)
# (310, -375.59503173828125)
# (311, -315.90521240234375)
# (312, -210.02308654785156)
# (313, -155.453369140625)
# (314, -122.94514465332031)
# (315, -112.40072631835938)
# (316, -143.86212158203125)
# (317, -152.18722534179688)
# (318, -130.005615234375)
# (319, -201.5044403076172)
# (320, -383.3306884765625)
# (321, -517.2307739257812)
# (322, -517.5880737304688)
# (323, -415.4578552246094)
# (324, -227.16213989257812)
# (325, -27.896697998046875)
# (326, 33.650535583496094)
# (327, -24.99191665649414)
# (328, -35.024940490722656)
# (329, 24.970735549926758)
# (330, 36.00978469848633)
# (331, -27.98285484313965)
# (332, -109.97901916503906)
# (333, -157.6514129638672)
# (334, -121.13591003417969)
# (335, -32.52130126953125)
# (336, 2.7542953491210938)
# (337, -0.780651330947876)
# (338, 33.35660934448242)
# (339, 45.31730651855469)
# (340, 1.5724334716796875)
# (341, 19.02320098876953)
# (342, 72.45707702636719)
# (343, -8.281295776367188)
# (344, -160.98175048828125)
# (345, -211.71829223632812)
# (346, -249.62014770507812)
# (347, -384.9573669433594)
# (348, -446.6896057128906)
# (349, -309.763671875)
# (350, -143.99697875976562)
# (351, -110.5201187133789)
# (352, -151.96115112304688)
# (353, -153.5152587890625)
# (354, -100.41121673583984)
# (355, -55.74494171142578)
# (356, -45.13253402709961)
# (357, -28.73717498779297)
# (358, -41.103538513183594)
# (359, -165.37765502929688)
# (360, -292.5384826660156)
# (361, -210.09237670898438)
# (362, 33.85221862792969)
# (363, 196.2642822265625)
# (364, 209.80044555664062)
# (365, 198.69554138183594)
# (366, 224.09652709960938)
# (367, 231.3795623779297)
# (368, 211.46133422851562)
# (369, 261.4588317871094)
# (370, 376.0990295410156)
# (371, 359.1436767578125)
# (372, 165.68154907226562)
# (373, 22.65569305419922)
# (374, -8.691314697265625)
# (375, -67.49958801269531)
# (376, -77.03447723388672)
# (377, 25.903900146484375)
# (378, -19.428390502929688)
# (379, -218.01889038085938)
# (380, -193.6590576171875)
# (381, -25.91809844970703)
# (382, -103.50458526611328)
# (383, -205.432861328125)
# (384, 28.94268035888672)
# (385, 264.9563903808594)
# (386, 173.7765350341797)
# (387, 73.64337158203125)
# (388, 208.88824462890625)
# (389, 371.5630798339844)
# (390, 417.66741943359375)
# (391, 396.1004333496094)
# (392, 347.8910217285156)
# (393, 328.9703063964844)
# (394, 310.2630615234375)
# (395, 151.03076171875)
# (396, -115.70649719238281)
# (397, -326.8115234375)
# (398, -460.7709655761719)
# (399, -494.8023986816406)
# (400, -351.5123291015625)
# (401, -184.06956481933594)
# (402, -225.4714813232422)
# (403, -397.3658447265625)
# (404, -479.396484375)
# (405, -422.513671875)
# (406, -295.57012939453125)
# (407, -186.06143188476562)
# (408, -156.8607177734375)
# (409, -173.3721160888672)
# (410, -157.16522216796875)
# (411, -39.44544982910156)
# (412, 219.8733367919922)
# (413, 480.802001953125)
# (414, 509.02734375)
# (415, 348.966552734375)
# (416, 209.83493041992188)
# (417, 76.47615814208984)
# (418, -121.87985229492188)
# (419, -288.29998779296875)
# (420, -384.2290954589844)
# (421, -439.6820068359375)
# (422, -416.48138427734375)
# (423, -392.1874694824219)
# (424, -469.53936767578125)
# (425, -482.54156494140625)
# (426, -336.3511047363281)
# (427, -215.3515167236328)
# (428, -82.30464172363281)
# (429, 229.78695678710938)
# (430, 451.81805419921875)
# (431, 337.157958984375)
# (432, 179.2308807373047)
# (433, 172.10882568359375)
# (434, 140.4459228515625)
# (435, 141.06265258789062)
# (436, 317.97528076171875)
# (437, 435.2688903808594)
# (438, 344.11346435546875)
# (439, 279.6079406738281)
# (440, 351.3369140625)
# (441, 457.5636901855469)
# (442, 553.601806640625)
# (443, 528.150390625)
# (444, 295.8453674316406)
# (445, 69.11087799072266)
# (446, -4.587776184082031)
# (447, -81.97454071044922)
# (448, -174.44097900390625)
# (449, -128.76589965820312)
# (450, -40.795989990234375)
# (451, -32.301246643066406)
# (452, -4.534339904785156)
# (453, 13.29702377319336)
# (454, -85.82150268554688)
# (455, -110.74140167236328)
# (456, 55.108158111572266)
# (457, 136.9010772705078)
# (458, 64.34965515136719)
# (459, 142.04696655273438)
# (460, 336.5843505859375)
# (461, 296.112060546875)
# (462, 89.40179443359375)
# (463, 56.98187255859375)
# (464, 163.61732482910156)
# (465, 215.578125)
# (466, 281.82830810546875)
# (467, 401.77825927734375)
# (468, 403.18084716796875)
# (469, 267.9454345703125)
# (470, 169.90988159179688)
# (471, 158.8167266845703)
# (472, 182.7353973388672)
# (473, 199.30178833007812)
# (474, 109.03411865234375)
# (475, -72.07805633544922)
# (476, -134.56919860839844)
# (477, -97.61800384521484)
# (478, -210.94754028320312)
# (479, -344.14691162109375)
# (480, -155.9578399658203)
# (481, 159.0285186767578)
# (482, 172.47779846191406)
# (483, -6.605865478515625)
# (484, -46.79344177246094)
# (485, 27.259811401367188)
# (486, 113.0642318725586)
# (487, 264.6786193847656)
# (488, 373.14117431640625)
# (489, 225.98028564453125)
# (490, -53.90234375)
# (491, -122.50296783447266)
# (492, 63.61440658569336)
# (493, 209.0049591064453)
# (494, 133.71859741210938)
# (495, -34.40025329589844)
# (496, -164.72027587890625)
# (497, -297.7940673828125)
# (498, -428.018798828125)
# (499, -459.90032958984375)
# (500, -411.7402648925781)
# (501, -332.11328125)
# (502, -190.4237518310547)
# (503, -95.10098266601562)
# (504, -216.89468383789062)
# (505, -379.2828369140625)
# (506, -289.0442810058594)
# (507, -53.72577667236328)
# (508, -22.9844970703125)
# (509, -188.67318725585938)
# (510, -297.11944580078125)
# (511, -92.98805236816406)

# %%
def normalize_signals(data):
    """Return normalized data, means, and stds per segment (row)."""
    mean = np.mean(data, axis=1, keepdims=True)
    std = np.std(data, axis=1, keepdims=True)
    normalized = (data - mean) / std
    return normalized, mean, std

def denormalize_signals(normalized, mean, std):
    """Reconstruct original signals from normalized form."""
    return (normalized * std) + mean

# %%
# ✅ Get denoised EEG plotting points
x_points = list(range(len(denoised_segment)))      # X-axis: time/sample index
y_points = denoised_segment.tolist()               # Y-axis: denoised EEG values

# ✅ Print the plotting points
print("Denoised EEG Plotting Points:")
for x, y in zip(x_points, y_points):
    print(f"({x}, {y})")
# Out:
# Denoised EEG Plotting Points:
# (0, 0.41595181822776794)
# (1, 0.8609888553619385)
# (2, 1.162634253501892)
# (3, 1.3677676916122437)
# (4, 0.933000922203064)
# (5, 0.5720016360282898)
# (6, 0.670853853225708)
# (7, 0.6370759606361389)
# (8, 0.1839619129896164)
# (9, 0.0035499692894518375)
# (10, 0.2064511775970459)
# (11, 0.2230602651834488)
# (12, 0.1407758742570877)
# (13, 0.2758827805519104)
# (14, 0.5037899017333984)
# (15, 0.6879937052726746)
# (16, 0.7874892950057983)
# (17, 0.6201406121253967)
# (18, 0.4805481433868408)
# (19, 0.8087640404701233)
# (20, 1.2847554683685303)
# (21, 1.392065167427063)
# (22, 1.2854446172714233)
# (23, 1.0511592626571655)
# (24, 0.7004910707473755)
# (25, 0.7552125453948975)
# (26, 1.2588530778884888)
# (27, 1.2892346382141113)
# (28, 0.7398556470870972)
# (29, 0.5196182727813721)
# (30, 0.6921223998069763)
# (31, 0.5298998355865479)
# (32, 0.269804984331131)
# (33, 0.4440503418445587)
# (34, 0.6065389513969421)
# (35, 0.27468371391296387)
# (36, 0.04807799309492111)
# (37, 0.35486701130867004)
# (38, 0.5407588481903076)
# (39, -0.039498694241046906)
# (40, -0.897767961025238)
# (41, -1.2865406274795532)
# (42, -1.1566463708877563)
# (43, -0.8751469850540161)
# (44, -0.49643146991729736)
# (45, 0.11202891170978546)
# (46, 0.8560283184051514)
# (47, 1.265013337135315)
# (48, 1.0920284986495972)
# (49, 0.7788757681846619)
# (50, 0.8088847994804382)
# (51, 0.8032205700874329)
# (52, 0.3375851809978485)
# (53, -0.17463424801826477)
# (54, -0.3353961706161499)
# (55, -0.4164881110191345)
# (56, -0.4332170784473419)
# (57, -0.25319424271583557)
# (58, -0.22000472247600555)
# (59, -0.35301950573921204)
# (60, -0.09838011860847473)
# (61, 0.2602585256099701)
# (62, 0.07863584905862808)
# (63, -0.19360584020614624)
# (64, -0.10676100850105286)
# (65, -0.28116998076438904)
# (66, -0.8247125148773193)
# (67, -1.0153932571411133)
# (68, -0.9452421069145203)
# (69, -1.1118791103363037)
# (70, -1.2261213064193726)
# (71, -1.1574504375457764)
# (72, -1.2617701292037964)
# (73, -1.3493971824645996)
# (74, -1.092644214630127)
# (75, -0.9308862090110779)
# (76, -1.1408812999725342)
# (77, -1.2478665113449097)
# (78, -0.9010680913925171)
# (79, -0.4711129069328308)
# (80, -0.48366600275039673)
# (81, -0.906155526638031)
# (82, -0.9236463904380798)
# (83, -0.23325328528881073)
# (84, 0.17454926669597626)
# (85, -0.29668059945106506)
# (86, -0.7546386122703552)
# (87, -0.740181028842926)
# (88, -0.9005455374717712)
# (89, -1.255651593208313)
# (90, -1.1593972444534302)
# (91, -0.8117632865905762)
# (92, -0.7956967353820801)
# (93, -1.0379307270050049)
# (94, -1.1344622373580933)
# (95, -0.857207179069519)
# (96, -0.29646942019462585)
# (97, 0.038423143327236176)
# (98, -0.024352848529815674)
# (99, -0.06231101229786873)
# (100, -0.05908761918544769)
# (101, -0.4033251404762268)
# (102, -0.7802988290786743)
# (103, -0.7354732155799866)
# (104, -0.5421834588050842)
# (105, -0.5066617727279663)
# (106, -0.49603980779647827)
# (107, -0.48579004406929016)
# (108, -0.3886664807796478)
# (109, -0.06874363124370575)
# (110, 0.04447184503078461)
# (111, -0.42472705245018005)
# (112, -0.964674174785614)
# (113, -1.22858464717865)
# (114, -1.4923253059387207)
# (115, -1.5851479768753052)
# (116, -1.0808725357055664)
# (117, -0.3778802454471588)
# (118, -0.08574282377958298)
# (119, -0.11453129351139069)
# (120, -0.12108336389064789)
# (121, 0.02894829772412777)
# (122, 0.29488325119018555)
# (123, 0.398147851228714)
# (124, 0.2836626172065735)
# (125, 0.243545800447464)
# (126, 0.3003940284252167)
# (127, 0.19419698417186737)
# (128, 0.13164827227592468)
# (129, 0.33633697032928467)
# (130, 0.45504245162010193)
# (131, 0.27316856384277344)
# (132, 0.056897956877946854)
# (133, -0.11852259188890457)
# (134, -0.30232399702072144)
# (135, -0.3879813849925995)
# (136, -0.5323963165283203)
# (137, -0.9954246282577515)
# (138, -1.3064556121826172)
# (139, -1.0170050859451294)
# (140, -0.543419599533081)
# (141, -0.45490768551826477)
# (142, -0.5615813136100769)
# (143, -0.4991956651210785)
# (144, -0.19033603370189667)
# (145, 0.1836412400007248)
# (146, 0.3398035764694214)
# (147, 0.23607978224754333)
# (148, 0.3476891815662384)
# (149, 0.8623002767562866)
# (150, 1.2503917217254639)
# (151, 1.1751030683517456)
# (152, 1.0246680974960327)
# (153, 0.9705275893211365)
# (154, 0.7300658226013184)
# (155, 0.24906401336193085)
# (156, -0.15185891091823578)
# (157, -0.3710300028324127)
# (158, -0.5774542689323425)
# (159, -0.8681132197380066)
# (160, -0.989745557308197)
# (161, -0.5324737429618835)
# (162, 0.302203506231308)
# (163, 0.5860576033592224)
# (164, 0.1917504221200943)
# (165, 0.14210458099842072)
# (166, 0.6492857933044434)
# (167, 0.7235485315322876)
# (168, 0.42258137464523315)
# (169, 0.7862511277198792)
# (170, 1.5940477848052979)
# (171, 1.7412704229354858)
# (172, 1.3679744005203247)
# (173, 1.1889302730560303)
# (174, 1.1018320322036743)
# (175, 0.8585724830627441)
# (176, 0.7558919191360474)
# (177, 0.7688893675804138)
# (178, 0.5094084143638611)
# (179, -0.10505052655935287)
# (180, -0.726813793182373)
# (181, -1.071912407875061)
# (182, -1.207061529159546)
# (183, -1.5438827276229858)
# (184, -2.008056879043579)
# (185, -1.998740315437317)
# (186, -1.486521601676941)
# (187, -1.0408753156661987)
# (188, -0.6202977895736694)
# (189, 0.058356933295726776)
# (190, 0.6501479148864746)
# (191, 0.9485548138618469)
# (192, 1.4192869663238525)
# (193, 2.1659634113311768)
# (194, 2.78948974609375)
# (195, 3.101893901824951)
# (196, 3.076347589492798)
# (197, 2.6323888301849365)
# (198, 2.0483593940734863)
# (199, 1.6001132726669312)
# (200, 1.1640855073928833)
# (201, 0.6118614077568054)
# (202, 0.11446963250637054)
# (203, -0.20133425295352936)
# (204, -0.37791138887405396)
# (205, -0.6026085615158081)
# (206, -0.8890880942344666)
# (207, -0.9664900898933411)
# (208, -0.853799045085907)
# (209, -1.0830724239349365)
# (210, -1.4216221570968628)
# (211, -0.9673908352851868)
# (212, -0.0810825303196907)
# (213, -0.020186936482787132)
# (214, -0.4888323247432709)
# (215, -0.2853372097015381)
# (216, 0.32830294966697693)
# (217, 0.4673226773738861)
# (218, 0.6239335536956787)
# (219, 1.4107240438461304)
# (220, 2.160231590270996)
# (221, 2.238333225250244)
# (222, 2.1413326263427734)
# (223, 2.2718727588653564)
# (224, 2.2408335208892822)
# (225, 1.7976601123809814)
# (226, 1.2531447410583496)
# (227, 0.7580083608627319)
# (228, 0.2537108063697815)
# (229, -0.08661025762557983)
# (230, -0.08603756874799728)
# (231, 0.01400319579988718)
# (232, 0.0027428471948951483)
# (233, -0.12110661715269089)
# (234, -0.366606205701828)
# (235, -0.6297978758811951)
# (236, -0.6037070751190186)
# (237, -0.4930185079574585)
# (238, -0.6775400638580322)
# (239, -0.9010074138641357)
# (240, -0.7824928164482117)
# (241, -0.5741944313049316)
# (242, -0.330430269241333)
# (243, 0.23926086723804474)
# (244, 0.8373528718948364)
# (245, 0.9075652956962585)
# (246, 0.6623629927635193)
# (247, 0.5473986864089966)
# (248, 0.564397931098938)
# (249, 0.5522065162658691)
# (250, 0.5752583742141724)
# (251, 0.8285722732543945)
# (252, 1.2295818328857422)
# (253, 1.0105711221694946)
# (254, -0.052307721227407455)
# (255, -0.758630633354187)
# (256, -0.4809091091156006)
# (257, -0.34497782588005066)
# (258, -0.7393587827682495)
# (259, -0.7702275514602661)
# (260, -0.5991863012313843)
# (261, -1.0044543743133545)
# (262, -1.4710252285003662)
# (263, -1.6715898513793945)
# (264, -2.1467955112457275)
# (265, -2.4163990020751953)
# (266, -1.7956684827804565)
# (267, -1.2496778964996338)
# (268, -1.2488155364990234)
# (269, -0.6955344676971436)
# (270, 0.3355269134044647)
# (271, 0.533446192741394)
# (272, 0.15598011016845703)
# (273, 0.16636566817760468)
# (274, 0.22151190042495728)
# (275, -0.08147943764925003)
# (276, -0.1503208577632904)
# (277, 0.24902527034282684)
# (278, 0.5830050706863403)
# (279, 0.4255558252334595)
# (280, -0.09804684668779373)
# (281, -0.45539847016334534)
# (282, -0.40681180357933044)
# (283, -0.4396270513534546)
# (284, -0.6675055027008057)
# (285, -0.5674999952316284)
# (286, -0.24347428977489471)
# (287, -0.317070335149765)
# (288, -0.6443076729774475)
# (289, -0.9158117175102234)
# (290, -1.3223148584365845)
# (291, -1.7092541456222534)
# (292, -1.548296570777893)
# (293, -0.9773604869842529)
# (294, -0.45980602502822876)
# (295, -0.20934316515922546)
# (296, -0.2819831073284149)
# (297, -0.5393251180648804)
# (298, -0.7270534038543701)
# (299, -0.8734854459762573)
# (300, -0.8354705572128296)
# (301, -0.4589575231075287)
# (302, -0.1513894498348236)
# (303, -0.12117744982242584)
# (304, 0.20699867606163025)
# (305, 0.736465573310852)
# (306, 0.7829102277755737)
# (307, 0.8070783019065857)
# (308, 1.4093763828277588)
# (309, 1.673608660697937)
# (310, 1.037824034690857)
# (311, 0.4549579620361328)
# (312, 0.27368780970573425)
# (313, -0.17324578762054443)
# (314, -0.764250636100769)
# (315, -1.005996584892273)
# (316, -0.974833071231842)
# (317, -0.7546724081039429)
# (318, -0.35298532247543335)
# (319, -0.1223529502749443)
# (320, 0.015653982758522034)
# (321, 0.32143598794937134)
# (322, 0.36286941170692444)
# (323, -0.10559990257024765)
# (324, -0.45035743713378906)
# (325, -0.57253497838974)
# (326, -0.9907737374305725)
# (327, -1.4555469751358032)
# (328, -1.412488341331482)
# (329, -1.1819262504577637)
# (330, -0.9406735301017761)
# (331, -0.3101752996444702)
# (332, 0.5270051956176758)
# (333, 0.9801778793334961)
# (334, 1.3044555187225342)
# (335, 1.8452205657958984)
# (336, 2.0044302940368652)
# (337, 1.3083401918411255)
# (338, 0.381551057100296)
# (339, -0.2463112771511078)
# (340, -0.775187075138092)
# (341, -1.1403132677078247)
# (342, -0.9046363234519958)
# (343, -0.37749388813972473)
# (344, -0.13808484375476837)
# (345, -0.07645900547504425)
# (346, 0.0537056140601635)
# (347, 0.08841121941804886)
# (348, 0.17990218102931976)
# (349, 0.4922681450843811)
# (350, 0.533158004283905)
# (351, 0.14177381992340088)
# (352, 0.06510274112224579)
# (353, 0.48583540320396423)
# (354, 0.8847326636314392)
# (355, 1.2437702417373657)
# (356, 1.7182191610336304)
# (357, 1.9696030616760254)
# (358, 2.0574686527252197)
# (359, 2.234170913696289)
# (360, 2.044961452484131)
# (361, 1.1677931547164917)
# (362, 0.24460820853710175)
# (363, -0.45004802942276)
# (364, -1.2631274461746216)
# (365, -1.98900306224823)
# (366, -2.1221046447753906)
# (367, -1.9127788543701172)
# (368, -1.8276112079620361)
# (369, -1.818101406097412)
# (370, -1.6047208309173584)
# (371, -1.2539838552474976)
# (372, -1.1264628171920776)
# (373, -1.2186505794525146)
# (374, -0.9790968894958496)
# (375, -0.4585026502609253)
# (376, -0.3420163094997406)
# (377, -0.40839841961860657)
# (378, 0.1390170454978943)
# (379, 0.8223967552185059)
# (380, 1.0155788660049438)
# (381, 1.2850102186203003)
# (382, 1.7012373208999634)
# (383, 1.4097563028335571)
# (384, 0.769024133682251)
# (385, 0.5989530682563782)
# (386, 0.2768014371395111)
# (387, -0.543872058391571)
# (388, -0.7986518740653992)
# (389, -0.4972492754459381)
# (390, -0.7782697677612305)
# (391, -1.4122973680496216)
# (392, -1.4896231889724731)
# (393, -1.334634780883789)
# (394, -1.3223875761032104)
# (395, -1.1417181491851807)
# (396, -0.9553824663162231)
# (397, -1.1009382009506226)
# (398, -1.1064505577087402)
# (399, -0.7680109143257141)
# (400, -0.6278294920921326)
# (401, -0.771600604057312)
# (402, -0.7530974745750427)
# (403, -0.5937381982803345)
# (404, -0.5163934230804443)
# (405, -0.5423598289489746)
# (406, -0.6484858989715576)
# (407, -0.6941747665405273)
# (408, -0.455006867647171)
# (409, -0.3695712387561798)
# (410, -1.018758773803711)
# (411, -1.9487156867980957)
# (412, -2.2084150314331055)
# (413, -1.820214867591858)
# (414, -1.231494665145874)
# (415, -0.3283810317516327)
# (416, 0.788947582244873)
# (417, 1.3956066370010376)
# (418, 1.5318514108657837)
# (419, 2.0025315284729004)
# (420, 2.602510690689087)
# (421, 2.4450016021728516)
# (422, 1.914246916770935)
# (423, 1.930076241493225)
# (424, 2.0904533863067627)
# (425, 1.5253078937530518)
# (426, 0.6942095756530762)
# (427, 0.4127517640590668)
# (428, 0.52884441614151)
# (429, 0.47283270955085754)
# (430, 0.31331339478492737)
# (431, 0.38156262040138245)
# (432, 0.4974549114704132)
# (433, 0.024978501722216606)
# (434, -1.0189615488052368)
# (435, -1.6597880125045776)
# (436, -1.4000244140625)
# (437, -1.1524176597595215)
# (438, -1.449637770652771)
# (439, -1.3326973915100098)
# (440, -0.2188597172498703)
# (441, 0.7026209831237793)
# (442, 0.4847698211669922)
# (443, 0.08255045861005783)
# (444, 0.6031063795089722)
# (445, 1.41359543800354)
# (446, 1.6221020221710205)
# (447, 1.7648507356643677)
# (448, 2.3785383701324463)
# (449, 2.5943379402160645)
# (450, 1.975532054901123)
# (451, 1.450101613998413)
# (452, 1.2785300016403198)
# (453, 0.5921421647071838)
# (454, -0.28920334577560425)
# (455, -0.31903305649757385)
# (456, -0.014339516870677471)
# (457, -0.38300827145576477)
# (458, -0.8096656203269958)
# (459, -0.6236010789871216)
# (460, -0.5305694341659546)
# (461, -0.8871195316314697)
# (462, -0.8366801142692566)
# (463, -0.17361868917942047)
# (464, 0.1268235594034195)
# (465, -0.41113319993019104)
# (466, -1.162452220916748)
# (467, -1.5092613697052002)
# (468, -1.5503407716751099)
# (469, -1.6314053535461426)
# (470, -1.7122583389282227)
# (471, -1.5886359214782715)
# (472, -1.3263163566589355)
# (473, -1.1380000114440918)
# (474, -0.9281978607177734)
# (475, -0.5791725516319275)
# (476, -0.18856218457221985)
# (477, 0.032672908157110214)
# (478, 0.020515209063887596)
# (479, -0.19526590406894684)
# (480, -0.4730357229709625)
# (481, -0.6523192524909973)
# (482, -0.523178219795227)
# (483, -0.06232079863548279)
# (484, 0.41935670375823975)
# (485, 0.627996563911438)
# (486, 0.7082802057266235)
# (487, 0.8371587991714478)
# (488, 0.9384173154830933)
# (489, 1.0123851299285889)
# (490, 1.054669737815857)
# (491, 0.9182507395744324)
# (492, 0.7704620361328125)
# (493, 0.6805179119110107)
# (494, 0.19771750271320343)
# (495, -0.48509225249290466)
# (496, -0.2642717659473419)
# (497, 0.556657075881958)
# (498, 0.5723252296447754)
# (499, 0.16664080321788788)
# (500, 0.6709763407707214)
# (501, 1.3998414278030396)
# (502, 1.2812519073486328)
# (503, 1.079103708267212)
# (504, 1.3348106145858765)
# (505, 1.248692274093628)
# (506, 0.8270255923271179)
# (507, 0.8037973642349243)
# (508, 0.6349722146987915)
# (509, 0.26933449506759644)
# (510, 0.44433334469795227)
# (511, 1.4757609367370605)

# %%
# ✅ Get denoised EEG plotting points
x_points = list(range(len(contaminated_segment)))      # X-axis: time/sample index
y_points = denoised_segment.tolist()               # Y-axis: denoised EEG values

# ✅ Print the plotting points
print("Contaminatedf EEG Plotting Points:")
for x, y in zip(x_points, y_points):
    print(f"({x}, {y})")
# Out:
# Contaminatedf EEG Plotting Points:
# (0, 1.1689929962158203)
# (1, 1.9662199020385742)
# (2, 2.6759817600250244)
# (3, 3.734178066253662)
# (4, 2.183748483657837)
# (5, 0.704386830329895)
# (6, 1.7596099376678467)
# (7, 2.8765628337860107)
# (8, 1.7972841262817383)
# (9, 1.09077787399292)
# (10, 1.8402924537658691)
# (11, 1.807940125465393)
# (12, 0.9264942407608032)
# (13, 0.7254466414451599)
# (14, 1.3334693908691406)
# (15, 2.1910154819488525)
# (16, 2.5615148544311523)
# (17, 1.849653720855713)
# (18, 1.4280775785446167)
# (19, 2.644353151321411)
# (20, 4.099677562713623)
# (21, 4.300961017608643)
# (22, 3.8564112186431885)
# (23, 2.764322280883789)
# (24, 1.3831065893173218)
# (25, 1.713373064994812)
# (26, 3.351916790008545)
# (27, 3.1821608543395996)
# (28, 1.4570151567459106)
# (29, 1.0878089666366577)
# (30, 1.6937713623046875)
# (31, 1.1402806043624878)
# (32, 0.32812196016311646)
# (33, 0.5848128795623779)
# (34, 0.7577276229858398)
# (35, 0.02378445863723755)
# (36, -0.21873992681503296)
# (37, 0.8165966272354126)
# (38, 1.7307945489883423)
# (39, 1.0047578811645508)
# (40, -0.9240384101867676)
# (41, -2.451378345489502)
# (42, -2.444962978363037)
# (43, -1.3722611665725708)
# (44, -0.241237074136734)
# (45, 0.7794095277786255)
# (46, 2.2174336910247803)
# (47, 3.163597583770752)
# (48, 2.2600650787353516)
# (49, 0.801592230796814)
# (50, 1.1484053134918213)
# (51, 2.0664255619049072)
# (52, 1.3048653602600098)
# (53, 0.07690295577049255)
# (54, -0.0730411484837532)
# (55, -0.3938208222389221)
# (56, -0.7594718337059021)
# (57, 0.02623581886291504)
# (58, 0.4066525995731354)
# (59, -0.6549171805381775)
# (60, -0.5744093656539917)
# (61, 0.8799850344657898)
# (62, 0.9554849863052368)
# (63, 0.25143954157829285)
# (64, 0.7957196235656738)
# (65, 0.6863305568695068)
# (66, -1.2227554321289062)
# (67, -2.347470760345459)
# (68, -2.0456454753875732)
# (69, -2.137417793273926)
# (70, -2.327360153198242)
# (71, -2.255904197692871)
# (72, -2.8591055870056152)
# (73, -3.1267926692962646)
# (74, -1.706275463104248)
# (75, -0.726050615310669)
# (76, -1.887196660041809)
# (77, -3.2615487575531006)
# (78, -3.072436809539795)
# (79, -2.5086007118225098)
# (80, -3.2366092205047607)
# (81, -5.030017375946045)
# (82, -5.554333209991455)
# (83, -3.725311040878296)
# (84, -2.116164445877075)
# (85, -2.930680274963379)
# (86, -4.0574727058410645)
# (87, -3.82844877243042)
# (88, -3.4940390586853027)
# (89, -3.0567023754119873)
# (90, -1.34104585647583)
# (91, 0.07742726802825928)
# (92, -0.4909583330154419)
# (93, -1.897495985031128)
# (94, -2.908825635910034)
# (95, -3.2974672317504883)
# (96, -2.5882034301757812)
# (97, -1.9177676439285278)
# (98, -2.6296584606170654)
# (99, -3.06166410446167)
# (100, -1.9025979042053223)
# (101, -1.3473918437957764)
# (102, -1.957374095916748)
# (103, -1.3912622928619385)
# (104, 0.19436752796173096)
# (105, 0.3718793988227844)
# (106, -0.6364747881889343)
# (107, -1.2357094287872314)
# (108, -1.149381160736084)
# (109, -0.6229302883148193)
# (110, -0.2736978530883789)
# (111, -0.9863044619560242)
# (112, -1.8732744455337524)
# (113, -1.8429255485534668)
# (114, -1.9019793272018433)
# (115, -2.473052978515625)
# (116, -1.8327797651290894)
# (117, -0.09970712661743164)
# (118, 0.5692740678787231)
# (119, -0.3021659255027771)
# (120, -1.37654709815979)
# (121, -1.9714977741241455)
# (122, -1.7239391803741455)
# (123, -0.9168153405189514)
# (124, -0.47060900926589966)
# (125, -0.5520305633544922)
# (126, -0.7111880779266357)
# (127, -1.288642406463623)
# (128, -1.9725356101989746)
# (129, -1.6813523769378662)
# (130, -1.0382241010665894)
# (131, -1.5041042566299438)
# (132, -2.354386329650879)
# (133, -2.2152929306030273)
# (134, -1.396458625793457)
# (135, -0.7215161323547363)
# (136, -0.7018135786056519)
# (137, -1.813915491104126)
# (138, -2.980302333831787)
# (139, -2.6005971431732178)
# (140, -1.5519412755966187)
# (141, -1.5605685710906982)
# (142, -1.7911155223846436)
# (143, -1.062831997871399)
# (144, 0.03509974479675293)
# (145, 0.8268547058105469)
# (146, 1.1251585483551025)
# (147, 0.5211737155914307)
# (148, 0.019947409629821777)
# (149, 0.9382014870643616)
# (150, 2.035355567932129)
# (151, 1.6717513799667358)
# (152, 1.1924545764923096)
# (153, 1.4881924390792847)
# (154, 1.1725497245788574)
# (155, 0.1499309241771698)
# (156, 0.061234116554260254)
# (157, 0.48662352561950684)
# (158, -0.042816683650016785)
# (159, -1.2572121620178223)
# (160, -1.650256633758545)
# (161, -0.22310155630111694)
# (162, 2.0458757877349854)
# (163, 2.086601734161377)
# (164, -0.2534743547439575)
# (165, -0.8423227667808533)
# (166, 1.254729986190796)
# (167, 1.6481809616088867)
# (168, 0.05624687671661377)
# (169, 0.8342996835708618)
# (170, 3.530900001525879)
# (171, 4.0219316482543945)
# (172, 2.7944118976593018)
# (173, 2.4030954837799072)
# (174, 2.179821014404297)
# (175, 1.472500205039978)
# (176, 1.6545724868774414)
# (177, 2.5142102241516113)
# (178, 2.576026678085327)
# (179, 1.5761966705322266)
# (180, 0.2560317814350128)
# (181, -0.6182841062545776)
# (182, -0.681244969367981)
# (183, -1.0726014375686646)
# (184, -2.2861521244049072)
# (185, -2.5743274688720703)
# (186, -1.1486448049545288)
# (187, 0.4201531410217285)
# (188, 1.4937645196914673)
# (189, 2.385110378265381)
# (190, 2.5763192176818848)
# (191, 2.1450541019439697)
# (192, 2.3519153594970703)
# (193, 2.894458055496216)
# (194, 3.020587682723999)
# (195, 3.260526657104492)
# (196, 3.5596766471862793)
# (197, 2.7462563514709473)
# (198, 1.3206005096435547)
# (199, 0.7372130155563354)
# (200, 0.9369589686393738)
# (201, 1.0584481954574585)
# (202, 0.9364405870437622)
# (203, 0.7267850637435913)
# (204, 0.5520128607749939)
# (205, 0.0651683509349823)
# (206, -0.7057772278785706)
# (207, -0.7266697287559509)
# (208, -0.1733226180076599)
# (209, -1.2630805969238281)
# (210, -3.1515653133392334)
# (211, -2.1267104148864746)
# (212, 0.7554434537887573)
# (213, 0.6041799783706665)
# (214, -1.7827035188674927)
# (215, -1.822637677192688)
# (216, -0.11045520007610321)
# (217, 0.15780791640281677)
# (218, 0.4890328645706177)
# (219, 2.883826732635498)
# (220, 4.856614589691162)
# (221, 4.289071559906006)
# (222, 3.3725006580352783)
# (223, 3.90874981880188)
# (224, 4.638134956359863)
# (225, 4.159248352050781)
# (226, 2.8471946716308594)
# (227, 1.3475468158721924)
# (228, 0.2760932445526123)
# (229, 0.12691617012023926)
# (230, 0.551479160785675)
# (231, 0.8658511638641357)
# (232, 1.2355692386627197)
# (233, 1.296959638595581)
# (234, 0.27590516209602356)
# (235, -0.5635384917259216)
# (236, 0.4717212915420532)
# (237, 1.4823803901672363)
# (238, 0.5313016772270203)
# (239, -0.3842424154281616)
# (240, 0.2967061996459961)
# (241, 0.8216903209686279)
# (242, 1.0196776390075684)
# (243, 2.5319719314575195)
# (244, 3.806785821914673)
# (245, 2.3880419731140137)
# (246, 0.025032877922058105)
# (247, -0.6973084211349487)
# (248, -0.13914763927459717)
# (249, 0.20353293418884277)
# (250, 0.39861834049224854)
# (251, 1.5999244451522827)
# (252, 3.5812110900878906)
# (253, 3.1322901248931885)
# (254, -0.7693953514099121)
# (255, -3.343607187271118)
# (256, -1.8521006107330322)
# (257, -0.8650274276733398)
# (258, -2.3438665866851807)
# (259, -2.268813133239746)
# (260, -0.4307140111923218)
# (261, -0.6811065673828125)
# (262, -2.199734687805176)
# (263, -2.716207265853882)
# (264, -3.273125648498535)
# (265, -3.59547758102417)
# (266, -2.3356051445007324)
# (267, -1.6912779808044434)
# (268, -2.2612884044647217)
# (269, -0.8742626905441284)
# (270, 1.717678189277649)
# (271, 1.4394681453704834)
# (272, -0.7682279944419861)
# (273, -1.834784746170044)
# (274, -2.2407450675964355)
# (275, -2.872835874557495)
# (276, -2.810332775115967)
# (277, -2.0855863094329834)
# (278, -1.1117621660232544)
# (279, -0.21427738666534424)
# (280, -0.48218297958374023)
# (281, -1.603171706199646)
# (282, -1.695307970046997)
# (283, -1.5329039096832275)
# (284, -2.3824729919433594)
# (285, -2.3004977703094482)
# (286, -0.40763068199157715)
# (287, 0.35243701934814453)
# (288, -1.0155938863754272)
# (289, -2.522139310836792)
# (290, -3.4839324951171875)
# (291, -4.051690101623535)
# (292, -3.192190647125244)
# (293, -0.985815703868866)
# (294, 0.8067821264266968)
# (295, 1.0192747116088867)
# (296, -0.05034279823303223)
# (297, -1.3370914459228516)
# (298, -2.003690719604492)
# (299, -2.324517011642456)
# (300, -2.213813304901123)
# (301, -1.2028264999389648)
# (302, -0.2675095796585083)
# (303, -0.1486344039440155)
# (304, 0.8527495861053467)
# (305, 2.7961137294769287)
# (306, 3.067732810974121)
# (307, 1.9828675985336304)
# (308, 2.3185665607452393)
# (309, 3.0780372619628906)
# (310, 1.9807190895080566)
# (311, 0.6486712694168091)
# (312, 0.821276843547821)
# (313, 0.9076548218727112)
# (314, 0.056022271513938904)
# (315, -0.3477405905723572)
# (316, 0.2897750437259674)
# (317, 1.1686211824417114)
# (318, 1.5620583295822144)
# (319, 1.2550132274627686)
# (320, 0.9653414487838745)
# (321, 0.9306262731552124)
# (322, 0.033934637904167175)
# (323, -1.6571041345596313)
# (324, -2.0548810958862305)
# (325, -1.3674659729003906)
# (326, -1.7124638557434082)
# (327, -2.4639010429382324)
# (328, -1.691443920135498)
# (329, -0.855035126209259)
# (330, -1.465463638305664)
# (331, -1.7468018531799316)
# (332, -0.7402517795562744)
# (333, -0.257386714220047)
# (334, -0.22880947589874268)
# (335, 0.8984782695770264)
# (336, 1.625673770904541)
# (337, -0.0621069073677063)
# (338, -2.2394633293151855)
# (339, -2.9565892219543457)
# (340, -3.19114351272583)
# (341, -3.036015510559082)
# (342, -1.3521661758422852)
# (343, 0.05985105037689209)
# (344, -0.4592440724372864)
# (345, -1.0444914102554321)
# (346, -0.7113451361656189)
# (347, -0.9583377242088318)
# (348, -0.8827585577964783)
# (349, 0.7377201318740845)
# (350, 1.4373583793640137)
# (351, 0.1319398134946823)
# (352, -0.11130401492118835)
# (353, 1.1777814626693726)
# (354, 1.6552529335021973)
# (355, 1.785071611404419)
# (356, 2.7351932525634766)
# (357, 2.943918466567993)
# (358, 2.442721366882324)
# (359, 2.8773036003112793)
# (360, 3.1404502391815186)
# (361, 1.6943318843841553)
# (362, 0.08207276463508606)
# (363, -0.8269179463386536)
# (364, -1.9740405082702637)
# (365, -2.7961459159851074)
# (366, -2.206973075866699)
# (367, -1.3777614831924438)
# (368, -1.4155137538909912)
# (369, -1.6900157928466797)
# (370, -1.4507567882537842)
# (371, -1.2679474353790283)
# (372, -1.9031479358673096)
# (373, -2.649041175842285)
# (374, -1.8752827644348145)
# (375, -0.5344234704971313)
# (376, -0.9799997806549072)
# (377, -2.100935459136963)
# (378, -1.1457293033599854)
# (379, 0.5411476492881775)
# (380, 0.9001201391220093)
# (381, 1.1406311988830566)
# (382, 1.4942471981048584)
# (383, 0.33260250091552734)
# (384, -1.1750946044921875)
# (385, -1.5373880863189697)
# (386, -2.4631829261779785)
# (387, -4.091075897216797)
# (388, -3.542707681655884)
# (389, -1.3696664571762085)
# (390, -0.8396437168121338)
# (391, -1.9876179695129395)
# (392, -2.7588067054748535)
# (393, -2.6460835933685303)
# (394, -1.8266041278839111)
# (395, -1.0317814350128174)
# (396, -1.5096322298049927)
# (397, -2.829338788986206)
# (398, -3.2397501468658447)
# (399, -2.753873825073242)
# (400, -2.3026235103607178)
# (401, -2.456345558166504)
# (402, -3.3653392791748047)
# (403, -4.129745006561279)
# (404, -3.395935535430908)
# (405, -2.2094056606292725)
# (406, -2.388401985168457)
# (407, -2.7325940132141113)
# (408, -1.459334135055542)
# (409, -0.5457606315612793)
# (410, -2.2750353813171387)
# (411, -4.949667453765869)
# (412, -5.915886402130127)
# (413, -5.491588592529297)
# (414, -4.547628879547119)
# (415, -2.435849189758301)
# (416, 0.3467879295349121)
# (417, 1.4117488861083984)
# (418, 0.908735990524292)
# (419, 1.3882008790969849)
# (420, 2.610154151916504)
# (421, 2.2839488983154297)
# (422, 1.6139545440673828)
# (423, 2.853304862976074)
# (424, 4.327203750610352)
# (425, 3.6493284702301025)
# (426, 2.2219114303588867)
# (427, 1.7345407009124756)
# (428, 1.8003592491149902)
# (429, 1.865997552871704)
# (430, 2.223616600036621)
# (431, 2.984388828277588)
# (432, 3.899385929107666)
# (433, 3.530174732208252)
# (434, 1.3812406063079834)
# (435, 0.5126745700836182)
# (436, 2.861598253250122)
# (437, 4.540242671966553)
# (438, 3.0429635047912598)
# (439, 2.5739612579345703)
# (440, 5.609423637390137)
# (441, 7.340017318725586)
# (442, 4.645960330963135)
# (443, 1.6437506675720215)
# (444, 2.068899631500244)
# (445, 3.6323580741882324)
# (446, 3.7952919006347656)
# (447, 4.291484832763672)
# (448, 6.520483493804932)
# (449, 7.616877555847168)
# (450, 5.765531063079834)
# (451, 3.681889533996582)
# (452, 2.7280991077423096)
# (453, 0.3106549382209778)
# (454, -2.872633695602417)
# (455, -3.136828899383545)
# (456, -1.743492841720581)
# (457, -2.5296850204467773)
# (458, -3.836836576461792)
# (459, -2.9321577548980713)
# (460, -2.419219970703125)
# (461, -3.979684829711914)
# (462, -3.9537930488586426)
# (463, -1.273771047592163)
# (464, -0.41011786460876465)
# (465, -3.278144359588623)
# (466, -6.173511505126953)
# (467, -6.752681732177734)
# (468, -6.665661334991455)
# (469, -7.14265251159668)
# (470, -6.797029972076416)
# (471, -5.304078578948975)
# (472, -4.132607460021973)
# (473, -3.7167344093322754)
# (474, -3.026094436645508)
# (475, -2.1475889682769775)
# (476, -1.5352826118469238)
# (477, -0.8061825037002563)
# (478, -0.18334317207336426)
# (479, -0.8116178512573242)
# (480, -2.441622734069824)
# (481, -3.4238784313201904)
# (482, -2.3441426753997803)
# (483, 0.4668619632720947)
# (484, 2.7718048095703125)
# (485, 2.789759874343872)
# (486, 2.181264877319336)
# (487, 3.038489818572998)
# (488, 4.336220741271973)
# (489, 4.6168107986450195)
# (490, 4.491250991821289)
# (491, 4.233410358428955)
# (492, 3.9191346168518066)
# (493, 3.90083646774292)
# (494, 3.065807342529297)
# (495, 1.252231478691101)
# (496, 1.7081645727157593)
# (497, 4.276418209075928)
# (498, 4.297608375549316)
# (499, 2.615041732788086)
# (500, 4.193309307098389)
# (501, 6.615114212036133)
# (502, 5.49088716506958)
# (503, 4.1537699699401855)
# (504, 5.211051940917969)
# (505, 4.881438255310059)
# (506, 2.7430806159973145)
# (507, 2.3178844451904297)
# (508, 1.818969964981079)
# (509, 0.530968189239502)
# (510, 1.3547065258026123)
# (511, 5.164180278778076)
